# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'IID'
ALPHA = 1000000
NUM_PEERS = 10 # "number of peers: K" 
FRAC_PEERS = 1 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 100 #"number of rounds of federated model training"
LOCAL_EPOCHS = 1 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.001#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
print(DEVICE)
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1
# Out:
# cuda

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: fedavg
# Attack Type: label_flipping
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/200 [00:00<?, ?it/s]
#  | Global training round : 1/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 2.298370
#
# Average test loss: 2.2799, Test accuracy: 1549/10000 (15.49%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 2.1
# Two        - 55.4
# Three      - 6.0
# Four       - 0.0
# Five       - 0.2
# Six        - 0.0
# Seven      - 12.2
# Eight      - 26.3
# Nine       - 48.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 2.278892
#
# Average test loss: 2.2585, Test accuracy: 2988/10000 (29.88%)
#
# Class      - Accuracy
# Zero       - 1.3
# One        - 44.0
# Two        - 68.7
# Three      - 37.0
# Four       - 0.0
# Five       - 0.1
# Six        - 0.0
# Seven      - 51.3
# Eight      - 30.2
# Nine       - 62.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 2.258362
#
# Average test loss: 2.2282, Test accuracy: 4217/10000 (42.17%)
#
# Class      - Accuracy
# Zero       - 31.8
# One        - 77.0
# Two        - 67.9
# Three      - 51.0
# Four       - 7.3
# Five       - 1.2
# Six        - 5.8
# Seven      - 73.9
# Eight      - 52.6
# Nine       - 63.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/200 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 2.224507
#
# Average test loss: 2.1732, Test accuracy: 5489/10000 (54.89%)
#
# Class      - Accuracy
# Zero       - 75.0
# One        - 84.6
# Two        - 60.0
# Three      - 61.5
# Four       - 21.5
# Five       - 2.3
# Six        - 32.9
# Seven      - 83.7
# Eight      - 66.7
# Nine       - 62.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 2.170931
#
# Average test loss: 2.0714, Test accuracy: 6134/10000 (61.34%)
#
# Class      - Accuracy
# Zero       - 95.0
# One        - 94.3
# Two        - 46.7
# Three      - 71.5
# Four       - 45.2
# Five       - 2.2
# Six        - 62.7
# Seven      - 87.6
# Eight      - 68.6
# Nine       - 41.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 2.074200
#
# Average test loss: 1.8979, Test accuracy: 6555/10000 (65.55%)
#
# Class      - Accuracy
# Zero       - 95.7
# One        - 96.5
# Two        - 46.3
# Three      - 79.1
# Four       - 64.1
# Five       - 5.0
# Six        - 72.8
# Seven      - 89.0
# Eight      - 63.3
# Nine       - 40.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 1.917776
#
# Average test loss: 1.6296, Test accuracy: 6939/10000 (69.39%)
#
# Class      - Accuracy
# Zero       - 94.7
# One        - 97.3
# Two        - 59.5
# Three      - 79.3
# Four       - 73.8
# Five       - 17.8
# Six        - 78.0
# Seven      - 90.6
# Eight      - 66.1
# Nine       - 44.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 1.732054
#
# Average test loss: 1.3402, Test accuracy: 7518/10000 (75.18%)
#
# Class      - Accuracy
# Zero       - 95.8
# One        - 96.8
# Two        - 71.7
# Three      - 83.6
# Four       - 79.6
# Five       - 40.9
# Six        - 80.8
# Seven      - 88.8
# Eight      - 53.9
# Nine       - 54.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 1.525050
#
# Average test loss: 1.0743, Test accuracy: 7879/10000 (78.79%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 96.6
# Two        - 77.2
# Three      - 80.6
# Four       - 82.9
# Five       - 50.9
# Six        - 84.2
# Seven      - 88.0
# Eight      - 62.9
# Nine       - 61.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 1.350411
#
# Average test loss: 0.8768, Test accuracy: 8195/10000 (81.95%)
#
# Class      - Accuracy
# Zero       - 95.6
# One        - 95.3
# Two        - 83.0
# Three      - 86.3
# Four       - 85.0
# Five       - 64.0
# Six        - 86.0
# Seven      - 85.7
# Eight      - 67.2
# Nine       - 68.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Average of peers' local losses: 1.220951
#
# Average test loss: 0.7322, Test accuracy: 8401/10000 (84.01%)
#
# Class      - Accuracy
# Zero       - 96.4
# One        - 94.0
# Two        - 87.7
# Three      - 87.0
# Four       - 87.5
# Five       - 68.1
# Six        - 86.2
# Seven      - 88.6
# Eight      - 73.7
# Nine       - 70.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 1.117662
#
# Average test loss: 0.6478, Test accuracy: 8527/10000 (85.27%)
#
# Class      - Accuracy
# Zero       - 97.2
# One        - 95.2
# Two        - 86.2
# Three      - 89.3
# Four       - 87.4
# Five       - 74.5
# Six        - 86.3
# Seven      - 88.2
# Eight      - 69.3
# Nine       - 78.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 1.030961
#
# Average test loss: 0.5818, Test accuracy: 8580/10000 (85.80%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 95.7
# Two        - 88.6
# Three      - 89.4
# Four       - 89.2
# Five       - 77.6
# Six        - 88.9
# Seven      - 90.7
# Eight      - 77.2
# Nine       - 80.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/200 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Average of peers' local losses: 0.955848
#
# Average test loss: 0.5222, Test accuracy: 8708/10000 (87.08%)
#
# Class      - Accuracy
# Zero       - 97.3
# One        - 96.0
# Two        - 88.5
# Three      - 88.2
# Four       - 90.6
# Five       - 81.5
# Six        - 89.5
# Seven      - 86.0
# Eight      - 75.6
# Nine       - 76.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.913123
#
# Average test loss: 0.4882, Test accuracy: 8745/10000 (87.45%)
#
# Class      - Accuracy
# Zero       - 97.3
# One        - 95.2
# Two        - 87.7
# Three      - 89.9
# Four       - 88.7
# Five       - 80.5
# Six        - 91.7
# Seven      - 87.4
# Eight      - 77.2
# Nine       - 79.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.879537
#
# Average test loss: 0.4495, Test accuracy: 8893/10000 (88.93%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 96.3
# Two        - 88.7
# Three      - 88.9
# Four       - 90.5
# Five       - 82.6
# Six        - 91.3
# Seven      - 88.5
# Eight      - 78.4
# Nine       - 83.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/200 |
#
#
# Selected Peers:
# Peer 2  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.834951
#
# Average test loss: 0.4304, Test accuracy: 8915/10000 (89.15%)
#
# Class      - Accuracy
# Zero       - 97.0
# One        - 97.5
# Two        - 88.0
# Three      - 89.5
# Four       - 92.2
# Five       - 82.2
# Six        - 93.3
# Seven      - 89.6
# Eight      - 81.1
# Nine       - 83.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/200 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 0.799957
#
# Average test loss: 0.4024, Test accuracy: 8989/10000 (89.89%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 95.8
# Two        - 89.9
# Three      - 90.3
# Four       - 91.1
# Five       - 84.4
# Six        - 92.6
# Seven      - 89.5
# Eight      - 78.6
# Nine       - 84.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/200 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.766117
#
# Average test loss: 0.3818, Test accuracy: 8982/10000 (89.82%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 96.9
# Two        - 92.2
# Three      - 90.7
# Four       - 90.2
# Five       - 84.3
# Six        - 91.4
# Seven      - 89.7
# Eight      - 80.7
# Nine       - 84.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/200 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.745553
#
# Average test loss: 0.3669, Test accuracy: 9020/10000 (90.20%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.1
# Two        - 90.4
# Three      - 89.4
# Four       - 92.5
# Five       - 86.1
# Six        - 94.3
# Seven      - 92.5
# Eight      - 83.5
# Nine       - 84.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.715582
#
# Average test loss: 0.3401, Test accuracy: 9100/10000 (91.00%)
#
# Class      - Accuracy
# Zero       - 96.9
# One        - 96.6
# Two        - 89.8
# Three      - 90.3
# Four       - 92.4
# Five       - 84.9
# Six        - 92.8
# Seven      - 90.8
# Eight      - 84.0
# Nine       - 85.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/200 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.692527
#
# Average test loss: 0.3395, Test accuracy: 9093/10000 (90.93%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 97.7
# Two        - 92.2
# Three      - 89.5
# Four       - 93.8
# Five       - 85.0
# Six        - 95.0
# Seven      - 91.3
# Eight      - 84.3
# Nine       - 86.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.687891
#
# Average test loss: 0.3302, Test accuracy: 9141/10000 (91.41%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.2
# Two        - 87.5
# Three      - 89.8
# Four       - 94.3
# Five       - 87.7
# Six        - 94.1
# Seven      - 91.4
# Eight      - 86.6
# Nine       - 84.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/200 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.676450
#
# Average test loss: 0.3137, Test accuracy: 9181/10000 (91.81%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.8
# Two        - 89.2
# Three      - 90.2
# Four       - 92.5
# Five       - 89.4
# Six        - 94.3
# Seven      - 92.7
# Eight      - 86.4
# Nine       - 86.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.661879
#
# Average test loss: 0.3044, Test accuracy: 9186/10000 (91.86%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 92.4
# Three      - 93.3
# Four       - 93.9
# Five       - 89.3
# Six        - 94.7
# Seven      - 92.6
# Eight      - 85.8
# Nine       - 86.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 0.636273
#
# Average test loss: 0.2877, Test accuracy: 9246/10000 (92.46%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 97.8
# Two        - 91.8
# Three      - 91.7
# Four       - 94.7
# Five       - 88.5
# Six        - 94.3
# Seven      - 92.7
# Eight      - 88.1
# Nine       - 85.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 0.627490
#
# Average test loss: 0.2831, Test accuracy: 9237/10000 (92.37%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 98.6
# Two        - 92.3
# Three      - 90.5
# Four       - 96.1
# Five       - 90.5
# Six        - 94.0
# Seven      - 91.0
# Eight      - 85.7
# Nine       - 87.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.617373
#
# Average test loss: 0.2838, Test accuracy: 9230/10000 (92.30%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.5
# Two        - 92.4
# Three      - 92.4
# Four       - 93.6
# Five       - 90.1
# Six        - 95.8
# Seven      - 91.3
# Eight      - 88.6
# Nine       - 86.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/200 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 0.597367
#
# Average test loss: 0.2682, Test accuracy: 9269/10000 (92.69%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.5
# Two        - 92.3
# Three      - 93.2
# Four       - 93.1
# Five       - 92.1
# Six        - 95.1
# Seven      - 90.7
# Eight      - 85.1
# Nine       - 89.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/200 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.591656
#
# Average test loss: 0.2669, Test accuracy: 9247/10000 (92.47%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.1
# Two        - 92.5
# Three      - 92.7
# Four       - 94.7
# Five       - 91.1
# Six        - 96.0
# Seven      - 91.5
# Eight      - 86.4
# Nine       - 86.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.577423
#
# Average test loss: 0.2568, Test accuracy: 9278/10000 (92.78%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.5
# Two        - 92.9
# Three      - 92.1
# Four       - 94.3
# Five       - 90.2
# Six        - 95.6
# Seven      - 91.4
# Eight      - 87.3
# Nine       - 87.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 0.564048
#
# Average test loss: 0.2493, Test accuracy: 9286/10000 (92.86%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.4
# Two        - 92.2
# Three      - 91.6
# Four       - 95.0
# Five       - 91.6
# Six        - 94.2
# Seven      - 92.5
# Eight      - 88.5
# Nine       - 88.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.564596
#
# Average test loss: 0.2350, Test accuracy: 9321/10000 (93.21%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 97.9
# Two        - 92.4
# Three      - 93.1
# Four       - 93.9
# Five       - 92.1
# Six        - 95.3
# Seven      - 91.6
# Eight      - 89.7
# Nine       - 88.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/200 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.544816
#
# Average test loss: 0.2344, Test accuracy: 9341/10000 (93.41%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 92.0
# Three      - 93.6
# Four       - 95.3
# Five       - 90.9
# Six        - 94.4
# Seven      - 91.6
# Eight      - 86.5
# Nine       - 87.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/200 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.534364
#
# Average test loss: 0.2263, Test accuracy: 9379/10000 (93.79%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 97.9
# Two        - 91.5
# Three      - 93.5
# Four       - 94.5
# Five       - 91.4
# Six        - 95.7
# Seven      - 90.8
# Eight      - 88.9
# Nine       - 90.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.528005
#
# Average test loss: 0.2305, Test accuracy: 9350/10000 (93.50%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.6
# Two        - 91.6
# Three      - 92.1
# Four       - 94.4
# Five       - 91.1
# Six        - 95.5
# Seven      - 92.7
# Eight      - 91.1
# Nine       - 91.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/200 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.519941
#
# Average test loss: 0.2180, Test accuracy: 9379/10000 (93.79%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.4
# Two        - 92.3
# Three      - 92.9
# Four       - 95.1
# Five       - 91.5
# Six        - 96.2
# Seven      - 92.2
# Eight      - 89.9
# Nine       - 90.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.502580
#
# Average test loss: 0.2183, Test accuracy: 9360/10000 (93.60%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.3
# Two        - 92.3
# Three      - 93.8
# Four       - 94.2
# Five       - 92.6
# Six        - 96.1
# Seven      - 93.0
# Eight      - 88.6
# Nine       - 91.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.506564
#
# Average test loss: 0.2126, Test accuracy: 9397/10000 (93.97%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 99.1
# Two        - 92.4
# Three      - 92.5
# Four       - 94.7
# Five       - 93.6
# Six        - 94.4
# Seven      - 92.9
# Eight      - 87.1
# Nine       - 91.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.503869
#
# Average test loss: 0.2070, Test accuracy: 9400/10000 (94.00%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.4
# Two        - 93.3
# Three      - 94.3
# Four       - 95.0
# Five       - 92.2
# Six        - 95.8
# Seven      - 92.3
# Eight      - 89.6
# Nine       - 89.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/200 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.504120
#
# Average test loss: 0.2023, Test accuracy: 9408/10000 (94.08%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.8
# Two        - 92.2
# Three      - 95.3
# Four       - 95.0
# Five       - 93.1
# Six        - 96.1
# Seven      - 92.5
# Eight      - 90.6
# Nine       - 90.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/200 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.493738
#
# Average test loss: 0.1976, Test accuracy: 9427/10000 (94.27%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.7
# Two        - 93.5
# Three      - 94.3
# Four       - 94.3
# Five       - 94.0
# Six        - 95.2
# Seven      - 92.5
# Eight      - 89.3
# Nine       - 91.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.488354
#
# Average test loss: 0.1966, Test accuracy: 9425/10000 (94.25%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 97.7
# Two        - 91.1
# Three      - 94.6
# Four       - 94.5
# Five       - 92.6
# Six        - 96.2
# Seven      - 91.8
# Eight      - 91.0
# Nine       - 92.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Average of peers' local losses: 0.481961
#
# Average test loss: 0.2043, Test accuracy: 9408/10000 (94.08%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 92.2
# Three      - 93.2
# Four       - 95.6
# Five       - 93.0
# Six        - 95.6
# Seven      - 92.6
# Eight      - 90.8
# Nine       - 89.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.464837
#
# Average test loss: 0.1946, Test accuracy: 9400/10000 (94.00%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.3
# Two        - 93.2
# Three      - 94.6
# Four       - 96.4
# Five       - 94.0
# Six        - 95.6
# Seven      - 93.5
# Eight      - 91.4
# Nine       - 90.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.463173
#
# Average test loss: 0.1854, Test accuracy: 9479/10000 (94.79%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.5
# Two        - 93.8
# Three      - 95.0
# Four       - 95.7
# Five       - 92.6
# Six        - 96.1
# Seven      - 92.0
# Eight      - 89.5
# Nine       - 91.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Average of peers' local losses: 0.463244
#
# Average test loss: 0.1946, Test accuracy: 9422/10000 (94.22%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.1
# Two        - 90.9
# Three      - 94.6
# Four       - 94.8
# Five       - 92.2
# Six        - 95.9
# Seven      - 94.0
# Eight      - 89.3
# Nine       - 91.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 48/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.453860
#
# Average test loss: 0.1801, Test accuracy: 9475/10000 (94.75%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.1
# Two        - 91.8
# Three      - 94.3
# Four       - 95.8
# Five       - 93.4
# Six        - 97.7
# Seven      - 94.1
# Eight      - 90.7
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 49/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 0.446189
#
# Average test loss: 0.1792, Test accuracy: 9493/10000 (94.93%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 97.5
# Two        - 93.4
# Three      - 95.1
# Four       - 95.7
# Five       - 94.7
# Six        - 96.4
# Seven      - 93.4
# Eight      - 91.3
# Nine       - 92.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 50/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.450034
#
# Average test loss: 0.1755, Test accuracy: 9477/10000 (94.77%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.6
# Two        - 93.7
# Three      - 94.5
# Four       - 95.3
# Five       - 95.0
# Six        - 96.5
# Seven      - 93.5
# Eight      - 90.5
# Nine       - 91.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 51/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Average of peers' local losses: 0.438759
#
# Average test loss: 0.1641, Test accuracy: 9527/10000 (95.27%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.6
# Two        - 93.8
# Three      - 94.5
# Four       - 96.1
# Five       - 95.6
# Six        - 97.4
# Seven      - 93.5
# Eight      - 93.3
# Nine       - 91.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 52/200 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.435283
#
# Average test loss: 0.1774, Test accuracy: 9447/10000 (94.47%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.3
# Two        - 91.9
# Three      - 95.4
# Four       - 95.2
# Five       - 93.8
# Six        - 96.1
# Seven      - 92.0
# Eight      - 90.4
# Nine       - 93.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 53/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.430632
#
# Average test loss: 0.1669, Test accuracy: 9479/10000 (94.79%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.8
# Two        - 93.1
# Three      - 95.0
# Four       - 94.7
# Five       - 94.8
# Six        - 96.0
# Seven      - 92.2
# Eight      - 92.8
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 54/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Average of peers' local losses: 0.423611
#
# Average test loss: 0.1689, Test accuracy: 9496/10000 (94.96%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.0
# Two        - 93.0
# Three      - 95.1
# Four       - 95.2
# Five       - 93.1
# Six        - 97.2
# Seven      - 94.3
# Eight      - 92.3
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 55/200 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Average of peers' local losses: 0.426346
#
# Average test loss: 0.1648, Test accuracy: 9512/10000 (95.12%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.7
# Two        - 93.5
# Three      - 94.3
# Four       - 96.4
# Five       - 95.0
# Six        - 96.2
# Seven      - 93.3
# Eight      - 91.8
# Nine       - 91.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 56/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.421823
#
# Average test loss: 0.1626, Test accuracy: 9526/10000 (95.26%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 97.9
# Two        - 93.9
# Three      - 95.0
# Four       - 95.9
# Five       - 94.1
# Six        - 96.3
# Seven      - 92.1
# Eight      - 93.2
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 57/200 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.420167
#
# Average test loss: 0.1715, Test accuracy: 9516/10000 (95.16%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 95.1
# Three      - 95.6
# Four       - 95.6
# Five       - 94.6
# Six        - 96.8
# Seven      - 92.9
# Eight      - 91.3
# Nine       - 92.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 58/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 0.416140
#
# Average test loss: 0.1669, Test accuracy: 9524/10000 (95.24%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 97.8
# Two        - 94.6
# Three      - 95.1
# Four       - 94.6
# Five       - 94.9
# Six        - 96.2
# Seven      - 94.4
# Eight      - 91.4
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 59/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 0.402210
#
# Average test loss: 0.1528, Test accuracy: 9565/10000 (95.65%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.2
# Two        - 92.4
# Three      - 97.0
# Four       - 97.0
# Five       - 96.2
# Six        - 96.7
# Seven      - 94.1
# Eight      - 91.4
# Nine       - 91.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 60/200 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.395616
#
# Average test loss: 0.1566, Test accuracy: 9530/10000 (95.30%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.0
# Two        - 94.2
# Three      - 95.9
# Four       - 96.5
# Five       - 95.3
# Six        - 96.5
# Seven      - 95.0
# Eight      - 92.9
# Nine       - 92.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 61/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.400780
#
# Average test loss: 0.1538, Test accuracy: 9551/10000 (95.51%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.2
# Two        - 94.0
# Three      - 95.0
# Four       - 95.9
# Five       - 95.5
# Six        - 97.2
# Seven      - 93.5
# Eight      - 91.9
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 62/200 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.395355
#
# Average test loss: 0.1548, Test accuracy: 9564/10000 (95.64%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.0
# Two        - 95.9
# Three      - 95.0
# Four       - 96.9
# Five       - 97.4
# Six        - 97.8
# Seven      - 94.0
# Eight      - 92.8
# Nine       - 93.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 63/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 0.392606
#
# Average test loss: 0.1554, Test accuracy: 9555/10000 (95.55%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.7
# Two        - 94.3
# Three      - 95.9
# Four       - 95.7
# Five       - 95.6
# Six        - 96.6
# Seven      - 94.0
# Eight      - 93.5
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 64/200 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.399589
#
# Average test loss: 0.1508, Test accuracy: 9545/10000 (95.45%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.5
# Two        - 92.1
# Three      - 95.8
# Four       - 94.7
# Five       - 95.4
# Six        - 97.9
# Seven      - 94.4
# Eight      - 91.5
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 65/200 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# ...
#
# Backdoor ASR 0.0
#
#  | Global training round : 186/200 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Average of peers' local losses: 0.235680
#
# Average test loss: 0.0752, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.8
# Two        - 98.0
# Three      - 97.5
# Four       - 98.6
# Five       - 98.3
# Six        - 97.4
# Seven      - 96.5
# Eight      - 96.6
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 187/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.230486
#
# Average test loss: 0.0736, Test accuracy: 9766/10000 (97.66%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.1
# Two        - 98.6
# Three      - 98.3
# Four       - 98.2
# Five       - 99.4
# Six        - 98.2
# Seven      - 96.5
# Eight      - 95.4
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 188/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 0.228783
#
# Average test loss: 0.0791, Test accuracy: 9771/10000 (97.71%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 98.3
# Three      - 97.8
# Four       - 99.2
# Five       - 98.7
# Six        - 97.5
# Seven      - 97.2
# Eight      - 96.7
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 189/200 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.230647
#
# Average test loss: 0.0749, Test accuracy: 9773/10000 (97.73%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 97.7
# Three      - 98.4
# Four       - 98.5
# Five       - 99.4
# Six        - 97.7
# Seven      - 96.0
# Eight      - 95.7
# Nine       - 97.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 190/200 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.228554
#
# Average test loss: 0.0719, Test accuracy: 9783/10000 (97.83%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.5
# Three      - 98.1
# Four       - 98.2
# Five       - 99.0
# Six        - 97.7
# Seven      - 96.4
# Eight      - 96.3
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 191/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.230651
#
# Average test loss: 0.0787, Test accuracy: 9749/10000 (97.49%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.2
# Three      - 97.4
# Four       - 98.1
# Five       - 98.7
# Six        - 99.0
# Seven      - 97.2
# Eight      - 96.7
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 192/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.230853
#
# Average test loss: 0.0745, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 98.9
# Three      - 97.9
# Four       - 98.5
# Five       - 99.0
# Six        - 97.8
# Seven      - 95.1
# Eight      - 96.1
# Nine       - 94.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 193/200 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Average of peers' local losses: 0.230846
#
# Average test loss: 0.0793, Test accuracy: 9763/10000 (97.63%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 98.1
# Three      - 97.5
# Four       - 98.2
# Five       - 98.5
# Six        - 98.0
# Seven      - 95.6
# Eight      - 96.4
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 194/200 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.229916
#
# Average test loss: 0.0738, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.5
# Two        - 98.6
# Three      - 98.2
# Four       - 97.8
# Five       - 98.2
# Six        - 97.9
# Seven      - 96.7
# Eight      - 95.7
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 195/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.226855
#
# Average test loss: 0.0725, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.2
# Three      - 98.1
# Four       - 98.6
# Five       - 99.0
# Six        - 97.7
# Seven      - 95.5
# Eight      - 96.4
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 196/200 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.229794
#
# Average test loss: 0.0717, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.0
# Two        - 97.6
# Three      - 96.8
# Four       - 97.5
# Five       - 97.9
# Six        - 98.0
# Seven      - 96.1
# Eight      - 96.4
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 197/200 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Average of peers' local losses: 0.221797
#
# Average test loss: 0.0691, Test accuracy: 9796/10000 (97.96%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.6
# Two        - 98.2
# Three      - 98.3
# Four       - 97.7
# Five       - 98.6
# Six        - 97.8
# Seven      - 94.9
# Eight      - 96.0
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 198/200 |
#
#
# Selected Peers:
# Peer 2  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 0.237631
#
# Average test loss: 0.0685, Test accuracy: 9793/10000 (97.93%)
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 99.0
# Three      - 97.5
# Four       - 97.6
# Five       - 98.6
# Six        - 97.9
# Seven      - 96.5
# Eight      - 96.2
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 199/200 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.230202
#
# Average test loss: 0.0724, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.8
# Two        - 98.7
# Three      - 97.6
# Four       - 98.3
# Five       - 97.8
# Six        - 97.5
# Seven      - 96.7
# Eight      - 96.8
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 200/200 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.229184
#
# Average test loss: 0.0662, Test accuracy: 9787/10000 (97.87%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.2
# Two        - 98.6
# Three      - 97.4
# Four       - 98.5
# Five       - 97.6
# Six        - 97.7
# Seven      - 97.4
# Eight      - 96.2
# Nine       - 95.1
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0772, Test accuracy: 9773/10000 (97.73%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.7
# Three      - 98.4
# Four       - 98.3
# Five       - 98.3
# Six        - 98.1
# Seven      - 96.9
# Eight      - 97.4
# Nine       - 96.4
# Global accuracies:  [15.49, 29.88, 42.17, 54.89, 61.34, 65.55, 69.39, 75.18, 78.79, 81.95, 84.01, 85.27, 85.8, 87.08, 87.45, 88.93, 89.15, 89.89, 89.82, 90.2, 91.0, 90.93, 91.41, 91.81, 91.86, 92.46, 92.37, 92.3, 92.69, 92.47, 92.78, 92.86, 93.21, 93.41, 93.79, 93.5, 93.79, 93.6, 93.97, 94.0, 94.08, 94.27, 94.25, 94.08, 94.0, 94.79, 94.22, 94.75, 94.93, 94.77, 95.27, 94.47, 94.79, 94.96, 95.12, 95.26, 95.16, 95.24, 95.65, 95.3, 95.51, 95.64, 95.55, 95.45, 95.43, 95.49, 95.92, 95.75, 95.94, 96.16, 96.0, 96.09, 96.46, 95.92, 96.17, 95.91, 95.95, 96.5, 96.35, 96.29, 95.76, 96.54, 96.53, 95.96, 96.42, 96.44, 96.52, 96.2, 96.66, 96.62, 96.85, 96.41, 96.77, 96.79, 96.78, 96.7, 96.9, 96.87, 96.59, 96.6, 97.07, 96.6, 96.7, 96.76, 96.52, 96.68, 96.95, 96.87, 96.99, 96.87, 96.91, 96.97, 96.97, 96.85, 96.74, 96.93, 96.85, 96.95, 96.82, 96.94, 96.85, 97.16, 97.1, 97.19, 97.02, 97.26, 97.25, 97.23, 97.22, 97.07, 96.94, 97.26, 97.33, 97.01, 97.18, 97.44, 97.24, 97.29, 97.41, 97.17, 97.31, 97.14, 97.13, 97.3, 97.49, 97.33, 97.74, 97.32, 97.85, 97.59, 97.48, 97.33, 97.53, 97.45, 97.58, 97.47, 97.13, 97.43, 97.5, 97.76, 97.25, 97.51, 97.44, 97.59, 97.38, 97.51, 97.78, 97.5, 97.81, 97.63, 97.71, 97.79, 97.84, 97.55, 97.83, 97.5, 97.67, 97.64, 97.58, 97.34, 97.83, 97.5, 97.57, 97.73, 97.3, 97.65, 97.66, 97.71, 97.73, 97.83, 97.49, 97.68, 97.63, 97.7, 97.92, 97.92, 97.96, 97.93, 97.74, 97.87, 97.73]
# Class 7 accuracies:  [12.18, 51.32, 73.94, 83.71, 87.56, 88.99, 90.63, 88.78, 88.01, 85.67, 88.56, 88.21, 90.72, 85.97, 87.38, 88.49, 89.65, 89.45, 89.7, 92.55, 90.83, 91.27, 91.38, 92.66, 92.65, 92.75, 91.04, 91.34, 90.71, 91.49, 91.37, 92.49, 91.57, 91.63, 90.77, 92.73, 92.21, 92.98, 92.91, 92.31, 92.54, 92.54, 91.82, 92.63, 93.48, 91.99, 94.0, 94.1, 93.38, 93.47, 93.53, 92.01, 92.16, 94.29, 93.32, 92.13, 92.91, 94.42, 94.09, 95.04, 93.46, 94.02, 93.95, 94.42, 92.56, 92.03, 93.11, 94.1, 92.9, 94.11, 93.56, 94.18, 93.37, 93.72, 93.92, 93.19, 93.58, 94.02, 94.21, 93.41, 93.67, 94.77, 94.9, 94.61, 94.37, 95.52, 94.34, 95.08, 94.24, 95.01, 95.84, 94.73, 95.35, 93.44, 93.84, 95.63, 95.85, 94.51, 95.09, 95.31, 95.58, 95.12, 95.35, 96.39, 94.62, 95.4, 95.41, 95.42, 95.63, 95.91, 95.64, 95.79, 96.15, 96.41, 94.75, 94.87, 95.41, 96.25, 95.31, 96.43, 94.88, 95.84, 95.88, 96.93, 94.14, 95.8, 95.09, 95.73, 95.23, 95.46, 95.58, 95.6, 96.02, 96.3, 95.18, 94.47, 95.66, 95.39, 96.58, 95.43, 97.51, 95.49, 96.15, 96.72, 94.94, 96.36, 95.87, 96.1, 96.53, 95.38, 95.66, 95.69, 96.97, 96.49, 96.33, 96.11, 95.22, 97.29, 96.22, 96.25, 96.33, 96.14, 95.72, 95.91, 95.28, 96.0, 96.32, 96.35, 96.02, 95.63, 96.07, 95.52, 96.97, 96.45, 96.13, 96.4, 96.06, 96.35, 95.95, 96.3, 96.57, 95.9, 96.52, 95.28, 97.09, 96.46, 96.52, 97.19, 96.04, 96.44, 97.24, 95.15, 95.57, 96.74, 95.55, 96.15, 94.85, 96.54, 96.7, 97.37, 96.87]
# Test loss: [2.2799, 2.2585, 2.2282, 2.1732, 2.0714, 1.8979, 1.6296, 1.3402, 1.0743, 0.8768, 0.7322, 0.6478, 0.5818, 0.5222, 0.4882, 0.4495, 0.4304, 0.4024, 0.3818, 0.3669, 0.3401, 0.3395, 0.3302, 0.3137, 0.3044, 0.2877, 0.2831, 0.2838, 0.2682, 0.2669, 0.2568, 0.2493, 0.235, 0.2344, 0.2263, 0.2305, 0.218, 0.2183, 0.2126, 0.207, 0.2023, 0.1976, 0.1966, 0.2043, 0.1946, 0.1854, 0.1946, 0.1801, 0.1792, 0.1755, 0.1641, 0.1774, 0.1669, 0.1689, 0.1648, 0.1626, 0.1715, 0.1669, 0.1528, 0.1566, 0.1538, 0.1548, 0.1554, 0.1508, 0.1529, 0.1493, 0.1414, 0.1427, 0.1436, 0.1378, 0.1388, 0.1378, 0.1263, 0.139, 0.1345, 0.134, 0.1329, 0.1216, 0.1259, 0.1272, 0.1386, 0.1245, 0.1215, 0.1263, 0.1229, 0.1241, 0.1238, 0.1272, 0.1133, 0.113, 0.1098, 0.1157, 0.1147, 0.1073, 0.1102, 0.1128, 0.108, 0.1085, 0.1132, 0.1169, 0.105, 0.1187, 0.108, 0.1101, 0.1157, 0.1073, 0.0994, 0.1089, 0.1018, 0.1049, 0.1101, 0.1009, 0.1062, 0.1064, 0.1093, 0.1027, 0.1057, 0.1069, 0.1029, 0.1019, 0.101, 0.0914, 0.0937, 0.093, 0.102, 0.0916, 0.0967, 0.094, 0.0951, 0.0994, 0.1015, 0.0902, 0.0949, 0.0978, 0.0931, 0.0865, 0.0922, 0.0953, 0.08, 0.0906, 0.0958, 0.0994, 0.0926, 0.0906, 0.0842, 0.0918, 0.0791, 0.091, 0.0786, 0.0793, 0.0809, 0.0891, 0.0833, 0.0891, 0.0785, 0.0855, 0.0885, 0.0847, 0.084, 0.0731, 0.0919, 0.0857, 0.0792, 0.077, 0.0811, 0.0827, 0.0737, 0.083, 0.0712, 0.0815, 0.0759, 0.0747, 0.0721, 0.0746, 0.0716, 0.0791, 0.0781, 0.0779, 0.0781, 0.0854, 0.0732, 0.0799, 0.0799, 0.0724, 0.0871, 0.0752, 0.0736, 0.0791, 0.0749, 0.0719, 0.0787, 0.0745, 0.0793, 0.0738, 0.0725, 0.0717, 0.0691, 0.0685, 0.0724, 0.0662, 0.0772]
# Label-flipping attack succes rate: 0.2
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.001
#
# --> End of Experiment.

# %%
RULE = 'median'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,strategy = 's1', resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: NON_IID
# Aggregation rule: ffl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s2
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/200 [00:00<?, ?it/s]
#  | Global training round : 1/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 2  attack !
# 1  attack !
# 19  attack !
# Average of peers' local losses: 2.296993
# Mixing took 0.0315
# -> Update reputation
# Aggregation took 0.0432
#
# Average test loss: 2.2861, Test accuracy: 1129/10000 (11.29%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 25.5
# Two        - 25.4
# Three      - 1.0
# Four       - 0.0
# Five       - 0.0
# Six        - 0.0
# Seven      - 0.4
# Eight      - 27.3
# Nine       - 29.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: -0.01891624927520752
# Peer 18  is  honest reputation: 0.22804278135299683
# Peer 7  is  honest reputation: 0.015156924724578857
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.04520058631896973
# Peer 3  is  honest reputation: 0.040617525577545166
# Peer 16  is  honest reputation: 0.07948124408721924
# Peer 1  is  attacker reputation: -0.024659156799316406
# Peer 15  is  honest reputation: 0.0
# 19  attack !
# 1  attack !
# Average of peers' local losses: 2.288230
# Mixing took 0.024
# -> Update reputation
# Aggregation took 0.0185
#
# Average test loss: 2.2725, Test accuracy: 2048/10000 (20.48%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 67.7
# Two        - 40.2
# Three      - 5.0
# Four       - 0.0
# Five       - 0.3
# Six        - 0.0
# Seven      - 7.0
# Eight      - 43.0
# Nine       - 47.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.04519951343536377
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 3.0994415283203125e-06
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.2201576828956604
# Peer 1  is  attacker reputation: -0.4552481174468994
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.008829653263092041
# Peer 2  is  attacker reputation: -0.0050522685050964355
# Peer 11  is  attacker reputation: 0.0
# 1  attack !
# 2  attack !
# 11  attack !
# Average of peers' local losses: 2.278024
# Mixing took 0.023
# -> Update reputation
# Aggregation took 0.0221
#
# Average test loss: 2.2577, Test accuracy: 2612/10000 (26.12%)
#
# Class      - Accuracy
# Zero       - 4.9
# One        - 93.0
# Two        - 47.2
# Three      - 10.9
# Four       - 0.5
# Five       - 0.0
# Six        - 0.0
# Seven      - 10.1
# Eight      - 41.6
# Nine       - 52.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/200 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.05456608533859253
# Peer 6  is  honest reputation: 0.3104994297027588
# Peer 8  is  honest reputation: 0.2976575493812561
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: -0.4629973769187927
# Peer 1  is  attacker reputation: -0.5366345643997192
# Peer 16  is  honest reputation: 0.0908883810043335
# Peer 17  is  honest reputation: 0.023522019386291504
# Peer 11  is  attacker reputation: -0.08058363199234009
# Peer 5  is  honest reputation: 0.27187496423721313
# 19  attack !
# 1  attack !
# 11  attack !
# Average of peers' local losses: 2.265314
# Mixing took 0.0249
# -> Update reputation
# Aggregation took 0.0213
#
# Average test loss: 2.2350, Test accuracy: 3136/10000 (31.36%)
#
# Class      - Accuracy
# Zero       - 32.9
# One        - 99.6
# Two        - 30.4
# Three      - 24.4
# Four       - 4.7
# Five       - 0.5
# Six        - 0.8
# Seven      - 11.1
# Eight      - 44.3
# Nine       - 61.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.018130958080291748
# Peer 13  is  honest reputation: 0.49945926666259766
# Peer 4  is  honest reputation: 0.2748079299926758
# Peer 2  is  attacker reputation: -0.09434378147125244
# Peer 3  is  honest reputation: 0.04816502332687378
# Peer 12  is  honest reputation: 0.282384991645813
# Peer 14  is  honest reputation: 0.24175089597702026
# Peer 18  is  honest reputation: 0.23908263444900513
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: -0.5045313835144043
# 2  attack !
# 1  attack !
# Average of peers' local losses: 2.248458
# Mixing took 0.0235
# -> Update reputation
# Aggregation took 0.0184
#
# Average test loss: 2.1951, Test accuracy: 4936/10000 (49.36%)
#
# Class      - Accuracy
# Zero       - 74.7
# One        - 97.8
# Two        - 50.2
# Three      - 50.3
# Four       - 17.8
# Five       - 0.3
# Six        - 22.8
# Seven      - 45.5
# Eight      - 62.2
# Nine       - 78.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0378456711769104
# Peer 14  is  honest reputation: 0.45132094621658325
# Peer 7  is  honest reputation: 0.028104782104492188
# Peer 18  is  honest reputation: 0.4521788954734802
# Peer 8  is  honest reputation: 0.3056930899620056
# Peer 6  is  honest reputation: 0.3158355951309204
# Peer 5  is  honest reputation: 0.4365239143371582
# Peer 11  is  attacker reputation: -0.051343441009521484
# Peer 2  is  attacker reputation: -0.29992592334747314
# Peer 3  is  honest reputation: 0.27527451515197754
# 11  attack !
# 2  attack !
# Average of peers' local losses: 2.219044
# Mixing took 0.0197
# -> Update reputation
# Aggregation took 0.0153
#
# Average test loss: 2.1294, Test accuracy: 5715/10000 (57.15%)
#
# Class      - Accuracy
# Zero       - 89.5
# One        - 96.7
# Two        - 36.9
# Three      - 57.1
# Four       - 31.1
# Five       - 0.5
# Six        - 57.3
# Seven      - 62.4
# Eight      - 68.6
# Nine       - 71.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.46799594163894653
# Peer 2  is  attacker reputation: -0.5049920082092285
# Peer 7  is  honest reputation: 0.21450120210647583
# Peer 5  is  honest reputation: 0.6198068857192993
# Peer 19  is  attacker reputation: -0.46477609872817993
# Peer 11  is  attacker reputation: -0.2727481722831726
# Peer 16  is  honest reputation: 0.23367297649383545
# Peer 6  is  honest reputation: 0.333069384098053
# Peer 8  is  honest reputation: 0.29994845390319824
# Peer 13  is  honest reputation: 0.4928877353668213
# 2  attack !
# 19  attack !
# 11  attack !
# Average of peers' local losses: 2.171249
# Mixing took 0.0244
# -> Update reputation
# Aggregation took 0.0176
#
# Average test loss: 2.0301, Test accuracy: 5914/10000 (59.14%)
#
# Class      - Accuracy
# Zero       - 92.3
# One        - 96.2
# Two        - 31.8
# Three      - 65.2
# Four       - 41.9
# Five       - 1.2
# Six        - 73.4
# Seven      - 70.4
# Eight      - 65.5
# Nine       - 60.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/200 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: -0.5680124163627625
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.6125521659851074
# Peer 11  is  attacker reputation: -0.32699525356292725
# Peer 0  is  honest reputation: 0.23959094285964966
# Peer 10  is  honest reputation: -0.004926502704620361
# Peer 4  is  honest reputation: 0.7914211750030518
# Peer 12  is  honest reputation: 0.4927823543548584
# Peer 18  is  honest reputation: 0.6506893634796143
# Peer 5  is  honest reputation: 0.9473382830619812
# 2  attack !
# 11  attack !
# Average of peers' local losses: 2.099830
# Mixing took 0.0381
# -> Update reputation
# Aggregation took 0.0202
#
# Average test loss: 1.8643, Test accuracy: 6296/10000 (62.96%)
#
# Class      - Accuracy
# Zero       - 95.4
# One        - 98.4
# Two        - 38.7
# Three      - 67.7
# Four       - 61.2
# Five       - 5.3
# Six        - 73.2
# Seven      - 76.8
# Eight      - 60.1
# Nine       - 50.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.4264119863510132
# Peer 11  is  attacker reputation: -0.5772117972373962
# Peer 3  is  honest reputation: 0.45855844020843506
# Peer 14  is  honest reputation: 0.6322835087776184
# Peer 7  is  honest reputation: 0.542354166507721
# Peer 1  is  attacker reputation: -0.7314615845680237
# Peer 8  is  honest reputation: 0.6637091040611267
# Peer 9  is  honest reputation: 0.09496158361434937
# Peer 10  is  honest reputation: 0.09018558263778687
# Peer 16  is  honest reputation: 0.5440277457237244
# 11  attack !
# 1  attack !
# Average of peers' local losses: 1.981447
# Mixing took 0.0241
# -> Update reputation
# Aggregation took 0.0181
#
# Average test loss: 1.6316, Test accuracy: 6698/10000 (66.98%)
#
# Class      - Accuracy
# Zero       - 94.9
# One        - 98.2
# Two        - 49.7
# Three      - 74.8
# Four       - 70.8
# Five       - 17.6
# Six        - 74.5
# Seven      - 82.0
# Eight      - 59.2
# Nine       - 46.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.31270426511764526
# Peer 15  is  honest reputation: 0.23230111598968506
# Peer 12  is  honest reputation: 0.6101851463317871
# Peer 1  is  attacker reputation: -0.9198932647705078
# Peer 4  is  honest reputation: 0.9126541614532471
# Peer 14  is  honest reputation: 0.6049708724021912
# Peer 19  is  attacker reputation: -0.4958903193473816
# Peer 9  is  honest reputation: 0.24190139770507812
# Peer 3  is  honest reputation: 0.5819497108459473
# Peer 7  is  honest reputation: 0.6730940341949463
# 1  attack !
# 19  attack !
# Average of peers' local losses: 1.832749
# Mixing took 0.02
# -> Update reputation
# Aggregation took 0.0168
#
# Average test loss: 1.3630, Test accuracy: 7029/10000 (70.29%)
#
# Class      - Accuracy
# Zero       - 94.5
# One        - 98.7
# Two        - 59.2
# Three      - 79.8
# Four       - 74.1
# Five       - 25.1
# Six        - 74.6
# Seven      - 83.5
# Eight      - 53.0
# Nine       - 50.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.7630776166915894
# Peer 17  is  honest reputation: 0.30899161100387573
# Peer 8  is  honest reputation: 0.749379575252533
# Peer 2  is  attacker reputation: -0.7576701045036316
# Peer 5  is  honest reputation: 1.0432856678962708
# Peer 13  is  honest reputation: 0.7998283505439758
# Peer 6  is  honest reputation: 0.5083498954772949
# Peer 18  is  honest reputation: 0.7423096299171448
# Peer 16  is  honest reputation: 0.6797813773155212
# Peer 1  is  attacker reputation: -1.1922034621238708
# 2  attack !
# 1  attack !
# Average of peers' local losses: 1.667634
# Mixing took 0.0236
# -> Update reputation
# Aggregation took 0.0174
#
# Average test loss: 1.1294, Test accuracy: 7311/10000 (73.11%)
#
# Class      - Accuracy
# Zero       - 96.0
# One        - 98.6
# Two        - 68.3
# Three      - 84.0
# Four       - 81.0
# Five       - 43.1
# Six        - 81.0
# Seven      - 81.9
# Eight      - 58.5
# Nine       - 48.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/200 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: -0.9548786878585815
# Peer 10  is  honest reputation: 0.22014003992080688
# Peer 4  is  honest reputation: 0.9984015822410583
# Peer 6  is  honest reputation: 0.500964879989624
# Peer 12  is  honest reputation: 0.696977436542511
# Peer 14  is  honest reputation: 0.6843398213386536
# Peer 9  is  honest reputation: 0.2944267988204956
# Peer 18  is  honest reputation: 0.9034215211868286
# Peer 13  is  honest reputation: 0.9520202875137329
# Peer 17  is  honest reputation: 0.3311467170715332
# 2  attack !
# Average of peers' local losses: 1.493126
# Mixing took 0.0237
# -> Update reputation
# Aggregation took 0.0168
#
# Average test loss: 0.9069, Test accuracy: 7821/10000 (78.21%)
#
# Class      - Accuracy
# Zero       - 94.8
# One        - 97.3
# Two        - 74.4
# Three      - 84.5
# Four       - 78.3
# Five       - 54.7
# Six        - 81.4
# Seven      - 86.0
# Eight      - 59.0
# Nine       - 64.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.9266611933708191
# Peer 11  is  attacker reputation: -0.7826621532440186
# Peer 9  is  honest reputation: 0.29423439502716064
# Peer 8  is  honest reputation: 0.9130837917327881
# Peer 18  is  honest reputation: 0.9218245148658752
# Peer 5  is  honest reputation: 1.1935870051383972
# Peer 4  is  honest reputation: 1.0033870935440063
# Peer 12  is  honest reputation: 0.7201999425888062
# Peer 10  is  honest reputation: 0.24422293901443481
# Peer 19  is  attacker reputation: -0.7446703910827637
# 11  attack !
# 19  attack !
# Average of peers' local losses: 1.368609
# Mixing took 0.0241
# -> Update reputation
# Aggregation took 0.0175
#
# Average test loss: 0.7683, Test accuracy: 8078/10000 (80.78%)
#
# Class      - Accuracy
# Zero       - 96.1
# One        - 97.5
# Two        - 77.5
# Three      - 85.0
# Four       - 82.2
# Five       - 66.4
# Six        - 85.9
# Seven      - 86.1
# Eight      - 68.1
# Nine       - 69.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.8100127577781677
# Peer 10  is  honest reputation: 0.25824934244155884
# Peer 2  is  attacker reputation: -1.318697452545166
# Peer 18  is  honest reputation: 0.917149007320404
# Peer 15  is  honest reputation: 0.2434391975402832
# Peer 12  is  honest reputation: 0.8936871886253357
# Peer 19  is  attacker reputation: -0.9583589434623718
# Peer 11  is  attacker reputation: -0.9793105125427246
# Peer 9  is  honest reputation: 0.47601914405822754
# Peer 4  is  honest reputation: 1.1783934235572815
# 2  attack !
# 19  attack !
# 11  attack !
# Average of peers' local losses: 1.254616
# Mixing took 0.0241
# -> Update reputation
# Aggregation took 0.0186
#
# Average test loss: 0.6662, Test accuracy: 8198/10000 (81.98%)
#
# Class      - Accuracy
# Zero       - 96.8
# One        - 97.0
# Two        - 82.2
# Three      - 86.7
# Four       - 82.1
# Five       - 69.8
# Six        - 85.8
# Seven      - 84.2
# Eight      - 60.1
# Nine       - 69.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.5279185771942139
# Peer 6  is  honest reputation: 0.5151333808898926
# Peer 3  is  honest reputation: 0.6713719964027405
# Peer 18  is  honest reputation: 1.2095758318901062
# Peer 10  is  honest reputation: 0.5600283741950989
# Peer 7  is  honest reputation: 1.0871614217758179
# Peer 19  is  attacker reputation: -1.0084786415100098
# Peer 0  is  honest reputation: 0.22253865003585815
# Peer 11  is  attacker reputation: -1.049855649471283
# Peer 13  is  honest reputation: 1.1141451001167297
# 19  attack !
# 11  attack !
# Average of peers' local losses: 1.162918
# Mixing took 0.0231
# -> Update reputation
# Aggregation took 0.0157
#
# Average test loss: 0.5912, Test accuracy: 8373/10000 (83.73%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.1
# Two        - 86.0
# Three      - 88.2
# Four       - 83.0
# Five       - 72.0
# Six        - 89.1
# Seven      - 84.1
# Eight      - 68.6
# Nine       - 70.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/200 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: -1.334915041923523
# Peer 9  is  honest reputation: 0.7785719633102417
# Peer 3  is  honest reputation: 0.8454831838607788
# Peer 14  is  honest reputation: 0.7061869502067566
# Peer 17  is  honest reputation: 0.33172398805618286
# Peer 8  is  honest reputation: 1.070553183555603
# Peer 6  is  honest reputation: 0.6794721484184265
# Peer 7  is  honest reputation: 1.2455573678016663
# Peer 19  is  attacker reputation: -1.2514568567276
# Peer 2  is  attacker reputation: -1.3611517548561096
# 1  attack !
# 19  attack !
# 2  attack !
# Average of peers' local losses: 1.109082
# Mixing took 0.0247
# -> Update reputation
# Aggregation took 0.0219
#
# Average test loss: 0.5368, Test accuracy: 8556/10000 (85.56%)
#
# Class      - Accuracy
# Zero       - 96.4
# One        - 97.1
# Two        - 86.5
# Three      - 87.0
# Four       - 86.4
# Five       - 78.4
# Six        - 89.2
# Seven      - 85.5
# Eight      - 71.4
# Nine       - 70.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.6752965450286865
# Peer 12  is  honest reputation: 1.0210500955581665
# Peer 13  is  honest reputation: 1.2857788801193237
# Peer 16  is  honest reputation: 0.8417601585388184
# Peer 15  is  honest reputation: 0.5450116395950317
# Peer 18  is  honest reputation: 1.3554641008377075
# Peer 4  is  honest reputation: 1.475121796131134
# Peer 11  is  attacker reputation: -1.27559232711792
# Peer 5  is  honest reputation: 1.3597537279129028
# Peer 1  is  attacker reputation: -1.4105347394943237
# 11  attack !
# 1  attack !
# Average of peers' local losses: 1.026670
# Mixing took 0.022
# -> Update reputation
# Aggregation took 0.017
#
# Average test loss: 0.5010, Test accuracy: 8613/10000 (86.13%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 97.3
# Two        - 86.4
# Three      - 87.3
# Four       - 86.0
# Five       - 78.3
# Six        - 90.8
# Seven      - 85.1
# Eight      - 72.3
# Nine       - 76.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.5696587562561035
# Peer 5  is  honest reputation: 1.3941508531570435
# Peer 11  is  attacker reputation: -1.6899858117103577
# Peer 3  is  honest reputation: 1.1737434267997742
# Peer 13  is  honest reputation: 1.3232606053352356
# Peer 7  is  honest reputation: 1.5594319105148315
# Peer 2  is  attacker reputation: -1.4205965399742126
# Peer 17  is  honest reputation: 0.6978932619094849
# Peer 0  is  honest reputation: 0.2168409824371338
# Peer 12  is  honest reputation: 1.02395498752594
# 11  attack !
# 2  attack !
# Average of peers' local losses: 0.979434
# Mixing took 0.0249
# -> Update reputation
# Aggregation took 0.0172
#
# Average test loss: 0.4642, Test accuracy: 8667/10000 (86.67%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 98.1
# Two        - 87.2
# Three      - 88.1
# Four       - 87.0
# Five       - 80.5
# Six        - 89.8
# Seven      - 84.5
# Eight      - 71.5
# Nine       - 76.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/200 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 1.3544958233833313
# Peer 6  is  honest reputation: 0.9851284027099609
# Peer 7  is  honest reputation: 1.7342999577522278
# Peer 19  is  attacker reputation: -1.3324531316757202
# Peer 13  is  honest reputation: 1.5280506014823914
# Peer 16  is  honest reputation: 0.8931849002838135
# Peer 2  is  attacker reputation: -1.6333075165748596
# Peer 11  is  attacker reputation: -1.9321479499340057
# Peer 0  is  honest reputation: 0.4193658232688904
# Peer 3  is  honest reputation: 1.1698712706565857
# 19  attack !
# 2  attack !
# 11  attack !
# Average of peers' local losses: 0.960943
# Mixing took 0.0251
# -> Update reputation
# Aggregation took 0.0183
#
# Average test loss: 0.4758, Test accuracy: 8590/10000 (85.90%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 97.4
# Two        - 88.5
# Three      - 89.6
# Four       - 88.6
# Five       - 80.7
# Six        - 91.7
# Seven      - 75.0
# Eight      - 76.7
# Nine       - 76.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 1.7353161573410034
# Peer 18  is  honest reputation: 1.5658631920814514
# Peer 5  is  honest reputation: 1.566632330417633
# Peer 6  is  honest reputation: 0.9915791153907776
# Peer 12  is  honest reputation: 1.2113670706748962
# Peer 0  is  honest reputation: 0.5804482102394104
# Peer 9  is  honest reputation: 1.0910823941230774
# Peer 3  is  honest reputation: 1.3858872056007385
# Peer 4  is  honest reputation: 1.5101218819618225
# Peer 16  is  honest reputation: 0.8980762958526611
# Average of peers' local losses: 0.882001
# Mixing took 0.0336
# -> Update reputation
# Aggregation took 0.0191
#
# Average test loss: 0.4211, Test accuracy: 8742/10000 (87.42%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.2
# Two        - 89.0
# Three      - 87.6
# Four       - 91.0
# Five       - 83.7
# Six        - 89.8
# Seven      - 89.2
# Eight      - 73.7
# Nine       - 77.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.7451735734939575
# Peer 9  is  honest reputation: 1.0923633575439453
# Peer 12  is  honest reputation: 1.2109401226043701
# Peer 14  is  honest reputation: 1.0314556956291199
# Peer 4  is  honest reputation: 1.6440988183021545
# Peer 17  is  honest reputation: 0.7095096707344055
# Peer 8  is  honest reputation: 1.2488874793052673
# Peer 6  is  honest reputation: 1.1070064306259155
# Peer 18  is  honest reputation: 1.694008469581604
# Peer 13  is  honest reputation: 1.5330139994621277
# Average of peers' local losses: 0.834039
# Mixing took 0.0228
# -> Update reputation
# [0.81034213 0.80937116 0.58620458 0.44456788 0.36931587 0.21417369
#  0.77963913 0.01452903 0.55015974 0.5209285 ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9be9c44751f7> in <module>
#      11                 source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
#      12                class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS,
# ---> 13                rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
#
# ~\Desktop\文件\论文\论文源码\Enhanced Security and Privacy via\experiment_federated.py in run_exp(dataset_name, model_name, dd_type, num_peers, frac_peers, seed, test_batch_size, criterion, global_rounds, local_epochs, local_bs, local_lr, local_momentum, labels_dict, device, attackers_ratio, attack_type, malicious_behavior_rate, rule, class_per_peer, samples_per_class, rate_unbalance, alpha, source_class, target_class, strategy, resume)
#      25     flEnv.run_experiment(attack_type = attack_type, malicious_behavior_rate = malicious_behavior_rate,
#      26                     source_class = source_class, target_class = target_class,
# ---> 27                     rule=rule, strategy = strategy, resume = resume)
#      28     print('\n--> End of Experiment.')
#
# ~\Desktop\文件\论文\论文源码\Enhanced Security and Privacy via\environment_federated.py in run_experiment(self, attack_type, malicious_behavior_rate, source_class, target_class, rule, strategy, resume)
#     513                     v = v[idxs]
#     514                     print(v)
# --> 515                     global_weights = average_weights(models, v)
#     516                 t = time.time() - cur_time
#     517                 print('Aggregation took', np.round(t, 4))
#
# ~\Desktop\文件\论文\论文源码\Enhanced Security and Privacy via\aggregation.py in average_weights(w, marks)
#     310     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     311     w_avg = copy.deepcopy(w[0])
# --> 312     w.to(device)
#     313     w_avg.to(device)
#     314     marks.to(device)
#
# AttributeError: 'list' object has no attribute 'to'

# %%
RULE = 'fdfl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: fdfl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s2
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.283282
#
# 10selected Peers:
# Peer 10 is  honest reputation: 0.0
# Peer 5 is  honest reputation: 0.0
# Peer 3 is  honest reputation: 0.0
# Peer 18 is  honest reputation: 0.0
# Peer 14 is  honest reputation: 0.0
# Peer 15 is  honest reputation: 0.0
# Peer 12 is  honest reputation: 0.0
# Peer 7 is  honest reputation: 0.0
# Peer 13 is  honest reputation: 0.0
# Peer 11 is  attacker reputation: 0.0
# Peer 9 is  honest reputation: 0.0
# Peer 4 is  honest reputation: 0.0
# Peer 16 is  honest reputation: 0.0
# Peer 1 is  attacker reputation: 0.0
# Peer 19 is  attacker reputation: 0.0
# Peer 17 is  honest reputation: 0.0
# Peer 6 is  honest reputation: 0.0
# Peer 2 is  attacker reputation: 0.0
# Peer 8 is  honest reputation: 0.0
# Peer 0 is  honest reputation: 0.0
#
# 10selected Peers after refuse(delete 0):
# Peer 0 is  honest reputation: 0.0
# Peer 1 is  attacker reputation: 0.0
# Peer 2 is  attacker reputation: 0.0
# Peer 3 is  honest reputation: 0.0
# Peer 4 is  honest reputation: 0.0
# Peer 5 is  honest reputation: 0.0
# Peer 6 is  honest reputation: 0.0
# Peer 7 is  honest reputation: 0.0
# Peer 8 is  honest reputation: 0.0
# Peer 9 is  honest reputation: 0.0
# Peer 10 is  honest reputation: 0.0
# Peer 11 is  attacker reputation: 0.0
# Peer 12 is  honest reputation: 0.0
# Peer 13 is  honest reputation: 0.0
# Peer 14 is  honest reputation: 0.0
# Peer 15 is  honest reputation: 0.0
# Peer 16 is  honest reputation: 0.0
# Peer 17 is  honest reputation: 0.0
# Peer 18 is  honest reputation: 0.0
# Peer 19 is  attacker reputation: 0.0
# attack 1 Average test loss: 2.2735, Test accuracy: 1010/10000 (10.10%)
#
# honest 10 Average test loss: 2.2474, Test accuracy: 3194/10000 (31.94%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 45.0
# Two        - 49.3
# Three      - 48.8
# Four       - 1.1
# Five       - 0.4
# Six        - 2.3
# Seven      - 53.9
# Eight      - 22.8
# Nine       - 92.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.221355
#
# 10selected Peers:
# Peer 16 is  honest reputation: 0.06641358137130737
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 18 is  honest reputation: 0.033366382122039795
# Peer 5 is  honest reputation: 0.07593578100204468
# Peer 12 is  honest reputation: 0.030222713947296143
# Peer 8 is  honest reputation: 0.03313004970550537
# Peer 14 is  honest reputation: 0.019703984260559082
# Peer 6 is  honest reputation: 0.035974323749542236
# Peer 0 is  honest reputation: 0.03917503356933594
# Peer 3 is  honest reputation: 0.020196616649627686
# Peer 4 is  honest reputation: 0.06716108322143555
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 13 is  honest reputation: 0.04225367307662964
# Peer 9 is  honest reputation: 0.04175084829330444
# Peer 17 is  honest reputation: 0.051502346992492676
# Peer 7 is  honest reputation: 0.026239871978759766
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 15 is  honest reputation: 0.05652707815170288
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.03917503356933594
# Peer 3 is  honest reputation: 0.020196616649627686
# Peer 4 is  honest reputation: 0.06716108322143555
# Peer 5 is  honest reputation: 0.07593578100204468
# Peer 6 is  honest reputation: 0.035974323749542236
# Peer 7 is  honest reputation: 0.026239871978759766
# Peer 8 is  honest reputation: 0.03313004970550537
# Peer 9 is  honest reputation: 0.04175084829330444
# Peer 12 is  honest reputation: 0.030222713947296143
# Peer 13 is  honest reputation: 0.04225367307662964
# Peer 14 is  honest reputation: 0.019703984260559082
# Peer 15 is  honest reputation: 0.05652707815170288
# Peer 16 is  honest reputation: 0.06641358137130737
# Peer 17 is  honest reputation: 0.051502346992492676
# Peer 18 is  honest reputation: 0.033366382122039795
# attack 1 Average test loss: 2.2075, Test accuracy: 1362/10000 (13.62%)
#
# honest 10 Average test loss: 2.1215, Test accuracy: 5409/10000 (54.09%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 91.0
# Two        - 25.6
# Three      - 59.4
# Four       - 41.9
# Five       - 1.5
# Six        - 30.6
# Seven      - 89.0
# Eight      - 77.4
# Nine       - 38.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.061204
#
# 10selected Peers:
# Peer 15 is  honest reputation: 0.04297894239425659
# Peer 17 is  honest reputation: 0.06976193189620972
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 6 is  honest reputation: 0.033529818058013916
# Peer 4 is  honest reputation: 0.07242131233215332
# Peer 13 is  honest reputation: 0.050585389137268066
# Peer 9 is  honest reputation: 0.052496492862701416
# Peer 18 is  honest reputation: 0.0349200963973999
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 5 is  honest reputation: 0.09161287546157837
# Peer 3 is  honest reputation: 0.02352052927017212
# Peer 14 is  honest reputation: 0.023146331310272217
# Peer 7 is  honest reputation: 0.03975433111190796
# Peer 0 is  honest reputation: 0.0399898886680603
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 8 is  honest reputation: 0.02785670757293701
# Peer 16 is  honest reputation: 0.0765799880027771
# Peer 12 is  honest reputation: 0.03175085783004761
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.0399898886680603
# Peer 3 is  honest reputation: 0.02352052927017212
# Peer 4 is  honest reputation: 0.07242131233215332
# Peer 5 is  honest reputation: 0.09161287546157837
# Peer 6 is  honest reputation: 0.033529818058013916
# Peer 7 is  honest reputation: 0.03975433111190796
# Peer 8 is  honest reputation: 0.02785670757293701
# Peer 9 is  honest reputation: 0.052496492862701416
# Peer 12 is  honest reputation: 0.03175085783004761
# Peer 13 is  honest reputation: 0.050585389137268066
# Peer 14 is  honest reputation: 0.023146331310272217
# Peer 15 is  honest reputation: 0.04297894239425659
# Peer 16 is  honest reputation: 0.0765799880027771
# Peer 17 is  honest reputation: 0.06976193189620972
# Peer 18 is  honest reputation: 0.0349200963973999
# attack 1 Average test loss: 1.9802, Test accuracy: 4898/10000 (48.98%)
#
# honest 10 Average test loss: 1.7033, Test accuracy: 6552/10000 (65.52%)
#
# Class      - Accuracy
# Zero       - 94.3
# One        - 97.0
# Two        - 38.7
# Three      - 75.5
# Four       - 73.0
# Five       - 7.6
# Six        - 78.2
# Seven      - 87.8
# Eight      - 71.5
# Nine       - 28.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 1.701177
#
# 10selected Peers:
# Peer 13 is  honest reputation: 0.046118974685668945
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 3 is  honest reputation: 0.042638957500457764
# Peer 4 is  honest reputation: 0.11426788568496704
# Peer 7 is  honest reputation: 0.0585019588470459
# Peer 18 is  honest reputation: 0.05678510665893555
# Peer 9 is  honest reputation: 0.048625826835632324
# Peer 5 is  honest reputation: 0.10954737663269043
# Peer 0 is  honest reputation: 0.03139883279800415
# Peer 14 is  honest reputation: 0.0330386757850647
# Peer 6 is  honest reputation: 0.05551445484161377
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 17 is  honest reputation: 0.12756353616714478
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 15 is  honest reputation: 0.07280212640762329
# Peer 12 is  honest reputation: 0.0399433970451355
# Peer 16 is  honest reputation: 0.10908365249633789
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 8 is  honest reputation: 0.029146909713745117
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.03139883279800415
# Peer 3 is  honest reputation: 0.042638957500457764
# Peer 4 is  honest reputation: 0.11426788568496704
# Peer 5 is  honest reputation: 0.10954737663269043
# Peer 6 is  honest reputation: 0.05551445484161377
# Peer 7 is  honest reputation: 0.0585019588470459
# Peer 8 is  honest reputation: 0.029146909713745117
# Peer 9 is  honest reputation: 0.048625826835632324
# Peer 12 is  honest reputation: 0.0399433970451355
# Peer 13 is  honest reputation: 0.046118974685668945
# Peer 14 is  honest reputation: 0.0330386757850647
# Peer 15 is  honest reputation: 0.07280212640762329
# Peer 16 is  honest reputation: 0.10908365249633789
# Peer 17 is  honest reputation: 0.12756353616714478
# Peer 18 is  honest reputation: 0.05678510665893555
# attack 1 Average test loss: 1.5791, Test accuracy: 6519/10000 (65.19%)
#
# honest 10 Average test loss: 1.0866, Test accuracy: 7863/10000 (78.63%)
#
# Class      - Accuracy
# Zero       - 95.3
# One        - 94.2
# Two        - 78.2
# Three      - 84.4
# Four       - 85.9
# Five       - 53.6
# Six        - 81.2
# Seven      - 88.7
# Eight      - 57.9
# Nine       - 52.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 1.336258
#
# 10selected Peers:
# Peer 7 is  honest reputation: 0.06926900148391724
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 16 is  honest reputation: 0.1448257565498352
# Peer 15 is  honest reputation: 0.09523093700408936
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 3 is  honest reputation: 0.046453654766082764
# Peer 6 is  honest reputation: 0.06854158639907837
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 12 is  honest reputation: 0.04062855243682861
# Peer 8 is  honest reputation: 0.072776198387146
# Peer 0 is  honest reputation: 0.02934330701828003
# Peer 18 is  honest reputation: 0.03539884090423584
# Peer 5 is  honest reputation: 0.12639111280441284
# Peer 14 is  honest reputation: 0.04671275615692139
# Peer 9 is  honest reputation: 0.07761532068252563
# Peer 4 is  honest reputation: 0.11684709787368774
# Peer 17 is  honest reputation: 0.11768192052841187
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 13 is  honest reputation: 0.06212574243545532
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.02934330701828003
# Peer 3 is  honest reputation: 0.046453654766082764
# Peer 4 is  honest reputation: 0.11684709787368774
# Peer 5 is  honest reputation: 0.12639111280441284
# Peer 6 is  honest reputation: 0.06854158639907837
# Peer 7 is  honest reputation: 0.06926900148391724
# Peer 8 is  honest reputation: 0.072776198387146
# Peer 9 is  honest reputation: 0.07761532068252563
# Peer 12 is  honest reputation: 0.04062855243682861
# Peer 13 is  honest reputation: 0.06212574243545532
# Peer 14 is  honest reputation: 0.04671275615692139
# Peer 15 is  honest reputation: 0.09523093700408936
# Peer 16 is  honest reputation: 0.1448257565498352
# Peer 17 is  honest reputation: 0.11768192052841187
# Peer 18 is  honest reputation: 0.03539884090423584
# attack 1 Average test loss: 1.1901, Test accuracy: 7208/10000 (72.08%)
#
# honest 10 Average test loss: 0.7576, Test accuracy: 8303/10000 (83.03%)
#
# Class      - Accuracy
# Zero       - 96.1
# One        - 95.6
# Two        - 86.1
# Three      - 86.3
# Four       - 78.9
# Five       - 67.0
# Six        - 88.5
# Seven      - 87.1
# Eight      - 73.3
# Nine       - 74.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 1.100174
#
# 10selected Peers:
# Peer 0 is  honest reputation: 0.018196821212768555
# Peer 16 is  honest reputation: 0.1651310920715332
# Peer 7 is  honest reputation: 0.07104897499084473
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 9 is  honest reputation: 0.07580459117889404
# Peer 4 is  honest reputation: 0.1491371989250183
# Peer 6 is  honest reputation: 0.07610559463500977
# Peer 17 is  honest reputation: 0.11828547716140747
# Peer 18 is  honest reputation: 0.056977808475494385
# Peer 8 is  honest reputation: 0.08654874563217163
# Peer 3 is  honest reputation: 0.06414425373077393
# Peer 12 is  honest reputation: 0.04852670431137085
# Peer 15 is  honest reputation: 0.11284679174423218
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 14 is  honest reputation: 0.03856015205383301
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 13 is  honest reputation: 0.07290005683898926
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 5 is  honest reputation: 0.14667880535125732
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.018196821212768555
# Peer 3 is  honest reputation: 0.06414425373077393
# Peer 4 is  honest reputation: 0.1491371989250183
# Peer 5 is  honest reputation: 0.14667880535125732
# Peer 6 is  honest reputation: 0.07610559463500977
# Peer 7 is  honest reputation: 0.07104897499084473
# Peer 8 is  honest reputation: 0.08654874563217163
# Peer 9 is  honest reputation: 0.07580459117889404
# Peer 12 is  honest reputation: 0.04852670431137085
# Peer 13 is  honest reputation: 0.07290005683898926
# Peer 14 is  honest reputation: 0.03856015205383301
# Peer 15 is  honest reputation: 0.11284679174423218
# Peer 16 is  honest reputation: 0.1651310920715332
# Peer 17 is  honest reputation: 0.11828547716140747
# Peer 18 is  honest reputation: 0.056977808475494385
# attack 1 Average test loss: 1.1129, Test accuracy: 7516/10000 (75.16%)
#
# honest 10 Average test loss: 0.5811, Test accuracy: 8515/10000 (85.15%)
#
# Class      - Accuracy
# Zero       - 97.0
# One        - 97.1
# Two        - 88.9
# Three      - 86.1
# Four       - 86.9
# Five       - 82.2
# Six        - 93.0
# Seven      - 90.0
# Eight      - 65.2
# Nine       - 71.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.946443
#
# 10selected Peers:
# Peer 5 is  honest reputation: 0.14838415384292603
# Peer 4 is  honest reputation: 0.13269776105880737
# Peer 8 is  honest reputation: 0.0870356559753418
# Peer 7 is  honest reputation: 0.08562928438186646
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 13 is  honest reputation: 0.08829718828201294
# Peer 15 is  honest reputation: 0.11138606071472168
# Peer 12 is  honest reputation: 0.06348121166229248
# Peer 6 is  honest reputation: 0.10129386186599731
# Peer 14 is  honest reputation: 0.0455247163772583
# Peer 17 is  honest reputation: 0.10919642448425293
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 0 is  honest reputation: 0.029445230960845947
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 18 is  honest reputation: 0.06549501419067383
# Peer 9 is  honest reputation: 0.08011174201965332
# Peer 16 is  honest reputation: 0.18174171447753906
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 3 is  honest reputation: 0.0804746150970459
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.029445230960845947
# Peer 3 is  honest reputation: 0.0804746150970459
# Peer 4 is  honest reputation: 0.13269776105880737
# Peer 5 is  honest reputation: 0.14838415384292603
# Peer 6 is  honest reputation: 0.10129386186599731
# Peer 7 is  honest reputation: 0.08562928438186646
# Peer 8 is  honest reputation: 0.0870356559753418
# Peer 9 is  honest reputation: 0.08011174201965332
# Peer 12 is  honest reputation: 0.06348121166229248
# Peer 13 is  honest reputation: 0.08829718828201294
# Peer 14 is  honest reputation: 0.0455247163772583
# Peer 15 is  honest reputation: 0.11138606071472168
# Peer 16 is  honest reputation: 0.18174171447753906
# Peer 17 is  honest reputation: 0.10919642448425293
# Peer 18 is  honest reputation: 0.06549501419067383
# attack 1 Average test loss: 1.0400, Test accuracy: 7697/10000 (76.97%)
#
# honest 10 Average test loss: 0.4685, Test accuracy: 8865/10000 (88.65%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 97.7
# Two        - 86.8
# Three      - 91.2
# Four       - 87.1
# Five       - 83.1
# Six        - 89.0
# Seven      - 89.5
# Eight      - 77.2
# Nine       - 80.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.848700
#
# 10selected Peers:
# Peer 12 is  honest reputation: 0.07078325748443604
# Peer 9 is  honest reputation: 0.08230990171432495
# Peer 16 is  honest reputation: 0.18823301792144775
# Peer 3 is  honest reputation: 0.07097393274307251
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 15 is  honest reputation: 0.13265782594680786
# Peer 8 is  honest reputation: 0.09495991468429565
# Peer 6 is  honest reputation: 0.10405552387237549
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 0 is  honest reputation: 0.035994648933410645
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 17 is  honest reputation: 0.11796247959136963
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 14 is  honest reputation: 0.04041785001754761
# Peer 5 is  honest reputation: 0.14431631565093994
# Peer 13 is  honest reputation: 0.09676104784011841
# Peer 4 is  honest reputation: 0.13565629720687866
# Peer 7 is  honest reputation: 0.09445565938949585
# Peer 18 is  honest reputation: 0.06685096025466919
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.035994648933410645
# Peer 3 is  honest reputation: 0.07097393274307251
# Peer 4 is  honest reputation: 0.13565629720687866
# Peer 5 is  honest reputation: 0.14431631565093994
# Peer 6 is  honest reputation: 0.10405552387237549
# Peer 7 is  honest reputation: 0.09445565938949585
# Peer 8 is  honest reputation: 0.09495991468429565
# Peer 9 is  honest reputation: 0.08230990171432495
# Peer 12 is  honest reputation: 0.07078325748443604
# Peer 13 is  honest reputation: 0.09676104784011841
# Peer 14 is  honest reputation: 0.04041785001754761
# Peer 15 is  honest reputation: 0.13265782594680786
# Peer 16 is  honest reputation: 0.18823301792144775
# Peer 17 is  honest reputation: 0.11796247959136963
# Peer 18 is  honest reputation: 0.06685096025466919
# attack 1 Average test loss: 0.9694, Test accuracy: 7902/10000 (79.02%)
#
# honest 10 Average test loss: 0.4344, Test accuracy: 8890/10000 (88.90%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.4
# Two        - 89.1
# Three      - 87.8
# Four       - 88.1
# Five       - 84.9
# Six        - 92.5
# Seven      - 88.0
# Eight      - 76.5
# Nine       - 83.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.780482
#
# 10selected Peers:
# Peer 0 is  honest reputation: 0.036272287368774414
# Peer 15 is  honest reputation: 0.14462977647781372
# Peer 3 is  honest reputation: 0.07985532283782959
# Peer 13 is  honest reputation: 0.09949344396591187
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 12 is  honest reputation: 0.09449011087417603
# Peer 18 is  honest reputation: 0.08724355697631836
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 5 is  honest reputation: 0.14936161041259766
# Peer 4 is  honest reputation: 0.1558595895767212
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 7 is  honest reputation: 0.10397696495056152
# Peer 6 is  honest reputation: 0.11186909675598145
# Peer 14 is  honest reputation: 0.054950058460235596
# Peer 16 is  honest reputation: 0.187400221824646
# Peer 8 is  honest reputation: 0.0656842589378357
# Peer 9 is  honest reputation: 0.06944698095321655
# Peer 17 is  honest reputation: 0.14401143789291382
# Peer 1 is  attacker reputation: -0.05911201238632202
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.036272287368774414
# Peer 3 is  honest reputation: 0.07985532283782959
# Peer 4 is  honest reputation: 0.1558595895767212
# Peer 5 is  honest reputation: 0.14936161041259766
# Peer 6 is  honest reputation: 0.11186909675598145
# Peer 7 is  honest reputation: 0.10397696495056152
# Peer 8 is  honest reputation: 0.0656842589378357
# Peer 9 is  honest reputation: 0.06944698095321655
# Peer 12 is  honest reputation: 0.09449011087417603
# Peer 13 is  honest reputation: 0.09949344396591187
# Peer 14 is  honest reputation: 0.054950058460235596
# Peer 15 is  honest reputation: 0.14462977647781372
# Peer 16 is  honest reputation: 0.187400221824646
# Peer 17 is  honest reputation: 0.14401143789291382
# Peer 18 is  honest reputation: 0.08724355697631836
# attack 1 Average test loss: 0.9270, Test accuracy: 7919/10000 (79.19%)
#
# honest 10 Average test loss: 0.3832, Test accuracy: 9016/10000 (90.16%)
#
# Class      - Accuracy
# Zero       - 95.3
# One        - 97.7
# Two        - 92.4
# Three      - 87.5
# Four       - 88.6
# Five       - 87.8
# Six        - 95.1
# Seven      - 88.3
# Eight      - 83.8
# Nine       - 83.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.727067
#
# 10selected Peers:
# Peer 13 is  honest reputation: 0.12254410982131958
# Peer 0 is  honest reputation: 0.03181719779968262
# Peer 18 is  honest reputation: 0.07724153995513916
# Peer 16 is  honest reputation: 0.23189246654510498
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 3 is  honest reputation: 0.09690189361572266
# Peer 9 is  honest reputation: 0.08925151824951172
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 17 is  honest reputation: 0.18566393852233887
# Peer 12 is  honest reputation: 0.12444460391998291
# Peer 14 is  honest reputation: 0.0533638596534729
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 6 is  honest reputation: 0.1487157940864563
# Peer 4 is  honest reputation: 0.16823720932006836
# Peer 7 is  honest reputation: 0.12464594841003418
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 15 is  honest reputation: 0.19130867719650269
# Peer 8 is  honest reputation: 0.06621295213699341
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 5 is  honest reputation: 0.16704165935516357
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.03181719779968262
# Peer 3 is  honest reputation: 0.09690189361572266
# Peer 4 is  honest reputation: 0.16823720932006836
# Peer 5 is  honest reputation: 0.16704165935516357
# Peer 6 is  honest reputation: 0.1487157940864563
# Peer 7 is  honest reputation: 0.12464594841003418
# Peer 8 is  honest reputation: 0.06621295213699341
# Peer 9 is  honest reputation: 0.08925151824951172
# Peer 12 is  honest reputation: 0.12444460391998291
# Peer 13 is  honest reputation: 0.12254410982131958
# Peer 14 is  honest reputation: 0.0533638596534729
# Peer 15 is  honest reputation: 0.19130867719650269
# Peer 16 is  honest reputation: 0.23189246654510498
# Peer 17 is  honest reputation: 0.18566393852233887
# Peer 18 is  honest reputation: 0.07724153995513916
# attack 1 Average test loss: 0.8176, Test accuracy: 8259/10000 (82.59%)
#
# honest 10 Average test loss: 0.3473, Test accuracy: 9080/10000 (90.80%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.5
# Two        - 89.4
# Three      - 91.3
# Four       - 90.3
# Five       - 83.8
# Six        - 93.8
# Seven      - 90.0
# Eight      - 84.0
# Nine       - 85.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.682792
#
# 10selected Peers:
# Peer 4 is  honest reputation: 0.16824477910995483
# Peer 8 is  honest reputation: 0.05911451578140259
# Peer 12 is  honest reputation: 0.1585702896118164
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 3 is  honest reputation: 0.12070751190185547
# Peer 6 is  honest reputation: 0.1544862985610962
# Peer 15 is  honest reputation: 0.20035326480865479
# Peer 13 is  honest reputation: 0.13387221097946167
# Peer 18 is  honest reputation: 0.0989120602607727
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 16 is  honest reputation: 0.2552345395088196
# Peer 9 is  honest reputation: 0.11748230457305908
# Peer 14 is  honest reputation: 0.06838178634643555
# Peer 0 is  honest reputation: 0.038869500160217285
# Peer 17 is  honest reputation: 0.20087939500808716
# Peer 7 is  honest reputation: 0.12462329864501953
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 5 is  honest reputation: 0.16654431819915771
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.038869500160217285
# Peer 3 is  honest reputation: 0.12070751190185547
# Peer 4 is  honest reputation: 0.16824477910995483
# Peer 5 is  honest reputation: 0.16654431819915771
# Peer 6 is  honest reputation: 0.1544862985610962
# Peer 7 is  honest reputation: 0.12462329864501953
# Peer 8 is  honest reputation: 0.05911451578140259
# Peer 9 is  honest reputation: 0.11748230457305908
# Peer 12 is  honest reputation: 0.1585702896118164
# Peer 13 is  honest reputation: 0.13387221097946167
# Peer 14 is  honest reputation: 0.06838178634643555
# Peer 15 is  honest reputation: 0.20035326480865479
# Peer 16 is  honest reputation: 0.2552345395088196
# Peer 17 is  honest reputation: 0.20087939500808716
# Peer 18 is  honest reputation: 0.0989120602607727
# attack 1 Average test loss: 0.8631, Test accuracy: 8250/10000 (82.50%)
#
# honest 10 Average test loss: 0.3098, Test accuracy: 9147/10000 (91.47%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.5
# Two        - 92.1
# Three      - 92.6
# Four       - 91.1
# Five       - 86.7
# Six        - 94.2
# Seven      - 91.7
# Eight      - 87.5
# Nine       - 86.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.645316
#
# 10selected Peers:
# Peer 9 is  honest reputation: 0.13147717714309692
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 16 is  honest reputation: 0.24953442811965942
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 4 is  honest reputation: 0.17917996644973755
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 18 is  honest reputation: 0.09821218252182007
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 17 is  honest reputation: 0.20355898141860962
# Peer 0 is  honest reputation: 0.039102792739868164
# Peer 6 is  honest reputation: 0.15138155221939087
# Peer 8 is  honest reputation: 0.07844549417495728
# Peer 15 is  honest reputation: 0.21823376417160034
# Peer 3 is  honest reputation: 0.14016705751419067
# Peer 5 is  honest reputation: 0.18229693174362183
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 7 is  honest reputation: 0.146759033203125
# Peer 14 is  honest reputation: 0.07916748523712158
# Peer 12 is  honest reputation: 0.1718994379043579
# Peer 13 is  honest reputation: 0.1479828953742981
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.039102792739868164
# Peer 3 is  honest reputation: 0.14016705751419067
# Peer 4 is  honest reputation: 0.17917996644973755
# Peer 5 is  honest reputation: 0.18229693174362183
# Peer 6 is  honest reputation: 0.15138155221939087
# Peer 7 is  honest reputation: 0.146759033203125
# Peer 8 is  honest reputation: 0.07844549417495728
# Peer 9 is  honest reputation: 0.13147717714309692
# Peer 12 is  honest reputation: 0.1718994379043579
# Peer 13 is  honest reputation: 0.1479828953742981
# Peer 14 is  honest reputation: 0.07916748523712158
# Peer 15 is  honest reputation: 0.21823376417160034
# Peer 16 is  honest reputation: 0.24953442811965942
# Peer 17 is  honest reputation: 0.20355898141860962
# Peer 18 is  honest reputation: 0.09821218252182007
# attack 1 Average test loss: 0.7338, Test accuracy: 8384/10000 (83.84%)
#
# honest 10 Average test loss: 0.2874, Test accuracy: 9219/10000 (92.19%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.5
# Two        - 91.9
# Three      - 88.3
# Four       - 92.7
# Five       - 91.0
# Six        - 95.7
# Seven      - 90.9
# Eight      - 84.9
# Nine       - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.616204
#
# 10selected Peers:
# Peer 18 is  honest reputation: 0.10615837574005127
# Peer 9 is  honest reputation: 0.12902629375457764
# Peer 7 is  honest reputation: 0.1487749218940735
# Peer 5 is  honest reputation: 0.18171238899230957
# Peer 14 is  honest reputation: 0.07395559549331665
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 13 is  honest reputation: 0.16100335121154785
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 4 is  honest reputation: 0.183946430683136
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 6 is  honest reputation: 0.1534409523010254
# Peer 3 is  honest reputation: 0.14223402738571167
# Peer 15 is  honest reputation: 0.23925793170928955
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 12 is  honest reputation: 0.17270344495773315
# Peer 17 is  honest reputation: 0.2378171682357788
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 8 is  honest reputation: 0.07864034175872803
# Peer 0 is  honest reputation: 0.0517885684967041
# Peer 16 is  honest reputation: 0.25331658124923706
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.0517885684967041
# Peer 3 is  honest reputation: 0.14223402738571167
# Peer 4 is  honest reputation: 0.183946430683136
# Peer 5 is  honest reputation: 0.18171238899230957
# Peer 6 is  honest reputation: 0.1534409523010254
# Peer 7 is  honest reputation: 0.1487749218940735
# Peer 8 is  honest reputation: 0.07864034175872803
# Peer 9 is  honest reputation: 0.12902629375457764
# Peer 12 is  honest reputation: 0.17270344495773315
# Peer 13 is  honest reputation: 0.16100335121154785
# Peer 14 is  honest reputation: 0.07395559549331665
# Peer 15 is  honest reputation: 0.23925793170928955
# Peer 16 is  honest reputation: 0.25331658124923706
# Peer 17 is  honest reputation: 0.2378171682357788
# Peer 18 is  honest reputation: 0.10615837574005127
# attack 1 Average test loss: 0.7450, Test accuracy: 8277/10000 (82.77%)
#
# honest 10 Average test loss: 0.2713, Test accuracy: 9260/10000 (92.60%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 98.5
# Two        - 90.5
# Three      - 92.5
# Four       - 93.8
# Five       - 91.0
# Six        - 95.0
# Seven      - 91.2
# Eight      - 87.0
# Nine       - 91.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.591775
#
# 10selected Peers:
# Peer 15 is  honest reputation: 0.2373511791229248
# Peer 9 is  honest reputation: 0.12731516361236572
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 18 is  honest reputation: 0.12116134166717529
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 4 is  honest reputation: 0.20302218198776245
# Peer 13 is  honest reputation: 0.1763136386871338
# Peer 12 is  honest reputation: 0.17296713590621948
# Peer 14 is  honest reputation: 0.07737046480178833
# Peer 3 is  honest reputation: 0.17530858516693115
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 7 is  honest reputation: 0.1503428816795349
# Peer 8 is  honest reputation: 0.10680055618286133
# Peer 16 is  honest reputation: 0.27727532386779785
# Peer 0 is  honest reputation: 0.06486731767654419
# Peer 6 is  honest reputation: 0.18359637260437012
# Peer 17 is  honest reputation: 0.24505430459976196
# Peer 5 is  honest reputation: 0.18092143535614014
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 19 is  attacker reputation: -0.0851995050907135
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.06486731767654419
# Peer 3 is  honest reputation: 0.17530858516693115
# Peer 4 is  honest reputation: 0.20302218198776245
# Peer 5 is  honest reputation: 0.18092143535614014
# Peer 6 is  honest reputation: 0.18359637260437012
# Peer 7 is  honest reputation: 0.1503428816795349
# Peer 8 is  honest reputation: 0.10680055618286133
# Peer 9 is  honest reputation: 0.12731516361236572
# Peer 12 is  honest reputation: 0.17296713590621948
# Peer 13 is  honest reputation: 0.1763136386871338
# Peer 14 is  honest reputation: 0.07737046480178833
# Peer 15 is  honest reputation: 0.2373511791229248
# Peer 16 is  honest reputation: 0.27727532386779785
# Peer 17 is  honest reputation: 0.24505430459976196
# Peer 18 is  honest reputation: 0.12116134166717529
# attack 1 Average test loss: 0.7730, Test accuracy: 8268/10000 (82.68%)
#
# honest 10 Average test loss: 0.2625, Test accuracy: 9248/10000 (92.48%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 97.4
# Two        - 88.8
# Three      - 91.1
# Four       - 94.4
# Five       - 91.9
# Six        - 95.3
# Seven      - 93.9
# Eight      - 84.6
# Nine       - 89.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.568305
#
# 10selected Peers:
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 3 is  honest reputation: 0.18048906326293945
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 5 is  honest reputation: 0.19169414043426514
# Peer 7 is  honest reputation: 0.14976274967193604
# Peer 8 is  honest reputation: 0.1288536787033081
# Peer 4 is  honest reputation: 0.23102110624313354
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 18 is  honest reputation: 0.1467565894126892
# Peer 16 is  honest reputation: 0.2943522334098816
# Peer 9 is  honest reputation: 0.12518078088760376
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 14 is  honest reputation: 0.09353816509246826
# Peer 15 is  honest reputation: 0.26130211353302
# Peer 17 is  honest reputation: 0.2793392539024353
# Peer 0 is  honest reputation: 0.06506067514419556
# Peer 6 is  honest reputation: 0.2078542709350586
# Peer 13 is  honest reputation: 0.19309383630752563
# Peer 12 is  honest reputation: 0.16092783212661743
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.06506067514419556
# Peer 3 is  honest reputation: 0.18048906326293945
# Peer 4 is  honest reputation: 0.23102110624313354
# Peer 5 is  honest reputation: 0.19169414043426514
# Peer 6 is  honest reputation: 0.2078542709350586
# Peer 7 is  honest reputation: 0.14976274967193604
# Peer 8 is  honest reputation: 0.1288536787033081
# Peer 9 is  honest reputation: 0.12518078088760376
# Peer 12 is  honest reputation: 0.16092783212661743
# Peer 13 is  honest reputation: 0.19309383630752563
# Peer 14 is  honest reputation: 0.09353816509246826
# Peer 15 is  honest reputation: 0.26130211353302
# Peer 16 is  honest reputation: 0.2943522334098816
# Peer 17 is  honest reputation: 0.2793392539024353
# Peer 18 is  honest reputation: 0.1467565894126892
# attack 1 Average test loss: 0.6223, Test accuracy: 8412/10000 (84.12%)
#
# honest 10 Average test loss: 0.2460, Test accuracy: 9269/10000 (92.69%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.2
# Two        - 92.2
# Three      - 95.2
# Four       - 94.4
# Five       - 90.2
# Six        - 95.6
# Seven      - 91.9
# Eight      - 85.6
# Nine       - 91.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.545253
#
# 10selected Peers:
# Peer 8 is  honest reputation: 0.1161566972732544
# Peer 17 is  honest reputation: 0.27938562631607056
# Peer 13 is  honest reputation: 0.2145957350730896
# Peer 7 is  honest reputation: 0.1957550048828125
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 9 is  honest reputation: 0.11875909566879272
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 3 is  honest reputation: 0.19611728191375732
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 6 is  honest reputation: 0.23413705825805664
# Peer 16 is  honest reputation: 0.30922168493270874
# Peer 4 is  honest reputation: 0.2869148254394531
# Peer 12 is  honest reputation: 0.19377344846725464
# Peer 5 is  honest reputation: 0.21994036436080933
# Peer 15 is  honest reputation: 0.27380770444869995
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 14 is  honest reputation: 0.09788763523101807
# Peer 0 is  honest reputation: 0.06492167711257935
# Peer 18 is  honest reputation: 0.17328506708145142
# Peer 19 is  attacker reputation: -0.0851995050907135
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.06492167711257935
# Peer 3 is  honest reputation: 0.19611728191375732
# Peer 4 is  honest reputation: 0.2869148254394531
# Peer 5 is  honest reputation: 0.21994036436080933
# Peer 6 is  honest reputation: 0.23413705825805664
# Peer 7 is  honest reputation: 0.1957550048828125
# Peer 8 is  honest reputation: 0.1161566972732544
# Peer 9 is  honest reputation: 0.11875909566879272
# Peer 12 is  honest reputation: 0.19377344846725464
# Peer 13 is  honest reputation: 0.2145957350730896
# Peer 14 is  honest reputation: 0.09788763523101807
# Peer 15 is  honest reputation: 0.27380770444869995
# Peer 16 is  honest reputation: 0.30922168493270874
# Peer 17 is  honest reputation: 0.27938562631607056
# Peer 18 is  honest reputation: 0.17328506708145142
# attack 1 Average test loss: 0.7274, Test accuracy: 8374/10000 (83.74%)
#
# honest 10 Average test loss: 0.2318, Test accuracy: 9354/10000 (93.54%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.7
# Two        - 92.9
# Three      - 94.6
# Four       - 94.7
# Five       - 90.1
# Six        - 95.6
# Seven      - 93.8
# Eight      - 84.4
# Nine       - 91.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.520556
#
# 10selected Peers:
# Peer 3 is  honest reputation: 0.20036965608596802
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 18 is  honest reputation: 0.18267548084259033
# Peer 8 is  honest reputation: 0.11146003007888794
# Peer 9 is  honest reputation: 0.1481781005859375
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 14 is  honest reputation: 0.09408259391784668
# Peer 16 is  honest reputation: 0.31988561153411865
# Peer 5 is  honest reputation: 0.22120869159698486
# Peer 7 is  honest reputation: 0.23249012231826782
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 13 is  honest reputation: 0.22158145904541016
# Peer 6 is  honest reputation: 0.2693623900413513
# Peer 15 is  honest reputation: 0.29570335149765015
# Peer 0 is  honest reputation: 0.08420020341873169
# Peer 17 is  honest reputation: 0.29959696531295776
# Peer 12 is  honest reputation: 0.18867266178131104
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 4 is  honest reputation: 0.30040210485458374
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.08420020341873169
# Peer 3 is  honest reputation: 0.20036965608596802
# Peer 4 is  honest reputation: 0.30040210485458374
# Peer 5 is  honest reputation: 0.22120869159698486
# Peer 6 is  honest reputation: 0.2693623900413513
# Peer 7 is  honest reputation: 0.23249012231826782
# Peer 8 is  honest reputation: 0.11146003007888794
# Peer 9 is  honest reputation: 0.1481781005859375
# Peer 12 is  honest reputation: 0.18867266178131104
# Peer 13 is  honest reputation: 0.22158145904541016
# Peer 14 is  honest reputation: 0.09408259391784668
# Peer 15 is  honest reputation: 0.29570335149765015
# Peer 16 is  honest reputation: 0.31988561153411865
# Peer 17 is  honest reputation: 0.29959696531295776
# Peer 18 is  honest reputation: 0.18267548084259033
# attack 1 Average test loss: 0.6745, Test accuracy: 8425/10000 (84.25%)
#
# honest 10 Average test loss: 0.2143, Test accuracy: 9370/10000 (93.70%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.3
# Two        - 91.2
# Three      - 96.3
# Four       - 93.5
# Five       - 89.5
# Six        - 96.4
# Seven      - 91.7
# Eight      - 86.7
# Nine       - 89.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.512360
#
# 10selected Peers:
# Peer 6 is  honest reputation: 0.27717816829681396
# Peer 18 is  honest reputation: 0.1932528018951416
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 17 is  honest reputation: 0.31241172552108765
# Peer 0 is  honest reputation: 0.08465731143951416
# Peer 14 is  honest reputation: 0.10513156652450562
# Peer 12 is  honest reputation: 0.21226036548614502
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 4 is  honest reputation: 0.29818302392959595
# Peer 5 is  honest reputation: 0.21784377098083496
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 16 is  honest reputation: 0.3385707139968872
# Peer 15 is  honest reputation: 0.3209853172302246
# Peer 9 is  honest reputation: 0.16391712427139282
# Peer 13 is  honest reputation: 0.23773294687271118
# Peer 8 is  honest reputation: 0.1237061619758606
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 7 is  honest reputation: 0.2617282271385193
# Peer 3 is  honest reputation: 0.1989983320236206
# Peer 2 is  attacker reputation: -0.09938356280326843
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.08465731143951416
# Peer 3 is  honest reputation: 0.1989983320236206
# Peer 4 is  honest reputation: 0.29818302392959595
# Peer 5 is  honest reputation: 0.21784377098083496
# Peer 6 is  honest reputation: 0.27717816829681396
# Peer 7 is  honest reputation: 0.2617282271385193
# Peer 8 is  honest reputation: 0.1237061619758606
# Peer 9 is  honest reputation: 0.16391712427139282
# Peer 12 is  honest reputation: 0.21226036548614502
# Peer 13 is  honest reputation: 0.23773294687271118
# Peer 14 is  honest reputation: 0.10513156652450562
# Peer 15 is  honest reputation: 0.3209853172302246
# Peer 16 is  honest reputation: 0.3385707139968872
# Peer 17 is  honest reputation: 0.31241172552108765
# Peer 18 is  honest reputation: 0.1932528018951416
# attack 1 Average test loss: 0.6447, Test accuracy: 8498/10000 (84.98%)
#
# honest 10 Average test loss: 0.2344, Test accuracy: 9330/10000 (93.30%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.4
# Two        - 93.5
# Three      - 95.9
# Four       - 94.9
# Five       - 90.0
# Six        - 95.9
# Seven      - 93.1
# Eight      - 89.9
# Nine       - 89.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.497970
#
# 10selected Peers:
# Peer 15 is  honest reputation: 0.34552687406539917
# Peer 0 is  honest reputation: 0.11375880241394043
# Peer 6 is  honest reputation: 0.33951008319854736
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 5 is  honest reputation: 0.2202993631362915
# Peer 17 is  honest reputation: 0.31861448287963867
# Peer 4 is  honest reputation: 0.32144564390182495
# Peer 3 is  honest reputation: 0.2019408941268921
# Peer 13 is  honest reputation: 0.2478693127632141
# Peer 12 is  honest reputation: 0.21896088123321533
# Peer 9 is  honest reputation: 0.1657804250717163
# Peer 16 is  honest reputation: 0.328427255153656
# Peer 7 is  honest reputation: 0.28524452447891235
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 18 is  honest reputation: 0.18919134140014648
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 14 is  honest reputation: 0.10648542642593384
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 8 is  honest reputation: 0.11712950468063354
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.11375880241394043
# Peer 3 is  honest reputation: 0.2019408941268921
# Peer 4 is  honest reputation: 0.32144564390182495
# Peer 5 is  honest reputation: 0.2202993631362915
# Peer 6 is  honest reputation: 0.33951008319854736
# Peer 7 is  honest reputation: 0.28524452447891235
# Peer 8 is  honest reputation: 0.11712950468063354
# Peer 9 is  honest reputation: 0.1657804250717163
# Peer 12 is  honest reputation: 0.21896088123321533
# Peer 13 is  honest reputation: 0.2478693127632141
# Peer 14 is  honest reputation: 0.10648542642593384
# Peer 15 is  honest reputation: 0.34552687406539917
# Peer 16 is  honest reputation: 0.328427255153656
# Peer 17 is  honest reputation: 0.31861448287963867
# Peer 18 is  honest reputation: 0.18919134140014648
# attack 1 Average test loss: 0.6330, Test accuracy: 8529/10000 (85.29%)
#
# honest 10 Average test loss: 0.1985, Test accuracy: 9398/10000 (93.98%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.3
# Two        - 93.5
# Three      - 92.6
# Four       - 94.4
# Five       - 90.4
# Six        - 96.5
# Seven      - 93.1
# Eight      - 89.8
# Nine       - 92.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.483569
#
# 10selected Peers:
# Peer 2 is  attacker reputation: -0.09938356280326843
# Peer 0 is  honest reputation: 0.13442832231521606
# Peer 19 is  attacker reputation: -0.0851995050907135
# Peer 17 is  honest reputation: 0.3471057415008545
# Peer 3 is  honest reputation: 0.24019277095794678
# Peer 4 is  honest reputation: 0.3172603249549866
# Peer 14 is  honest reputation: 0.12077659368515015
# Peer 5 is  honest reputation: 0.20820146799087524
# Peer 18 is  honest reputation: 0.2005237340927124
# Peer 12 is  honest reputation: 0.23109793663024902
# Peer 10 is  honest reputation: -0.12901750206947327
# Peer 9 is  honest reputation: 0.17880094051361084
# Peer 11 is  attacker reputation: -0.09720325469970703
# Peer 7 is  honest reputation: 0.2864050269126892
# Peer 1 is  attacker reputation: -0.05911201238632202
# Peer 6 is  honest reputation: 0.34863990545272827
# Peer 13 is  honest reputation: 0.272988498210907
# Peer 15 is  honest reputation: 0.3487650156021118
# Peer 8 is  honest reputation: 0.1255958080291748
# Peer 16 is  honest reputation: 0.3249458074569702
#
# 10selected Peers after refuse(delete 5):
# Peer 0 is  honest reputation: 0.13442832231521606
# Peer 3 is  honest reputation: 0.24019277095794678
# Peer 4 is  honest reputation: 0.3172603249549866
# Peer 5 is  honest reputation: 0.20820146799087524
# Peer 6 is  honest reputation: 0.34863990545272827
# Peer 7 is  honest reputation: 0.2864050269126892
# Peer 8 is  honest reputation: 0.1255958080291748
# Peer 9 is  honest reputation: 0.17880094051361084
# Peer 12 is  honest reputation: 0.23109793663024902
# Peer 13 is  honest reputation: 0.272988498210907
# Peer 14 is  honest reputation: 0.12077659368515015
# Peer 15 is  honest reputation: 0.3487650156021118
# Peer 16 is  honest reputation: 0.3249458074569702
# Peer 17 is  honest reputation: 0.3471057415008545
# Peer 18 is  honest reputation: 0.2005237340927124
# attack 1 Average test loss: 0.6037, Test accuracy: 8495/10000 (84.95%)
#
# honest 10 Average test loss: 0.2036, Test accuracy: 9374/10000 (93.74%)
#
# Class      - Accuracy
# Zero       - 96.8
# One        - 98.3
# Two        - 91.8
# Three      - 91.4
# Four       - 96.6
# Five       - 92.4
# Six        - 97.0
# Seven      - 92.5
# Eight      - 90.1
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.468536
#
# 10selected Peers:
# ...
# Peer 17 is  honest reputation: 1.1727049350738525
# Peer 18 is  honest reputation: 0.6674269437789917
# attack 1 Average test loss: 1.8772, Test accuracy: 8746/10000 (87.46%)
#
# honest 10 Average test loss: 0.0729, Test accuracy: 9761/10000 (97.61%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 97.2
# Three      - 97.5
# Four       - 98.0
# Five       - 99.1
# Six        - 98.2
# Seven      - 95.3
# Eight      - 94.8
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.219000
#
# 10selected Peers:
# Peer 0 is  honest reputation: 0.691237211227417
# Peer 9 is  honest reputation: 0.7349110841751099
# Peer 15 is  honest reputation: 0.8980726599693298
# Peer 8 is  honest reputation: 0.585602343082428
# Peer 14 is  honest reputation: 1.145117163658142
# Peer 12 is  honest reputation: 1.1598494052886963
# Peer 16 is  honest reputation: 1.3070958852767944
# Peer 17 is  honest reputation: 1.2049809694290161
# Peer 4 is  honest reputation: 1.2777820825576782
# Peer 18 is  honest reputation: 0.6621291041374207
# Peer 7 is  honest reputation: 0.7800930738449097
# Peer 6 is  honest reputation: 1.2988898158073425
# Peer 3 is  honest reputation: 1.4122583866119385
# Peer 13 is  honest reputation: 1.0716371536254883
# Peer 5 is  honest reputation: 0.6996524930000305
#
# 10selected Peers after refuse(delete 4):
# Peer 0 is  honest reputation: 0.691237211227417
# Peer 3 is  honest reputation: 1.4122583866119385
# Peer 4 is  honest reputation: 1.2777820825576782
# Peer 5 is  honest reputation: 0.6996524930000305
# Peer 6 is  honest reputation: 1.2988898158073425
# Peer 7 is  honest reputation: 0.7800930738449097
# Peer 8 is  honest reputation: 0.585602343082428
# Peer 9 is  honest reputation: 0.7349110841751099
# Peer 12 is  honest reputation: 1.1598494052886963
# Peer 13 is  honest reputation: 1.0716371536254883
# Peer 14 is  honest reputation: 1.145117163658142
# Peer 15 is  honest reputation: 0.8980726599693298
# Peer 16 is  honest reputation: 1.3070958852767944
# Peer 17 is  honest reputation: 1.2049809694290161
# Peer 18 is  honest reputation: 0.6621291041374207
# attack 1 Average test loss: 1.9184, Test accuracy: 8711/10000 (87.11%)
#
# honest 10 Average test loss: 0.0725, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 98.0
# Three      - 97.8
# Four       - 98.9
# Five       - 98.8
# Six        - 97.9
# Seven      - 96.3
# Eight      - 96.8
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.222294
#
# 10selected Peers:
# Peer 16 is  honest reputation: 1.3484429717063904
# Peer 18 is  honest reputation: 0.6698645353317261
# Peer 12 is  honest reputation: 1.167063593864441
# Peer 7 is  honest reputation: 0.7377596497535706
# Peer 8 is  honest reputation: 0.6010143756866455
# Peer 13 is  honest reputation: 1.0959815979003906
# Peer 9 is  honest reputation: 0.7686953544616699
# Peer 6 is  honest reputation: 1.3029986023902893
# Peer 14 is  honest reputation: 1.128173589706421
# Peer 0 is  honest reputation: 0.6992005705833435
# Peer 15 is  honest reputation: 0.8857461810112
# Peer 5 is  honest reputation: 0.735539436340332
# Peer 4 is  honest reputation: 1.2895857095718384
# Peer 3 is  honest reputation: 1.4250469207763672
# Peer 17 is  honest reputation: 1.2181616425514221
#
# 10selected Peers after refuse(delete 4):
# Peer 0 is  honest reputation: 0.6992005705833435
# Peer 3 is  honest reputation: 1.4250469207763672
# Peer 4 is  honest reputation: 1.2895857095718384
# Peer 5 is  honest reputation: 0.735539436340332
# Peer 6 is  honest reputation: 1.3029986023902893
# Peer 7 is  honest reputation: 0.7377596497535706
# Peer 8 is  honest reputation: 0.6010143756866455
# Peer 9 is  honest reputation: 0.7686953544616699
# Peer 12 is  honest reputation: 1.167063593864441
# Peer 13 is  honest reputation: 1.0959815979003906
# Peer 14 is  honest reputation: 1.128173589706421
# Peer 15 is  honest reputation: 0.8857461810112
# Peer 16 is  honest reputation: 1.3484429717063904
# Peer 17 is  honest reputation: 1.2181616425514221
# Peer 18 is  honest reputation: 0.6698645353317261
# attack 1 Average test loss: 1.9230, Test accuracy: 8715/10000 (87.15%)
#
# honest 10 Average test loss: 0.0742, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.5
# Two        - 97.0
# Three      - 97.7
# Four       - 98.8
# Five       - 98.8
# Six        - 98.6
# Seven      - 97.2
# Eight      - 96.3
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.217526
#
# 10selected Peers:
# Peer 7 is  honest reputation: 0.7477168440818787
# Peer 3 is  honest reputation: 1.4633712768554688
# Peer 0 is  honest reputation: 0.6946969032287598
# Peer 15 is  honest reputation: 0.8831471800804138
# Peer 8 is  honest reputation: 0.588144838809967
# Peer 16 is  honest reputation: 1.3498883247375488
# Peer 18 is  honest reputation: 0.686487078666687
# Peer 17 is  honest reputation: 1.2334691286087036
# Peer 5 is  honest reputation: 0.7611261010169983
# Peer 6 is  honest reputation: 1.3131722211837769
# Peer 4 is  honest reputation: 1.3295623660087585
# Peer 13 is  honest reputation: 1.1039989590644836
# Peer 12 is  honest reputation: 1.1894860863685608
# Peer 9 is  honest reputation: 0.7888583540916443
# Peer 14 is  honest reputation: 1.1290399432182312
#
# 10selected Peers after refuse(delete 4):
# Peer 0 is  honest reputation: 0.6946969032287598
# Peer 3 is  honest reputation: 1.4633712768554688
# Peer 4 is  honest reputation: 1.3295623660087585
# Peer 5 is  honest reputation: 0.7611261010169983
# Peer 6 is  honest reputation: 1.3131722211837769
# Peer 7 is  honest reputation: 0.7477168440818787
# Peer 8 is  honest reputation: 0.588144838809967
# Peer 9 is  honest reputation: 0.7888583540916443
# Peer 12 is  honest reputation: 1.1894860863685608
# Peer 13 is  honest reputation: 1.1039989590644836
# Peer 14 is  honest reputation: 1.1290399432182312
# Peer 15 is  honest reputation: 0.8831471800804138
# Peer 16 is  honest reputation: 1.3498883247375488
# Peer 17 is  honest reputation: 1.2334691286087036
# Peer 18 is  honest reputation: 0.686487078666687
# attack 1 Average test loss: 1.7412, Test accuracy: 8848/10000 (88.48%)
#
# honest 10 Average test loss: 0.0736, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.3
# Two        - 96.6
# Three      - 98.5
# Four       - 97.5
# Five       - 98.0
# Six        - 98.8
# Seven      - 96.0
# Eight      - 98.3
# Nine       - 97.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.219798
#
# 10selected Peers:
# Peer 7 is  honest reputation: 0.7627612948417664
# Peer 18 is  honest reputation: 0.6878257393836975
# Peer 0 is  honest reputation: 0.7177541851997375
# Peer 8 is  honest reputation: 0.5873803496360779
# Peer 5 is  honest reputation: 0.7467210292816162
# Peer 16 is  honest reputation: 1.3440819382667542
# Peer 6 is  honest reputation: 1.3239308595657349
# Peer 15 is  honest reputation: 0.8912734985351562
# Peer 3 is  honest reputation: 1.4961495995521545
# Peer 13 is  honest reputation: 1.1112467050552368
# Peer 12 is  honest reputation: 1.2087056040763855
# Peer 17 is  honest reputation: 1.2337239384651184
# Peer 4 is  honest reputation: 1.3600096702575684
# Peer 14 is  honest reputation: 1.169417679309845
# Peer 9 is  honest reputation: 0.7918370962142944
#
# 10selected Peers after refuse(delete 4):
# Peer 0 is  honest reputation: 0.7177541851997375
# Peer 3 is  honest reputation: 1.4961495995521545
# Peer 4 is  honest reputation: 1.3600096702575684
# Peer 5 is  honest reputation: 0.7467210292816162
# Peer 6 is  honest reputation: 1.3239308595657349
# Peer 7 is  honest reputation: 0.7627612948417664
# Peer 8 is  honest reputation: 0.5873803496360779
# Peer 9 is  honest reputation: 0.7918370962142944
# Peer 12 is  honest reputation: 1.2087056040763855
# Peer 13 is  honest reputation: 1.1112467050552368
# Peer 14 is  honest reputation: 1.169417679309845
# Peer 15 is  honest reputation: 0.8912734985351562
# Peer 16 is  honest reputation: 1.3440819382667542
# Peer 17 is  honest reputation: 1.2337239384651184
# Peer 18 is  honest reputation: 0.6878257393836975
# attack 1 Average test loss: 1.7677, Test accuracy: 8790/10000 (87.90%)
#
# honest 10 Average test loss: 0.0774, Test accuracy: 9752/10000 (97.52%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.1
# Two        - 97.3
# Three      - 97.3
# Four       - 98.0
# Five       - 99.1
# Six        - 97.1
# Seven      - 96.2
# Eight      - 97.6
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.215972
#
# 10selected Peers:
# Peer 7 is  honest reputation: 0.7696044445037842
# Peer 14 is  honest reputation: 1.1727271676063538
# Peer 4 is  honest reputation: 1.3777689337730408
# Peer 3 is  honest reputation: 1.508628487586975
# Peer 18 is  honest reputation: 0.6967087388038635
# Peer 15 is  honest reputation: 0.9089135527610779
# Peer 13 is  honest reputation: 1.1190231442451477
# Peer 17 is  honest reputation: 1.238840103149414
# Peer 9 is  honest reputation: 0.8142468333244324
# Peer 6 is  honest reputation: 1.3690628409385681
# Peer 12 is  honest reputation: 1.2262613773345947
# Peer 16 is  honest reputation: 1.3422572016716003
# Peer 8 is  honest reputation: 0.5789926052093506
# Peer 0 is  honest reputation: 0.7183624505996704
# Peer 5 is  honest reputation: 0.7418322563171387
#
# 10selected Peers after refuse(delete 4):
# Peer 0 is  honest reputation: 0.7183624505996704
# Peer 3 is  honest reputation: 1.508628487586975
# Peer 4 is  honest reputation: 1.3777689337730408
# Peer 5 is  honest reputation: 0.7418322563171387
# Peer 6 is  honest reputation: 1.3690628409385681
# Peer 7 is  honest reputation: 0.7696044445037842
# Peer 8 is  honest reputation: 0.5789926052093506
# Peer 9 is  honest reputation: 0.8142468333244324
# Peer 12 is  honest reputation: 1.2262613773345947
# Peer 13 is  honest reputation: 1.1190231442451477
# Peer 14 is  honest reputation: 1.1727271676063538
# Peer 15 is  honest reputation: 0.9089135527610779
# Peer 16 is  honest reputation: 1.3422572016716003
# Peer 17 is  honest reputation: 1.238840103149414
# Peer 18 is  honest reputation: 0.6967087388038635
# attack 1 Average test loss: 1.7844, Test accuracy: 8819/10000 (88.19%)
#
# honest 10 Average test loss: 0.0822, Test accuracy: 9736/10000 (97.36%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.9
# Three      - 97.4
# Four       - 96.5
# Five       - 98.5
# Six        - 97.8
# Seven      - 96.6
# Eight      - 96.7
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.217734
#
# 10selected Peers:
# Peer 6 is  honest reputation: 1.3795128464698792
# Peer 14 is  honest reputation: 1.16614431142807
# Peer 12 is  honest reputation: 1.235440194606781
# Peer 5 is  honest reputation: 0.7594072222709656
# Peer 15 is  honest reputation: 0.91020667552948
# Peer 0 is  honest reputation: 0.7232088446617126
# Peer 4 is  honest reputation: 1.388890564441681
# Peer 9 is  honest reputation: 0.8122615218162537
# Peer 18 is  honest reputation: 0.7060043811798096
# Peer 3 is  honest reputation: 1.5404826998710632
# Peer 17 is  honest reputation: 1.2741700410842896
# Peer 16 is  honest reputation: 1.3587157130241394
# Peer 7 is  honest reputation: 0.767981231212616
# Peer 8 is  honest reputation: 0.5795336961746216
# Peer 13 is  honest reputation: 1.1198261976242065
#
# 10selected Peers after refuse(delete 4):
# Peer 0 is  honest reputation: 0.7232088446617126
# Peer 3 is  honest reputation: 1.5404826998710632
# Peer 4 is  honest reputation: 1.388890564441681
# Peer 5 is  honest reputation: 0.7594072222709656
# Peer 6 is  honest reputation: 1.3795128464698792
# Peer 7 is  honest reputation: 0.767981231212616
# Peer 8 is  honest reputation: 0.5795336961746216
# Peer 9 is  honest reputation: 0.8122615218162537
# Peer 12 is  honest reputation: 1.235440194606781
# Peer 13 is  honest reputation: 1.1198261976242065
# Peer 14 is  honest reputation: 1.16614431142807
# Peer 15 is  honest reputation: 0.91020667552948
# Peer 16 is  honest reputation: 1.3587157130241394
# Peer 17 is  honest reputation: 1.2741700410842896
# Peer 18 is  honest reputation: 0.7060043811798096
# attack 1 Average test loss: 1.8693, Test accuracy: 8786/10000 (87.86%)
#
# honest 10 Average test loss: 0.0704, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.6
# Two        - 98.5
# Three      - 97.9
# Four       - 98.0
# Five       - 98.2
# Six        - 98.9
# Seven      - 95.4
# Eight      - 97.8
# Nine       - 96.8
#
# Backdoor ASR 0.0
# Last 10 updates results
# honest 10 Average test loss: 0.0717, Test accuracy: 9775/10000 (97.75%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.8
# Three      - 96.5
# Four       - 97.9
# Five       - 99.0
# Six        - 98.5
# Seven      - 97.2
# Eight      - 96.6
# Nine       - 96.1
# Global accuracies:  [31.94, 54.09, 65.52, 78.63, 83.03, 85.15, 88.65, 88.9, 90.16, 90.8, 91.47, 92.19, 92.6, 92.48, 92.69, 93.54, 93.7, 93.3, 93.98, 93.74, 94.6, 94.54, 94.76, 94.61, 95.12, 95.21, 95.59, 95.05, 95.29, 95.59, 95.75, 96.01, 95.88, 96.17, 96.32, 96.33, 96.38, 96.01, 96.14, 96.58, 96.44, 96.49, 96.86, 96.58, 96.55, 96.82, 96.69, 96.64, 96.73, 96.62, 96.95, 97.06, 97.06, 97.33, 97.1, 97.07, 97.1, 97.34, 97.01, 97.38, 97.31, 97.27, 97.3, 97.54, 97.28, 97.29, 97.82, 97.23, 97.17, 97.27, 97.29, 97.32, 97.24, 97.56, 97.35, 97.88, 97.48, 97.52, 97.51, 97.35, 98.07, 97.56, 97.84, 97.53, 97.55, 97.57, 97.51, 97.78, 97.66, 97.63, 97.85, 97.35, 97.63, 97.61, 97.75, 97.8, 97.68, 97.52, 97.36, 97.68, 97.75]
# Class 7 accuracies:  [53.89, 89.01, 87.76, 88.66, 87.08, 89.99, 89.53, 88.02, 88.29, 90.03, 91.72, 90.94, 91.19, 93.94, 91.91, 93.77, 91.71, 93.09, 93.09, 92.52, 92.86, 93.72, 94.44, 94.49, 92.91, 92.54, 92.92, 94.53, 95.25, 93.38, 91.94, 94.14, 93.2, 93.4, 93.16, 93.83, 94.52, 93.99, 96.4, 93.42, 92.59, 95.44, 95.99, 94.46, 95.76, 94.76, 95.08, 94.65, 94.77, 94.01, 96.72, 96.08, 95.25, 96.69, 95.51, 97.07, 95.98, 95.01, 94.43, 95.44, 95.6, 95.9, 96.1, 96.92, 94.37, 96.37, 95.63, 95.57, 95.38, 94.44, 97.27, 95.67, 96.89, 97.25, 95.61, 96.58, 97.23, 96.06, 97.04, 97.73, 95.59, 95.9, 95.81, 96.84, 96.58, 97.23, 95.87, 96.78, 97.46, 96.54, 96.32, 96.44, 97.27, 95.34, 96.29, 97.16, 95.96, 96.23, 96.6, 95.39, 97.22]
# Test loss: [2.2474, 2.1215, 1.7033, 1.0866, 0.7576, 0.5811, 0.4685, 0.4344, 0.3832, 0.3473, 0.3098, 0.2874, 0.2713, 0.2625, 0.246, 0.2318, 0.2143, 0.2344, 0.1985, 0.2036, 0.1915, 0.1867, 0.1727, 0.1817, 0.1679, 0.1587, 0.1524, 0.1579, 0.1503, 0.1489, 0.1394, 0.1383, 0.1374, 0.1298, 0.1305, 0.121, 0.1226, 0.126, 0.1246, 0.1125, 0.1108, 0.1199, 0.1107, 0.1098, 0.115, 0.1031, 0.1071, 0.1053, 0.1062, 0.1119, 0.101, 0.098, 0.0993, 0.0949, 0.1022, 0.098, 0.0982, 0.0911, 0.096, 0.0894, 0.0915, 0.0901, 0.0904, 0.0846, 0.0901, 0.0907, 0.0769, 0.0853, 0.0936, 0.0858, 0.0831, 0.0928, 0.0901, 0.0806, 0.0819, 0.0734, 0.0839, 0.0798, 0.0841, 0.0887, 0.0691, 0.0791, 0.0755, 0.0773, 0.08, 0.0762, 0.0752, 0.0751, 0.0726, 0.0757, 0.0692, 0.076, 0.0741, 0.0729, 0.0725, 0.0742, 0.0736, 0.0774, 0.0822, 0.0704, 0.0717]
# Label-flipping attack succes rate: 0.19
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: nan
# honest!
# E:\anaconda\envs\fragments\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# E:\anaconda\envs\fragments\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# attacker!
# --> End of Experiment.

# %%
RULE = 'fdfl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = 'EXTREME_NON_IID', num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: EXTREME_NON_IID
# Aggregation rule: fdfl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s2
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 2.088349
#
# 4selected Peers:
# Peer 19 is  honest reputation: 0.0
# Peer 5 is  honest reputation: 0.0
# Peer 4 is  honest reputation: 10.0
# Peer 6 is  honest reputation: 0.0
# Peer 15 is  honest reputation: 0.0
# Peer 13 is  honest reputation: 0.0
# Peer 1 is  attacker reputation: 0.0
# Peer 17 is  honest reputation: 0.0
# Peer 11 is  honest reputation: 0.0
# Peer 8 is  honest reputation: 0.0
# Peer 9 is  honest reputation: 0.0
# Peer 3 is  attacker reputation: 0.0
# Peer 0 is  attacker reputation: 0.0
# Peer 2 is  attacker reputation: 0.0
# Peer 18 is  honest reputation: 0.0
# Peer 12 is  honest reputation: 0.0
# Peer 7 is  honest reputation: 0.0
# Peer 16 is  honest reputation: 0.0
# Peer 10 is  honest reputation: 0.0
# Peer 14 is  honest reputation: 0.0
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.0
# Peer 1 is  attacker reputation: 0.0
# Peer 2 is  attacker reputation: 0.0
# Peer 3 is  attacker reputation: 0.0
# Peer 5 is  honest reputation: 0.0
# Peer 6 is  honest reputation: 0.0
# Peer 7 is  honest reputation: 0.0
# Peer 8 is  honest reputation: 0.0
# Peer 9 is  honest reputation: 0.0
# Peer 10 is  honest reputation: 0.0
# Peer 11 is  honest reputation: 0.0
# Peer 12 is  honest reputation: 0.0
# Peer 13 is  honest reputation: 0.0
# Peer 14 is  honest reputation: 0.0
# Peer 15 is  honest reputation: 0.0
# Peer 16 is  honest reputation: 0.0
# Peer 17 is  honest reputation: 0.0
# Peer 18 is  honest reputation: 0.0
# Peer 19 is  honest reputation: 0.0
# 4 Aggregation took 0.0496
# attack 0 Average test loss: 2.8890, Test accuracy: 1010/10000 (10.10%)
#
# honest 4 Average test loss: 2.4939, Test accuracy: 1422/10000 (14.22%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 0.0
# Three      - 0.0
# Four       - 0.0
# Five       - 0.0
# Six        - 42.8
# Seven      - 0.0
# Eight      - 95.1
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 1.584800
#
# 4selected Peers:
# Peer 10 is  honest reputation: 0.006481945514678955
# Peer 17 is  honest reputation: 0.03778749704360962
# Peer 11 is  honest reputation: 0.013989567756652832
# Peer 6 is  honest reputation: 0.05629831552505493
# Peer 16 is  honest reputation: -0.0009002089500427246
# Peer 2 is  attacker reputation: -0.009720981121063232
# Peer 14 is  honest reputation: 0.008944869041442871
# Peer 19 is  honest reputation: 0.042950570583343506
# Peer 9 is  honest reputation: 0.0003000497817993164
# Peer 12 is  honest reputation: 0.054037630558013916
# Peer 7 is  honest reputation: 0.020657777786254883
# Peer 3 is  attacker reputation: 0.013069093227386475
# Peer 4 is  honest reputation: 10.0
# Peer 0 is  attacker reputation: 0.0012413859367370605
# Peer 18 is  honest reputation: 0.03521674871444702
# Peer 13 is  honest reputation: 0.013902068138122559
# Peer 1 is  attacker reputation: 0.04955810308456421
# Peer 8 is  honest reputation: -0.024234294891357422
# Peer 5 is  honest reputation: -0.01209712028503418
# Peer 15 is  honest reputation: 0.03801232576370239
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.0012413859367370605
# Peer 1 is  attacker reputation: 0.04955810308456421
# Peer 2 is  attacker reputation: -0.009720981121063232
# Peer 3 is  attacker reputation: 0.013069093227386475
# Peer 5 is  honest reputation: -0.01209712028503418
# Peer 6 is  honest reputation: 0.05629831552505493
# Peer 7 is  honest reputation: 0.020657777786254883
# Peer 8 is  honest reputation: -0.024234294891357422
# Peer 9 is  honest reputation: 0.0003000497817993164
# Peer 10 is  honest reputation: 0.006481945514678955
# Peer 11 is  honest reputation: 0.013989567756652832
# Peer 12 is  honest reputation: 0.054037630558013916
# Peer 13 is  honest reputation: 0.013902068138122559
# Peer 14 is  honest reputation: 0.008944869041442871
# Peer 15 is  honest reputation: 0.03801232576370239
# Peer 16 is  honest reputation: -0.0009002089500427246
# Peer 17 is  honest reputation: 0.03778749704360962
# Peer 18 is  honest reputation: 0.03521674871444702
# Peer 19 is  honest reputation: 0.042950570583343506
# 4 Aggregation took 0.0433
# attack 0 Average test loss: 4.4826, Test accuracy: 1709/10000 (17.09%)
#
# honest 4 Average test loss: 3.4271, Test accuracy: 2735/10000 (27.35%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 90.3
# Three      - 83.4
# Four       - 0.0
# Five       - 0.0
# Six        - 95.4
# Seven      - 0.0
# Eight      - 7.1
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 1.217954
#
# 4selected Peers:
# Peer 2 is  attacker reputation: -0.005215048789978027
# Peer 8 is  honest reputation: -0.033075690269470215
# Peer 3 is  attacker reputation: 0.005084395408630371
# Peer 1 is  attacker reputation: 0.06436312198638916
# Peer 0 is  attacker reputation: -0.0023185014724731445
# Peer 16 is  honest reputation: 0.03400331735610962
# Peer 13 is  honest reputation: 0.04458415508270264
# Peer 18 is  honest reputation: 0.0364033579826355
# Peer 5 is  honest reputation: -0.016615986824035645
# Peer 19 is  honest reputation: 0.07806766033172607
# Peer 12 is  honest reputation: 0.08732247352600098
# Peer 4 is  honest reputation: 10.0
# Peer 6 is  honest reputation: 0.12214243412017822
# Peer 9 is  honest reputation: 0.038764894008636475
# Peer 14 is  honest reputation: 0.013037800788879395
# Peer 17 is  honest reputation: 0.056867003440856934
# Peer 15 is  honest reputation: 0.08226585388183594
# Peer 10 is  honest reputation: 0.007881700992584229
# Peer 7 is  honest reputation: 0.06384265422821045
# Peer 11 is  honest reputation: 0.03730010986328125
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: -0.0023185014724731445
# Peer 1 is  attacker reputation: 0.06436312198638916
# Peer 2 is  attacker reputation: -0.005215048789978027
# Peer 3 is  attacker reputation: 0.005084395408630371
# Peer 5 is  honest reputation: -0.016615986824035645
# Peer 6 is  honest reputation: 0.12214243412017822
# Peer 7 is  honest reputation: 0.06384265422821045
# Peer 8 is  honest reputation: -0.033075690269470215
# Peer 9 is  honest reputation: 0.038764894008636475
# Peer 10 is  honest reputation: 0.007881700992584229
# Peer 11 is  honest reputation: 0.03730010986328125
# Peer 12 is  honest reputation: 0.08732247352600098
# Peer 13 is  honest reputation: 0.04458415508270264
# Peer 14 is  honest reputation: 0.013037800788879395
# Peer 15 is  honest reputation: 0.08226585388183594
# Peer 16 is  honest reputation: 0.03400331735610962
# Peer 17 is  honest reputation: 0.056867003440856934
# Peer 18 is  honest reputation: 0.0364033579826355
# Peer 19 is  honest reputation: 0.07806766033172607
# 4 Aggregation took 0.0451
# attack 0 Average test loss: 5.3656, Test accuracy: 2393/10000 (23.93%)
#
# honest 4 Average test loss: 4.1725, Test accuracy: 3387/10000 (33.87%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 72.9
# Three      - 94.3
# Four       - 0.0
# Five       - 0.0
# Six        - 97.1
# Seven      - 0.0
# Eight      - 72.7
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.887330
#
# 4selected Peers:
# Peer 16 is  honest reputation: 0.06966942548751831
# Peer 7 is  honest reputation: 0.07163763046264648
# Peer 17 is  honest reputation: 0.05108922719955444
# Peer 12 is  honest reputation: 0.0892484188079834
# Peer 15 is  honest reputation: 0.11283242702484131
# Peer 14 is  honest reputation: 0.03315412998199463
# Peer 9 is  honest reputation: 0.05050438642501831
# Peer 18 is  honest reputation: 0.06456822156906128
# Peer 1 is  attacker reputation: 0.08199721574783325
# Peer 4 is  honest reputation: 10.0
# Peer 2 is  attacker reputation: 0.02187877893447876
# Peer 3 is  attacker reputation: -0.022813141345977783
# Peer 10 is  honest reputation: 0.020348012447357178
# Peer 13 is  honest reputation: 0.1024746298789978
# Peer 8 is  honest reputation: -0.04691052436828613
# Peer 0 is  attacker reputation: 0.002989828586578369
# Peer 5 is  honest reputation: -0.007791638374328613
# Peer 19 is  honest reputation: 0.10239464044570923
# Peer 6 is  honest reputation: 0.14158815145492554
# Peer 11 is  honest reputation: 0.009383618831634521
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.002989828586578369
# Peer 1 is  attacker reputation: 0.08199721574783325
# Peer 2 is  attacker reputation: 0.02187877893447876
# Peer 3 is  attacker reputation: -0.022813141345977783
# Peer 5 is  honest reputation: -0.007791638374328613
# Peer 6 is  honest reputation: 0.14158815145492554
# Peer 7 is  honest reputation: 0.07163763046264648
# Peer 8 is  honest reputation: -0.04691052436828613
# Peer 9 is  honest reputation: 0.05050438642501831
# Peer 10 is  honest reputation: 0.020348012447357178
# Peer 11 is  honest reputation: 0.009383618831634521
# Peer 12 is  honest reputation: 0.0892484188079834
# Peer 13 is  honest reputation: 0.1024746298789978
# Peer 14 is  honest reputation: 0.03315412998199463
# Peer 15 is  honest reputation: 0.11283242702484131
# Peer 16 is  honest reputation: 0.06966942548751831
# Peer 17 is  honest reputation: 0.05108922719955444
# Peer 18 is  honest reputation: 0.06456822156906128
# Peer 19 is  honest reputation: 0.10239464044570923
# 4 Aggregation took 0.0478
# attack 0 Average test loss: 5.1766, Test accuracy: 3084/10000 (30.84%)
#
# honest 4 Average test loss: 4.7638, Test accuracy: 3357/10000 (33.57%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 96.8
# Three      - 70.8
# Four       - 0.0
# Five       - 0.0
# Six        - 91.4
# Seven      - 0.0
# Eight      - 76.9
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.683730
#
# 4selected Peers:
# Peer 9 is  honest reputation: 0.04569023847579956
# Peer 16 is  honest reputation: 0.08939886093139648
# Peer 17 is  honest reputation: 0.07163679599761963
# Peer 11 is  honest reputation: 0.014823734760284424
# Peer 18 is  honest reputation: 0.09852027893066406
# Peer 12 is  honest reputation: 0.14304327964782715
# Peer 7 is  honest reputation: 0.10519766807556152
# Peer 10 is  honest reputation: 0.04547625780105591
# Peer 19 is  honest reputation: 0.12311214208602905
# Peer 5 is  honest reputation: 0.002361476421356201
# Peer 3 is  attacker reputation: -0.07344156503677368
# Peer 13 is  honest reputation: 0.16017818450927734
# Peer 8 is  honest reputation: -0.039940059185028076
# Peer 15 is  honest reputation: 0.14609861373901367
# Peer 2 is  attacker reputation: 0.023298025131225586
# Peer 1 is  attacker reputation: 0.11211150884628296
# Peer 6 is  honest reputation: 0.13563936948776245
# Peer 14 is  honest reputation: 0.02999800443649292
# Peer 0 is  attacker reputation: 0.004041850566864014
# Peer 4 is  honest reputation: 10.0
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.004041850566864014
# Peer 1 is  attacker reputation: 0.11211150884628296
# Peer 2 is  attacker reputation: 0.023298025131225586
# Peer 3 is  attacker reputation: -0.07344156503677368
# Peer 5 is  honest reputation: 0.002361476421356201
# Peer 6 is  honest reputation: 0.13563936948776245
# Peer 7 is  honest reputation: 0.10519766807556152
# Peer 8 is  honest reputation: -0.039940059185028076
# Peer 9 is  honest reputation: 0.04569023847579956
# Peer 10 is  honest reputation: 0.04547625780105591
# Peer 11 is  honest reputation: 0.014823734760284424
# Peer 12 is  honest reputation: 0.14304327964782715
# Peer 13 is  honest reputation: 0.16017818450927734
# Peer 14 is  honest reputation: 0.02999800443649292
# Peer 15 is  honest reputation: 0.14609861373901367
# Peer 16 is  honest reputation: 0.08939886093139648
# Peer 17 is  honest reputation: 0.07163679599761963
# Peer 18 is  honest reputation: 0.09852027893066406
# Peer 19 is  honest reputation: 0.12311214208602905
# 4 Aggregation took 0.0461
# attack 0 Average test loss: 5.2823, Test accuracy: 3592/10000 (35.92%)
#
# honest 4 Average test loss: 4.9865, Test accuracy: 3608/10000 (36.08%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 89.0
# Three      - 95.5
# Four       - 0.0
# Five       - 0.0
# Six        - 98.1
# Seven      - 0.0
# Eight      - 80.1
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.570657
#
# 4selected Peers:
# Peer 10 is  honest reputation: 0.07121777534484863
# Peer 3 is  attacker reputation: -0.12383812665939331
# Peer 19 is  honest reputation: 0.17671948671340942
# Peer 8 is  honest reputation: -0.03295791149139404
# Peer 14 is  honest reputation: 0.03221362829208374
# Peer 15 is  honest reputation: 0.18315088748931885
# Peer 0 is  attacker reputation: 0.012653827667236328
# Peer 5 is  honest reputation: -0.011732220649719238
# Peer 1 is  attacker reputation: 0.14196574687957764
# Peer 4 is  honest reputation: 10.0
# Peer 2 is  attacker reputation: 0.033592402935028076
# Peer 16 is  honest reputation: 0.11331450939178467
# Peer 7 is  honest reputation: 0.1472994089126587
# Peer 11 is  honest reputation: 0.025859713554382324
# Peer 13 is  honest reputation: 0.2087869644165039
# Peer 9 is  honest reputation: 0.02797091007232666
# Peer 6 is  honest reputation: 0.12899255752563477
# Peer 17 is  honest reputation: 0.135658860206604
# Peer 18 is  honest reputation: 0.13765263557434082
# Peer 12 is  honest reputation: 0.19933468103408813
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.012653827667236328
# Peer 1 is  attacker reputation: 0.14196574687957764
# Peer 2 is  attacker reputation: 0.033592402935028076
# Peer 3 is  attacker reputation: -0.12383812665939331
# Peer 5 is  honest reputation: -0.011732220649719238
# Peer 6 is  honest reputation: 0.12899255752563477
# Peer 7 is  honest reputation: 0.1472994089126587
# Peer 8 is  honest reputation: -0.03295791149139404
# Peer 9 is  honest reputation: 0.02797091007232666
# Peer 10 is  honest reputation: 0.07121777534484863
# Peer 11 is  honest reputation: 0.025859713554382324
# Peer 12 is  honest reputation: 0.19933468103408813
# Peer 13 is  honest reputation: 0.2087869644165039
# Peer 14 is  honest reputation: 0.03221362829208374
# Peer 15 is  honest reputation: 0.18315088748931885
# Peer 16 is  honest reputation: 0.11331450939178467
# Peer 17 is  honest reputation: 0.135658860206604
# Peer 18 is  honest reputation: 0.13765263557434082
# Peer 19 is  honest reputation: 0.17671948671340942
# 4 Aggregation took 0.0451
# attack 0 Average test loss: 5.5213, Test accuracy: 3595/10000 (35.95%)
#
# honest 4 Average test loss: 5.3397, Test accuracy: 3617/10000 (36.17%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 86.3
# Three      - 94.5
# Four       - 0.0
# Five       - 0.0
# Six        - 96.8
# Seven      - 0.0
# Eight      - 92.7
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.506506
#
# 4selected Peers:
# Peer 8 is  honest reputation: -0.042660415172576904
# Peer 7 is  honest reputation: 0.1700427532196045
# Peer 9 is  honest reputation: 0.009111166000366211
# Peer 17 is  honest reputation: 0.17722058296203613
# Peer 3 is  attacker reputation: -0.13219338655471802
# Peer 14 is  honest reputation: 0.03657501935958862
# Peer 1 is  attacker reputation: 0.16987228393554688
# Peer 5 is  honest reputation: -0.010808765888214111
# Peer 6 is  honest reputation: 0.13159126043319702
# Peer 18 is  honest reputation: 0.1502596139907837
# Peer 2 is  attacker reputation: 0.05233573913574219
# Peer 16 is  honest reputation: 0.11781108379364014
# Peer 4 is  honest reputation: 10.0
# Peer 0 is  attacker reputation: 0.032972633838653564
# Peer 12 is  honest reputation: 0.24006694555282593
# Peer 15 is  honest reputation: 0.22634637355804443
# Peer 19 is  honest reputation: 0.22403043508529663
# Peer 11 is  honest reputation: 0.055123746395111084
# Peer 13 is  honest reputation: 0.22881388664245605
# Peer 10 is  honest reputation: 0.06844747066497803
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.032972633838653564
# Peer 1 is  attacker reputation: 0.16987228393554688
# Peer 2 is  attacker reputation: 0.05233573913574219
# Peer 3 is  attacker reputation: -0.13219338655471802
# Peer 5 is  honest reputation: -0.010808765888214111
# Peer 6 is  honest reputation: 0.13159126043319702
# Peer 7 is  honest reputation: 0.1700427532196045
# Peer 8 is  honest reputation: -0.042660415172576904
# Peer 9 is  honest reputation: 0.009111166000366211
# Peer 10 is  honest reputation: 0.06844747066497803
# Peer 11 is  honest reputation: 0.055123746395111084
# Peer 12 is  honest reputation: 0.24006694555282593
# Peer 13 is  honest reputation: 0.22881388664245605
# Peer 14 is  honest reputation: 0.03657501935958862
# Peer 15 is  honest reputation: 0.22634637355804443
# Peer 16 is  honest reputation: 0.11781108379364014
# Peer 17 is  honest reputation: 0.17722058296203613
# Peer 18 is  honest reputation: 0.1502596139907837
# Peer 19 is  honest reputation: 0.22403043508529663
# 4 Aggregation took 0.0497
# attack 0 Average test loss: 5.9825, Test accuracy: 3634/10000 (36.34%)
#
# honest 4 Average test loss: 4.9455, Test accuracy: 3641/10000 (36.41%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 87.1
# Three      - 96.8
# Four       - 0.0
# Five       - 0.0
# Six        - 97.7
# Seven      - 0.0
# Eight      - 83.2
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.457697
#
# 4selected Peers:
# Peer 14 is  honest reputation: 0.04046142101287842
# Peer 6 is  honest reputation: 0.14660382270812988
# Peer 13 is  honest reputation: 0.2521849274635315
# Peer 9 is  honest reputation: 0.02121502161026001
# Peer 11 is  honest reputation: 0.04583895206451416
# Peer 16 is  honest reputation: 0.11931389570236206
# Peer 0 is  attacker reputation: 0.051496148109436035
# Peer 19 is  honest reputation: 0.2649640440940857
# Peer 2 is  attacker reputation: 0.07762128114700317
# Peer 5 is  honest reputation: -0.04147040843963623
# Peer 8 is  honest reputation: -0.04716891050338745
# Peer 15 is  honest reputation: 0.26033222675323486
# Peer 1 is  attacker reputation: 0.21283334493637085
# Peer 4 is  honest reputation: 10.0
# Peer 18 is  honest reputation: 0.18957608938217163
# Peer 3 is  attacker reputation: -0.1642259955406189
# Peer 12 is  honest reputation: 0.2482835054397583
# Peer 7 is  honest reputation: 0.22006195783615112
# Peer 10 is  honest reputation: 0.10261410474777222
# Peer 17 is  honest reputation: 0.20970594882965088
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.051496148109436035
# Peer 1 is  attacker reputation: 0.21283334493637085
# Peer 2 is  attacker reputation: 0.07762128114700317
# Peer 3 is  attacker reputation: -0.1642259955406189
# Peer 5 is  honest reputation: -0.04147040843963623
# Peer 6 is  honest reputation: 0.14660382270812988
# Peer 7 is  honest reputation: 0.22006195783615112
# Peer 8 is  honest reputation: -0.04716891050338745
# Peer 9 is  honest reputation: 0.02121502161026001
# Peer 10 is  honest reputation: 0.10261410474777222
# Peer 11 is  honest reputation: 0.04583895206451416
# Peer 12 is  honest reputation: 0.2482835054397583
# Peer 13 is  honest reputation: 0.2521849274635315
# Peer 14 is  honest reputation: 0.04046142101287842
# Peer 15 is  honest reputation: 0.26033222675323486
# Peer 16 is  honest reputation: 0.11931389570236206
# Peer 17 is  honest reputation: 0.20970594882965088
# Peer 18 is  honest reputation: 0.18957608938217163
# Peer 19 is  honest reputation: 0.2649640440940857
# 4 Aggregation took 0.0452
# attack 0 Average test loss: 6.3651, Test accuracy: 3728/10000 (37.28%)
#
# honest 4 Average test loss: 5.1344, Test accuracy: 3749/10000 (37.49%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 89.3
# Three      - 96.0
# Four       - 0.0
# Five       - 0.0
# Six        - 97.5
# Seven      - 0.0
# Eight      - 92.2
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.421178
#
# 4selected Peers:
# Peer 4 is  honest reputation: 10.0
# Peer 19 is  honest reputation: 0.3474511504173279
# Peer 7 is  honest reputation: 0.24659818410873413
# Peer 3 is  attacker reputation: -0.16375315189361572
# Peer 16 is  honest reputation: 0.1376030445098877
# Peer 5 is  honest reputation: -0.047239840030670166
# Peer 2 is  attacker reputation: 0.0840420126914978
# Peer 9 is  honest reputation: 0.0065081119537353516
# Peer 13 is  honest reputation: 0.2711591124534607
# Peer 8 is  honest reputation: -0.052369773387908936
# Peer 15 is  honest reputation: 0.2953663468360901
# Peer 10 is  honest reputation: 0.12343728542327881
# Peer 6 is  honest reputation: 0.15794742107391357
# Peer 0 is  attacker reputation: 0.06915569305419922
# Peer 11 is  honest reputation: 0.05060058832168579
# Peer 17 is  honest reputation: 0.25155317783355713
# Peer 1 is  attacker reputation: 0.22144782543182373
# Peer 14 is  honest reputation: 0.08149129152297974
# Peer 18 is  honest reputation: 0.1881575584411621
# Peer 12 is  honest reputation: 0.2870744466781616
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.06915569305419922
# Peer 1 is  attacker reputation: 0.22144782543182373
# Peer 2 is  attacker reputation: 0.0840420126914978
# Peer 3 is  attacker reputation: -0.16375315189361572
# Peer 5 is  honest reputation: -0.047239840030670166
# Peer 6 is  honest reputation: 0.15794742107391357
# Peer 7 is  honest reputation: 0.24659818410873413
# Peer 8 is  honest reputation: -0.052369773387908936
# Peer 9 is  honest reputation: 0.0065081119537353516
# Peer 10 is  honest reputation: 0.12343728542327881
# Peer 11 is  honest reputation: 0.05060058832168579
# Peer 12 is  honest reputation: 0.2870744466781616
# Peer 13 is  honest reputation: 0.2711591124534607
# Peer 14 is  honest reputation: 0.08149129152297974
# Peer 15 is  honest reputation: 0.2953663468360901
# Peer 16 is  honest reputation: 0.1376030445098877
# Peer 17 is  honest reputation: 0.25155317783355713
# Peer 18 is  honest reputation: 0.1881575584411621
# Peer 19 is  honest reputation: 0.3474511504173279
# 4 Aggregation took 0.0448
# attack 0 Average test loss: 5.8839, Test accuracy: 3838/10000 (38.38%)
#
# honest 4 Average test loss: 4.9068, Test accuracy: 3828/10000 (38.28%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 94.7
# Three      - 94.2
# Four       - 0.0
# Five       - 0.0
# Six        - 97.4
# Seven      - 0.0
# Eight      - 92.4
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.392798
#
# 4selected Peers:
# Peer 11 is  honest reputation: 0.0236741304397583
# Peer 18 is  honest reputation: 0.21677076816558838
# Peer 10 is  honest reputation: 0.14813315868377686
# Peer 19 is  honest reputation: 0.3880886435508728
# Peer 0 is  attacker reputation: 0.08481341600418091
# Peer 8 is  honest reputation: -0.06195974349975586
# Peer 9 is  honest reputation: 0.026354968547821045
# Peer 16 is  honest reputation: 0.12756025791168213
# Peer 3 is  attacker reputation: -0.21190810203552246
# Peer 15 is  honest reputation: 0.3233335614204407
# Peer 13 is  honest reputation: 0.2967965006828308
# Peer 7 is  honest reputation: 0.2925441861152649
# Peer 12 is  honest reputation: 0.3056023120880127
# Peer 5 is  honest reputation: -0.022138893604278564
# Peer 14 is  honest reputation: 0.09204870462417603
# Peer 17 is  honest reputation: 0.2547498345375061
# Peer 4 is  honest reputation: 10.0
# Peer 1 is  attacker reputation: 0.25608885288238525
# Peer 6 is  honest reputation: 0.17747008800506592
# Peer 2 is  attacker reputation: 0.09170544147491455
#
# 4selected Peers after refuse(delete 0):
# Peer 0 is  attacker reputation: 0.08481341600418091
# Peer 1 is  attacker reputation: 0.25608885288238525
# Peer 2 is  attacker reputation: 0.09170544147491455
# Peer 3 is  attacker reputation: -0.21190810203552246
# Peer 5 is  honest reputation: -0.022138893604278564
# Peer 6 is  honest reputation: 0.17747008800506592
# Peer 7 is  honest reputation: 0.2925441861152649
# Peer 8 is  honest reputation: -0.06195974349975586
# Peer 9 is  honest reputation: 0.026354968547821045
# Peer 10 is  honest reputation: 0.14813315868377686
# Peer 11 is  honest reputation: 0.0236741304397583
# Peer 12 is  honest reputation: 0.3056023120880127
# Peer 13 is  honest reputation: 0.2967965006828308
# Peer 14 is  honest reputation: 0.09204870462417603
# Peer 15 is  honest reputation: 0.3233335614204407
# Peer 16 is  honest reputation: 0.12756025791168213
# Peer 17 is  honest reputation: 0.2547498345375061
# Peer 18 is  honest reputation: 0.21677076816558838
# Peer 19 is  honest reputation: 0.3880886435508728
# 4 Aggregation took 0.047
# attack 0 Average test loss: 5.9544, Test accuracy: 3911/10000 (39.11%)
#
# honest 4 Average test loss: 5.1305, Test accuracy: 3709/10000 (37.09%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 94.2
# Three      - 93.5
# Four       - 0.0
# Five       - 0.0
# Six        - 97.0
# Seven      - 0.0
# Eight      - 90.6
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.366077
#
# 4selected Peers:
# Peer 1 is  attacker reputation: 0.2603456377983093
# Peer 10 is  honest reputation: 0.14911997318267822
# Peer 12 is  honest reputation: 0.32788002490997314
# Peer 4 is  honest reputation: 10.0
# Peer 7 is  honest reputation: 0.3031734824180603
# Peer 15 is  honest reputation: 0.3378797769546509
# Peer 6 is  honest reputation: 0.17450976371765137
# Peer 17 is  honest reputation: 0.2706491947174072
# Peer 2 is  attacker reputation: 0.09646421670913696
# Peer 13 is  honest reputation: 0.323652446269989
# Peer 18 is  honest reputation: 0.22940552234649658
# Peer 14 is  honest reputation: 0.10399407148361206
# Peer 19 is  honest reputation: 0.4083669185638428
# Peer 16 is  honest reputation: 0.13464653491973877
# Peer 0 is  attacker reputation: 0.10710233449935913
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: 0.10710233449935913
# Peer 1 is  attacker reputation: 0.2603456377983093
# Peer 2 is  attacker reputation: 0.09646421670913696
# Peer 6 is  honest reputation: 0.17450976371765137
# Peer 7 is  honest reputation: 0.3031734824180603
# Peer 10 is  honest reputation: 0.14911997318267822
# Peer 12 is  honest reputation: 0.32788002490997314
# Peer 13 is  honest reputation: 0.323652446269989
# Peer 14 is  honest reputation: 0.10399407148361206
# Peer 15 is  honest reputation: 0.3378797769546509
# Peer 16 is  honest reputation: 0.13464653491973877
# Peer 17 is  honest reputation: 0.2706491947174072
# Peer 18 is  honest reputation: 0.22940552234649658
# Peer 19 is  honest reputation: 0.4083669185638428
# 4 Aggregation took 0.0325
# attack 0 Average test loss: 4.0296, Test accuracy: 3738/10000 (37.38%)
#
# honest 4 Average test loss: 3.1614, Test accuracy: 3756/10000 (37.56%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 92.6
# Three      - 94.9
# Four       - 0.0
# Five       - 0.0
# Six        - 97.5
# Seven      - 0.0
# Eight      - 92.6
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.399833
#
# 4selected Peers:
# Peer 1 is  attacker reputation: 0.2897180914878845
# Peer 4 is  honest reputation: 10.0
# Peer 18 is  honest reputation: 0.24263006448745728
# Peer 15 is  honest reputation: 0.38082605600357056
# Peer 14 is  honest reputation: 0.10397428274154663
# Peer 0 is  attacker reputation: 0.10240864753723145
# Peer 2 is  attacker reputation: 0.09648400545120239
# Peer 17 is  honest reputation: 0.31474149227142334
# Peer 7 is  honest reputation: 0.3343689441680908
# Peer 12 is  honest reputation: 0.3570224642753601
# Peer 19 is  honest reputation: 0.47040289640426636
# Peer 10 is  honest reputation: 0.19075435400009155
# Peer 16 is  honest reputation: 0.14365530014038086
# Peer 13 is  honest reputation: 0.33911043405532837
# Peer 6 is  honest reputation: 0.17329859733581543
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: 0.10240864753723145
# Peer 1 is  attacker reputation: 0.2897180914878845
# Peer 2 is  attacker reputation: 0.09648400545120239
# Peer 6 is  honest reputation: 0.17329859733581543
# Peer 7 is  honest reputation: 0.3343689441680908
# Peer 10 is  honest reputation: 0.19075435400009155
# Peer 12 is  honest reputation: 0.3570224642753601
# Peer 13 is  honest reputation: 0.33911043405532837
# Peer 14 is  honest reputation: 0.10397428274154663
# Peer 15 is  honest reputation: 0.38082605600357056
# Peer 16 is  honest reputation: 0.14365530014038086
# Peer 17 is  honest reputation: 0.31474149227142334
# Peer 18 is  honest reputation: 0.24263006448745728
# Peer 19 is  honest reputation: 0.47040289640426636
# 4 Aggregation took 0.0335
# attack 0 Average test loss: 3.2266, Test accuracy: 3689/10000 (36.89%)
#
# honest 4 Average test loss: 2.4750, Test accuracy: 3787/10000 (37.87%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 91.7
# Three      - 94.4
# Four       - 0.0
# Five       - 0.0
# Six        - 97.1
# Seven      - 9.9
# Eight      - 93.8
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.406694
#
# 4selected Peers:
# Peer 18 is  honest reputation: 0.2503071427345276
# Peer 7 is  honest reputation: 0.3748122453689575
# Peer 16 is  honest reputation: 0.1886986494064331
# Peer 1 is  attacker reputation: 0.3403053283691406
# Peer 4 is  honest reputation: 10.0
# Peer 0 is  attacker reputation: 0.09288501739501953
# Peer 10 is  honest reputation: 0.22339361906051636
# Peer 2 is  attacker reputation: 0.08627057075500488
# Peer 14 is  honest reputation: 0.10814374685287476
# Peer 12 is  honest reputation: 0.41657084226608276
# Peer 13 is  honest reputation: 0.37343084812164307
# Peer 17 is  honest reputation: 0.34241706132888794
# Peer 19 is  honest reputation: 0.4779616594314575
# Peer 15 is  honest reputation: 0.39485788345336914
# Peer 6 is  honest reputation: 0.1691291332244873
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: 0.09288501739501953
# Peer 1 is  attacker reputation: 0.3403053283691406
# Peer 2 is  attacker reputation: 0.08627057075500488
# Peer 6 is  honest reputation: 0.1691291332244873
# Peer 7 is  honest reputation: 0.3748122453689575
# Peer 10 is  honest reputation: 0.22339361906051636
# Peer 12 is  honest reputation: 0.41657084226608276
# Peer 13 is  honest reputation: 0.37343084812164307
# Peer 14 is  honest reputation: 0.10814374685287476
# Peer 15 is  honest reputation: 0.39485788345336914
# Peer 16 is  honest reputation: 0.1886986494064331
# Peer 17 is  honest reputation: 0.34241706132888794
# Peer 18 is  honest reputation: 0.2503071427345276
# Peer 19 is  honest reputation: 0.4779616594314575
# 4 Aggregation took 0.0344
# attack 0 Average test loss: 2.7854, Test accuracy: 4175/10000 (41.75%)
#
# honest 4 Average test loss: 1.9758, Test accuracy: 4069/10000 (40.69%)
#
# Class      - Accuracy
# Zero       - 9.2
# One        - 1.8
# Two        - 93.8
# Three      - 96.1
# Four       - 9.4
# Five       - 0.0
# Six        - 95.6
# Seven      - 23.5
# Eight      - 87.8
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.405241
#
# 4selected Peers:
# Peer 10 is  honest reputation: 0.25070780515670776
# Peer 14 is  honest reputation: 0.11969316005706787
# Peer 19 is  honest reputation: 0.5070027709007263
# Peer 4 is  honest reputation: 10.0
# Peer 18 is  honest reputation: 0.27357959747314453
# Peer 17 is  honest reputation: 0.3697517514228821
# Peer 16 is  honest reputation: 0.20893383026123047
# Peer 2 is  attacker reputation: 0.08625483512878418
# Peer 12 is  honest reputation: 0.4631393551826477
# Peer 1 is  attacker reputation: 0.3827066421508789
# Peer 13 is  honest reputation: 0.4079076647758484
# Peer 7 is  honest reputation: 0.3748279809951782
# Peer 0 is  attacker reputation: 0.06072092056274414
# Peer 6 is  honest reputation: 0.1337605118751526
# Peer 15 is  honest reputation: 0.4184739589691162
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: 0.06072092056274414
# Peer 1 is  attacker reputation: 0.3827066421508789
# Peer 2 is  attacker reputation: 0.08625483512878418
# Peer 6 is  honest reputation: 0.1337605118751526
# Peer 7 is  honest reputation: 0.3748279809951782
# Peer 10 is  honest reputation: 0.25070780515670776
# Peer 12 is  honest reputation: 0.4631393551826477
# Peer 13 is  honest reputation: 0.4079076647758484
# Peer 14 is  honest reputation: 0.11969316005706787
# Peer 15 is  honest reputation: 0.4184739589691162
# Peer 16 is  honest reputation: 0.20893383026123047
# Peer 17 is  honest reputation: 0.3697517514228821
# Peer 18 is  honest reputation: 0.27357959747314453
# Peer 19 is  honest reputation: 0.5070027709007263
# 4 Aggregation took 0.0359
# attack 0 Average test loss: 2.7417, Test accuracy: 4267/10000 (42.67%)
#
# honest 4 Average test loss: 1.7867, Test accuracy: 4601/10000 (46.01%)
#
# Class      - Accuracy
# Zero       - 9.3
# One        - 10.6
# Two        - 94.3
# Three      - 96.9
# Four       - 23.0
# Five       - 0.0
# Six        - 94.7
# Seven      - 47.8
# Eight      - 84.8
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.397100
#
# 4selected Peers:
# Peer 15 is  honest reputation: 0.4218360185623169
# Peer 0 is  attacker reputation: 0.04863846302032471
# Peer 13 is  honest reputation: 0.41892141103744507
# Peer 2 is  attacker reputation: 0.061090707778930664
# Peer 18 is  honest reputation: 0.29874372482299805
# Peer 19 is  honest reputation: 0.5553553700447083
# Peer 1 is  attacker reputation: 0.41456443071365356
# Peer 14 is  honest reputation: 0.1276056170463562
# Peer 16 is  honest reputation: 0.25857120752334595
# Peer 6 is  honest reputation: 0.13039839267730713
# Peer 12 is  honest reputation: 0.49802953004837036
# Peer 4 is  honest reputation: 10.0
# Peer 10 is  honest reputation: 0.28343665599823
# Peer 17 is  honest reputation: 0.40534645318984985
# Peer 7 is  honest reputation: 0.4131200909614563
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: 0.04863846302032471
# Peer 1 is  attacker reputation: 0.41456443071365356
# Peer 2 is  attacker reputation: 0.061090707778930664
# Peer 6 is  honest reputation: 0.13039839267730713
# Peer 7 is  honest reputation: 0.4131200909614563
# Peer 10 is  honest reputation: 0.28343665599823
# Peer 12 is  honest reputation: 0.49802953004837036
# Peer 13 is  honest reputation: 0.41892141103744507
# Peer 14 is  honest reputation: 0.1276056170463562
# Peer 15 is  honest reputation: 0.4218360185623169
# Peer 16 is  honest reputation: 0.25857120752334595
# Peer 17 is  honest reputation: 0.40534645318984985
# Peer 18 is  honest reputation: 0.29874372482299805
# Peer 19 is  honest reputation: 0.5553553700447083
# 4 Aggregation took 0.0332
# attack 0 Average test loss: 2.7086, Test accuracy: 4612/10000 (46.12%)
#
# honest 4 Average test loss: 1.5895, Test accuracy: 5305/10000 (53.05%)
#
# Class      - Accuracy
# Zero       - 19.3
# One        - 29.6
# Two        - 91.9
# Three      - 97.1
# Four       - 37.0
# Five       - 0.0
# Six        - 97.7
# Seven      - 52.1
# Eight      - 89.4
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.385175
#
# 4selected Peers:
# Peer 7 is  honest reputation: 0.4305243492126465
# Peer 13 is  honest reputation: 0.44473206996917725
# Peer 14 is  honest reputation: 0.14683914184570312
# Peer 2 is  attacker reputation: 0.04596966505050659
# Peer 12 is  honest reputation: 0.5129159688949585
# Peer 16 is  honest reputation: 0.30364131927490234
# Peer 4 is  honest reputation: 10.0
# Peer 19 is  honest reputation: 0.5773657560348511
# Peer 1 is  attacker reputation: 0.4477517008781433
# Peer 6 is  honest reputation: 0.1164712905883789
# Peer 0 is  attacker reputation: 0.0404011607170105
# Peer 15 is  honest reputation: 0.4333224296569824
# Peer 10 is  honest reputation: 0.31258881092071533
# Peer 17 is  honest reputation: 0.41358381509780884
# Peer 18 is  honest reputation: 0.3105255961418152
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: 0.0404011607170105
# Peer 1 is  attacker reputation: 0.4477517008781433
# Peer 2 is  attacker reputation: 0.04596966505050659
# Peer 6 is  honest reputation: 0.1164712905883789
# Peer 7 is  honest reputation: 0.4305243492126465
# Peer 10 is  honest reputation: 0.31258881092071533
# Peer 12 is  honest reputation: 0.5129159688949585
# Peer 13 is  honest reputation: 0.44473206996917725
# Peer 14 is  honest reputation: 0.14683914184570312
# Peer 15 is  honest reputation: 0.4333224296569824
# Peer 16 is  honest reputation: 0.30364131927490234
# Peer 17 is  honest reputation: 0.41358381509780884
# Peer 18 is  honest reputation: 0.3105255961418152
# Peer 19 is  honest reputation: 0.5773657560348511
# 4 Aggregation took 0.0462
# attack 0 Average test loss: 2.5693, Test accuracy: 4736/10000 (47.36%)
#
# honest 4 Average test loss: 1.4529, Test accuracy: 5795/10000 (57.95%)
#
# Class      - Accuracy
# Zero       - 37.7
# One        - 57.0
# Two        - 95.3
# Three      - 96.8
# Four       - 52.6
# Five       - 0.0
# Six        - 97.0
# Seven      - 56.0
# Eight      - 91.3
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.374244
#
# 4selected Peers:
# Peer 18 is  honest reputation: 0.3413625955581665
# Peer 12 is  honest reputation: 0.5407366752624512
# Peer 10 is  honest reputation: 0.34863394498825073
# Peer 6 is  honest reputation: 0.08921122550964355
# Peer 4 is  honest reputation: 10.0
# Peer 2 is  attacker reputation: 0.02401447296142578
# Peer 17 is  honest reputation: 0.45159912109375
# Peer 16 is  honest reputation: 0.34767383337020874
# Peer 19 is  honest reputation: 0.62254798412323
# Peer 14 is  honest reputation: 0.16879427433013916
# Peer 11 is  honest reputation: 0.035922467708587646
# Peer 13 is  honest reputation: 0.4784596562385559
# Peer 1 is  attacker reputation: 0.5049357414245605
# Peer 7 is  honest reputation: 0.45938432216644287
# Peer 15 is  honest reputation: 0.4635668992996216
#
# 4selected Peers after refuse(delete 4):
# Peer 1 is  attacker reputation: 0.5049357414245605
# Peer 2 is  attacker reputation: 0.02401447296142578
# Peer 6 is  honest reputation: 0.08921122550964355
# Peer 7 is  honest reputation: 0.45938432216644287
# Peer 10 is  honest reputation: 0.34863394498825073
# Peer 11 is  honest reputation: 0.035922467708587646
# Peer 12 is  honest reputation: 0.5407366752624512
# Peer 13 is  honest reputation: 0.4784596562385559
# Peer 14 is  honest reputation: 0.16879427433013916
# Peer 15 is  honest reputation: 0.4635668992996216
# Peer 16 is  honest reputation: 0.34767383337020874
# Peer 17 is  honest reputation: 0.45159912109375
# Peer 18 is  honest reputation: 0.3413625955581665
# Peer 19 is  honest reputation: 0.62254798412323
# 4 Aggregation took 0.038
# attack 0 Average test loss: 2.3943, Test accuracy: 5029/10000 (50.29%)
#
# honest 4 Average test loss: 1.3466, Test accuracy: 6109/10000 (61.09%)
#
# Class      - Accuracy
# Zero       - 48.7
# One        - 57.4
# Two        - 94.2
# Three      - 97.1
# Four       - 65.1
# Five       - 0.0
# Six        - 97.9
# Seven      - 65.2
# Eight      - 91.7
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.355707
#
# 4selected Peers:
# Peer 6 is  honest reputation: 0.05042785406112671
# Peer 16 is  honest reputation: 0.3693915605545044
# Peer 14 is  honest reputation: 0.21560055017471313
# Peer 19 is  honest reputation: 0.6583667993545532
# Peer 15 is  honest reputation: 0.4882138967514038
# Peer 12 is  honest reputation: 0.5702945590019226
# Peer 18 is  honest reputation: 0.3923523426055908
# Peer 4 is  honest reputation: 10.0
# Peer 17 is  honest reputation: 0.4670640230178833
# Peer 10 is  honest reputation: 0.4002224802970886
# Peer 0 is  attacker reputation: 0.016595959663391113
# Peer 13 is  honest reputation: 0.5139510035514832
# Peer 11 is  honest reputation: 0.014242708683013916
# Peer 1 is  attacker reputation: 0.5412043333053589
# Peer 7 is  honest reputation: 0.5088344216346741
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: 0.016595959663391113
# Peer 1 is  attacker reputation: 0.5412043333053589
# Peer 6 is  honest reputation: 0.05042785406112671
# Peer 7 is  honest reputation: 0.5088344216346741
# Peer 10 is  honest reputation: 0.4002224802970886
# Peer 11 is  honest reputation: 0.014242708683013916
# Peer 12 is  honest reputation: 0.5702945590019226
# Peer 13 is  honest reputation: 0.5139510035514832
# Peer 14 is  honest reputation: 0.21560055017471313
# Peer 15 is  honest reputation: 0.4882138967514038
# Peer 16 is  honest reputation: 0.3693915605545044
# Peer 17 is  honest reputation: 0.4670640230178833
# Peer 18 is  honest reputation: 0.3923523426055908
# Peer 19 is  honest reputation: 0.6583667993545532
# 4 Aggregation took 0.0331
# attack 0 Average test loss: 2.4174, Test accuracy: 5115/10000 (51.15%)
#
# honest 4 Average test loss: 1.0948, Test accuracy: 6708/10000 (67.08%)
#
# Class      - Accuracy
# Zero       - 69.0
# One        - 75.3
# Two        - 93.7
# Three      - 97.8
# Four       - 76.2
# Five       - 0.3
# Six        - 98.0
# Seven      - 77.3
# Eight      - 92.2
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.350252
#
# 4selected Peers:
# Peer 7 is  honest reputation: 0.5491244792938232
# Peer 14 is  honest reputation: 0.2608465552330017
# Peer 12 is  honest reputation: 0.604290246963501
# Peer 16 is  honest reputation: 0.3886120915412903
# Peer 13 is  honest reputation: 0.5598730444908142
# Peer 9 is  honest reputation: -0.002709686756134033
# Peer 1 is  attacker reputation: 0.5964250564575195
# Peer 17 is  honest reputation: 0.5029951930046082
# Peer 19 is  honest reputation: 0.7039519548416138
# Peer 15 is  honest reputation: 0.5104584097862244
# Peer 4 is  honest reputation: 10.0
# Peer 18 is  honest reputation: 0.420276939868927
# Peer 0 is  attacker reputation: -0.00262451171875
# Peer 10 is  honest reputation: 0.42959874868392944
# Peer 2 is  attacker reputation: 0.008549630641937256
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: -0.00262451171875
# Peer 1 is  attacker reputation: 0.5964250564575195
# Peer 2 is  attacker reputation: 0.008549630641937256
# Peer 7 is  honest reputation: 0.5491244792938232
# Peer 9 is  honest reputation: -0.002709686756134033
# Peer 10 is  honest reputation: 0.42959874868392944
# Peer 12 is  honest reputation: 0.604290246963501
# Peer 13 is  honest reputation: 0.5598730444908142
# Peer 14 is  honest reputation: 0.2608465552330017
# Peer 15 is  honest reputation: 0.5104584097862244
# Peer 16 is  honest reputation: 0.3886120915412903
# Peer 17 is  honest reputation: 0.5029951930046082
# Peer 18 is  honest reputation: 0.420276939868927
# Peer 19 is  honest reputation: 0.7039519548416138
# 4 Aggregation took 0.0405
# attack 0 Average test loss: 2.3040, Test accuracy: 5264/10000 (52.64%)
#
# honest 4 Average test loss: 1.2000, Test accuracy: 6485/10000 (64.85%)
#
# Class      - Accuracy
# Zero       - 55.5
# One        - 74.7
# Two        - 90.4
# Three      - 97.0
# Four       - 71.2
# Five       - 0.6
# Six        - 97.7
# Seven      - 70.2
# Eight      - 92.2
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.342256
#
# 4selected Peers:
# Peer 14 is  honest reputation: 0.27606284618377686
# Peer 15 is  honest reputation: 0.5253207683563232
# Peer 18 is  honest reputation: 0.4605739116668701
# Peer 10 is  honest reputation: 0.47241950035095215
# Peer 17 is  honest reputation: 0.5338901877403259
# Peer 19 is  honest reputation: 0.7491776943206787
# Peer 6 is  honest reputation: -0.00940018892288208
# Peer 11 is  honest reputation: -0.019137322902679443
# Peer 1 is  attacker reputation: 0.6366004943847656
# Peer 0 is  attacker reputation: -0.017486929893493652
# Peer 7 is  honest reputation: 0.5657246112823486
# Peer 16 is  honest reputation: 0.42334216833114624
# Peer 12 is  honest reputation: 0.6257388591766357
# Peer 4 is  honest reputation: 10.0
# Peer 13 is  honest reputation: 0.5868858695030212
#
# 4selected Peers after refuse(delete 4):
# Peer 0 is  attacker reputation: -0.017486929893493652
# Peer 1 is  attacker reputation: 0.6366004943847656
# Peer 6 is  honest reputation: -0.00940018892288208
# Peer 7 is  honest reputation: 0.5657246112823486
# Peer 10 is  honest reputation: 0.47241950035095215
# Peer 11 is  honest reputation: -0.019137322902679443
# Peer 12 is  honest reputation: 0.6257388591766357
# Peer 13 is  honest reputation: 0.5868858695030212
# Peer 14 is  honest reputation: 0.27606284618377686
# Peer 15 is  honest reputation: 0.5253207683563232
# Peer 16 is  honest reputation: 0.42334216833114624
# Peer 17 is  honest reputation: 0.5338901877403259
# Peer 18 is  honest reputation: 0.4605739116668701
# Peer 19 is  honest reputation: 0.7491776943206787
# 4 Aggregation took 0.0301
# attack 0 Average test loss: 2.2067, Test accuracy: 5460/10000 (54.60%)
#
# honest 4 Average test loss: 1.0960, Test accuracy: 6653/10000 (66.53%)
#
# Class      - Accuracy
# Zero       - 67.0
# One        - 72.7
# Two        - 94.2
# Three      - 95.8
# Four       - 74.9
# Five       - 1.5
# Six        - 97.8
# Seven      - 74.8
# Eight      - 90.8
# Nine       - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.332989
#
# 4selected Peers:
# Peer 13 is  honest reputation: 0.6296741366386414
# Peer 19 is  honest reputation: 0.7877219319343567
# Peer 9 is  honest reputation: -0.027374267578125
# Peer 1 is  attacker reputation: 0.6856654286384583
# Peer 18 is  honest reputation: 0.49576693773269653
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 12 is  honest reputation: 0.6437562108039856
# Peer 10 is  honest reputation: 0.5221259593963623
# Peer 17 is  honest reputation: 0.5413289666175842
# Peer 0 is  attacker reputation: -0.02492576837539673
# Peer 16 is  honest reputation: 0.444683313369751
# Peer 15 is  honest reputation: 0.5520933866500854
# Peer 14 is  honest reputation: 0.3178709149360657
# Peer 4 is  honest reputation: 10.0
# Peer 7 is  honest reputation: 0.6009951233863831
#
# 4selected Peers after refuse(delete 5):
# Peer 0 is  attacker reputation: -0.02492576837539673
# Peer 1 is  attacker reputation: 0.6856654286384583
# Peer 7 is  honest reputation: 0.6009951233863831
# Peer 9 is  honest reputation: -0.027374267578125
# Peer 10 is  honest reputation: 0.5221259593963623
# Peer 12 is  honest reputation: 0.6437562108039856
# ...
#
# 4selected Peers:
# Peer 10 is  honest reputation: 0.7030923962593079
# Peer 17 is  honest reputation: 0.6487313508987427
# Peer 9 is  honest reputation: -0.13902342319488525
# Peer 4 is  honest reputation: 10.0
# Peer 12 is  honest reputation: 0.7548043727874756
# Peer 16 is  honest reputation: 0.668986976146698
# Peer 8 is  honest reputation: -0.1491064429283142
# Peer 7 is  honest reputation: 0.8092573285102844
# Peer 13 is  honest reputation: 0.8396515250205994
# Peer 1 is  attacker reputation: 0.739411473274231
# Peer 19 is  honest reputation: 1.1544398665428162
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 18 is  honest reputation: 0.7434255480766296
# Peer 14 is  honest reputation: 0.5122882723808289
# Peer 15 is  honest reputation: 0.7618405818939209
#
# 4selected Peers after refuse(delete 5):
# Peer 1 is  attacker reputation: 0.739411473274231
# Peer 7 is  honest reputation: 0.8092573285102844
# Peer 8 is  honest reputation: -0.1491064429283142
# Peer 9 is  honest reputation: -0.13902342319488525
# Peer 10 is  honest reputation: 0.7030923962593079
# Peer 12 is  honest reputation: 0.7548043727874756
# Peer 13 is  honest reputation: 0.8396515250205994
# Peer 14 is  honest reputation: 0.5122882723808289
# Peer 15 is  honest reputation: 0.7618405818939209
# Peer 16 is  honest reputation: 0.668986976146698
# Peer 17 is  honest reputation: 0.6487313508987427
# Peer 18 is  honest reputation: 0.7434255480766296
# Peer 19 is  honest reputation: 1.1544398665428162
# 4 Aggregation took 0.0371
# attack 0 Average test loss: 1.4584, Test accuracy: 6530/10000 (65.30%)
#
# honest 4 Average test loss: 0.7948, Test accuracy: 7459/10000 (74.59%)
#
# Class      - Accuracy
# Zero       - 84.9
# One        - 84.4
# Two        - 95.0
# Three      - 98.3
# Four       - 83.7
# Five       - 24.7
# Six        - 98.0
# Seven      - 74.0
# Eight      - 91.8
# Nine       - 10.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.275469
#
# 4selected Peers:
# Peer 17 is  honest reputation: 0.6659063100814819
# Peer 7 is  honest reputation: 0.8700646162033081
# Peer 2 is  attacker reputation: -0.16552874445915222
# Peer 4 is  honest reputation: 10.0
# Peer 13 is  honest reputation: 0.8413471579551697
# Peer 15 is  honest reputation: 0.7840755581855774
# Peer 9 is  honest reputation: -0.15719854831695557
# Peer 18 is  honest reputation: 0.76435786485672
# Peer 1 is  attacker reputation: 0.7388462424278259
# Peer 14 is  honest reputation: 0.5275049805641174
# Peer 12 is  honest reputation: 0.7831973433494568
# Peer 10 is  honest reputation: 0.7455910444259644
# Peer 19 is  honest reputation: 1.2206624746322632
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 16 is  honest reputation: 0.6908897757530212
#
# 4selected Peers after refuse(delete 5):
# Peer 1 is  attacker reputation: 0.7388462424278259
# Peer 2 is  attacker reputation: -0.16552874445915222
# Peer 7 is  honest reputation: 0.8700646162033081
# Peer 9 is  honest reputation: -0.15719854831695557
# Peer 10 is  honest reputation: 0.7455910444259644
# Peer 12 is  honest reputation: 0.7831973433494568
# Peer 13 is  honest reputation: 0.8413471579551697
# Peer 14 is  honest reputation: 0.5275049805641174
# Peer 15 is  honest reputation: 0.7840755581855774
# Peer 16 is  honest reputation: 0.6908897757530212
# Peer 17 is  honest reputation: 0.6659063100814819
# Peer 18 is  honest reputation: 0.76435786485672
# Peer 19 is  honest reputation: 1.2206624746322632
# 4 Aggregation took 0.0346
# attack 0 Average test loss: 1.5493, Test accuracy: 6403/10000 (64.03%)
#
# honest 4 Average test loss: 0.7216, Test accuracy: 7642/10000 (76.42%)
#
# Class      - Accuracy
# Zero       - 88.1
# One        - 88.0
# Two        - 94.2
# Three      - 98.0
# Four       - 87.4
# Five       - 29.9
# Six        - 97.6
# Seven      - 77.2
# Eight      - 89.0
# Nine       - 10.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.275290
#
# 4selected Peers:
# Peer 13 is  honest reputation: 0.8608209490776062
# Peer 7 is  honest reputation: 0.8759219646453857
# Peer 19 is  honest reputation: 1.2218965291976929
# Peer 15 is  honest reputation: 0.7853572368621826
# Peer 12 is  honest reputation: 0.7852374315261841
# Peer 14 is  honest reputation: 0.5593500137329102
# Peer 4 is  honest reputation: 10.0
# Peer 10 is  honest reputation: 0.7451797127723694
# Peer 17 is  honest reputation: 0.6990423798561096
# Peer 11 is  honest reputation: -0.16788804531097412
# Peer 18 is  honest reputation: 0.778831958770752
# Peer 1 is  attacker reputation: 0.7482069730758667
# Peer 0 is  attacker reputation: -0.1689438819885254
# Peer 16 is  honest reputation: 0.7019222378730774
# Peer 5 is  honest reputation: -0.02033144235610962
#
# 4selected Peers after refuse(delete 5):
# Peer 0 is  attacker reputation: -0.1689438819885254
# Peer 1 is  attacker reputation: 0.7482069730758667
# Peer 7 is  honest reputation: 0.8759219646453857
# Peer 10 is  honest reputation: 0.7451797127723694
# Peer 11 is  honest reputation: -0.16788804531097412
# Peer 12 is  honest reputation: 0.7852374315261841
# Peer 13 is  honest reputation: 0.8608209490776062
# Peer 14 is  honest reputation: 0.5593500137329102
# Peer 15 is  honest reputation: 0.7853572368621826
# Peer 16 is  honest reputation: 0.7019222378730774
# Peer 17 is  honest reputation: 0.6990423798561096
# Peer 18 is  honest reputation: 0.778831958770752
# Peer 19 is  honest reputation: 1.2218965291976929
# 4 Aggregation took 0.0323
# attack 0 Average test loss: 1.4263, Test accuracy: 6542/10000 (65.42%)
#
# honest 4 Average test loss: 0.6867, Test accuracy: 7749/10000 (77.49%)
#
# Class      - Accuracy
# Zero       - 90.8
# One        - 86.9
# Two        - 95.6
# Three      - 98.2
# Four       - 89.6
# Five       - 28.1
# Six        - 98.4
# Seven      - 79.2
# Eight      - 90.9
# Nine       - 18.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.267033
#
# 4selected Peers:
# Peer 19 is  honest reputation: 1.266621172428131
# Peer 10 is  honest reputation: 0.7978426814079285
# Peer 12 is  honest reputation: 0.8072391152381897
# Peer 7 is  honest reputation: 0.8957798480987549
# Peer 16 is  honest reputation: 0.7479261755943298
# Peer 9 is  honest reputation: -0.17943799495697021
# Peer 14 is  honest reputation: 0.5872846245765686
# Peer 8 is  honest reputation: -0.19037377834320068
# Peer 4 is  honest reputation: 10.0
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 17 is  honest reputation: 0.6987688541412354
# Peer 13 is  honest reputation: 0.8914827704429626
# Peer 18 is  honest reputation: 0.8032514452934265
# Peer 1 is  attacker reputation: 0.7490274310112
# Peer 15 is  honest reputation: 0.7948147654533386
#
# 4selected Peers after refuse(delete 5):
# Peer 1 is  attacker reputation: 0.7490274310112
# Peer 7 is  honest reputation: 0.8957798480987549
# Peer 8 is  honest reputation: -0.19037377834320068
# Peer 9 is  honest reputation: -0.17943799495697021
# Peer 10 is  honest reputation: 0.7978426814079285
# Peer 12 is  honest reputation: 0.8072391152381897
# Peer 13 is  honest reputation: 0.8914827704429626
# Peer 14 is  honest reputation: 0.5872846245765686
# Peer 15 is  honest reputation: 0.7948147654533386
# Peer 16 is  honest reputation: 0.7479261755943298
# Peer 17 is  honest reputation: 0.6987688541412354
# Peer 18 is  honest reputation: 0.8032514452934265
# Peer 19 is  honest reputation: 1.266621172428131
# 4 Aggregation took 0.0327
# attack 0 Average test loss: 1.3932, Test accuracy: 6649/10000 (66.49%)
#
# honest 4 Average test loss: 0.6577, Test accuracy: 7824/10000 (78.24%)
#
# Class      - Accuracy
# Zero       - 87.9
# One        - 89.8
# Two        - 95.9
# Three      - 98.9
# Four       - 88.8
# Five       - 37.2
# Six        - 98.8
# Seven      - 82.5
# Eight      - 88.9
# Nine       - 18.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.266325
#
# 4selected Peers:
# Peer 13 is  honest reputation: 0.9098308086395264
# Peer 17 is  honest reputation: 0.7321938276290894
# Peer 19 is  honest reputation: 1.282001554965973
# Peer 7 is  honest reputation: 0.9158732891082764
# Peer 4 is  honest reputation: 10.0
# Peer 1 is  attacker reputation: 0.7445864081382751
# Peer 14 is  honest reputation: 0.6189603805541992
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 15 is  honest reputation: 0.8066747784614563
# Peer 18 is  honest reputation: 0.8356761932373047
# Peer 9 is  honest reputation: -0.18339133262634277
# Peer 11 is  honest reputation: -0.20708155632019043
# Peer 10 is  honest reputation: 0.8275729417800903
# Peer 16 is  honest reputation: 0.7845284342765808
# Peer 12 is  honest reputation: 0.8513577580451965
#
# 4selected Peers after refuse(delete 5):
# Peer 1 is  attacker reputation: 0.7445864081382751
# Peer 7 is  honest reputation: 0.9158732891082764
# Peer 9 is  honest reputation: -0.18339133262634277
# Peer 10 is  honest reputation: 0.8275729417800903
# Peer 11 is  honest reputation: -0.20708155632019043
# Peer 12 is  honest reputation: 0.8513577580451965
# Peer 13 is  honest reputation: 0.9098308086395264
# Peer 14 is  honest reputation: 0.6189603805541992
# Peer 15 is  honest reputation: 0.8066747784614563
# Peer 16 is  honest reputation: 0.7845284342765808
# Peer 17 is  honest reputation: 0.7321938276290894
# Peer 18 is  honest reputation: 0.8356761932373047
# Peer 19 is  honest reputation: 1.282001554965973
# 4 Aggregation took 0.0267
# attack 0 Average test loss: 1.4208, Test accuracy: 6550/10000 (65.50%)
#
# honest 4 Average test loss: 0.6769, Test accuracy: 7767/10000 (77.67%)
#
# Class      - Accuracy
# Zero       - 90.3
# One        - 90.8
# Two        - 96.4
# Three      - 98.3
# Four       - 88.9
# Five       - 31.9
# Six        - 97.9
# Seven      - 84.4
# Eight      - 90.7
# Nine       - 11.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.261031
#
# 4selected Peers:
# Peer 19 is  honest reputation: 1.306775152683258
# Peer 4 is  honest reputation: 10.0
# Peer 16 is  honest reputation: 0.811225950717926
# Peer 10 is  honest reputation: 0.8355940580368042
# Peer 17 is  honest reputation: 0.7847276926040649
# Peer 1 is  attacker reputation: 0.7660542130470276
# Peer 9 is  honest reputation: -0.20901155471801758
# Peer 0 is  attacker reputation: -0.21377569437026978
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 13 is  honest reputation: 0.9254282712936401
# Peer 7 is  honest reputation: 0.9203585386276245
# Peer 18 is  honest reputation: 0.8463554382324219
# Peer 12 is  honest reputation: 0.8538175225257874
# Peer 14 is  honest reputation: 0.618140459060669
# Peer 15 is  honest reputation: 0.8184101581573486
#
# 4selected Peers after refuse(delete 5):
# Peer 0 is  attacker reputation: -0.21377569437026978
# Peer 1 is  attacker reputation: 0.7660542130470276
# Peer 7 is  honest reputation: 0.9203585386276245
# Peer 9 is  honest reputation: -0.20901155471801758
# Peer 10 is  honest reputation: 0.8355940580368042
# Peer 12 is  honest reputation: 0.8538175225257874
# Peer 13 is  honest reputation: 0.9254282712936401
# Peer 14 is  honest reputation: 0.618140459060669
# Peer 15 is  honest reputation: 0.8184101581573486
# Peer 16 is  honest reputation: 0.811225950717926
# Peer 17 is  honest reputation: 0.7847276926040649
# Peer 18 is  honest reputation: 0.8463554382324219
# Peer 19 is  honest reputation: 1.306775152683258
# 4 Aggregation took 0.036
# attack 0 Average test loss: 1.2776, Test accuracy: 6957/10000 (69.57%)
#
# honest 4 Average test loss: 0.7358, Test accuracy: 7658/10000 (76.58%)
#
# Class      - Accuracy
# Zero       - 88.6
# One        - 87.4
# Two        - 96.0
# Three      - 97.9
# Four       - 88.0
# Five       - 29.5
# Six        - 98.0
# Seven      - 78.6
# Eight      - 93.5
# Nine       - 12.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.256940
#
# 4selected Peers:
# Peer 17 is  honest reputation: 0.8109340667724609
# Peer 18 is  honest reputation: 0.8807336688041687
# Peer 4 is  honest reputation: 10.0
# Peer 16 is  honest reputation: 0.8450530767440796
# Peer 12 is  honest reputation: 0.8633103966712952
# Peer 6 is  honest reputation: -0.21720263361930847
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 10 is  honest reputation: 0.8542903065681458
# Peer 19 is  honest reputation: 1.3367025256156921
# Peer 1 is  attacker reputation: 0.7628899216651917
# Peer 15 is  honest reputation: 0.8673993349075317
# Peer 14 is  honest reputation: 0.6474236845970154
# Peer 9 is  honest reputation: -0.21688741445541382
# Peer 13 is  honest reputation: 0.9352734684944153
# Peer 7 is  honest reputation: 0.9440606236457825
#
# 4selected Peers after refuse(delete 5):
# Peer 1 is  attacker reputation: 0.7628899216651917
# Peer 6 is  honest reputation: -0.21720263361930847
# Peer 7 is  honest reputation: 0.9440606236457825
# Peer 9 is  honest reputation: -0.21688741445541382
# Peer 10 is  honest reputation: 0.8542903065681458
# Peer 12 is  honest reputation: 0.8633103966712952
# Peer 13 is  honest reputation: 0.9352734684944153
# Peer 14 is  honest reputation: 0.6474236845970154
# Peer 15 is  honest reputation: 0.8673993349075317
# Peer 16 is  honest reputation: 0.8450530767440796
# Peer 17 is  honest reputation: 0.8109340667724609
# Peer 18 is  honest reputation: 0.8807336688041687
# Peer 19 is  honest reputation: 1.3367025256156921
# 4 Aggregation took 0.0293
# attack 0 Average test loss: 1.3533, Test accuracy: 6810/10000 (68.10%)
#
# honest 4 Average test loss: 0.5913, Test accuracy: 8023/10000 (80.23%)
#
# Class      - Accuracy
# Zero       - 91.1
# One        - 87.9
# Two        - 95.1
# Three      - 98.3
# Four       - 87.8
# Five       - 39.2
# Six        - 98.1
# Seven      - 83.9
# Eight      - 93.7
# Nine       - 20.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
# Average of peers' local losses: 0.253637
#
# 4selected Peers:
# Peer 14 is  honest reputation: 0.6683934330940247
# Peer 8 is  honest reputation: -0.22746336460113525
# Peer 12 is  honest reputation: 0.8771016001701355
# Peer 16 is  honest reputation: 0.8518263697624207
# Peer 4 is  honest reputation: 10.0
# Peer 13 is  honest reputation: 0.9695261120796204
# Peer 5 is  honest reputation: -0.02033144235610962
# Peer 9 is  honest reputation: -0.21902227401733398
# Peer 18 is  honest reputation: 0.9107145667076111
# Peer 10 is  honest reputation: 0.8606950044631958
# Peer 7 is  honest reputation: 0.9663395881652832
# Peer 1 is  attacker reputation: 0.7539277672767639
# Peer 15 is  honest reputation: 0.8860673904418945
# Peer 19 is  honest reputation: 1.3602481484413147
# Peer 17 is  honest reputation: 0.8454067707061768
#
# 4selected Peers after refuse(delete 5):
# Peer 1 is  attacker reputation: 0.7539277672767639
# Peer 7 is  honest reputation: 0.9663395881652832
# Peer 8 is  honest reputation: -0.22746336460113525
# Peer 9 is  honest reputation: -0.21902227401733398
# Peer 10 is  honest reputation: 0.8606950044631958
# Peer 12 is  honest reputation: 0.8771016001701355
# Peer 13 is  honest reputation: 0.9695261120796204
# Peer 14 is  honest reputation: 0.6683934330940247
# Peer 15 is  honest reputation: 0.8860673904418945
# Peer 16 is  honest reputation: 0.8518263697624207
# Peer 17 is  honest reputation: 0.8454067707061768
# Peer 18 is  honest reputation: 0.9107145667076111
# Peer 19 is  honest reputation: 1.3602481484413147
# 4 Aggregation took 0.0285
# attack 0 Average test loss: 1.4135, Test accuracy: 6824/10000 (68.24%)
#
# honest 4 Average test loss: 0.6581, Test accuracy: 7837/10000 (78.37%)
#
# Class      - Accuracy
# Zero       - 89.6
# One        - 88.6
# Two        - 95.6
# Three      - 97.0
# Four       - 90.4
# Five       - 36.3
# Six        - 97.7
# Seven      - 83.6
# Eight      - 90.3
# Nine       - 17.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
# 0  attack  8  to  1 !
# 1  attack  8  to  1 !
# 2  attack  8  to  1 !
# 3  attack  8  to  1 !
