# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'IID'
ALPHA = 1000000
NUM_PEERS = 100 # "number of peers: K" 
FRAC_PEERS = 1 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 100 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.001#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'median'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)

# %%
RULE = 'fdfl'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 100
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: fdfl
# Attack Type: gaussian_noise
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s2
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
# 8 gaussian_noise attack ！
# 12 gaussian_noise attack ！
# 13 gaussian_noise attack ！
# 21 gaussian_noise attack ！
# 24 gaussian_noise attack ！
# 28 gaussian_noise attack ！
# 29 gaussian_noise attack ！
# 32 gaussian_noise attack ！
# 34 gaussian_noise attack ！
# 43 gaussian_noise attack ！
# 46 gaussian_noise attack ！
# 57 gaussian_noise attack ！
# 60 gaussian_noise attack ！
# 75 gaussian_noise attack ！
# 87 gaussian_noise attack ！
# 90 gaussian_noise attack ！
# 92 gaussian_noise attack ！
# 97 gaussian_noise attack ！
# 98 gaussian_noise attack ！
# 99 gaussian_noise attack ！
# Average of peers' local losses: 2.302969
#
# 91selected Peers:
# Peer 37 is  honest reputation: 0.0
# Peer 86 is  honest reputation: 0.0
# Peer 23 is  honest reputation: 0.0
# Peer 44 is  honest reputation: 0.0
# Peer 69 is  honest reputation: 0.0
# Peer 32 is  attacker reputation: 0.0
# Peer 64 is  honest reputation: 0.0
# Peer 52 is  honest reputation: 0.0
# Peer 95 is  honest reputation: 0.0
# Peer 98 is  attacker reputation: 0.0
# Peer 6 is  honest reputation: 0.0
# Peer 96 is  honest reputation: 0.0
# Peer 58 is  honest reputation: 0.0
# Peer 4 is  honest reputation: 0.0
# Peer 65 is  honest reputation: 0.0
# Peer 24 is  attacker reputation: 0.0
# Peer 25 is  honest reputation: 0.0
# Peer 72 is  honest reputation: 0.0
# Peer 15 is  honest reputation: 0.0
# Peer 1 is  honest reputation: 0.0
# Peer 93 is  honest reputation: 0.0
# Peer 84 is  honest reputation: 0.0
# Peer 26 is  honest reputation: 0.0
# Peer 81 is  honest reputation: 0.0
# Peer 8 is  attacker reputation: 0.0
# Peer 79 is  honest reputation: 0.0
# Peer 90 is  attacker reputation: 0.0
# Peer 7 is  honest reputation: 0.0
# Peer 41 is  honest reputation: 0.0
# Peer 10 is  honest reputation: 0.0
# Peer 63 is  honest reputation: 0.0
# Peer 14 is  honest reputation: 0.0
# Peer 73 is  honest reputation: 0.0
# Peer 60 is  attacker reputation: 0.0
# Peer 99 is  attacker reputation: 0.0
# Peer 13 is  attacker reputation: 0.0
# Peer 18 is  honest reputation: 0.0
# Peer 61 is  honest reputation: 0.0
# Peer 48 is  honest reputation: 0.0
# Peer 36 is  honest reputation: 0.0
# Peer 38 is  honest reputation: 0.0
# Peer 39 is  honest reputation: 0.0
# Peer 21 is  attacker reputation: 0.0
# Peer 87 is  attacker reputation: 0.0
# Peer 0 is  honest reputation: 0.0
# Peer 71 is  honest reputation: 0.0
# Peer 76 is  honest reputation: 0.0
# Peer 2 is  honest reputation: 0.0
# Peer 57 is  attacker reputation: 0.0
# Peer 97 is  attacker reputation: 0.0
# Peer 49 is  honest reputation: 0.0
# Peer 45 is  honest reputation: 0.0
# Peer 66 is  honest reputation: 0.0
# Peer 5 is  honest reputation: 0.0
# Peer 55 is  honest reputation: 0.0
# Peer 35 is  honest reputation: 0.0
# Peer 11 is  honest reputation: 0.0
# Peer 62 is  honest reputation: 0.0
# Peer 12 is  attacker reputation: 0.0
# Peer 28 is  attacker reputation: 0.0
# Peer 33 is  honest reputation: 0.0
# Peer 43 is  attacker reputation: 0.0
# Peer 75 is  attacker reputation: 0.0
# Peer 29 is  attacker reputation: 0.0
# Peer 30 is  honest reputation: 0.0
# Peer 92 is  attacker reputation: 0.0
# Peer 59 is  honest reputation: 0.0
# Peer 9 is  honest reputation: 0.0
# Peer 89 is  honest reputation: 0.0
# Peer 82 is  honest reputation: 0.0
# Peer 50 is  honest reputation: 0.0
# Peer 31 is  honest reputation: 0.0
# Peer 27 is  honest reputation: 0.0
# Peer 17 is  honest reputation: 0.0
# Peer 68 is  honest reputation: 0.0
# Peer 22 is  honest reputation: 0.0
# Peer 16 is  honest reputation: 0.0
# Peer 20 is  honest reputation: 0.0
# Peer 34 is  attacker reputation: 0.0
# Peer 3 is  honest reputation: 0.0
# Peer 46 is  attacker reputation: 0.0
# Peer 54 is  honest reputation: 0.0
# Peer 40 is  honest reputation: 0.0
# Peer 78 is  honest reputation: 0.0
# Peer 85 is  honest reputation: 0.0
# Peer 74 is  honest reputation: 0.0
# Peer 91 is  honest reputation: 10.0
# Peer 42 is  honest reputation: 0.0
# Peer 88 is  honest reputation: 0.0
# Peer 19 is  honest reputation: 0.0
# Peer 56 is  honest reputation: 0.0
# Peer 47 is  honest reputation: 0.0
# Peer 83 is  honest reputation: 0.0
# Peer 70 is  honest reputation: 0.0
# Peer 77 is  honest reputation: 0.0
# Peer 67 is  honest reputation: 0.0
# Peer 51 is  honest reputation: 0.0
# Peer 80 is  honest reputation: 0.0
# Peer 94 is  honest reputation: 0.0
# Peer 53 is  honest reputation: 0.0
#
# 91selected Peers after refuse(delete 0):
# Peer 0 is  honest reputation: 0.0
# Peer 1 is  honest reputation: 0.0
# Peer 2 is  honest reputation: 0.0
# Peer 3 is  honest reputation: 0.0
# Peer 4 is  honest reputation: 0.0
# Peer 5 is  honest reputation: 0.0
# Peer 6 is  honest reputation: 0.0
# Peer 7 is  honest reputation: 0.0
# Peer 8 is  attacker reputation: 0.0
# Peer 9 is  honest reputation: 0.0
# Peer 10 is  honest reputation: 0.0
# Peer 11 is  honest reputation: 0.0
# Peer 12 is  attacker reputation: 0.0
# Peer 13 is  attacker reputation: 0.0
# Peer 14 is  honest reputation: 0.0
# Peer 15 is  honest reputation: 0.0
# Peer 16 is  honest reputation: 0.0
# Peer 17 is  honest reputation: 0.0
# Peer 18 is  honest reputation: 0.0
# Peer 19 is  honest reputation: 0.0
# Peer 20 is  honest reputation: 0.0
# Peer 21 is  attacker reputation: 0.0
# Peer 22 is  honest reputation: 0.0
# Peer 23 is  honest reputation: 0.0
# Peer 24 is  attacker reputation: 0.0
# Peer 25 is  honest reputation: 0.0
# Peer 26 is  honest reputation: 0.0
# Peer 27 is  honest reputation: 0.0
# Peer 28 is  attacker reputation: 0.0
# Peer 29 is  attacker reputation: 0.0
# Peer 30 is  honest reputation: 0.0
# Peer 31 is  honest reputation: 0.0
# Peer 32 is  attacker reputation: 0.0
# Peer 33 is  honest reputation: 0.0
# Peer 34 is  attacker reputation: 0.0
# Peer 35 is  honest reputation: 0.0
# Peer 36 is  honest reputation: 0.0
# Peer 37 is  honest reputation: 0.0
# Peer 38 is  honest reputation: 0.0
# Peer 39 is  honest reputation: 0.0
# Peer 40 is  honest reputation: 0.0
# Peer 41 is  honest reputation: 0.0
# Peer 42 is  honest reputation: 0.0
# Peer 43 is  attacker reputation: 0.0
# Peer 44 is  honest reputation: 0.0
# Peer 45 is  honest reputation: 0.0
# Peer 46 is  attacker reputation: 0.0
# Peer 47 is  honest reputation: 0.0
# Peer 48 is  honest reputation: 0.0
# Peer 49 is  honest reputation: 0.0
# Peer 50 is  honest reputation: 0.0
# Peer 51 is  honest reputation: 0.0
# Peer 52 is  honest reputation: 0.0
# Peer 53 is  honest reputation: 0.0
# Peer 54 is  honest reputation: 0.0
# Peer 55 is  honest reputation: 0.0
# Peer 56 is  honest reputation: 0.0
# Peer 57 is  attacker reputation: 0.0
# Peer 58 is  honest reputation: 0.0
# Peer 59 is  honest reputation: 0.0
# Peer 60 is  attacker reputation: 0.0
# Peer 61 is  honest reputation: 0.0
# Peer 62 is  honest reputation: 0.0
# Peer 63 is  honest reputation: 0.0
# Peer 64 is  honest reputation: 0.0
# Peer 65 is  honest reputation: 0.0
# Peer 66 is  honest reputation: 0.0
# Peer 67 is  honest reputation: 0.0
# Peer 68 is  honest reputation: 0.0
# Peer 69 is  honest reputation: 0.0
# Peer 70 is  honest reputation: 0.0
# Peer 71 is  honest reputation: 0.0
# Peer 72 is  honest reputation: 0.0
# Peer 73 is  honest reputation: 0.0
# Peer 74 is  honest reputation: 0.0
# Peer 75 is  attacker reputation: 0.0
# Peer 76 is  honest reputation: 0.0
# Peer 77 is  honest reputation: 0.0
# Peer 78 is  honest reputation: 0.0
# Peer 79 is  honest reputation: 0.0
# Peer 80 is  honest reputation: 0.0
# Peer 81 is  honest reputation: 0.0
# Peer 82 is  honest reputation: 0.0
# Peer 83 is  honest reputation: 0.0
# Peer 84 is  honest reputation: 0.0
# Peer 85 is  honest reputation: 0.0
# Peer 86 is  honest reputation: 0.0
# Peer 87 is  attacker reputation: 0.0
# Peer 88 is  honest reputation: 0.0
# Peer 89 is  honest reputation: 0.0
# Peer 90 is  attacker reputation: 0.0
# Peer 92 is  attacker reputation: 0.0
# Peer 93 is  honest reputation: 0.0
# Peer 94 is  honest reputation: 0.0
# Peer 95 is  honest reputation: 0.0
# Peer 96 is  honest reputation: 0.0
# Peer 97 is  attacker reputation: 0.0
# Peer 98 is  attacker reputation: 0.0
# Peer 99 is  attacker reputation: 0.0
# 91 Aggregation took 0.1823
# attack 99 Average test loss: 8.8627, Test accuracy: 740/10000 (7.40%)
#
# honest 91 Average test loss: 2.2888, Test accuracy: 1382/10000 (13.82%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 47.5
# Three      - 3.2
# Four       - 0.0
# Five       - 0.0
# Six        - 0.0
# Seven      - 8.3
# Eight      - 34.0
# Nine       - 48.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
# 8 gaussian_noise attack ！
# 12 gaussian_noise attack ！
# 13 gaussian_noise attack ！
# 21 gaussian_noise attack ！
# 24 gaussian_noise attack ！
# 28 gaussian_noise attack ！
# 29 gaussian_noise attack ！
# 32 gaussian_noise attack ！
# 34 gaussian_noise attack ！
# 43 gaussian_noise attack ！
# 46 gaussian_noise attack ！
# 57 gaussian_noise attack ！
# 60 gaussian_noise attack ！
# 75 gaussian_noise attack ！
# 87 gaussian_noise attack ！
# 90 gaussian_noise attack ！
# 92 gaussian_noise attack ！
# 97 gaussian_noise attack ！
# 98 gaussian_noise attack ！
# 99 gaussian_noise attack ！
# Average of peers' local losses: 3.241756
#
# 91selected Peers:
# Peer 41 is  honest reputation: 0.018066108226776123
# Peer 2 is  honest reputation: -0.00881737470626831
# Peer 13 is  attacker reputation: -0.2154146432876587
# Peer 61 is  honest reputation: 0.019189059734344482
# Peer 27 is  honest reputation: 0.02380204200744629
# Peer 98 is  attacker reputation: -0.19334548711776733
# Peer 0 is  honest reputation: 0.061937153339385986
# Peer 19 is  honest reputation: 0.11070853471755981
# Peer 76 is  honest reputation: 0.02269059419631958
# Peer 66 is  honest reputation: 0.02003854513168335
# Peer 11 is  honest reputation: 0.039360225200653076
# Peer 86 is  honest reputation: -0.005678713321685791
# Peer 30 is  honest reputation: 0.034404635429382324
# Peer 90 is  attacker reputation: -0.21889209747314453
# Peer 97 is  attacker reputation: -0.1977573037147522
# Peer 70 is  honest reputation: 0.02451944351196289
# Peer 25 is  honest reputation: 0.059501826763153076
# Peer 74 is  honest reputation: 0.05261027812957764
# Peer 81 is  honest reputation: 0.00972527265548706
# Peer 64 is  honest reputation: 0.012141883373260498
# Peer 65 is  honest reputation: 0.010888278484344482
# Peer 31 is  honest reputation: 0.0064653754234313965
# Peer 72 is  honest reputation: 0.05504131317138672
# Peer 14 is  honest reputation: 0.02910900115966797
# Peer 89 is  honest reputation: 0.04669386148452759
# Peer 67 is  honest reputation: 0.012628138065338135
# Peer 49 is  honest reputation: 0.008577227592468262
# Peer 3 is  honest reputation: 0.009501874446868896
# Peer 34 is  attacker reputation: -0.2460724115371704
# Peer 73 is  honest reputation: 0.02898240089416504
# Peer 26 is  honest reputation: 0.007330715656280518
# Peer 9 is  honest reputation: 0.009386122226715088
# Peer 82 is  honest reputation: 0.009615957736968994
# Peer 1 is  honest reputation: 0.05109661817550659
# Peer 60 is  attacker reputation: -0.18303456902503967
# Peer 63 is  honest reputation: 0.0613366961479187
# Peer 37 is  honest reputation: 0.05665355920791626
# Peer 28 is  attacker reputation: -0.21379151940345764
# Peer 15 is  honest reputation: 0.04678565263748169
# Peer 48 is  honest reputation: 0.042597949504852295
# Peer 96 is  honest reputation: 0.024941861629486084
# Peer 71 is  honest reputation: 0.07432663440704346
# Peer 18 is  honest reputation: 0.02284395694732666
# Peer 50 is  honest reputation: 0.04902535676956177
# Peer 20 is  honest reputation: 0.04731625318527222
# Peer 59 is  honest reputation: 0.023241877555847168
# Peer 87 is  attacker reputation: -0.20797285437583923
# Peer 77 is  honest reputation: 0.012731671333312988
# Peer 94 is  honest reputation: 0.02036869525909424
# Peer 40 is  honest reputation: 0.05961877107620239
# Peer 56 is  honest reputation: 0.01877492666244507
# Peer 95 is  honest reputation: 0.02355867624282837
# Peer 38 is  honest reputation: 0.06154227256774902
# Peer 6 is  honest reputation: 0.00019073486328125
# Peer 80 is  honest reputation: 0.012471020221710205
# Peer 39 is  honest reputation: -0.0005722641944885254
# Peer 29 is  attacker reputation: -0.18526536226272583
# Peer 32 is  attacker reputation: -0.14601463079452515
# Peer 44 is  honest reputation: 0.007518768310546875
# Peer 46 is  attacker reputation: -0.22232785820960999
# Peer 55 is  honest reputation: 0.043452680110931396
# Peer 57 is  attacker reputation: -0.20405921339988708
# Peer 10 is  honest reputation: 0.033642590045928955
# Peer 58 is  honest reputation: 0.039238572120666504
# Peer 79 is  honest reputation: 0.03298419713973999
# Peer 36 is  honest reputation: 0.023932158946990967
# Peer 51 is  honest reputation: 0.034594953060150146
# Peer 92 is  attacker reputation: -0.21282655000686646
# Peer 47 is  honest reputation: 0.07863706350326538
# Peer 78 is  honest reputation: 0.034323275089263916
# Peer 68 is  honest reputation: 0.004573047161102295
# Peer 23 is  honest reputation: 0.05369788408279419
# Peer 24 is  attacker reputation: -0.2006947100162506
# Peer 42 is  honest reputation: -0.0008856654167175293
# Peer 99 is  attacker reputation: -0.20833146572113037
# Peer 84 is  honest reputation: 0.019163072109222412
# Peer 75 is  attacker reputation: -0.17701640725135803
# Peer 62 is  honest reputation: 0.047035157680511475
# Peer 16 is  honest reputation: 0.057170748710632324
# Peer 7 is  honest reputation: 0.04812246561050415
# Peer 4 is  honest reputation: 0.0549275279045105
# Peer 53 is  honest reputation: 0.009425103664398193
# Peer 93 is  honest reputation: 0.02208554744720459
# Peer 85 is  honest reputation: 0.00961083173751831
# Peer 17 is  honest reputation: 0.03867441415786743
# Peer 69 is  honest reputation: 0.07421445846557617
# Peer 35 is  honest reputation: 0.01559823751449585
# Peer 5 is  honest reputation: 0.026751697063446045
# Peer 22 is  honest reputation: 0.026073753833770752
# Peer 8 is  attacker reputation: -0.2212108075618744
# Peer 54 is  honest reputation: 0.010679900646209717
# Peer 45 is  honest reputation: 0.028540432453155518
# Peer 83 is  honest reputation: 0.01908588409423828
# Peer 21 is  attacker reputation: -0.22049620747566223
# Peer 43 is  attacker reputation: -0.187567800283432
# Peer 33 is  honest reputation: 0.029009461402893066
# Peer 12 is  attacker reputation: -0.21350547671318054
# Peer 52 is  honest reputation: 0.042446136474609375
# Peer 91 is  honest reputation: 10.0
# Peer 88 is  honest reputation: 0.029759645462036133
#
# 91selected Peers after refuse(delete 0):
# Peer 0 is  honest reputation: 0.061937153339385986
# Peer 1 is  honest reputation: 0.05109661817550659
# Peer 2 is  honest reputation: -0.00881737470626831
# Peer 3 is  honest reputation: 0.009501874446868896
# Peer 4 is  honest reputation: 0.0549275279045105
# Peer 5 is  honest reputation: 0.026751697063446045
# Peer 6 is  honest reputation: 0.00019073486328125
# Peer 7 is  honest reputation: 0.04812246561050415
# Peer 8 is  attacker reputation: -0.2212108075618744
# Peer 9 is  honest reputation: 0.009386122226715088
# Peer 10 is  honest reputation: 0.033642590045928955
# Peer 11 is  honest reputation: 0.039360225200653076
# Peer 12 is  attacker reputation: -0.21350547671318054
# Peer 13 is  attacker reputation: -0.2154146432876587
# Peer 14 is  honest reputation: 0.02910900115966797
# Peer 15 is  honest reputation: 0.04678565263748169
# Peer 16 is  honest reputation: 0.057170748710632324
# Peer 17 is  honest reputation: 0.03867441415786743
# Peer 18 is  honest reputation: 0.02284395694732666
# Peer 19 is  honest reputation: 0.11070853471755981
# Peer 20 is  honest reputation: 0.04731625318527222
# Peer 21 is  attacker reputation: -0.22049620747566223
# Peer 22 is  honest reputation: 0.026073753833770752
# Peer 23 is  honest reputation: 0.05369788408279419
# Peer 24 is  attacker reputation: -0.2006947100162506
# Peer 25 is  honest reputation: 0.059501826763153076
# Peer 26 is  honest reputation: 0.007330715656280518
# Peer 27 is  honest reputation: 0.02380204200744629
# Peer 28 is  attacker reputation: -0.21379151940345764
# Peer 29 is  attacker reputation: -0.18526536226272583
# Peer 30 is  honest reputation: 0.034404635429382324
# Peer 31 is  honest reputation: 0.0064653754234313965
# Peer 32 is  attacker reputation: -0.14601463079452515
# Peer 33 is  honest reputation: 0.029009461402893066
# Peer 34 is  attacker reputation: -0.2460724115371704
# Peer 35 is  honest reputation: 0.01559823751449585
# Peer 36 is  honest reputation: 0.023932158946990967
# Peer 37 is  honest reputation: 0.05665355920791626
# Peer 38 is  honest reputation: 0.06154227256774902
# Peer 39 is  honest reputation: -0.0005722641944885254
# Peer 40 is  honest reputation: 0.05961877107620239
# Peer 41 is  honest reputation: 0.018066108226776123
# Peer 42 is  honest reputation: -0.0008856654167175293
# Peer 43 is  attacker reputation: -0.187567800283432
# Peer 44 is  honest reputation: 0.007518768310546875
# Peer 45 is  honest reputation: 0.028540432453155518
# Peer 46 is  attacker reputation: -0.22232785820960999
# Peer 47 is  honest reputation: 0.07863706350326538
# Peer 48 is  honest reputation: 0.042597949504852295
# Peer 49 is  honest reputation: 0.008577227592468262
# Peer 50 is  honest reputation: 0.04902535676956177
# Peer 51 is  honest reputation: 0.034594953060150146
# Peer 52 is  honest reputation: 0.042446136474609375
# Peer 53 is  honest reputation: 0.009425103664398193
# Peer 54 is  honest reputation: 0.010679900646209717
# Peer 55 is  honest reputation: 0.043452680110931396
# Peer 56 is  honest reputation: 0.01877492666244507
# Peer 57 is  attacker reputation: -0.20405921339988708
# Peer 58 is  honest reputation: 0.039238572120666504
# Peer 59 is  honest reputation: 0.023241877555847168
# Peer 60 is  attacker reputation: -0.18303456902503967
# Peer 61 is  honest reputation: 0.019189059734344482
# Peer 62 is  honest reputation: 0.047035157680511475
# Peer 63 is  honest reputation: 0.0613366961479187
# Peer 64 is  honest reputation: 0.012141883373260498
# Peer 65 is  honest reputation: 0.010888278484344482
# Peer 66 is  honest reputation: 0.02003854513168335
# Peer 67 is  honest reputation: 0.012628138065338135
# Peer 68 is  honest reputation: 0.004573047161102295
# Peer 69 is  honest reputation: 0.07421445846557617
# Peer 70 is  honest reputation: 0.02451944351196289
# Peer 71 is  honest reputation: 0.07432663440704346
# Peer 72 is  honest reputation: 0.05504131317138672
# Peer 73 is  honest reputation: 0.02898240089416504
# Peer 74 is  honest reputation: 0.05261027812957764
# Peer 75 is  attacker reputation: -0.17701640725135803
# Peer 76 is  honest reputation: 0.02269059419631958
# Peer 77 is  honest reputation: 0.012731671333312988
# Peer 78 is  honest reputation: 0.034323275089263916
# Peer 79 is  honest reputation: 0.03298419713973999
# Peer 80 is  honest reputation: 0.012471020221710205
# Peer 81 is  honest reputation: 0.00972527265548706
# Peer 82 is  honest reputation: 0.009615957736968994
# Peer 83 is  honest reputation: 0.01908588409423828
# Peer 84 is  honest reputation: 0.019163072109222412
# Peer 85 is  honest reputation: 0.00961083173751831
# Peer 86 is  honest reputation: -0.005678713321685791
# Peer 87 is  attacker reputation: -0.20797285437583923
# Peer 88 is  honest reputation: 0.029759645462036133
# Peer 89 is  honest reputation: 0.04669386148452759
# Peer 90 is  attacker reputation: -0.21889209747314453
# Peer 92 is  attacker reputation: -0.21282655000686646
# Peer 93 is  honest reputation: 0.02208554744720459
# Peer 94 is  honest reputation: 0.02036869525909424
# Peer 95 is  honest reputation: 0.02355867624282837
# Peer 96 is  honest reputation: 0.024941861629486084
# Peer 97 is  attacker reputation: -0.1977573037147522
# Peer 98 is  attacker reputation: -0.19334548711776733
# Peer 99 is  attacker reputation: -0.20833146572113037
# 91 Aggregation took 0.2157
# attack 99 Average test loss: 11.8947, Test accuracy: 964/10000 (9.64%)
#
# honest 91 Average test loss: 2.2804, Test accuracy: 1633/10000 (16.33%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 1.5
# Two        - 48.3
# Three      - 4.4
# Four       - 0.0
# Five       - 0.0
# Six        - 0.0
# Seven      - 6.9
# Eight      - 31.8
# Nine       - 66.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
# 8 gaussian_noise attack ！
# 12 gaussian_noise attack ！
# 13 gaussian_noise attack ！
# 21 gaussian_noise attack ！
# 24 gaussian_noise attack ！
# 28 gaussian_noise attack ！
# 29 gaussian_noise attack ！
# 32 gaussian_noise attack ！
# 34 gaussian_noise attack ！
# 43 gaussian_noise attack ！
# 46 gaussian_noise attack ！
# 57 gaussian_noise attack ！
# 60 gaussian_noise attack ！
# 75 gaussian_noise attack ！
# 87 gaussian_noise attack ！
# 90 gaussian_noise attack ！
# 92 gaussian_noise attack ！
# 97 gaussian_noise attack ！
# 98 gaussian_noise attack ！
# 99 gaussian_noise attack ！
# Average of peers' local losses: 3.155130
#
# 91selected Peers:
# Peer 50 is  honest reputation: 0.05981278419494629
# Peer 62 is  honest reputation: 0.047044575214385986
# Peer 14 is  honest reputation: 0.03178328275680542
# Peer 15 is  honest reputation: 0.09301841259002686
# Peer 37 is  honest reputation: 0.0558314323425293
# Peer 35 is  honest reputation: 0.017418324947357178
# Peer 8 is  attacker reputation: -0.42512786388397217
# Peer 73 is  honest reputation: 0.030030548572540283
# Peer 97 is  attacker reputation: -0.4019031822681427
# Peer 95 is  honest reputation: 0.031962573528289795
# Peer 72 is  honest reputation: 0.09424108266830444
# Peer 33 is  honest reputation: 0.05828726291656494
# Peer 96 is  honest reputation: 0.05640912055969238
# Peer 64 is  honest reputation: 0.05402040481567383
# Peer 56 is  honest reputation: 0.02101367712020874
# Peer 47 is  honest reputation: 0.09080857038497925
# Peer 28 is  attacker reputation: -0.4415435791015625
# Peer 18 is  honest reputation: 0.030070185661315918
# Peer 65 is  honest reputation: 0.010860025882720947
# Peer 29 is  attacker reputation: -0.3870088756084442
# Peer 90 is  attacker reputation: -0.4349280297756195
# Peer 48 is  honest reputation: 0.05702608823776245
# Peer 99 is  attacker reputation: -0.43225598335266113
# Peer 13 is  attacker reputation: -0.42300912737846375
# Peer 26 is  honest reputation: 0.04357701539993286
# Peer 60 is  attacker reputation: -0.3783617317676544
# Peer 46 is  attacker reputation: -0.4340220093727112
# Peer 19 is  honest reputation: 0.14681291580200195
# Peer 10 is  honest reputation: 0.05730777978897095
# Peer 92 is  attacker reputation: -0.37706515192985535
# Peer 31 is  honest reputation: 0.046160876750946045
# Peer 86 is  honest reputation: 0.051483094692230225
# Peer 83 is  honest reputation: 0.02719569206237793
# Peer 11 is  honest reputation: 0.08651286363601685
# Peer 57 is  attacker reputation: -0.4025219976902008
# Peer 9 is  honest reputation: 0.06788146495819092
# Peer 0 is  honest reputation: 0.09341210126876831
# Peer 22 is  honest reputation: 0.05828911066055298
# Peer 7 is  honest reputation: 0.08631497621536255
# Peer 80 is  honest reputation: 0.043001532554626465
# Peer 98 is  attacker reputation: -0.3872036039829254
# Peer 94 is  honest reputation: 0.02340829372406006
# Peer 58 is  honest reputation: 0.10052067041397095
# Peer 52 is  honest reputation: 0.08309292793273926
# Peer 34 is  attacker reputation: -0.4505661129951477
# Peer 30 is  honest reputation: 0.06670606136322021
# Peer 44 is  honest reputation: 0.04628509283065796
# Peer 75 is  attacker reputation: -0.37534239888191223
# Peer 89 is  honest reputation: 0.0776485800743103
# Peer 67 is  honest reputation: 0.03153902292251587
# Peer 21 is  attacker reputation: -0.39535078406333923
# Peer 59 is  honest reputation: 0.0472644567489624
# Peer 16 is  honest reputation: 0.07036709785461426
# Peer 38 is  honest reputation: 0.05633282661437988
# Peer 39 is  honest reputation: 0.003834664821624756
# Peer 93 is  honest reputation: 0.06239813566207886
# Peer 20 is  honest reputation: 0.07111501693725586
# Peer 23 is  honest reputation: 0.08738827705383301
# Peer 85 is  honest reputation: 0.029873311519622803
# Peer 42 is  honest reputation: 0.016924679279327393
# Peer 2 is  honest reputation: 0.02718949317932129
# Peer 70 is  honest reputation: 0.07104998826980591
# Peer 49 is  honest reputation: 0.05745124816894531
# Peer 77 is  honest reputation: 0.023502588272094727
# Peer 76 is  honest reputation: 0.060761988162994385
# Peer 88 is  honest reputation: 0.03984951972961426
# Peer 51 is  honest reputation: 0.05317157506942749
# Peer 25 is  honest reputation: 0.07054966688156128
# Peer 54 is  honest reputation: 0.025476396083831787
# Peer 69 is  honest reputation: 0.08422738313674927
# Peer 81 is  honest reputation: 0.040804505348205566
# Peer 55 is  honest reputation: 0.05923748016357422
# Peer 63 is  honest reputation: 0.1071733832359314
# Peer 12 is  attacker reputation: -0.42686936259269714
# Peer 40 is  honest reputation: 0.06123709678649902
# Peer 32 is  attacker reputation: -0.3529786765575409
# Peer 6 is  honest reputation: 0.023973703384399414
# Peer 17 is  honest reputation: 0.03115558624267578
# Peer 45 is  honest reputation: 0.08076924085617065
# Peer 24 is  attacker reputation: -0.4319266974925995
# Peer 53 is  honest reputation: 0.04334855079650879
# Peer 78 is  honest reputation: 0.04160231351852417
# Peer 68 is  honest reputation: 0.023168861865997314
# Peer 71 is  honest reputation: 0.12171077728271484
# Peer 4 is  honest reputation: 0.08511495590209961
# Peer 84 is  honest reputation: 0.0458335280418396
# Peer 87 is  attacker reputation: -0.4114770293235779
# Peer 79 is  honest reputation: 0.05071210861206055
# Peer 43 is  attacker reputation: -0.3904106914997101
# Peer 1 is  honest reputation: 0.05789440870285034
# Peer 82 is  honest reputation: 0.029262840747833252
# Peer 91 is  honest reputation: 10.0
# Peer 27 is  honest reputation: 0.03738147020339966
# Peer 5 is  honest reputation: 0.051227688789367676
# Peer 3 is  honest reputation: 0.04874551296234131
# Peer 36 is  honest reputation: 0.05567669868469238
# Peer 66 is  honest reputation: 0.0444294810295105
# Peer 74 is  honest reputation: 0.08608156442642212
# Peer 41 is  honest reputation: 0.030554890632629395
# Peer 61 is  honest reputation: 0.04499506950378418
#
# 91selected Peers after refuse(delete 0):
# Peer 0 is  honest reputation: 0.09341210126876831
# Peer 1 is  honest reputation: 0.05789440870285034
# Peer 2 is  honest reputation: 0.02718949317932129
# Peer 3 is  honest reputation: 0.04874551296234131
# Peer 4 is  honest reputation: 0.08511495590209961
# Peer 5 is  honest reputation: 0.051227688789367676
# Peer 6 is  honest reputation: 0.023973703384399414
# Peer 7 is  honest reputation: 0.08631497621536255
# Peer 8 is  attacker reputation: -0.42512786388397217
# Peer 9 is  honest reputation: 0.06788146495819092
# Peer 10 is  honest reputation: 0.05730777978897095
# Peer 11 is  honest reputation: 0.08651286363601685
# Peer 12 is  attacker reputation: -0.42686936259269714
# Peer 13 is  attacker reputation: -0.42300912737846375
# Peer 14 is  honest reputation: 0.03178328275680542
# Peer 15 is  honest reputation: 0.09301841259002686
# Peer 16 is  honest reputation: 0.07036709785461426
# Peer 17 is  honest reputation: 0.03115558624267578
# Peer 18 is  honest reputation: 0.030070185661315918
# Peer 19 is  honest reputation: 0.14681291580200195
# Peer 20 is  honest reputation: 0.07111501693725586
# Peer 21 is  attacker reputation: -0.39535078406333923
# Peer 22 is  honest reputation: 0.05828911066055298
# Peer 23 is  honest reputation: 0.08738827705383301
# Peer 24 is  attacker reputation: -0.4319266974925995
# Peer 25 is  honest reputation: 0.07054966688156128
# Peer 26 is  honest reputation: 0.04357701539993286
# Peer 27 is  honest reputation: 0.03738147020339966
# Peer 28 is  attacker reputation: -0.4415435791015625
# Peer 29 is  attacker reputation: -0.3870088756084442
# Peer 30 is  honest reputation: 0.06670606136322021
# Peer 31 is  honest reputation: 0.046160876750946045
# Peer 32 is  attacker reputation: -0.3529786765575409
# Peer 33 is  honest reputation: 0.05828726291656494
# Peer 34 is  attacker reputation: -0.4505661129951477
# Peer 35 is  honest reputation: 0.017418324947357178
# Peer 36 is  honest reputation: 0.05567669868469238
# Peer 37 is  honest reputation: 0.0558314323425293
# Peer 38 is  honest reputation: 0.05633282661437988
# Peer 39 is  honest reputation: 0.003834664821624756
# Peer 40 is  honest reputation: 0.06123709678649902
# Peer 41 is  honest reputation: 0.030554890632629395
# Peer 42 is  honest reputation: 0.016924679279327393
# Peer 43 is  attacker reputation: -0.3904106914997101
# Peer 44 is  honest reputation: 0.04628509283065796
# Peer 45 is  honest reputation: 0.08076924085617065
# Peer 46 is  attacker reputation: -0.4340220093727112
# Peer 47 is  honest reputation: 0.09080857038497925
# Peer 48 is  honest reputation: 0.05702608823776245
# Peer 49 is  honest reputation: 0.05745124816894531
# Peer 50 is  honest reputation: 0.05981278419494629
# Peer 51 is  honest reputation: 0.05317157506942749
# Peer 52 is  honest reputation: 0.08309292793273926
# Peer 53 is  honest reputation: 0.04334855079650879
# Peer 54 is  honest reputation: 0.025476396083831787
# Peer 55 is  honest reputation: 0.05923748016357422
# Peer 56 is  honest reputation: 0.02101367712020874
# Peer 57 is  attacker reputation: -0.4025219976902008
# Peer 58 is  honest reputation: 0.10052067041397095
# Peer 59 is  honest reputation: 0.0472644567489624
# Peer 60 is  attacker reputation: -0.3783617317676544
# Peer 61 is  honest reputation: 0.04499506950378418
# Peer 62 is  honest reputation: 0.047044575214385986
# Peer 63 is  honest reputation: 0.1071733832359314
# Peer 64 is  honest reputation: 0.05402040481567383
# Peer 65 is  honest reputation: 0.010860025882720947
# Peer 66 is  honest reputation: 0.0444294810295105
# Peer 67 is  honest reputation: 0.03153902292251587
# Peer 68 is  honest reputation: 0.023168861865997314
# Peer 69 is  honest reputation: 0.08422738313674927
# Peer 70 is  honest reputation: 0.07104998826980591
# Peer 71 is  honest reputation: 0.12171077728271484
# Peer 72 is  honest reputation: 0.09424108266830444
# Peer 73 is  honest reputation: 0.030030548572540283
# Peer 74 is  honest reputation: 0.08608156442642212
# Peer 75 is  attacker reputation: -0.37534239888191223
# Peer 76 is  honest reputation: 0.060761988162994385
# Peer 77 is  honest reputation: 0.023502588272094727
# Peer 78 is  honest reputation: 0.04160231351852417
# Peer 79 is  honest reputation: 0.05071210861206055
# Peer 80 is  honest reputation: 0.043001532554626465
# Peer 81 is  honest reputation: 0.040804505348205566
# Peer 82 is  honest reputation: 0.029262840747833252
# Peer 83 is  honest reputation: 0.02719569206237793
# Peer 84 is  honest reputation: 0.0458335280418396
# Peer 85 is  honest reputation: 0.029873311519622803
# Peer 86 is  honest reputation: 0.051483094692230225
# Peer 87 is  attacker reputation: -0.4114770293235779
# Peer 88 is  honest reputation: 0.03984951972961426
# Peer 89 is  honest reputation: 0.0776485800743103
# Peer 90 is  attacker reputation: -0.4349280297756195
# Peer 92 is  attacker reputation: -0.37706515192985535
# Peer 93 is  honest reputation: 0.06239813566207886
# Peer 94 is  honest reputation: 0.02340829372406006
# Peer 95 is  honest reputation: 0.031962573528289795
# Peer 96 is  honest reputation: 0.05640912055969238
# Peer 97 is  attacker reputation: -0.4019031822681427
# Peer 98 is  attacker reputation: -0.3872036039829254
# Peer 99 is  attacker reputation: -0.43225598335266113
# 91 Aggregation took 0.2037
# attack 99 Average test loss: 12.4935, Test accuracy: 1069/10000 (10.69%)
#
# honest 91 Average test loss: 2.2706, Test accuracy: 2079/10000 (20.79%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 21.9
# Two        - 57.2
# Three      - 11.2
# Four       - 0.0
# Five       - 0.0
# Six        - 0.0
# Seven      - 18.1
# Eight      - 46.1
# Nine       - 57.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
# 8 gaussian_noise attack ！
# 12 gaussian_noise attack ！
# 13 gaussian_noise attack ！
# 21 gaussian_noise attack ！
# 24 gaussian_noise attack ！
# 28 gaussian_noise attack ！
# 29 gaussian_noise attack ！
# 32 gaussian_noise attack ！
# 34 gaussian_noise attack ！
# 43 gaussian_noise attack ！
# 46 gaussian_noise attack ！
# 57 gaussian_noise attack ！
# 60 gaussian_noise attack ！
# 75 gaussian_noise attack ！
# 87 gaussian_noise attack ！
# 90 gaussian_noise attack ！
# 92 gaussian_noise attack ！
# 97 gaussian_noise attack ！
# 98 gaussian_noise attack ！
# 99 gaussian_noise attack ！
# Average of peers' local losses: 3.055082
#
# 91selected Peers:
# Peer 74 is  honest reputation: 0.1741275191307068
# Peer 83 is  honest reputation: 0.11697953939437866
# Peer 28 is  attacker reputation: -0.6352611184120178
# Peer 10 is  honest reputation: 0.06216007471084595
# Peer 14 is  honest reputation: 0.03186655044555664
# Peer 89 is  honest reputation: 0.07739871740341187
# Peer 33 is  honest reputation: 0.06085860729217529
# Peer 62 is  honest reputation: 0.05587679147720337
# Peer 97 is  attacker reputation: -0.5917002558708191
# Peer 39 is  honest reputation: 0.07459074258804321
# Peer 73 is  honest reputation: 0.05973285436630249
# Peer 12 is  attacker reputation: -0.62999027967453
# Peer 75 is  attacker reputation: -0.5751569271087646
# Peer 16 is  honest reputation: 0.14317727088928223
# Peer 96 is  honest reputation: 0.06596362590789795
# Peer 6 is  honest reputation: 0.11527246236801147
# Peer 67 is  honest reputation: 0.04375737905502319
# Peer 52 is  honest reputation: 0.14105772972106934
# Peer 21 is  attacker reputation: -0.6167217493057251
# Peer 59 is  honest reputation: 0.046173274517059326
# Peer 42 is  honest reputation: 0.06155973672866821
# Peer 5 is  honest reputation: 0.09791386127471924
# Peer 98 is  attacker reputation: -0.5789342522621155
# Peer 82 is  honest reputation: 0.09703254699707031
# Peer 18 is  honest reputation: 0.03440201282501221
# Peer 57 is  attacker reputation: -0.5826853513717651
# Peer 13 is  attacker reputation: -0.6118154227733612
# Peer 34 is  attacker reputation: -0.6776266694068909
# Peer 80 is  honest reputation: 0.045648813247680664
# Peer 23 is  honest reputation: 0.09077495336532593
# Peer 86 is  honest reputation: 0.080005943775177
# Peer 29 is  attacker reputation: -0.5988177061080933
# Peer 11 is  honest reputation: 0.11771005392074585
# Peer 36 is  honest reputation: 0.05875903367996216
# Peer 49 is  honest reputation: 0.1360573172569275
# Peer 78 is  honest reputation: 0.04293006658554077
# Peer 76 is  honest reputation: 0.12359970808029175
# Peer 60 is  attacker reputation: -0.5746758282184601
# Peer 53 is  honest reputation: 0.07049810886383057
# Peer 95 is  honest reputation: 0.028727829456329346
# Peer 31 is  honest reputation: 0.08177638053894043
# Peer 51 is  honest reputation: 0.10909038782119751
# Peer 45 is  honest reputation: 0.1689184308052063
# Peer 47 is  honest reputation: 0.17114371061325073
# Peer 70 is  honest reputation: 0.07434940338134766
# Peer 61 is  honest reputation: 0.08130234479904175
# Peer 92 is  attacker reputation: -0.5394632816314697
# Peer 25 is  honest reputation: 0.0832856297492981
# Peer 0 is  honest reputation: 0.09544438123703003
# Peer 4 is  honest reputation: 0.0926937460899353
# Peer 85 is  honest reputation: 0.09312176704406738
# Peer 17 is  honest reputation: 0.13753318786621094
# Peer 44 is  honest reputation: 0.11192071437835693
# Peer 38 is  honest reputation: 0.06578052043914795
# Peer 63 is  honest reputation: 0.19732487201690674
# Peer 87 is  attacker reputation: -0.6569910049438477
# Peer 26 is  honest reputation: 0.06999379396438599
# Peer 72 is  honest reputation: 0.12441885471343994
# Peer 64 is  honest reputation: 0.05981248617172241
# Peer 90 is  attacker reputation: -0.6810489296913147
# Peer 7 is  honest reputation: 0.09488832950592041
# Peer 77 is  honest reputation: 0.028647959232330322
# Peer 41 is  honest reputation: 0.10812419652938843
# Peer 35 is  honest reputation: 0.10865199565887451
# Peer 15 is  honest reputation: 0.14401906728744507
# Peer 2 is  honest reputation: 0.035130202770233154
# Peer 69 is  honest reputation: 0.08648014068603516
# Peer 88 is  honest reputation: 0.04682213068008423
# Peer 54 is  honest reputation: 0.03687942028045654
# Peer 30 is  honest reputation: 0.11777669191360474
# Peer 94 is  honest reputation: 0.07077604532241821
# Peer 71 is  honest reputation: 0.16211605072021484
# Peer 56 is  honest reputation: 0.021268606185913086
# Peer 48 is  honest reputation: 0.11575055122375488
# Peer 68 is  honest reputation: 0.05567711591720581
# Peer 24 is  attacker reputation: -0.6301247179508209
# Peer 58 is  honest reputation: 0.10342055559158325
# Peer 19 is  honest reputation: 0.2101510763168335
# Peer 93 is  honest reputation: 0.0689237117767334
# Peer 9 is  honest reputation: 0.11517685651779175
# Peer 22 is  honest reputation: 0.10960900783538818
# Peer 8 is  attacker reputation: -0.593546986579895
# Peer 32 is  attacker reputation: -0.5329823791980743
# Peer 20 is  honest reputation: 0.14628082513809204
# Peer 37 is  honest reputation: 0.06314802169799805
# Peer 84 is  honest reputation: 0.04825800657272339
# Peer 65 is  honest reputation: 0.01562744379043579
# Peer 46 is  attacker reputation: -0.594418853521347
# Peer 91 is  honest reputation: 10.0
# Peer 50 is  honest reputation: 0.12787002325057983
# Peer 55 is  honest reputation: 0.061626136302948
# Peer 3 is  honest reputation: 0.12292975187301636
# Peer 99 is  attacker reputation: -0.6169426441192627
# Peer 66 is  honest reputation: 0.05382293462753296
# Peer 81 is  honest reputation: 0.03693598508834839
# Peer 27 is  honest reputation: 0.04311555624008179
# Peer 1 is  honest reputation: 0.13630598783493042
# Peer 40 is  honest reputation: 0.09158545732498169
# Peer 79 is  honest reputation: 0.1038358211517334
# Peer 43 is  attacker reputation: -0.5876061916351318
#
# 91selected Peers after refuse(delete 0):
# Peer 0 is  honest reputation: 0.09544438123703003
# Peer 1 is  honest reputation: 0.13630598783493042
# Peer 2 is  honest reputation: 0.035130202770233154
# Peer 3 is  honest reputation: 0.12292975187301636
# Peer 4 is  honest reputation: 0.0926937460899353
# Peer 5 is  honest reputation: 0.09791386127471924
# Peer 6 is  honest reputation: 0.11527246236801147
# Peer 7 is  honest reputation: 0.09488832950592041
# Peer 8 is  attacker reputation: -0.593546986579895
# Peer 9 is  honest reputation: 0.11517685651779175
# Peer 10 is  honest reputation: 0.06216007471084595
# Peer 11 is  honest reputation: 0.11771005392074585
# Peer 12 is  attacker reputation: -0.62999027967453
# Peer 13 is  attacker reputation: -0.6118154227733612
# Peer 14 is  honest reputation: 0.03186655044555664
# Peer 15 is  honest reputation: 0.14401906728744507
# Peer 16 is  honest reputation: 0.14317727088928223
# Peer 17 is  honest reputation: 0.13753318786621094
# Peer 18 is  honest reputation: 0.03440201282501221
# Peer 19 is  honest reputation: 0.2101510763168335
# Peer 20 is  honest reputation: 0.14628082513809204
# Peer 21 is  attacker reputation: -0.6167217493057251
# Peer 22 is  honest reputation: 0.10960900783538818
# Peer 23 is  honest reputation: 0.09077495336532593
# Peer 24 is  attacker reputation: -0.6301247179508209
# Peer 25 is  honest reputation: 0.0832856297492981
# Peer 26 is  honest reputation: 0.06999379396438599
# Peer 27 is  honest reputation: 0.04311555624008179
# Peer 28 is  attacker reputation: -0.6352611184120178
# Peer 29 is  attacker reputation: -0.5988177061080933
# Peer 30 is  honest reputation: 0.11777669191360474
# Peer 31 is  honest reputation: 0.08177638053894043
# Peer 32 is  attacker reputation: -0.5329823791980743
# Peer 33 is  honest reputation: 0.06085860729217529
# Peer 34 is  attacker reputation: -0.6776266694068909
# Peer 35 is  honest reputation: 0.10865199565887451
# Peer 36 is  honest reputation: 0.05875903367996216
# Peer 37 is  honest reputation: 0.06314802169799805
# Peer 38 is  honest reputation: 0.06578052043914795
# Peer 39 is  honest reputation: 0.07459074258804321
# Peer 40 is  honest reputation: 0.09158545732498169
# Peer 41 is  honest reputation: 0.10812419652938843
# Peer 42 is  honest reputation: 0.06155973672866821
# Peer 43 is  attacker reputation: -0.5876061916351318
# Peer 44 is  honest reputation: 0.11192071437835693
# Peer 45 is  honest reputation: 0.1689184308052063
# Peer 46 is  attacker reputation: -0.594418853521347
# Peer 47 is  honest reputation: 0.17114371061325073
# Peer 48 is  honest reputation: 0.11575055122375488
# Peer 49 is  honest reputation: 0.1360573172569275
# Peer 50 is  honest reputation: 0.12787002325057983
# Peer 51 is  honest reputation: 0.10909038782119751
# Peer 52 is  honest reputation: 0.14105772972106934
# Peer 53 is  honest reputation: 0.07049810886383057
# Peer 54 is  honest reputation: 0.03687942028045654
# Peer 55 is  honest reputation: 0.061626136302948
# Peer 56 is  honest reputation: 0.021268606185913086
# Peer 57 is  attacker reputation: -0.5826853513717651
# Peer 58 is  honest reputation: 0.10342055559158325
# Peer 59 is  honest reputation: 0.046173274517059326
# Peer 60 is  attacker reputation: -0.5746758282184601
# Peer 61 is  honest reputation: 0.08130234479904175
# Peer 62 is  honest reputation: 0.05587679147720337
# Peer 63 is  honest reputation: 0.19732487201690674
# Peer 64 is  honest reputation: 0.05981248617172241
# Peer 65 is  honest reputation: 0.01562744379043579
# Peer 66 is  honest reputation: 0.05382293462753296
# Peer 67 is  honest reputation: 0.04375737905502319
# Peer 68 is  honest reputation: 0.05567711591720581
# Peer 69 is  honest reputation: 0.08648014068603516
# Peer 70 is  honest reputation: 0.07434940338134766
# Peer 71 is  honest reputation: 0.16211605072021484
# Peer 72 is  honest reputation: 0.12441885471343994
# Peer 73 is  honest reputation: 0.05973285436630249
# Peer 74 is  honest reputation: 0.1741275191307068
# Peer 75 is  attacker reputation: -0.5751569271087646
# Peer 76 is  honest reputation: 0.12359970808029175
# Peer 77 is  honest reputation: 0.028647959232330322
# Peer 78 is  honest reputation: 0.04293006658554077
# Peer 79 is  honest reputation: 0.1038358211517334
# Peer 80 is  honest reputation: 0.045648813247680664
# Peer 81 is  honest reputation: 0.03693598508834839
# Peer 82 is  honest reputation: 0.09703254699707031
# Peer 83 is  honest reputation: 0.11697953939437866
# Peer 84 is  honest reputation: 0.04825800657272339
# Peer 85 is  honest reputation: 0.09312176704406738
# Peer 86 is  honest reputation: 0.080005943775177
# Peer 87 is  attacker reputation: -0.6569910049438477
# Peer 88 is  honest reputation: 0.04682213068008423
# Peer 89 is  honest reputation: 0.07739871740341187
# Peer 90 is  attacker reputation: -0.6810489296913147
# Peer 92 is  attacker reputation: -0.5394632816314697
# Peer 93 is  honest reputation: 0.0689237117767334
# Peer 94 is  honest reputation: 0.07077604532241821
# Peer 95 is  honest reputation: 0.028727829456329346
# Peer 96 is  honest reputation: 0.06596362590789795
# Peer 97 is  attacker reputation: -0.5917002558708191
# Peer 98 is  attacker reputation: -0.5789342522621155
# Peer 99 is  attacker reputation: -0.6169426441192627
# 91 Aggregation took 0.2246
# attack 99 Average test loss: 7.5337, Test accuracy: 1072/10000 (10.72%)
#
# honest 91 Average test loss: 2.2586, Test accuracy: 2976/10000 (29.76%)
#
# Class      - Accuracy
# Zero       - 0.8
# One        - 58.4
# Two        - 59.4
# Three      - 26.6
# Four       - 0.0
# Five       - 0.0
# Six        - 2.0
# Seven      - 43.7
# Eight      - 53.5
# Nine       - 56.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
# 8 gaussian_noise attack ！
# 12 gaussian_noise attack ！
# 13 gaussian_noise attack ！
# 21 gaussian_noise attack ！
# 24 gaussian_noise attack ！
# 28 gaussian_noise attack ！
# 29 gaussian_noise attack ！
# 32 gaussian_noise attack ！
# 34 gaussian_noise attack ！
# 43 gaussian_noise attack ！
# 46 gaussian_noise attack ！
# 57 gaussian_noise attack ！
# 60 gaussian_noise attack ！
# 75 gaussian_noise attack ！
# 87 gaussian_noise attack ！
# 90 gaussian_noise attack ！
# 92 gaussian_noise attack ！
# 97 gaussian_noise attack ！
# 98 gaussian_noise attack ！
# 99 gaussian_noise attack ！
# Average of peers' local losses: 2.803097
#
# 91selected Peers:
# Peer 88 is  honest reputation: 0.10671842098236084
# Peer 25 is  honest reputation: 0.2153615951538086
# Peer 78 is  honest reputation: 0.09575378894805908
# Peer 95 is  honest reputation: 0.034681499004364014
# Peer 97 is  attacker reputation: -0.7878248691558838
# Peer 4 is  honest reputation: 0.19860219955444336
# Peer 73 is  honest reputation: 0.056561410427093506
# Peer 99 is  attacker reputation: -0.8174684345722198
# Peer 9 is  honest reputation: 0.19903439283370972
# Peer 21 is  attacker reputation: -0.8107695579528809
# Peer 68 is  honest reputation: 0.054593682289123535
# Peer 24 is  attacker reputation: -0.7641684412956238
# Peer 46 is  attacker reputation: -0.8166942894458771
# Peer 3 is  honest reputation: 0.19164156913757324
# Peer 72 is  honest reputation: 0.13430845737457275
# Peer 93 is  honest reputation: 0.08245128393173218
# Peer 79 is  honest reputation: 0.1177709698677063
# Peer 77 is  honest reputation: 0.11002218723297119
# Peer 67 is  honest reputation: 0.0948868989944458
# Peer 92 is  attacker reputation: -0.7237377762794495
# Peer 55 is  honest reputation: 0.17368924617767334
# Peer 20 is  honest reputation: 0.15135538578033447
# Peer 54 is  honest reputation: 0.13830935955047607
# Peer 85 is  honest reputation: 0.15496641397476196
# Peer 49 is  honest reputation: 0.1386151909828186
# Peer 5 is  honest reputation: 0.0994749665260315
# Peer 63 is  honest reputation: 0.2587875723838806
# Peer 14 is  honest reputation: 0.05088794231414795
# Peer 41 is  honest reputation: 0.15864580869674683
# Peer 61 is  honest reputation: 0.09593653678894043
# Peer 53 is  honest reputation: 0.07946020364761353
# Peer 60 is  attacker reputation: -0.7597103416919708
# Peer 15 is  honest reputation: 0.17579913139343262
# Peer 30 is  honest reputation: 0.1617293357849121
# Peer 69 is  honest reputation: 0.10221850872039795
# Peer 1 is  honest reputation: 0.13774043321609497
# Peer 27 is  honest reputation: 0.11191129684448242
# Peer 13 is  attacker reputation: -0.8129745125770569
# Peer 89 is  honest reputation: 0.20334899425506592
# Peer 51 is  honest reputation: 0.12228679656982422
# Peer 74 is  honest reputation: 0.2753205895423889
# Peer 29 is  attacker reputation: -0.76081782579422
# Peer 22 is  honest reputation: 0.19940310716629028
# Peer 65 is  honest reputation: 0.03301382064819336
# Peer 82 is  honest reputation: 0.232671320438385
# Peer 33 is  honest reputation: 0.1690806746482849
# Peer 56 is  honest reputation: 0.09716898202896118
# Peer 76 is  honest reputation: 0.26134657859802246
# Peer 86 is  honest reputation: 0.1516503095626831
# Peer 87 is  attacker reputation: -0.8449236750602722
# Peer 45 is  honest reputation: 0.18027102947235107
# Peer 8 is  attacker reputation: -0.7994126379489899
# Peer 94 is  honest reputation: 0.08992421627044678
# Peer 31 is  honest reputation: 0.1435731053352356
# Peer 11 is  honest reputation: 0.11807119846343994
# Peer 48 is  honest reputation: 0.15788275003433228
# Peer 91 is  honest reputation: 10.0
# Peer 80 is  honest reputation: 0.11185586452484131
# Peer 18 is  honest reputation: 0.12197625637054443
# Peer 62 is  honest reputation: 0.062006473541259766
# Peer 64 is  honest reputation: 0.17664599418640137
# Peer 28 is  attacker reputation: -0.8157236874103546
# Peer 50 is  honest reputation: 0.13746535778045654
# Peer 32 is  attacker reputation: -0.7230094373226166
# Peer 34 is  attacker reputation: -0.8766569495201111
# Peer 0 is  honest reputation: 0.10024261474609375
# Peer 75 is  attacker reputation: -0.7769429683685303
# Peer 17 is  honest reputation: 0.14066511392593384
# Peer 6 is  honest reputation: 0.19490933418273926
# Peer 57 is  attacker reputation: -0.7836976945400238
# Peer 16 is  honest reputation: 0.2045772671699524
# Peer 96 is  honest reputation: 0.08125776052474976
# Peer 38 is  honest reputation: 0.1531795859336853
# Peer 98 is  attacker reputation: -0.7644066214561462
# Peer 59 is  honest reputation: 0.06293708086013794
# Peer 7 is  honest reputation: 0.2108992338180542
# Peer 90 is  attacker reputation: -0.8868428170681
# Peer 58 is  honest reputation: 0.20355147123336792
# Peer 23 is  honest reputation: 0.14827829599380493
# Peer 2 is  honest reputation: 0.09400433301925659
# Peer 10 is  honest reputation: 0.1440274715423584
# Peer 12 is  attacker reputation: -0.8173200786113739
# Peer 66 is  honest reputation: 0.11665666103363037
# Peer 71 is  honest reputation: 0.25980329513549805
# Peer 35 is  honest reputation: 0.103970468044281
# Peer 52 is  honest reputation: 0.21166163682937622
# Peer 40 is  honest reputation: 0.0900987982749939
# Peer 36 is  honest reputation: 0.0646355152130127
# Peer 39 is  honest reputation: 0.10806787014007568
# ...
# Peer 94 is  honest reputation: 2.096254289150238
# Peer 84 is  honest reputation: 2.641599178314209
# Peer 81 is  honest reputation: 2.7221835255622864
# Peer 3 is  honest reputation: 1.7142637968063354
# Peer 56 is  honest reputation: 2.8221957683563232
# Peer 26 is  honest reputation: 2.8116666078567505
# Peer 77 is  honest reputation: 2.5149856209754944
# Peer 2 is  honest reputation: 2.2256866693496704
# Peer 85 is  honest reputation: 3.0749510526657104
# Peer 23 is  honest reputation: 1.8410354256629944
# Peer 65 is  honest reputation: 1.6294564008712769
# Peer 67 is  honest reputation: 2.4999032616615295
# Peer 48 is  honest reputation: 3.1644376516342163
# Peer 14 is  honest reputation: 1.156197965145111
# Peer 18 is  honest reputation: 2.9160231351852417
# Peer 40 is  honest reputation: 2.2047295570373535
# Peer 55 is  honest reputation: 2.0620192885398865
# Peer 19 is  honest reputation: 2.447383224964142
# Peer 63 is  honest reputation: 0.46173185110092163
#
# 91selected Peers after refuse(delete 25):
# Peer 0 is  honest reputation: 2.5161755084991455
# Peer 1 is  honest reputation: 2.249577820301056
# Peer 2 is  honest reputation: 2.2256866693496704
# Peer 3 is  honest reputation: 1.7142637968063354
# Peer 4 is  honest reputation: 2.4504401087760925
# Peer 5 is  honest reputation: 2.690039098262787
# Peer 6 is  honest reputation: 1.9258590340614319
# Peer 7 is  honest reputation: 2.6625806093215942
# Peer 9 is  honest reputation: 2.4092986583709717
# Peer 10 is  honest reputation: 2.7114866971969604
# Peer 11 is  honest reputation: 1.5337612628936768
# Peer 14 is  honest reputation: 1.156197965145111
# Peer 15 is  honest reputation: 1.7059068083763123
# Peer 16 is  honest reputation: 2.693366587162018
# Peer 17 is  honest reputation: 2.567811071872711
# Peer 18 is  honest reputation: 2.9160231351852417
# Peer 19 is  honest reputation: 2.447383224964142
# Peer 20 is  honest reputation: 2.2673100233078003
# Peer 22 is  honest reputation: 1.7216010689735413
# Peer 23 is  honest reputation: 1.8410354256629944
# Peer 25 is  honest reputation: 1.8952977061271667
# Peer 26 is  honest reputation: 2.8116666078567505
# Peer 27 is  honest reputation: 2.571453809738159
# Peer 30 is  honest reputation: 2.2726219296455383
# Peer 31 is  honest reputation: 2.493420720100403
# Peer 33 is  honest reputation: 2.1449277997016907
# Peer 35 is  honest reputation: 2.393582344055176
# Peer 36 is  honest reputation: 1.98306405544281
# Peer 37 is  honest reputation: 2.7248752117156982
# Peer 38 is  honest reputation: 1.6610976457595825
# Peer 39 is  honest reputation: 2.6538578867912292
# Peer 40 is  honest reputation: 2.2047295570373535
# Peer 41 is  honest reputation: 2.456161379814148
# Peer 42 is  honest reputation: 2.8211764097213745
# Peer 44 is  honest reputation: 2.3514370918273926
# Peer 45 is  honest reputation: 2.5914247035980225
# Peer 47 is  honest reputation: 2.866431772708893
# Peer 48 is  honest reputation: 3.1644376516342163
# Peer 49 is  honest reputation: 2.721618890762329
# Peer 52 is  honest reputation: 2.1918954253196716
# Peer 54 is  honest reputation: 2.5610361099243164
# Peer 55 is  honest reputation: 2.0620192885398865
# Peer 56 is  honest reputation: 2.8221957683563232
# Peer 58 is  honest reputation: 2.2489892840385437
# Peer 61 is  honest reputation: 3.1612783074378967
# Peer 62 is  honest reputation: 2.4847137928009033
# Peer 64 is  honest reputation: 1.8734824657440186
# Peer 65 is  honest reputation: 1.6294564008712769
# Peer 66 is  honest reputation: 2.4972426295280457
# Peer 67 is  honest reputation: 2.4999032616615295
# Peer 69 is  honest reputation: 2.931009292602539
# Peer 70 is  honest reputation: 2.3539053797721863
# Peer 71 is  honest reputation: 2.2189866304397583
# Peer 72 is  honest reputation: 2.9970494508743286
# Peer 74 is  honest reputation: 2.574699282646179
# Peer 76 is  honest reputation: 2.3030861616134644
# Peer 77 is  honest reputation: 2.5149856209754944
# Peer 79 is  honest reputation: 2.672560393810272
# Peer 80 is  honest reputation: 2.9308796525001526
# Peer 81 is  honest reputation: 2.7221835255622864
# Peer 82 is  honest reputation: 2.55942165851593
# Peer 83 is  honest reputation: 2.712165117263794
# Peer 84 is  honest reputation: 2.641599178314209
# Peer 85 is  honest reputation: 3.0749510526657104
# Peer 86 is  honest reputation: 2.3282352685928345
# Peer 88 is  honest reputation: 1.74671471118927
# Peer 89 is  honest reputation: 2.8800072073936462
# Peer 93 is  honest reputation: 2.9456029534339905
# Peer 94 is  honest reputation: 2.096254289150238
# Peer 95 is  honest reputation: 2.587056040763855
# Peer 96 is  honest reputation: 1.9600805044174194
# 91 Aggregation took 0.1429
# attack 99 Average test loss: 2.3834, Test accuracy: 1032/10000 (10.32%)
#
# honest 91 Average test loss: 0.1805, Test accuracy: 9439/10000 (94.39%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 97.8
# Two        - 93.0
# Three      - 93.8
# Four       - 93.3
# Five       - 94.1
# Six        - 94.7
# Seven      - 91.5
# Eight      - 93.3
# Nine       - 93.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
# 8 gaussian_noise attack ！
# 12 gaussian_noise attack ！
# 13 gaussian_noise attack ！
# 21 gaussian_noise attack ！
# 24 gaussian_noise attack ！
# 28 gaussian_noise attack ！
# 29 gaussian_noise attack ！
# 32 gaussian_noise attack ！
# 34 gaussian_noise attack ！
# 43 gaussian_noise attack ！
# 46 gaussian_noise attack ！
# 57 gaussian_noise attack ！
# 60 gaussian_noise attack ！
# 75 gaussian_noise attack ！
# 87 gaussian_noise attack ！
# 90 gaussian_noise attack ！
# 92 gaussian_noise attack ！
# 97 gaussian_noise attack ！
# 98 gaussian_noise attack ！
# 99 gaussian_noise attack ！
# Average of peers' local losses: 0.816290
#
# 91selected Peers:
# Peer 44 is  honest reputation: 2.364607810974121
# Peer 35 is  honest reputation: 2.40773743391037
# Peer 26 is  honest reputation: 2.848770260810852
# Peer 70 is  honest reputation: 2.411772668361664
# Peer 58 is  honest reputation: 2.329200267791748
# Peer 83 is  honest reputation: 2.689655363559723
# Peer 45 is  honest reputation: 2.5779577493667603
# Peer 72 is  honest reputation: 3.085797667503357
# Peer 18 is  honest reputation: 2.9150615334510803
# Peer 39 is  honest reputation: 2.6514715552330017
# Peer 52 is  honest reputation: 2.2500282526016235
# Peer 2 is  honest reputation: 2.2357524633407593
# Peer 0 is  honest reputation: 2.5962494015693665
# Peer 80 is  honest reputation: 2.9438640475273132
# Peer 55 is  honest reputation: 2.0719745755195618
# Peer 95 is  honest reputation: 2.5851470828056335
# Peer 89 is  honest reputation: 2.900619685649872
# Peer 64 is  honest reputation: 1.9036612510681152
# Peer 9 is  honest reputation: 2.4659642577171326
# Peer 7 is  honest reputation: 2.6871355175971985
# Peer 20 is  honest reputation: 2.3392274975776672
# Peer 71 is  honest reputation: 2.217188775539398
# Peer 62 is  honest reputation: 2.536605715751648
# Peer 76 is  honest reputation: 2.3123778700828552
# Peer 36 is  honest reputation: 2.01496022939682
# Peer 82 is  honest reputation: 2.546445846557617
# Peer 79 is  honest reputation: 2.694173038005829
# Peer 6 is  honest reputation: 1.9029112458229065
# Peer 11 is  honest reputation: 1.5332226753234863
# Peer 38 is  honest reputation: 1.6966124773025513
# Peer 37 is  honest reputation: 2.734510362148285
# Peer 23 is  honest reputation: 1.875813066959381
# Peer 10 is  honest reputation: 2.7467836141586304
# Peer 14 is  honest reputation: 1.1607350707054138
# Peer 1 is  honest reputation: 2.2409298419952393
# Peer 77 is  honest reputation: 2.570356607437134
# Peer 17 is  honest reputation: 2.5911030769348145
# Peer 50 is  honest reputation: 0.22471129894256592
# Peer 27 is  honest reputation: 2.5731313824653625
# Peer 3 is  honest reputation: 1.708325982093811
# Peer 15 is  honest reputation: 1.7171990275382996
# Peer 19 is  honest reputation: 2.446669042110443
# Peer 49 is  honest reputation: 2.749151289463043
# Peer 47 is  honest reputation: 2.8898083567619324
# Peer 96 is  honest reputation: 2.009364128112793
# Peer 25 is  honest reputation: 1.904461920261383
# Peer 91 is  honest reputation: 10.0
# Peer 94 is  honest reputation: 2.1953929662704468
# Peer 30 is  honest reputation: 2.281255841255188
# Peer 41 is  honest reputation: 2.4416322112083435
# Peer 69 is  honest reputation: 2.9920994639396667
# Peer 4 is  honest reputation: 2.4423230290412903
# Peer 63 is  honest reputation: 0.46173185110092163
# Peer 53 is  honest reputation: 0.24165254831314087
# Peer 65 is  honest reputation: 1.6533945798873901
# Peer 61 is  honest reputation: 3.1935837864875793
# Peer 81 is  honest reputation: 2.717781901359558
# Peer 16 is  honest reputation: 2.7213266491889954
# Peer 54 is  honest reputation: 2.581112563610077
# Peer 40 is  honest reputation: 2.2243086099624634
# Peer 88 is  honest reputation: 1.787100911140442
# Peer 22 is  honest reputation: 1.7693836688995361
# Peer 86 is  honest reputation: 2.4381117820739746
# Peer 74 is  honest reputation: 2.6503503918647766
# Peer 5 is  honest reputation: 2.6978678107261658
# Peer 33 is  honest reputation: 2.116965591907501
# Peer 67 is  honest reputation: 2.5313668251037598
# Peer 66 is  honest reputation: 2.5553179383277893
# Peer 93 is  honest reputation: 2.945782482624054
# Peer 42 is  honest reputation: 2.868294417858124
# Peer 85 is  honest reputation: 3.1084789037704468
# Peer 48 is  honest reputation: 3.2208682894706726
# Peer 84 is  honest reputation: 2.636127471923828
# Peer 31 is  honest reputation: 2.560505449771881
# Peer 56 is  honest reputation: 2.8319717049598694
#
# 91selected Peers after refuse(delete 25):
# Peer 0 is  honest reputation: 2.5962494015693665
# Peer 1 is  honest reputation: 2.2409298419952393
# Peer 2 is  honest reputation: 2.2357524633407593
# Peer 3 is  honest reputation: 1.708325982093811
# Peer 4 is  honest reputation: 2.4423230290412903
# Peer 5 is  honest reputation: 2.6978678107261658
# Peer 6 is  honest reputation: 1.9029112458229065
# Peer 7 is  honest reputation: 2.6871355175971985
# Peer 9 is  honest reputation: 2.4659642577171326
# Peer 10 is  honest reputation: 2.7467836141586304
# Peer 11 is  honest reputation: 1.5332226753234863
# Peer 14 is  honest reputation: 1.1607350707054138
# Peer 15 is  honest reputation: 1.7171990275382996
# Peer 16 is  honest reputation: 2.7213266491889954
# Peer 17 is  honest reputation: 2.5911030769348145
# Peer 18 is  honest reputation: 2.9150615334510803
# Peer 19 is  honest reputation: 2.446669042110443
# Peer 20 is  honest reputation: 2.3392274975776672
# Peer 22 is  honest reputation: 1.7693836688995361
# Peer 23 is  honest reputation: 1.875813066959381
# Peer 25 is  honest reputation: 1.904461920261383
# Peer 26 is  honest reputation: 2.848770260810852
# Peer 27 is  honest reputation: 2.5731313824653625
# Peer 30 is  honest reputation: 2.281255841255188
# Peer 31 is  honest reputation: 2.560505449771881
# Peer 33 is  honest reputation: 2.116965591907501
# Peer 35 is  honest reputation: 2.40773743391037
# Peer 36 is  honest reputation: 2.01496022939682
# Peer 37 is  honest reputation: 2.734510362148285
# Peer 38 is  honest reputation: 1.6966124773025513
# Peer 39 is  honest reputation: 2.6514715552330017
# Peer 40 is  honest reputation: 2.2243086099624634
# Peer 41 is  honest reputation: 2.4416322112083435
# Peer 42 is  honest reputation: 2.868294417858124
# Peer 44 is  honest reputation: 2.364607810974121
# Peer 45 is  honest reputation: 2.5779577493667603
# Peer 47 is  honest reputation: 2.8898083567619324
# Peer 48 is  honest reputation: 3.2208682894706726
# Peer 49 is  honest reputation: 2.749151289463043
# Peer 52 is  honest reputation: 2.2500282526016235
# Peer 54 is  honest reputation: 2.581112563610077
# Peer 55 is  honest reputation: 2.0719745755195618
# Peer 56 is  honest reputation: 2.8319717049598694
# Peer 58 is  honest reputation: 2.329200267791748
# Peer 61 is  honest reputation: 3.1935837864875793
# Peer 62 is  honest reputation: 2.536605715751648
# Peer 64 is  honest reputation: 1.9036612510681152
# Peer 65 is  honest reputation: 1.6533945798873901
# Peer 66 is  honest reputation: 2.5553179383277893
# Peer 67 is  honest reputation: 2.5313668251037598
# Peer 69 is  honest reputation: 2.9920994639396667
# Peer 70 is  honest reputation: 2.411772668361664
# Peer 71 is  honest reputation: 2.217188775539398
# Peer 72 is  honest reputation: 3.085797667503357
# Peer 74 is  honest reputation: 2.6503503918647766
# Peer 76 is  honest reputation: 2.3123778700828552
# Peer 77 is  honest reputation: 2.570356607437134
# Peer 79 is  honest reputation: 2.694173038005829
# Peer 80 is  honest reputation: 2.9438640475273132
# Peer 81 is  honest reputation: 2.717781901359558
# Peer 82 is  honest reputation: 2.546445846557617
# Peer 83 is  honest reputation: 2.689655363559723
# Peer 84 is  honest reputation: 2.636127471923828
# Peer 85 is  honest reputation: 3.1084789037704468
# Peer 86 is  honest reputation: 2.4381117820739746
# Peer 88 is  honest reputation: 1.787100911140442
# Peer 89 is  honest reputation: 2.900619685649872
# Peer 93 is  honest reputation: 2.945782482624054
# Peer 94 is  honest reputation: 2.1953929662704468
# Peer 95 is  honest reputation: 2.5851470828056335
# Peer 96 is  honest reputation: 2.009364128112793
# 91 Aggregation took 0.1474
# attack 99 Average test loss: 2.3519, Test accuracy: 1008/10000 (10.08%)
#
# honest 91 Average test loss: 0.1667, Test accuracy: 9486/10000 (94.86%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.5
# Two        - 93.5
# Three      - 93.2
# Four       - 93.3
# Five       - 93.6
# Six        - 96.5
# Seven      - 91.5
# Eight      - 90.9
# Nine       - 93.6
#
# Backdoor ASR 0.0
# Last 10 updates results
# honest 91 Average test loss: 0.1856, Test accuracy: 9415/10000 (94.15%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.8
# Two        - 94.4
# Three      - 90.3
# Four       - 94.8
# Five       - 95.2
# Six        - 95.1
# Seven      - 94.1
# Eight      - 92.9
# Nine       - 92.3
# Global accuracies:  [13.82, 16.33, 20.79, 29.76, 37.08, 42.93, 48.78, 48.93, 60.91, 61.9, 64.24, 65.72, 67.31, 69.85, 73.43, 76.19, 77.81, 79.83, 80.06, 81.21, 83.06, 84.63, 84.85, 85.4, 85.78, 86.66, 87.53, 87.93, 87.92, 87.79, 88.65, 88.49, 89.12, 89.37, 89.92, 89.25, 89.66, 90.3, 89.98, 90.36, 90.45, 91.17, 90.53, 91.25, 90.91, 91.62, 91.58, 91.82, 91.75, 91.55, 91.25, 91.71, 91.67, 92.28, 92.21, 91.94, 91.98, 92.4, 92.33, 92.64, 92.86, 92.35, 93.07, 92.72, 92.74, 92.98, 93.07, 93.22, 93.19, 93.14, 94.09, 93.17, 93.38, 93.6, 93.52, 93.16, 93.18, 93.33, 93.82, 93.89, 94.14, 93.4, 94.07, 93.92, 93.81, 93.62, 93.74, 94.0, 94.4, 94.22, 94.13, 94.43, 94.37, 94.57, 94.29, 94.5, 93.94, 94.3, 94.39, 94.86, 94.15]
# Class 7 accuracies:  [8.27, 6.85, 18.15, 43.72, 71.37, 73.02, 83.78, 86.48, 90.44, 82.24, 88.04, 90.37, 91.77, 90.5, 89.0, 88.2, 89.31, 88.96, 84.86, 88.18, 89.35, 87.05, 90.4, 88.36, 88.54, 88.63, 86.85, 89.1, 89.39, 91.27, 90.25, 90.04, 88.81, 89.55, 91.37, 90.32, 89.85, 88.63, 90.76, 88.66, 90.8, 89.81, 89.46, 91.59, 89.68, 90.09, 90.58, 90.6, 88.66, 92.02, 90.21, 92.73, 90.77, 90.22, 89.84, 93.16, 91.22, 92.41, 91.05, 94.18, 91.47, 91.29, 93.02, 91.34, 90.42, 91.14, 92.3, 92.78, 91.67, 90.48, 90.79, 91.96, 92.0, 95.08, 93.09, 91.98, 92.94, 92.51, 93.25, 93.88, 92.4, 93.1, 91.38, 92.63, 92.26, 91.79, 91.98, 92.61, 92.12, 90.94, 92.07, 92.59, 90.85, 92.83, 92.84, 91.69, 93.82, 91.91, 91.52, 91.5, 94.14]
# Test loss: [2.2888, 2.2804, 2.2706, 2.2586, 2.2458, 2.2281, 2.2038, 2.1694, 2.1217, 2.065, 1.9851, 1.8726, 1.7425, 1.5904, 1.4175, 1.2792, 1.1353, 1.0213, 0.9254, 0.844, 0.7698, 0.6894, 0.6592, 0.6143, 0.5955, 0.5575, 0.5143, 0.5051, 0.4812, 0.477, 0.464, 0.4334, 0.4211, 0.4155, 0.3998, 0.3873, 0.3814, 0.3602, 0.3713, 0.3562, 0.3516, 0.3451, 0.34, 0.3286, 0.3302, 0.3105, 0.315, 0.3057, 0.3068, 0.2953, 0.2941, 0.2942, 0.2898, 0.278, 0.2817, 0.2766, 0.2724, 0.2643, 0.2682, 0.2569, 0.2531, 0.2593, 0.2374, 0.2406, 0.254, 0.2374, 0.2445, 0.2261, 0.2324, 0.2365, 0.214, 0.2297, 0.2323, 0.2252, 0.2206, 0.2268, 0.2287, 0.2207, 0.2085, 0.2116, 0.2019, 0.2205, 0.2018, 0.1996, 0.2118, 0.2115, 0.1937, 0.1994, 0.1866, 0.1952, 0.1939, 0.1855, 0.19, 0.1853, 0.1932, 0.1864, 0.2043, 0.1859, 0.1805, 0.1667, 0.1856]
# Label-flipping attack succes rate: 0.52
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.161
# honest!
# attacker!
# --> End of Experiment.
