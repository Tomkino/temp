# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'IID'
ALPHA = 1000000
NUM_PEERS = 100 # "number of peers: K" 
FRAC_PEERS = 0.5 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 100 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.001#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: fedavg
# Attack Type: gaussian_noise
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 94  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Average of peers' local losses: 2.303277
#
# Average test loss: 2.2893, Test accuracy: 1284/10000 (12.84%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 42.9
# Three      - 1.5
# Four       - 0.0
# Five       - 0.0
# Six        - 0.0
# Seven      - 6.8
# Eight      - 30.6
# Nine       - 45.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Average of peers' local losses: 2.292384
#
# Average test loss: 2.2794, Test accuracy: 1679/10000 (16.79%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 2.7
# Two        - 51.3
# Three      - 8.4
# Four       - 0.0
# Five       - 0.1
# Six        - 0.0
# Seven      - 12.2
# Eight      - 32.2
# Nine       - 53.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 21  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Average of peers' local losses: 2.283446
#
# Average test loss: 2.2704, Test accuracy: 2244/10000 (22.44%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 17.1
# Two        - 59.0
# Three      - 23.2
# Four       - 0.0
# Five       - 0.6
# Six        - 0.0
# Seven      - 26.1
# Eight      - 35.0
# Nine       - 57.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 20  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Average of peers' local losses: 2.273835
#
# Average test loss: 2.2589, Test accuracy: 2945/10000 (29.45%)
#
# Class      - Accuracy
# Zero       - 1.2
# One        - 44.6
# Two        - 65.0
# Three      - 34.1
# Four       - 0.0
# Five       - 0.3
# Six        - 0.0
# Seven      - 49.8
# Eight      - 42.6
# Nine       - 62.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 66  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 2.262876
#
# Average test loss: 2.2430, Test accuracy: 3684/10000 (36.84%)
#
# Class      - Accuracy
# Zero       - 6.0
# One        - 66.3
# Two        - 63.9
# Three      - 48.3
# Four       - 0.7
# Five       - 0.8
# Six        - 1.6
# Seven      - 67.8
# Eight      - 51.9
# Nine       - 63.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 69  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Average of peers' local losses: 2.249234
#
# Average test loss: 2.2259, Test accuracy: 4225/10000 (42.25%)
#
# Class      - Accuracy
# Zero       - 26.0
# One        - 76.2
# Two        - 64.3
# Three      - 55.3
# Four       - 7.1
# Five       - 0.6
# Six        - 9.0
# Seven      - 79.0
# Eight      - 58.4
# Nine       - 66.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Average of peers' local losses: 2.233163
#
# Average test loss: 2.2007, Test accuracy: 4974/10000 (49.74%)
#
# Class      - Accuracy
# Zero       - 48.0
# One        - 82.0
# Two        - 60.9
# Three      - 55.2
# Four       - 16.4
# Five       - 1.5
# Six        - 18.5
# Seven      - 87.1
# Eight      - 70.3
# Nine       - 61.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 98  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Average of peers' local losses: 2.210852
#
# Average test loss: 2.1688, Test accuracy: 5468/10000 (54.68%)
#
# Class      - Accuracy
# Zero       - 69.3
# One        - 87.4
# Two        - 54.1
# Three      - 59.6
# Four       - 24.3
# Five       - 2.9
# Six        - 35.2
# Seven      - 86.0
# Eight      - 69.7
# Nine       - 59.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 33  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Average of peers' local losses: 2.181541
#
# Average test loss: 2.1255, Test accuracy: 5957/10000 (59.57%)
#
# Class      - Accuracy
# Zero       - 83.4
# One        - 92.4
# Two        - 53.1
# Three      - 62.2
# Four       - 32.9
# Five       - 3.0
# Six        - 53.3
# Seven      - 87.3
# Eight      - 70.9
# Nine       - 45.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 68  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Average of peers' local losses: 2.141639
#
# Average test loss: 2.0614, Test accuracy: 6138/10000 (61.38%)
#
# Class      - Accuracy
# Zero       - 88.5
# One        - 94.0
# Two        - 45.1
# Three      - 69.0
# Four       - 41.7
# Five       - 4.2
# Six        - 65.5
# Seven      - 89.3
# Eight      - 71.1
# Nine       - 43.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 56  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Average of peers' local losses: 2.089361
#
# Average test loss: 1.9774, Test accuracy: 6409/10000 (64.09%)
#
# Class      - Accuracy
# Zero       - 94.5
# One        - 95.1
# Two        - 51.4
# Three      - 74.3
# Four       - 54.1
# Five       - 3.9
# Six        - 69.6
# Seven      - 90.3
# Eight      - 71.3
# Nine       - 43.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 76  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Average of peers' local losses: 2.025165
#
# Average test loss: 1.8737, Test accuracy: 6550/10000 (65.50%)
#
# Class      - Accuracy
# Zero       - 94.6
# One        - 97.0
# Two        - 49.6
# Three      - 76.4
# Four       - 64.3
# Five       - 6.3
# Six        - 73.0
# Seven      - 89.0
# Eight      - 64.7
# Nine       - 42.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 24  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Average of peers' local losses: 1.943406
#
# Average test loss: 1.7515, Test accuracy: 6688/10000 (66.88%)
#
# Class      - Accuracy
# Zero       - 95.6
# One        - 97.0
# Two        - 57.3
# Three      - 78.9
# Four       - 71.0
# Five       - 11.2
# Six        - 72.4
# Seven      - 91.1
# Eight      - 62.0
# Nine       - 43.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 70  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Average of peers' local losses: 1.847242
#
# Average test loss: 1.6014, Test accuracy: 6972/10000 (69.72%)
#
# Class      - Accuracy
# Zero       - 95.0
# One        - 97.4
# Two        - 62.7
# Three      - 78.8
# Four       - 71.6
# Five       - 18.2
# Six        - 77.9
# Seven      - 87.4
# Eight      - 59.1
# Nine       - 46.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 52  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Average of peers' local losses: 1.742168
#
# Average test loss: 1.4449, Test accuracy: 7200/10000 (72.00%)
#
# Class      - Accuracy
# Zero       - 94.1
# One        - 96.6
# Two        - 66.8
# Three      - 80.9
# Four       - 76.9
# Five       - 29.2
# Six        - 79.7
# Seven      - 89.3
# Eight      - 63.0
# Nine       - 47.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 51  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Average of peers' local losses: 1.635021
#
# Average test loss: 1.2959, Test accuracy: 7502/10000 (75.02%)
#
# Class      - Accuracy
# Zero       - 94.2
# One        - 97.4
# Two        - 72.7
# Three      - 82.0
# Four       - 78.0
# Five       - 38.4
# Six        - 79.8
# Seven      - 87.2
# Eight      - 59.6
# Nine       - 56.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 23  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Average of peers' local losses: 1.539437
#
# Average test loss: 1.1592, Test accuracy: 7750/10000 (77.50%)
#
# Class      - Accuracy
# Zero       - 95.4
# One        - 97.4
# Two        - 72.7
# Three      - 81.8
# Four       - 82.6
# Five       - 47.6
# Six        - 83.7
# Seven      - 88.1
# Eight      - 63.4
# Nine       - 62.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 1.445721
#
# Average test loss: 1.0435, Test accuracy: 7933/10000 (79.33%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 96.3
# Two        - 78.4
# Three      - 83.6
# Four       - 82.2
# Five       - 53.3
# Six        - 84.9
# Seven      - 86.9
# Eight      - 65.8
# Nine       - 65.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Average of peers' local losses: 1.360836
#
# Average test loss: 0.9426, Test accuracy: 8045/10000 (80.45%)
#
# Class      - Accuracy
# Zero       - 95.3
# One        - 94.9
# Two        - 83.4
# Three      - 87.3
# Four       - 83.9
# Five       - 58.8
# Six        - 85.0
# Seven      - 87.6
# Eight      - 65.2
# Nine       - 69.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 20  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 24  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Average of peers' local losses: 1.282794
#
# Average test loss: 0.8581, Test accuracy: 8245/10000 (82.45%)
#
# Class      - Accuracy
# Zero       - 97.3
# One        - 95.9
# Two        - 83.8
# Three      - 84.7
# Four       - 85.0
# Five       - 63.8
# Six        - 86.4
# Seven      - 88.6
# Eight      - 66.6
# Nine       - 68.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 42  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 99  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Average of peers' local losses: 1.216378
#
# Average test loss: 0.7769, Test accuracy: 8332/10000 (83.32%)
#
# Class      - Accuracy
# Zero       - 95.6
# One        - 94.9
# Two        - 85.4
# Three      - 84.5
# Four       - 85.6
# Five       - 68.9
# Six        - 85.1
# Seven      - 86.4
# Eight      - 69.7
# Nine       - 70.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 83  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 43  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 21  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# ...
# Two        - 92.2
# Three      - 92.6
# Four       - 92.5
# Five       - 91.6
# Six        - 95.2
# Seven      - 93.3
# Eight      - 89.6
# Nine       - 92.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 79  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Average of peers' local losses: 0.562083
#
# Average test loss: 0.2121, Test accuracy: 9401/10000 (94.01%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 97.1
# Two        - 92.4
# Three      - 93.0
# Four       - 95.6
# Five       - 93.7
# Six        - 96.0
# Seven      - 92.3
# Eight      - 88.2
# Nine       - 91.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Average of peers' local losses: 0.563604
#
# Average test loss: 0.2112, Test accuracy: 9362/10000 (93.62%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.2
# Two        - 93.2
# Three      - 91.8
# Four       - 91.2
# Five       - 92.7
# Six        - 94.8
# Seven      - 91.2
# Eight      - 92.0
# Nine       - 92.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 88  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Average of peers' local losses: 0.573096
#
# Average test loss: 0.2299, Test accuracy: 9332/10000 (93.32%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.7
# Two        - 91.5
# Three      - 93.8
# Four       - 94.1
# Five       - 91.9
# Six        - 96.1
# Seven      - 91.3
# Eight      - 88.4
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 55  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.557761
#
# Average test loss: 0.2193, Test accuracy: 9367/10000 (93.67%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 97.5
# Two        - 91.9
# Three      - 90.9
# Four       - 93.0
# Five       - 93.5
# Six        - 95.9
# Seven      - 91.6
# Eight      - 90.6
# Nine       - 91.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 25  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Average of peers' local losses: 0.554597
#
# Average test loss: 0.2218, Test accuracy: 9337/10000 (93.37%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.5
# Two        - 92.6
# Three      - 92.8
# Four       - 94.9
# Five       - 91.1
# Six        - 95.7
# Seven      - 92.2
# Eight      - 90.2
# Nine       - 91.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 79  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Average of peers' local losses: 0.552672
#
# Average test loss: 0.2151, Test accuracy: 9397/10000 (93.97%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 97.1
# Two        - 92.8
# Three      - 93.5
# Four       - 92.7
# Five       - 92.4
# Six        - 94.0
# Seven      - 92.1
# Eight      - 89.0
# Nine       - 93.1
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.2172, Test accuracy: 9402/10000 (94.02%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 97.3
# One        - 98.0
# Two        - 92.3
# Three      - 93.6
# Four       - 94.0
# Five       - 91.5
# Six        - 95.3
# Seven      - 90.8
# Eight      - 91.0
# Nine       - 93.6
# Global accuracies:  [14.92, 18.8, 18.58, 25.97, 28.88, 36.49, 37.41, 49.76, 58.4, 63.67, 67.2, 68.36, 68.76, 69.09, 71.23, 71.23, 74.25, 76.88, 78.09, 79.24, 81.03, 81.66, 82.15, 83.24, 84.03, 85.09, 86.26, 86.49, 87.26, 87.3, 86.93, 87.28, 87.27, 88.0, 89.14, 88.55, 88.72, 89.32, 88.84, 88.75, 90.26, 90.17, 89.76, 90.34, 90.51, 90.0, 90.59, 90.8, 91.24, 91.65, 91.21, 91.04, 91.23, 91.56, 91.35, 91.68, 91.5, 92.13, 92.2, 92.5, 91.69, 92.11, 92.11, 92.0, 91.67, 92.31, 92.69, 92.49, 91.63, 92.17, 92.5, 92.6, 92.31, 92.81, 92.93, 92.78, 92.76, 92.58, 93.02, 92.11, 93.15, 92.73, 93.22, 93.11, 93.55, 93.66, 93.14, 93.1, 93.51, 93.66, 93.17, 92.94, 93.17, 93.42, 94.01, 93.62, 93.32, 93.67, 93.37, 93.97, 94.02]
# Class 7 accuracies:  [12.89, 34.33, 30.25, 49.33, 53.88, 58.03, 71.04, 73.74, 75.6, 84.44, 84.24, 83.5, 87.57, 89.87, 83.33, 82.51, 86.06, 82.42, 87.39, 88.65, 86.71, 85.6, 87.72, 86.36, 88.04, 86.2, 88.36, 85.59, 87.67, 88.91, 86.05, 90.72, 90.58, 89.83, 88.83, 88.56, 90.36, 86.49, 88.86, 89.11, 90.52, 89.17, 89.11, 89.84, 88.51, 88.59, 89.84, 88.8, 92.26, 91.18, 91.09, 89.22, 92.32, 91.26, 88.95, 90.26, 90.56, 89.69, 89.28, 90.85, 90.2, 92.44, 91.59, 88.66, 89.35, 89.64, 89.88, 91.37, 90.92, 90.54, 90.48, 89.59, 90.97, 91.04, 91.64, 91.98, 89.27, 92.45, 91.63, 89.11, 93.06, 90.31, 90.28, 90.65, 92.85, 90.48, 91.16, 91.94, 92.82, 92.88, 92.31, 92.87, 89.41, 93.33, 92.25, 91.17, 91.34, 91.63, 92.2, 92.13, 90.79]
# Test loss: [2.2874, 2.2787, 2.2716, 2.2597, 2.2434, 2.226, 2.198, 2.1643, 2.1183, 2.0554, 1.9775, 1.8706, 1.76, 1.6214, 1.4858, 1.3416, 1.2228, 1.0964, 1.0141, 0.9443, 0.8463, 0.8027, 0.7514, 0.7015, 0.6545, 0.6077, 0.5868, 0.5584, 0.532, 0.5067, 0.5096, 0.4919, 0.4911, 0.4745, 0.4522, 0.4499, 0.4601, 0.4196, 0.4254, 0.41, 0.3957, 0.3941, 0.3894, 0.3776, 0.3735, 0.3689, 0.3496, 0.3425, 0.3345, 0.3299, 0.3401, 0.3255, 0.3293, 0.321, 0.3203, 0.3199, 0.3075, 0.3048, 0.2978, 0.2856, 0.3044, 0.2923, 0.2931, 0.2978, 0.2998, 0.2938, 0.278, 0.2744, 0.285, 0.2823, 0.2659, 0.2589, 0.274, 0.2606, 0.2502, 0.2533, 0.2569, 0.2692, 0.2428, 0.2641, 0.2472, 0.2461, 0.2417, 0.2481, 0.2343, 0.2282, 0.2456, 0.2394, 0.2255, 0.2234, 0.2327, 0.2361, 0.2302, 0.2294, 0.2121, 0.2112, 0.2299, 0.2193, 0.2218, 0.2151, 0.2172]
# Label-flipping attack succes rate: 0.78
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.027
# --> End of Experiment.

# %%
RULE = 'median'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: median
# Attack Type: gaussian_noise
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 94  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Average of peers' local losses: 2.303309
#
# Average test loss: 2.2892, Test accuracy: 1275/10000 (12.75%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 0.0
# Two        - 44.6
# Three      - 1.5
# Four       - 0.0
# Five       - 0.0
# Six        - 0.0
# Seven      - 6.8
# Eight      - 30.9
# Nine       - 44.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 53  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Average of peers' local losses: 2.292273
#
# Average test loss: 2.2792, Test accuracy: 1627/10000 (16.27%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 2.3
# Two        - 51.1
# Three      - 7.4
# Four       - 0.0
# Five       - 0.1
# Six        - 0.0
# Seven      - 12.5
# Eight      - 34.3
# Nine       - 50.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 49  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 2.283808
#
# Average test loss: 2.2703, Test accuracy: 2152/10000 (21.52%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 15.2
# Two        - 60.4
# Three      - 21.8
# Four       - 0.0
# Five       - 0.5
# Six        - 0.0
# Seven      - 26.2
# Eight      - 33.5
# Nine       - 51.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 55  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Average of peers' local losses: 2.274434
#
# Average test loss: 2.2589, Test accuracy: 2847/10000 (28.47%)
#
# Class      - Accuracy
# Zero       - 1.2
# One        - 40.6
# Two        - 67.0
# Three      - 32.4
# Four       - 0.0
# Five       - 0.3
# Six        - 0.4
# Seven      - 49.5
# Eight      - 40.7
# Nine       - 58.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 2.262380
#
# Average test loss: 2.2428, Test accuracy: 3606/10000 (36.06%)
#
# Class      - Accuracy
# Zero       - 6.7
# One        - 63.5
# Two        - 64.1
# Three      - 44.2
# Four       - 0.8
# Five       - 0.5
# Six        - 1.4
# Seven      - 67.8
# Eight      - 51.6
# Nine       - 59.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 82  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Average of peers' local losses: 2.250041
#
# Average test loss: 2.2260, Test accuracy: 4222/10000 (42.22%)
#
# Class      - Accuracy
# Zero       - 26.9
# One        - 75.5
# Two        - 64.3
# Three      - 53.6
# Four       - 7.7
# Five       - 0.6
# Six        - 8.6
# Seven      - 79.9
# Eight      - 57.3
# Nine       - 64.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 93  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Average of peers' local losses: 2.232931
#
# Average test loss: 2.2007, Test accuracy: 4979/10000 (49.79%)
#
# Class      - Accuracy
# Zero       - 50.3
# One        - 81.6
# Two        - 63.1
# Three      - 54.9
# Four       - 16.5
# Five       - 0.9
# Six        - 18.6
# Seven      - 87.8
# Eight      - 66.9
# Nine       - 61.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 27  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 2.211682
#
# Average test loss: 2.1693, Test accuracy: 5494/10000 (54.94%)
#
# Class      - Accuracy
# Zero       - 71.3
# One        - 87.3
# Two        - 59.0
# Three      - 60.3
# Four       - 23.1
# Five       - 2.1
# Six        - 35.4
# Seven      - 86.9
# Eight      - 65.7
# Nine       - 59.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 87  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Average of peers' local losses: 2.183437
#
# Average test loss: 2.1268, Test accuracy: 5976/10000 (59.76%)
#
# Class      - Accuracy
# Zero       - 86.4
# One        - 91.4
# Two        - 55.4
# Three      - 62.3
# Four       - 33.4
# Five       - 3.3
# Six        - 50.9
# Seven      - 88.0
# Eight      - 71.3
# Nine       - 41.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 95  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Average of peers' local losses: 2.142264
#
# Average test loss: 2.0626, Test accuracy: 6132/10000 (61.32%)
#
# Class      - Accuracy
# Zero       - 88.8
# One        - 93.6
# Two        - 46.8
# Three      - 69.8
# Four       - 39.3
# Five       - 3.1
# Six        - 66.6
# Seven      - 89.9
# Eight      - 68.9
# Nine       - 45.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 25  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Average of peers' local losses: 2.091860
#
# Average test loss: 1.9801, Test accuracy: 6410/10000 (64.10%)
#
# Class      - Accuracy
# Zero       - 95.4
# One        - 94.9
# Two        - 52.4
# Three      - 73.1
# Four       - 54.1
# Five       - 4.7
# Six        - 69.1
# Seven      - 90.9
# Eight      - 71.1
# Nine       - 41.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 69  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Average of peers' local losses: 2.026523
#
# Average test loss: 1.8761, Test accuracy: 6553/10000 (65.53%)
#
# Class      - Accuracy
# Zero       - 95.0
# One        - 97.0
# Two        - 49.1
# Three      - 76.5
# Four       - 63.9
# Five       - 7.4
# Six        - 71.8
# Seven      - 89.4
# Eight      - 64.1
# Nine       - 43.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 67  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Average of peers' local losses: 1.946839
#
# Average test loss: 1.7537, Test accuracy: 6718/10000 (67.18%)
#
# Class      - Accuracy
# Zero       - 94.5
# One        - 97.0
# Two        - 57.7
# Three      - 78.7
# Four       - 72.5
# Five       - 13.8
# Six        - 72.1
# Seven      - 91.1
# Eight      - 62.8
# Nine       - 40.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 87  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Average of peers' local losses: 1.849650
#
# Average test loss: 1.6041, Test accuracy: 6969/10000 (69.69%)
#
# Class      - Accuracy
# Zero       - 95.2
# One        - 97.3
# Two        - 62.8
# Three      - 79.0
# Four       - 70.5
# Five       - 18.0
# Six        - 78.0
# Seven      - 87.6
# Eight      - 59.5
# Nine       - 45.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 1.743575
#
# Average test loss: 1.4459, Test accuracy: 7234/10000 (72.34%)
#
# Class      - Accuracy
# Zero       - 93.9
# One        - 96.8
# Two        - 67.0
# Three      - 80.3
# Four       - 76.4
# Five       - 29.9
# Six        - 80.5
# Seven      - 88.7
# Eight      - 63.1
# Nine       - 49.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 47  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Average of peers' local losses: 1.639953
#
# Average test loss: 1.2980, Test accuracy: 7494/10000 (74.94%)
#
# Class      - Accuracy
# Zero       - 95.0
# One        - 96.6
# Two        - 72.7
# Three      - 81.5
# Four       - 78.7
# Five       - 37.9
# Six        - 79.9
# Seven      - 87.0
# Eight      - 61.1
# Nine       - 53.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 27  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 1.540766
#
# Average test loss: 1.1608, Test accuracy: 7734/10000 (77.34%)
#
# Class      - Accuracy
# Zero       - 95.4
# One        - 97.4
# Two        - 74.0
# Three      - 81.7
# Four       - 83.0
# Five       - 46.9
# Six        - 83.6
# Seven      - 88.1
# Eight      - 61.5
# Nine       - 61.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 87  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 1.438786
#
# Average test loss: 1.0392, Test accuracy: 7939/10000 (79.39%)
#
# Class      - Accuracy
# Zero       - 94.9
# One        - 95.9
# Two        - 79.4
# Three      - 82.9
# Four       - 82.5
# Five       - 54.0
# Six        - 85.1
# Seven      - 85.7
# Eight      - 65.3
# Nine       - 66.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 83  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Average of peers' local losses: 1.357659
#
# Average test loss: 0.9392, Test accuracy: 8046/10000 (80.46%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 95.2
# Two        - 83.3
# Three      - 87.3
# Four       - 82.6
# Five       - 58.6
# Six        - 84.8
# Seven      - 87.4
# Eight      - 66.0
# Nine       - 71.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 96  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Average of peers' local losses: 1.288210
#
# Average test loss: 0.8588, Test accuracy: 8248/10000 (82.48%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 95.9
# Two        - 84.3
# Three      - 84.3
# Four       - 86.2
# Five       - 66.0
# Six        - 86.4
# Seven      - 88.7
# Eight      - 67.0
# Nine       - 66.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Average of peers' local losses: 1.221177
#
# Average test loss: 0.7802, Test accuracy: 8325/10000 (83.25%)
#
# Class      - Accuracy
# Zero       - 95.6
# One        - 94.9
# Two        - 85.9
# Three      - 85.1
# Four       - 85.9
# Five       - 67.1
# Six        - 84.6
# Seven      - 86.6
# Eight      - 69.5
# Nine       - 70.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 83  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 91  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 32  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# ...
# Two        - 92.9
# Three      - 94.2
# Four       - 95.3
# Five       - 92.6
# Six        - 95.5
# Seven      - 94.6
# Eight      - 91.9
# Nine       - 91.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 79  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Average of peers' local losses: 0.448941
#
# Average test loss: 0.1742, Test accuracy: 9472/10000 (94.72%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.1
# Two        - 93.7
# Three      - 94.8
# Four       - 96.0
# Five       - 93.6
# Six        - 96.7
# Seven      - 92.6
# Eight      - 91.2
# Nine       - 91.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 92  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Average of peers' local losses: 0.448428
#
# Average test loss: 0.1781, Test accuracy: 9486/10000 (94.86%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.0
# Two        - 93.7
# Three      - 93.9
# Four       - 95.2
# Five       - 93.6
# Six        - 95.7
# Seven      - 92.7
# Eight      - 92.7
# Nine       - 90.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 88  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 97  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Average of peers' local losses: 0.457244
#
# Average test loss: 0.1965, Test accuracy: 9405/10000 (94.05%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.6
# Two        - 92.5
# Three      - 96.0
# Four       - 94.6
# Five       - 93.7
# Six        - 96.0
# Seven      - 92.0
# Eight      - 91.9
# Nine       - 91.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 55  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 28  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.444220
#
# Average test loss: 0.1880, Test accuracy: 9457/10000 (94.57%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.5
# Two        - 92.9
# Three      - 94.0
# Four       - 95.1
# Five       - 93.3
# Six        - 96.9
# Seven      - 92.2
# Eight      - 91.3
# Nine       - 91.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 25  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 57  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 90  is  honest reputation: 0.0
# Average of peers' local losses: 0.438950
#
# Average test loss: 0.1908, Test accuracy: 9444/10000 (94.44%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.8
# Two        - 93.7
# Three      - 94.6
# Four       - 95.2
# Five       - 91.6
# Six        - 95.6
# Seven      - 92.7
# Eight      - 92.8
# Nine       - 91.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 79  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 60  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 69  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 55  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 34  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 29  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 87  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 75  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 94  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 98  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Average of peers' local losses: 0.444240
#
# Average test loss: 0.1781, Test accuracy: 9493/10000 (94.93%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.0
# Two        - 93.4
# Three      - 93.9
# Four       - 93.6
# Five       - 94.1
# Six        - 94.0
# Seven      - 92.8
# Eight      - 91.8
# Nine       - 92.8
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.1879, Test accuracy: 9468/10000 (94.68%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.5
# Two        - 93.9
# Three      - 93.4
# Four       - 95.8
# Five       - 92.1
# Six        - 95.8
# Seven      - 91.4
# Eight      - 93.0
# Nine       - 93.4
# Global accuracies:  [12.75, 16.27, 21.52, 28.47, 36.06, 42.22, 49.79, 54.94, 59.76, 61.32, 64.1, 65.53, 67.18, 69.69, 72.34, 74.94, 77.34, 79.39, 80.46, 82.48, 83.25, 83.84, 84.19, 85.28, 85.85, 86.95, 87.2, 87.64, 88.0, 88.38, 88.22, 88.85, 88.69, 88.81, 89.87, 89.51, 89.88, 90.28, 89.89, 90.29, 90.78, 91.04, 90.51, 90.91, 91.46, 91.11, 90.97, 91.31, 92.08, 91.81, 91.6, 91.53, 92.12, 92.12, 92.07, 92.14, 92.0, 92.74, 92.52, 92.91, 92.8, 92.67, 92.62, 92.57, 92.4, 93.08, 93.1, 93.19, 92.89, 92.92, 93.17, 93.86, 92.97, 93.47, 93.47, 93.43, 93.72, 93.39, 93.95, 93.23, 93.86, 93.83, 93.74, 93.84, 94.56, 94.35, 93.98, 93.97, 94.23, 94.33, 94.05, 93.84, 94.02, 94.26, 94.72, 94.86, 94.05, 94.57, 94.44, 94.93, 94.68]
# Class 7 accuracies:  [6.79, 12.54, 26.23, 49.54, 67.77, 79.88, 87.76, 86.92, 88.04, 89.87, 90.86, 89.39, 91.11, 87.56, 88.7, 86.98, 88.07, 85.71, 87.39, 88.65, 86.6, 87.29, 87.31, 87.08, 88.34, 87.69, 89.79, 87.55, 87.86, 90.5, 89.53, 90.62, 91.2, 89.43, 90.22, 90.19, 90.93, 89.62, 88.96, 90.17, 92.05, 90.6, 91.25, 90.35, 90.83, 90.75, 91.95, 91.58, 92.89, 92.1, 92.45, 89.42, 92.32, 91.66, 91.09, 91.65, 91.55, 91.98, 91.66, 92.56, 92.6, 92.04, 93.33, 90.14, 91.21, 92.15, 91.87, 92.18, 93.61, 92.17, 92.48, 92.22, 92.85, 92.17, 91.54, 91.5, 92.05, 92.64, 91.94, 92.01, 93.95, 92.19, 91.68, 91.78, 93.04, 92.24, 93.55, 93.43, 93.7, 92.5, 94.15, 93.69, 92.69, 94.56, 92.55, 92.71, 91.96, 92.24, 92.69, 92.85, 91.37]
# Test loss: [2.2892, 2.2792, 2.2703, 2.2589, 2.2428, 2.226, 2.2007, 2.1693, 2.1268, 2.0626, 1.9801, 1.8761, 1.7537, 1.6041, 1.4459, 1.298, 1.1608, 1.0392, 0.9392, 0.8588, 0.7802, 0.7233, 0.6782, 0.6298, 0.5884, 0.5471, 0.5293, 0.5045, 0.4811, 0.4648, 0.457, 0.4347, 0.4299, 0.4231, 0.3994, 0.4019, 0.3915, 0.3708, 0.3685, 0.3571, 0.3496, 0.3442, 0.349, 0.3398, 0.319, 0.3206, 0.319, 0.3049, 0.2959, 0.2969, 0.3054, 0.2967, 0.2913, 0.2843, 0.2826, 0.2812, 0.2728, 0.2665, 0.2683, 0.2565, 0.264, 0.2634, 0.2545, 0.2609, 0.2596, 0.2451, 0.2423, 0.2434, 0.2376, 0.242, 0.2308, 0.2169, 0.2388, 0.2257, 0.2206, 0.2251, 0.2131, 0.2233, 0.208, 0.2255, 0.2163, 0.2089, 0.2089, 0.2133, 0.1995, 0.1971, 0.2114, 0.2029, 0.1896, 0.1897, 0.1932, 0.2036, 0.1944, 0.1943, 0.1742, 0.1781, 0.1965, 0.188, 0.1908, 0.1781, 0.1879]
# Label-flipping attack succes rate: 0.68
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.038
# --> End of Experiment.

# %%
RULE = 'tmean'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,  strategy = 's1', resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)
