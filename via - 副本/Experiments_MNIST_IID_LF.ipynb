# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'IID'
ALPHA = 1000000
NUM_PEERS = 20 # "number of peers: K" 
FRAC_PEERS = 0.5 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 100 #"number of rounds of federated model training"
LOCAL_EPOCHS = 1 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 32 #"local batch size: B for each peer"
LOCAL_LR =  0.001#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
print(DEVICE)
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1
# Out:
# cuda

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: fedavg
# Attack Type: label_flipping
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 2.287905
#
# Average test loss: 2.2534, Test accuracy: 3330/10000 (33.30%)
#
# Class      - Accuracy
# Zero       - 3.1
# One        - 66.5
# Two        - 66.3
# Three      - 37.8
# Four       - 0.8
# Five       - 0.4
# Six        - 0.0
# Seven      - 63.2
# Eight      - 34.3
# Nine       - 58.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 2.231630
#
# Average test loss: 2.1418, Test accuracy: 5774/10000 (57.74%)
#
# Class      - Accuracy
# Zero       - 86.0
# One        - 92.1
# Two        - 54.4
# Three      - 62.8
# Four       - 38.2
# Five       - 1.2
# Six        - 44.4
# Seven      - 91.3
# Eight      - 66.6
# Nine       - 52.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 2.068903
#
# Average test loss: 1.7630, Test accuracy: 6751/10000 (67.51%)
#
# Class      - Accuracy
# Zero       - 93.7
# One        - 96.7
# Two        - 50.1
# Three      - 80.8
# Four       - 70.7
# Five       - 14.0
# Six        - 77.1
# Seven      - 87.6
# Eight      - 58.5
# Nine       - 46.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 1.710040
#
# Average test loss: 1.1467, Test accuracy: 7679/10000 (76.79%)
#
# Class      - Accuracy
# Zero       - 95.8
# One        - 96.6
# Two        - 78.9
# Three      - 81.1
# Four       - 82.8
# Five       - 44.3
# Six        - 80.1
# Seven      - 87.5
# Eight      - 65.4
# Nine       - 54.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 1.321437
#
# Average test loss: 0.7530, Test accuracy: 8419/10000 (84.19%)
#
# Class      - Accuracy
# Zero       - 96.2
# One        - 94.2
# Two        - 86.2
# Three      - 85.8
# Four       - 84.4
# Five       - 75.4
# Six        - 88.2
# Seven      - 87.1
# Eight      - 71.9
# Nine       - 73.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 1.089897
#
# Average test loss: 0.5782, Test accuracy: 8638/10000 (86.38%)
#
# Class      - Accuracy
# Zero       - 97.5
# One        - 96.0
# Two        - 87.2
# Three      - 90.3
# Four       - 88.7
# Five       - 77.2
# Six        - 89.3
# Seven      - 89.9
# Eight      - 71.1
# Nine       - 76.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.941673
#
# Average test loss: 0.4762, Test accuracy: 8797/10000 (87.97%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 96.5
# Two        - 88.3
# Three      - 90.5
# Four       - 91.6
# Five       - 80.8
# Six        - 91.6
# Seven      - 90.2
# Eight      - 82.3
# Nine       - 78.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 0.850886
#
# Average test loss: 0.4106, Test accuracy: 8932/10000 (89.32%)
#
# Class      - Accuracy
# Zero       - 96.9
# One        - 96.9
# Two        - 90.4
# Three      - 90.0
# Four       - 92.1
# Five       - 83.3
# Six        - 93.1
# Seven      - 89.8
# Eight      - 79.6
# Nine       - 80.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 0.789356
#
# Average test loss: 0.3779, Test accuracy: 9023/10000 (90.23%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 97.5
# Two        - 91.2
# Three      - 89.2
# Four       - 92.3
# Five       - 87.2
# Six        - 94.9
# Seven      - 90.0
# Eight      - 80.0
# Nine       - 82.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.713822
#
# Average test loss: 0.3405, Test accuracy: 9059/10000 (90.59%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.3
# Two        - 91.0
# Three      - 90.5
# Four       - 94.9
# Five       - 88.0
# Six        - 95.3
# Seven      - 88.8
# Eight      - 81.1
# Nine       - 85.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Average of peers' local losses: 0.682559
#
# Average test loss: 0.3032, Test accuracy: 9177/10000 (91.77%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.6
# Two        - 92.1
# Three      - 91.6
# Four       - 94.2
# Five       - 86.4
# Six        - 94.4
# Seven      - 92.0
# Eight      - 83.6
# Nine       - 84.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.654606
#
# Average test loss: 0.2827, Test accuracy: 9242/10000 (92.42%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.2
# Two        - 90.3
# Three      - 93.1
# Four       - 96.1
# Five       - 87.6
# Six        - 94.5
# Seven      - 93.6
# Eight      - 84.2
# Nine       - 86.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.619873
#
# Average test loss: 0.2791, Test accuracy: 9168/10000 (91.68%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.4
# Two        - 92.6
# Three      - 91.9
# Four       - 96.3
# Five       - 90.5
# Six        - 95.3
# Seven      - 93.2
# Eight      - 86.7
# Nine       - 87.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Average of peers' local losses: 0.585181
#
# Average test loss: 0.2509, Test accuracy: 9287/10000 (92.87%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.2
# Two        - 91.6
# Three      - 92.9
# Four       - 95.7
# Five       - 92.2
# Six        - 95.7
# Seven      - 89.3
# Eight      - 88.4
# Nine       - 85.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.568579
#
# Average test loss: 0.2443, Test accuracy: 9281/10000 (92.81%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.2
# Two        - 90.9
# Three      - 93.9
# Four       - 93.9
# Five       - 90.8
# Six        - 95.6
# Seven      - 91.2
# Eight      - 87.4
# Nine       - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.550198
#
# Average test loss: 0.2237, Test accuracy: 9365/10000 (93.65%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.5
# Two        - 91.6
# Three      - 93.9
# Four       - 96.1
# Five       - 91.3
# Six        - 96.1
# Seven      - 93.2
# Eight      - 88.1
# Nine       - 90.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 2  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.534396
#
# Average test loss: 0.2241, Test accuracy: 9346/10000 (93.46%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 91.3
# Three      - 94.3
# Four       - 95.6
# Five       - 90.8
# Six        - 96.2
# Seven      - 92.4
# Eight      - 88.9
# Nine       - 92.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 0.506905
#
# Average test loss: 0.2113, Test accuracy: 9379/10000 (93.79%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 97.6
# Two        - 92.5
# Three      - 93.5
# Four       - 95.2
# Five       - 92.0
# Six        - 96.1
# Seven      - 92.9
# Eight      - 87.3
# Nine       - 93.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.498161
#
# Average test loss: 0.2022, Test accuracy: 9400/10000 (94.00%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.2
# Two        - 94.2
# Three      - 94.7
# Four       - 95.3
# Five       - 93.2
# Six        - 96.2
# Seven      - 92.2
# Eight      - 90.7
# Nine       - 91.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.474682
#
# Average test loss: 0.1963, Test accuracy: 9414/10000 (94.14%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.8
# Two        - 92.9
# Three      - 95.1
# Four       - 95.8
# Five       - 92.3
# Six        - 96.8
# Seven      - 94.1
# Eight      - 89.5
# Nine       - 91.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.472148
#
# Average test loss: 0.1772, Test accuracy: 9472/10000 (94.72%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.3
# Two        - 93.6
# Three      - 93.0
# Four       - 93.9
# Five       - 94.2
# Six        - 95.8
# Seven      - 92.4
# Eight      - 91.3
# Nine       - 92.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.448785
#
# Average test loss: 0.1834, Test accuracy: 9436/10000 (94.36%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.5
# Two        - 96.0
# Three      - 93.5
# Four       - 96.0
# Five       - 93.8
# Six        - 96.0
# Seven      - 92.7
# Eight      - 89.0
# Nine       - 92.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.453934
#
# Average test loss: 0.1793, Test accuracy: 9451/10000 (94.51%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.6
# Two        - 90.8
# Three      - 94.3
# Four       - 94.7
# Five       - 92.7
# Six        - 96.6
# Seven      - 94.4
# Eight      - 92.8
# Nine       - 91.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.442491
#
# Average test loss: 0.1673, Test accuracy: 9508/10000 (95.08%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.2
# Two        - 93.3
# Three      - 94.8
# Four       - 95.7
# Five       - 94.6
# Six        - 96.4
# Seven      - 95.0
# Eight      - 91.8
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.431641
#
# Average test loss: 0.1669, Test accuracy: 9508/10000 (95.08%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 95.1
# Three      - 96.0
# Four       - 95.5
# Five       - 94.9
# Six        - 96.6
# Seven      - 94.4
# Eight      - 91.4
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 0.416640
#
# Average test loss: 0.1514, Test accuracy: 9572/10000 (95.72%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.4
# Two        - 96.1
# Three      - 96.0
# Four       - 96.3
# Five       - 95.3
# Six        - 95.7
# Seven      - 94.1
# Eight      - 93.5
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 0.419080
#
# Average test loss: 0.1508, Test accuracy: 9561/10000 (95.61%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.9
# Two        - 95.9
# Three      - 94.6
# Four       - 97.2
# Five       - 96.6
# Six        - 97.2
# Seven      - 92.8
# Eight      - 91.6
# Nine       - 93.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.407284
#
# Average test loss: 0.1565, Test accuracy: 9539/10000 (95.39%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 95.8
# Three      - 95.3
# Four       - 95.3
# Five       - 96.4
# Six        - 97.5
# Seven      - 94.2
# Eight      - 92.1
# Nine       - 92.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 0.400487
#
# Average test loss: 0.1428, Test accuracy: 9577/10000 (95.77%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.7
# Two        - 96.1
# Three      - 95.6
# Four       - 96.0
# Five       - 97.0
# Six        - 97.4
# Seven      - 93.2
# Eight      - 90.2
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.391705
#
# Average test loss: 0.1448, Test accuracy: 9574/10000 (95.74%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 96.9
# Three      - 95.3
# Four       - 96.7
# Five       - 96.7
# Six        - 97.6
# Seven      - 93.3
# Eight      - 92.6
# Nine       - 92.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.378638
#
# Average test loss: 0.1410, Test accuracy: 9572/10000 (95.72%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 96.2
# Three      - 96.8
# Four       - 96.2
# Five       - 96.7
# Six        - 96.9
# Seven      - 93.7
# Eight      - 91.6
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 0.375104
#
# Average test loss: 0.1333, Test accuracy: 9602/10000 (96.02%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.7
# Two        - 96.2
# Three      - 95.7
# Four       - 96.7
# Five       - 97.4
# Six        - 96.6
# Seven      - 93.5
# Eight      - 94.1
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.372605
#
# Average test loss: 0.1312, Test accuracy: 9600/10000 (96.00%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.4
# Two        - 95.5
# Three      - 95.9
# Four       - 95.7
# Five       - 96.8
# Six        - 97.8
# Seven      - 94.5
# Eight      - 93.9
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.365637
#
# Average test loss: 0.1287, Test accuracy: 9628/10000 (96.28%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 95.9
# Three      - 95.7
# Four       - 96.9
# Five       - 97.3
# Six        - 96.7
# Seven      - 93.7
# Eight      - 93.6
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.362805
#
# Average test loss: 0.1239, Test accuracy: 9634/10000 (96.34%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.7
# Two        - 95.3
# Three      - 96.7
# Four       - 95.5
# Five       - 96.8
# Six        - 97.3
# Seven      - 93.3
# Eight      - 93.2
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.352988
#
# Average test loss: 0.1280, Test accuracy: 9604/10000 (96.04%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.5
# Two        - 96.1
# Three      - 94.8
# Four       - 96.2
# Five       - 96.4
# Six        - 97.6
# Seven      - 94.2
# Eight      - 95.2
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.347880
#
# Average test loss: 0.1235, Test accuracy: 9631/10000 (96.31%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.3
# Two        - 96.7
# Three      - 96.4
# Four       - 96.2
# Five       - 98.0
# Six        - 97.2
# Seven      - 94.4
# Eight      - 94.2
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.341628
#
# Average test loss: 0.1201, Test accuracy: 9632/10000 (96.32%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.2
# Two        - 97.1
# Three      - 96.4
# Four       - 97.1
# Five       - 97.7
# Six        - 97.2
# Seven      - 96.1
# Eight      - 93.4
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.345954
#
# Average test loss: 0.1185, Test accuracy: 9658/10000 (96.58%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.1
# Two        - 96.7
# Three      - 96.7
# Four       - 96.9
# Five       - 97.5
# Six        - 96.6
# Seven      - 95.0
# Eight      - 91.5
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.329177
#
# Average test loss: 0.1182, Test accuracy: 9657/10000 (96.57%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.8
# Two        - 97.6
# Three      - 96.6
# Four       - 96.7
# Five       - 97.2
# Six        - 97.5
# Seven      - 95.2
# Eight      - 93.4
# Nine       - 93.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.338090
#
# Average test loss: 0.1122, Test accuracy: 9677/10000 (96.77%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.9
# Two        - 96.1
# Three      - 96.2
# Four       - 97.4
# Five       - 97.7
# Six        - 97.3
# Seven      - 94.7
# Eight      - 94.5
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.327761
#
# Average test loss: 0.1104, Test accuracy: 9663/10000 (96.63%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 96.8
# Three      - 96.5
# Four       - 96.2
# Five       - 98.7
# Six        - 96.8
# Seven      - 95.4
# Eight      - 93.6
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.328572
#
# Average test loss: 0.1098, Test accuracy: 9673/10000 (96.73%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.0
# Two        - 95.3
# Three      - 96.9
# Four       - 96.5
# Five       - 97.4
# Six        - 97.8
# Seven      - 94.2
# Eight      - 93.8
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Average of peers' local losses: 0.321360
#
# Average test loss: 0.1160, Test accuracy: 9677/10000 (96.77%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 96.6
# Three      - 96.0
# Four       - 97.2
# Five       - 97.8
# Six        - 97.3
# Seven      - 95.9
# Eight      - 93.8
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.322970
#
# Average test loss: 0.1107, Test accuracy: 9659/10000 (96.59%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 96.9
# Three      - 96.6
# Four       - 98.1
# Five       - 98.6
# Six        - 96.9
# Seven      - 94.8
# Eight      - 95.7
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.305005
#
# Average test loss: 0.1059, Test accuracy: 9698/10000 (96.98%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 97.5
# Three      - 97.1
# Four       - 97.2
# Five       - 97.2
# Six        - 97.5
# Seven      - 94.5
# Eight      - 94.6
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Average of peers' local losses: 0.319924
#
# Average test loss: 0.1118, Test accuracy: 9682/10000 (96.82%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.5
# Two        - 96.5
# Three      - 95.6
# Four       - 98.1
# Five       - 97.6
# Six        - 98.0
# Seven      - 95.4
# Eight      - 94.2
# Nine       - 92.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 48/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Average of peers' local losses: 0.306894
#
# Average test loss: 0.1032, Test accuracy: 9690/10000 (96.90%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.6
# Two        - 96.2
# Three      - 96.1
# Four       - 97.7
# Five       - 98.8
# Six        - 98.6
# Seven      - 95.4
# Eight      - 94.8
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 49/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 0.306563
#
# Average test loss: 0.1048, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 97.8
# Two        - 97.3
# Three      - 97.5
# Four       - 97.5
# Five       - 98.1
# Six        - 97.5
# Seven      - 95.8
# Eight      - 94.8
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 50/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.304173
#
# Average test loss: 0.1038, Test accuracy: 9682/10000 (96.82%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 97.3
# Three      - 96.7
# Four       - 97.6
# Five       - 98.1
# Six        - 97.8
# Seven      - 95.2
# Eight      - 93.7
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 51/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Average of peers' local losses: 0.302573
#
# Average test loss: 0.0936, Test accuracy: 9718/10000 (97.18%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.6
# Two        - 96.9
# Three      - 96.0
# Four       - 97.2
# Five       - 99.0
# Six        - 97.9
# Seven      - 95.6
# Eight      - 96.4
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 52/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.294884
#
# Average test loss: 0.1012, Test accuracy: 9673/10000 (96.73%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 96.1
# Three      - 96.9
# Four       - 97.6
# Five       - 97.9
# Six        - 97.1
# Seven      - 95.9
# Eight      - 94.4
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 53/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.296782
#
# Average test loss: 0.0961, Test accuracy: 9696/10000 (96.96%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.5
# Three      - 96.5
# Four       - 97.2
# Five       - 98.1
# Six        - 97.5
# Seven      - 94.7
# Eight      - 96.1
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 54/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Average of peers' local losses: 0.292789
#
# Average test loss: 0.1018, Test accuracy: 9706/10000 (97.06%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.6
# Two        - 96.9
# Three      - 96.8
# Four       - 97.5
# Five       - 98.4
# Six        - 98.5
# Seven      - 95.8
# Eight      - 94.5
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 55/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Average of peers' local losses: 0.288660
#
# Average test loss: 0.0945, Test accuracy: 9730/10000 (97.30%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.9
# Two        - 97.1
# Three      - 97.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.0
# Seven      - 94.9
# Eight      - 95.0
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 56/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.288856
#
# Average test loss: 0.0989, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.5
# Two        - 96.3
# Three      - 97.0
# Four       - 98.7
# Five       - 98.8
# Six        - 97.7
# Seven      - 94.7
# Eight      - 96.0
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 57/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.293096
#
# Average test loss: 0.1055, Test accuracy: 9680/10000 (96.80%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.6
# Three      - 97.1
# Four       - 97.4
# Five       - 98.0
# Six        - 98.3
# Seven      - 96.8
# Eight      - 94.6
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 58/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Average of peers' local losses: 0.284324
#
# Average test loss: 0.1023, Test accuracy: 9708/10000 (97.08%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.7
# Two        - 97.6
# Three      - 96.4
# Four       - 97.0
# Five       - 98.1
# Six        - 98.3
# Seven      - 96.0
# Eight      - 95.4
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 59/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 0.280074
#
# Average test loss: 0.0887, Test accuracy: 9750/10000 (97.50%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.2
# Two        - 96.5
# Three      - 97.8
# Four       - 98.3
# Five       - 98.1
# Six        - 97.8
# Seven      - 96.4
# Eight      - 94.5
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 60/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.276509
#
# Average test loss: 0.0945, Test accuracy: 9715/10000 (97.15%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.7
# Two        - 97.5
# Three      - 97.0
# Four       - 97.9
# Five       - 98.8
# Six        - 97.2
# Seven      - 96.9
# Eight      - 96.2
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 61/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.271913
#
# Average test loss: 0.0908, Test accuracy: 9717/10000 (97.17%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.0
# Two        - 97.3
# Three      - 96.5
# Four       - 97.3
# Five       - 99.0
# Six        - 97.6
# Seven      - 95.8
# Eight      - 94.5
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 62/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.276514
#
# Average test loss: 0.0944, Test accuracy: 9728/10000 (97.28%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.8
# Three      - 96.7
# Four       - 97.7
# Five       - 98.9
# Six        - 98.3
# Seven      - 95.6
# Eight      - 95.5
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 63/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 0.272146
#
# Average test loss: 0.0912, Test accuracy: 9732/10000 (97.32%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.1
# Two        - 96.9
# Three      - 96.9
# Four       - 97.4
# Five       - 98.5
# Six        - 97.1
# Seven      - 95.2
# Eight      - 96.4
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 64/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.270854
#
# Average test loss: 0.0923, Test accuracy: 9739/10000 (97.39%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.6
# Two        - 95.8
# Three      - 97.1
# Four       - 97.2
# Five       - 98.4
# Six        - 98.5
# Seven      - 96.2
# Eight      - 94.8
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 65/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# ...
#
#  | Global training round : 83/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Average of peers' local losses: 0.239467
#
# Average test loss: 0.0782, Test accuracy: 9756/10000 (97.56%)
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.1
# Three      - 97.0
# Four       - 98.6
# Five       - 98.5
# Six        - 97.7
# Seven      - 95.7
# Eight      - 95.8
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 84/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.240650
#
# Average test loss: 0.0798, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.0
# Two        - 98.3
# Three      - 97.0
# Four       - 98.0
# Five       - 98.6
# Six        - 97.9
# Seven      - 96.3
# Eight      - 97.6
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 85/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.239571
#
# Average test loss: 0.0805, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 98.2
# Three      - 97.9
# Four       - 98.3
# Five       - 98.9
# Six        - 96.8
# Seven      - 95.1
# Eight      - 94.9
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 86/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 0.239564
#
# Average test loss: 0.0817, Test accuracy: 9739/10000 (97.39%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.0
# Three      - 97.8
# Four       - 97.5
# Five       - 98.7
# Six        - 97.5
# Seven      - 96.0
# Eight      - 96.4
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 87/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Average of peers' local losses: 0.232386
#
# Average test loss: 0.0815, Test accuracy: 9772/10000 (97.72%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 97.4
# Three      - 98.0
# Four       - 98.9
# Five       - 98.8
# Six        - 97.3
# Seven      - 96.3
# Eight      - 96.0
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 88/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 0.240640
#
# Average test loss: 0.0795, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 98.0
# Three      - 97.6
# Four       - 98.4
# Five       - 98.8
# Six        - 97.7
# Seven      - 97.2
# Eight      - 96.3
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 89/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Average of peers' local losses: 0.233620
#
# Average test loss: 0.0703, Test accuracy: 9796/10000 (97.96%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.6
# Two        - 97.0
# Three      - 97.6
# Four       - 98.6
# Five       - 99.1
# Six        - 98.2
# Seven      - 96.1
# Eight      - 96.0
# Nine       - 97.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 90/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Average of peers' local losses: 0.232811
#
# Average test loss: 0.0711, Test accuracy: 9785/10000 (97.85%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.4
# Two        - 97.7
# Three      - 97.2
# Four       - 98.8
# Five       - 98.4
# Six        - 98.5
# Seven      - 96.4
# Eight      - 97.4
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 91/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Average of peers' local losses: 0.228157
#
# Average test loss: 0.0725, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.7
# Two        - 98.4
# Three      - 97.6
# Four       - 98.5
# Five       - 99.3
# Six        - 97.8
# Seven      - 96.6
# Eight      - 96.1
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 92/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 0.236637
#
# Average test loss: 0.0751, Test accuracy: 9758/10000 (97.58%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 97.5
# Three      - 97.6
# Four       - 97.9
# Five       - 99.0
# Six        - 98.6
# Seven      - 96.0
# Eight      - 96.3
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 93/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.228836
#
# Average test loss: 0.0751, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 96.9
# Three      - 97.5
# Four       - 98.8
# Five       - 98.1
# Six        - 98.1
# Seven      - 96.8
# Eight      - 96.7
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 94/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Average of peers' local losses: 0.218746
#
# Average test loss: 0.0678, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 98.7
# Two        - 97.9
# Three      - 97.0
# Four       - 98.5
# Five       - 99.1
# Six        - 97.6
# Seven      - 96.2
# Eight      - 96.3
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 0.230123
#
# Average test loss: 0.0705, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 98.7
# Three      - 98.0
# Four       - 98.2
# Five       - 99.1
# Six        - 97.9
# Seven      - 94.5
# Eight      - 96.9
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 0.224758
#
# Average test loss: 0.0745, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.1
# Two        - 98.3
# Three      - 98.5
# Four       - 98.8
# Five       - 99.5
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.8
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.222232
#
# Average test loss: 0.0703, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.7
# Three      - 97.8
# Four       - 98.7
# Five       - 99.2
# Six        - 97.9
# Seven      - 97.0
# Eight      - 96.3
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Average of peers' local losses: 0.219420
#
# Average test loss: 0.0712, Test accuracy: 9783/10000 (97.83%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.2
# Three      - 97.5
# Four       - 97.7
# Five       - 99.0
# Six        - 97.5
# Seven      - 95.4
# Eight      - 96.6
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Average of peers' local losses: 0.214649
#
# Average test loss: 0.0710, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 98.8
# Two        - 98.7
# Three      - 97.8
# Four       - 98.2
# Five       - 98.8
# Six        - 98.8
# Seven      - 96.3
# Eight      - 97.4
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Average of peers' local losses: 0.225285
#
# Average test loss: 0.0773, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.6
# Two        - 97.7
# Three      - 97.2
# Four       - 97.8
# Five       - 99.0
# Six        - 98.2
# Seven      - 95.8
# Eight      - 95.8
# Nine       - 96.9
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0687, Test accuracy: 9808/10000 (98.08%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 98.0
# Three      - 98.1
# Four       - 99.1
# Five       - 99.1
# Six        - 97.4
# Seven      - 96.5
# Eight      - 96.6
# Nine       - 96.6
# Global accuracies:  [33.3, 57.74, 67.51, 76.79, 84.19, 86.38, 87.97, 89.32, 90.23, 90.59, 91.77, 92.42, 91.68, 92.87, 92.81, 93.65, 93.46, 93.79, 94.0, 94.14, 94.72, 94.36, 94.51, 95.08, 95.08, 95.72, 95.61, 95.39, 95.77, 95.74, 95.72, 96.02, 96.0, 96.28, 96.34, 96.04, 96.31, 96.32, 96.58, 96.57, 96.77, 96.63, 96.73, 96.77, 96.59, 96.98, 96.82, 96.9, 97.0, 96.82, 97.18, 96.73, 96.96, 97.06, 97.3, 97.19, 96.8, 97.08, 97.5, 97.15, 97.17, 97.28, 97.32, 97.39, 96.98, 97.24, 97.36, 97.26, 97.27, 97.54, 97.43, 97.53, 97.77, 97.36, 97.61, 97.57, 97.56, 97.69, 97.78, 97.56, 97.41, 97.75, 97.56, 97.56, 97.67, 97.39, 97.72, 97.54, 97.96, 97.85, 97.74, 97.58, 97.76, 98.01, 97.74, 97.76, 97.82, 97.83, 97.82, 97.54, 98.08]
# Class 7 accuracies:  [63.17, 91.3, 87.63, 87.5, 87.08, 89.91, 90.23, 89.76, 90.01, 88.83, 92.04, 93.58, 93.2, 89.28, 91.24, 93.22, 92.42, 92.87, 92.22, 94.06, 92.35, 92.65, 94.41, 94.97, 94.44, 94.1, 92.81, 94.19, 93.19, 93.27, 93.67, 93.55, 94.45, 93.67, 93.31, 94.2, 94.42, 96.09, 95.04, 95.17, 94.73, 95.36, 94.2, 95.87, 94.78, 94.53, 95.38, 95.4, 95.75, 95.23, 95.55, 95.85, 94.71, 95.79, 94.89, 94.72, 96.84, 96.01, 96.35, 96.85, 95.85, 95.62, 95.24, 96.17, 95.04, 94.31, 95.68, 96.0, 94.8, 96.76, 96.02, 96.49, 95.81, 95.22, 96.19, 96.12, 95.23, 95.98, 95.75, 95.86, 95.62, 96.74, 95.73, 96.27, 95.09, 96.01, 96.26, 97.25, 96.09, 96.41, 96.58, 96.04, 96.79, 96.19, 94.46, 96.77, 97.03, 95.42, 96.34, 95.8, 96.52]
# Test loss: [2.2534, 2.1418, 1.763, 1.1467, 0.753, 0.5782, 0.4762, 0.4106, 0.3779, 0.3405, 0.3032, 0.2827, 0.2791, 0.2509, 0.2443, 0.2237, 0.2241, 0.2113, 0.2022, 0.1963, 0.1772, 0.1834, 0.1793, 0.1673, 0.1669, 0.1514, 0.1508, 0.1565, 0.1428, 0.1448, 0.141, 0.1333, 0.1312, 0.1287, 0.1239, 0.128, 0.1235, 0.1201, 0.1185, 0.1182, 0.1122, 0.1104, 0.1098, 0.116, 0.1107, 0.1059, 0.1118, 0.1032, 0.1048, 0.1038, 0.0936, 0.1012, 0.0961, 0.1018, 0.0945, 0.0989, 0.1055, 0.1023, 0.0887, 0.0945, 0.0908, 0.0944, 0.0912, 0.0923, 0.0984, 0.0901, 0.0901, 0.0909, 0.088, 0.0841, 0.084, 0.0845, 0.0795, 0.089, 0.0848, 0.0866, 0.0824, 0.0763, 0.0786, 0.0796, 0.0908, 0.079, 0.0782, 0.0798, 0.0805, 0.0817, 0.0815, 0.0795, 0.0703, 0.0711, 0.0725, 0.0751, 0.0751, 0.0678, 0.0705, 0.0745, 0.0703, 0.0712, 0.071, 0.0773, 0.0687]
# Label-flipping attack succes rate: 0.28
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.006
# --> End of Experiment.

# %%
RULE = 'median'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,strategy = 's1', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: median
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.281665
#
# Average test loss: 2.2557, Test accuracy: 3047/10000 (30.47%)
#
# Class      - Accuracy
# Zero       - 5.6
# One        - 91.6
# Two        - 65.3
# Three      - 31.0
# Four       - 0.8
# Five       - 0.3
# Six        - 0.0
# Seven      - 24.4
# Eight      - 32.3
# Nine       - 48.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.229664
#
# Average test loss: 2.1513, Test accuracy: 5903/10000 (59.03%)
#
# Class      - Accuracy
# Zero       - 90.0
# One        - 98.5
# Two        - 52.0
# Three      - 69.8
# Four       - 38.4
# Five       - 1.7
# Six        - 45.2
# Seven      - 77.9
# Eight      - 64.2
# Nine       - 66.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 2.081949
#
# Average test loss: 1.7952, Test accuracy: 6731/10000 (67.31%)
#
# Class      - Accuracy
# Zero       - 93.2
# One        - 97.7
# Two        - 50.4
# Three      - 80.2
# Four       - 63.7
# Five       - 10.4
# Six        - 75.7
# Seven      - 82.6
# Eight      - 57.8
# Nine       - 60.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 1.732349
#
# Average test loss: 1.1901, Test accuracy: 7532/10000 (75.32%)
#
# Class      - Accuracy
# Zero       - 95.3
# One        - 97.3
# Two        - 70.3
# Three      - 81.2
# Four       - 82.6
# Five       - 41.6
# Six        - 80.1
# Seven      - 82.8
# Eight      - 63.5
# Nine       - 57.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 1.358505
#
# Average test loss: 0.7850, Test accuracy: 8292/10000 (82.92%)
#
# Class      - Accuracy
# Zero       - 96.3
# One        - 93.9
# Two        - 83.7
# Three      - 85.4
# Four       - 84.9
# Five       - 74.3
# Six        - 87.7
# Seven      - 85.3
# Eight      - 69.9
# Nine       - 69.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 1.125403
#
# Average test loss: 0.5910, Test accuracy: 8638/10000 (86.38%)
#
# Class      - Accuracy
# Zero       - 97.0
# One        - 96.1
# Two        - 85.0
# Three      - 88.6
# Four       - 85.9
# Five       - 78.5
# Six        - 90.9
# Seven      - 87.2
# Eight      - 75.9
# Nine       - 79.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.968998
#
# Average test loss: 0.4935, Test accuracy: 8765/10000 (87.65%)
#
# Class      - Accuracy
# Zero       - 97.5
# One        - 96.7
# Two        - 88.7
# Three      - 90.1
# Four       - 91.9
# Five       - 80.7
# Six        - 90.7
# Seven      - 88.8
# Eight      - 79.6
# Nine       - 79.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.871173
#
# Average test loss: 0.4237, Test accuracy: 8931/10000 (89.31%)
#
# Class      - Accuracy
# Zero       - 96.9
# One        - 96.6
# Two        - 90.8
# Three      - 89.8
# Four       - 92.1
# Five       - 82.9
# Six        - 94.8
# Seven      - 86.6
# Eight      - 81.1
# Nine       - 79.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.843006
#
# Average test loss: 0.3970, Test accuracy: 8993/10000 (89.93%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 97.3
# Two        - 91.7
# Three      - 90.0
# Four       - 92.6
# Five       - 87.9
# Six        - 95.1
# Seven      - 84.4
# Eight      - 79.2
# Nine       - 83.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.757140
#
# Average test loss: 0.3474, Test accuracy: 9060/10000 (90.60%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 97.8
# Two        - 90.7
# Three      - 90.3
# Four       - 91.6
# Five       - 87.8
# Six        - 95.9
# Seven      - 86.1
# Eight      - 82.9
# Nine       - 88.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.718017
#
# Average test loss: 0.3025, Test accuracy: 9177/10000 (91.77%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.3
# Two        - 91.0
# Three      - 91.8
# Four       - 94.7
# Five       - 86.9
# Six        - 93.3
# Seven      - 89.9
# Eight      - 84.5
# Nine       - 86.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.694902
#
# Average test loss: 0.2840, Test accuracy: 9234/10000 (92.34%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.2
# Two        - 91.0
# Three      - 93.0
# Four       - 94.8
# Five       - 88.6
# Six        - 94.8
# Seven      - 89.2
# Eight      - 82.8
# Nine       - 89.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.659738
#
# Average test loss: 0.2809, Test accuracy: 9178/10000 (91.78%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 97.5
# Two        - 92.7
# Three      - 93.3
# Four       - 95.0
# Five       - 89.5
# Six        - 95.2
# Seven      - 89.3
# Eight      - 89.5
# Nine       - 89.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.613565
#
# Average test loss: 0.2530, Test accuracy: 9282/10000 (92.82%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 97.8
# Two        - 90.6
# Three      - 93.0
# Four       - 94.9
# Five       - 91.2
# Six        - 95.7
# Seven      - 87.7
# Eight      - 86.7
# Nine       - 88.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.601785
#
# Average test loss: 0.2472, Test accuracy: 9285/10000 (92.85%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 98.2
# Two        - 90.8
# Three      - 94.3
# Four       - 94.0
# Five       - 91.2
# Six        - 96.1
# Seven      - 90.1
# Eight      - 86.5
# Nine       - 89.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.570995
#
# Average test loss: 0.2269, Test accuracy: 9363/10000 (93.63%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.4
# Two        - 91.8
# Three      - 94.0
# Four       - 96.2
# Five       - 92.3
# Six        - 96.4
# Seven      - 88.7
# Eight      - 89.9
# Nine       - 91.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.550552
#
# Average test loss: 0.2231, Test accuracy: 9356/10000 (93.56%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 91.0
# Three      - 94.8
# Four       - 95.5
# Five       - 91.4
# Six        - 95.8
# Seven      - 90.2
# Eight      - 89.7
# Nine       - 92.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.526499
#
# Average test loss: 0.2101, Test accuracy: 9389/10000 (93.89%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 97.7
# Two        - 93.3
# Three      - 93.8
# Four       - 95.3
# Five       - 93.0
# Six        - 96.1
# Seven      - 90.8
# Eight      - 88.0
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.528436
#
# Average test loss: 0.2068, Test accuracy: 9401/10000 (94.01%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.2
# Two        - 94.8
# Three      - 95.4
# Four       - 95.0
# Five       - 92.3
# Six        - 96.7
# Seven      - 89.6
# Eight      - 91.1
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.500215
#
# Average test loss: 0.1945, Test accuracy: 9411/10000 (94.11%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.7
# Two        - 92.5
# Three      - 94.3
# Four       - 96.3
# Five       - 92.5
# Six        - 97.0
# Seven      - 93.5
# Eight      - 90.4
# Nine       - 91.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.500074
#
# Average test loss: 0.1790, Test accuracy: 9487/10000 (94.87%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.4
# Two        - 92.8
# Three      - 93.6
# Four       - 94.2
# Five       - 94.5
# Six        - 96.2
# Seven      - 91.2
# Eight      - 90.2
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.481518
#
# Average test loss: 0.1867, Test accuracy: 9428/10000 (94.28%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.5
# Two        - 95.9
# Three      - 94.9
# Four       - 95.6
# Five       - 94.3
# Six        - 95.7
# Seven      - 91.3
# Eight      - 89.0
# Nine       - 93.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.478800
#
# Average test loss: 0.1825, Test accuracy: 9438/10000 (94.38%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.6
# Two        - 91.8
# Three      - 93.7
# Four       - 94.7
# Five       - 95.9
# Six        - 96.3
# Seven      - 92.2
# Eight      - 92.1
# Nine       - 93.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.437803
#
# Average test loss: 0.1671, Test accuracy: 9497/10000 (94.97%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 92.4
# Three      - 94.3
# Four       - 94.5
# Five       - 94.0
# Six        - 96.0
# Seven      - 94.8
# Eight      - 92.0
# Nine       - 93.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.457565
#
# Average test loss: 0.1694, Test accuracy: 9495/10000 (94.95%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.9
# Two        - 96.1
# Three      - 95.9
# Four       - 94.9
# Five       - 94.2
# Six        - 96.3
# Seven      - 92.8
# Eight      - 91.9
# Nine       - 92.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.454531
#
# Average test loss: 0.1555, Test accuracy: 9536/10000 (95.36%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 97.9
# Two        - 95.0
# Three      - 96.3
# Four       - 96.2
# Five       - 94.7
# Six        - 95.7
# Seven      - 91.3
# Eight      - 93.2
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.423559
#
# Average test loss: 0.1514, Test accuracy: 9550/10000 (95.50%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 94.9
# Three      - 95.4
# Four       - 96.7
# Five       - 96.2
# Six        - 96.8
# Seven      - 90.7
# Eight      - 91.2
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.435886
#
# Average test loss: 0.1582, Test accuracy: 9510/10000 (95.10%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.7
# Two        - 95.1
# Three      - 95.3
# Four       - 95.1
# Five       - 97.2
# Six        - 97.0
# Seven      - 92.8
# Eight      - 92.6
# Nine       - 92.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.439102
#
# Average test loss: 0.1487, Test accuracy: 9543/10000 (95.43%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.7
# Two        - 95.8
# Three      - 95.5
# Four       - 96.3
# Five       - 96.0
# Six        - 97.3
# Seven      - 89.6
# Eight      - 90.8
# Nine       - 94.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.432459
#
# Average test loss: 0.1485, Test accuracy: 9547/10000 (95.47%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.3
# Two        - 97.0
# Three      - 96.3
# Four       - 96.5
# Five       - 96.3
# Six        - 97.2
# Seven      - 91.4
# Eight      - 92.4
# Nine       - 92.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.426044
#
# Average test loss: 0.1474, Test accuracy: 9559/10000 (95.59%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 95.6
# Three      - 96.6
# Four       - 97.0
# Five       - 95.9
# Six        - 96.8
# Seven      - 90.1
# Eight      - 91.7
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.397884
#
# Average test loss: 0.1387, Test accuracy: 9564/10000 (95.64%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.4
# Two        - 96.8
# Three      - 96.2
# Four       - 95.6
# Five       - 97.3
# Six        - 96.6
# Seven      - 91.4
# Eight      - 93.3
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.395575
#
# Average test loss: 0.1336, Test accuracy: 9600/10000 (96.00%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.5
# Two        - 96.4
# Three      - 96.7
# Four       - 95.9
# Five       - 96.0
# Six        - 97.0
# Seven      - 93.5
# Eight      - 93.5
# Nine       - 93.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.394010
#
# Average test loss: 0.1302, Test accuracy: 9639/10000 (96.39%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 96.1
# Three      - 96.1
# Four       - 96.8
# Five       - 98.2
# Six        - 96.7
# Seven      - 92.8
# Eight      - 93.8
# Nine       - 92.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.396442
#
# Average test loss: 0.1296, Test accuracy: 9611/10000 (96.11%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.4
# Two        - 96.2
# Three      - 97.3
# Four       - 95.6
# Five       - 96.6
# Six        - 97.0
# Seven      - 91.9
# Eight      - 93.8
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.395202
#
# Average test loss: 0.1359, Test accuracy: 9591/10000 (95.91%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.6
# Two        - 96.1
# Three      - 96.2
# Four       - 96.3
# Five       - 96.5
# Six        - 97.4
# Seven      - 92.5
# Eight      - 94.4
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.371692
#
# Average test loss: 0.1289, Test accuracy: 9592/10000 (95.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.6
# Two        - 96.5
# Three      - 97.0
# Four       - 96.1
# Five       - 97.7
# Six        - 97.2
# Seven      - 93.9
# Eight      - 92.8
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.391050
#
# Average test loss: 0.1250, Test accuracy: 9613/10000 (96.13%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.2
# Two        - 97.4
# Three      - 96.8
# Four       - 96.2
# Five       - 97.7
# Six        - 97.2
# Seven      - 93.4
# Eight      - 94.4
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.364323
#
# Average test loss: 0.1209, Test accuracy: 9653/10000 (96.53%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.1
# Two        - 96.5
# Three      - 97.2
# Four       - 96.6
# Five       - 98.1
# Six        - 96.6
# Seven      - 93.5
# Eight      - 91.9
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.352198
#
# Average test loss: 0.1203, Test accuracy: 9656/10000 (96.56%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.1
# Two        - 97.2
# Three      - 97.6
# Four       - 96.8
# Five       - 96.9
# Six        - 97.6
# Seven      - 95.8
# Eight      - 93.0
# Nine       - 94.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.376191
#
# Average test loss: 0.1156, Test accuracy: 9659/10000 (96.59%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 96.2
# Three      - 97.5
# Four       - 96.5
# Five       - 98.2
# Six        - 97.7
# Seven      - 92.1
# Eight      - 93.7
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.365942
#
# Average test loss: 0.1156, Test accuracy: 9639/10000 (96.39%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.3
# Three      - 96.7
# Four       - 96.3
# Five       - 98.7
# Six        - 96.9
# Seven      - 94.4
# Eight      - 92.2
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.372063
#
# Average test loss: 0.1152, Test accuracy: 9646/10000 (96.46%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.0
# Two        - 95.4
# Three      - 96.4
# Four       - 96.2
# Five       - 98.1
# Six        - 97.9
# Seven      - 91.6
# Eight      - 93.0
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.355755
#
# Average test loss: 0.1217, Test accuracy: 9625/10000 (96.25%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 96.7
# Three      - 96.2
# Four       - 96.8
# Five       - 97.6
# Six        - 97.4
# Seven      - 93.7
# Eight      - 93.0
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.337237
#
# Average test loss: 0.1153, Test accuracy: 9636/10000 (96.36%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.3
# Two        - 96.8
# Three      - 97.1
# Four       - 97.7
# Five       - 97.5
# Six        - 97.2
# Seven      - 94.7
# Eight      - 94.8
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.334570
#
# Average test loss: 0.1066, Test accuracy: 9683/10000 (96.83%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.2
# Two        - 97.4
# Three      - 97.0
# Four       - 97.4
# Five       - 96.6
# Six        - 97.5
# Seven      - 93.7
# Eight      - 94.5
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.345052
#
# Average test loss: 0.1143, Test accuracy: 9661/10000 (96.61%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.7
# Two        - 96.1
# Three      - 96.5
# Four       - 97.3
# Five       - 98.4
# Six        - 97.4
# Seven      - 94.7
# Eight      - 94.6
# Nine       - 92.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 48/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.345142
#
# Average test loss: 0.1091, Test accuracy: 9675/10000 (96.75%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 95.7
# Three      - 96.2
# Four       - 97.5
# Five       - 98.1
# Six        - 98.5
# Seven      - 95.4
# Eight      - 93.8
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 49/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.326502
#
# Average test loss: 0.1081, Test accuracy: 9684/10000 (96.84%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.8
# Two        - 96.5
# Three      - 97.7
# Four       - 97.1
# Five       - 98.5
# Six        - 97.5
# Seven      - 95.5
# Eight      - 93.7
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 50/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.332162
#
# Average test loss: 0.1062, Test accuracy: 9665/10000 (96.65%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.6
# Two        - 96.9
# Three      - 96.7
# Four       - 97.3
# Five       - 98.3
# Six        - 97.3
# Seven      - 94.8
# Eight      - 93.8
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 51/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.318099
#
# Average test loss: 0.0957, Test accuracy: 9713/10000 (97.13%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.7
# Two        - 97.1
# Three      - 95.9
# Four       - 97.4
# Five       - 98.8
# Six        - 97.8
# Seven      - 95.0
# Eight      - 95.1
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 52/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.315447
#
# Average test loss: 0.1029, Test accuracy: 9678/10000 (96.78%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.5
# Three      - 97.6
# Four       - 96.9
# Five       - 97.9
# Six        - 97.1
# Seven      - 94.9
# Eight      - 93.6
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 53/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.342966
#
# Average test loss: 0.1010, Test accuracy: 9684/10000 (96.84%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.2
# Two        - 97.3
# Three      - 97.0
# Four       - 97.0
# Five       - 97.9
# Six        - 97.3
# Seven      - 93.6
# Eight      - 96.2
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 54/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.319797
#
# Average test loss: 0.1065, Test accuracy: 9683/10000 (96.83%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.2
# Two        - 96.7
# Three      - 97.2
# Four       - 97.0
# Five       - 97.7
# Six        - 98.0
# Seven      - 94.7
# Eight      - 93.0
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 55/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.318770
#
# Average test loss: 0.1006, Test accuracy: 9698/10000 (96.98%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 96.8
# Three      - 98.0
# Four       - 97.8
# Five       - 98.5
# Six        - 97.1
# Seven      - 94.2
# Eight      - 93.4
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 56/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.314996
#
# Average test loss: 0.1033, Test accuracy: 9689/10000 (96.89%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 97.2
# Three      - 97.3
# Four       - 98.0
# Five       - 97.6
# Six        - 97.1
# Seven      - 93.3
# Eight      - 95.8
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 57/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.312275
#
# Average test loss: 0.1091, Test accuracy: 9670/10000 (96.70%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.8
# Three      - 96.7
# Four       - 97.5
# Five       - 97.8
# Six        - 98.0
# Seven      - 95.9
# Eight      - 94.4
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 58/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.295125
#
# Average test loss: 0.1072, Test accuracy: 9694/10000 (96.94%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.7
# Three      - 96.4
# Four       - 96.6
# Five       - 97.6
# Six        - 97.3
# Seven      - 96.1
# Eight      - 95.6
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 59/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.320478
#
# Average test loss: 0.0938, Test accuracy: 9701/10000 (97.01%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.2
# Two        - 96.9
# Three      - 97.9
# Four       - 98.3
# Five       - 97.8
# Six        - 97.7
# Seven      - 93.8
# Eight      - 95.0
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 60/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.317431
#
# Average test loss: 0.0995, Test accuracy: 9701/10000 (97.01%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.8
# Two        - 97.5
# Three      - 96.7
# Four       - 97.8
# Five       - 98.5
# Six        - 97.3
# Seven      - 96.8
# Eight      - 95.7
# Nine       - 94.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 61/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# ...
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.281067
#
# Average test loss: 0.0854, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.2
# Two        - 98.2
# Three      - 98.1
# Four       - 97.7
# Five       - 98.5
# Six        - 97.5
# Seven      - 95.3
# Eight      - 97.6
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 85/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.271591
#
# Average test loss: 0.0839, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.8
# Two        - 97.9
# Three      - 98.1
# Four       - 98.2
# Five       - 98.9
# Six        - 96.9
# Seven      - 94.8
# Eight      - 95.9
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 86/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.261606
#
# Average test loss: 0.0856, Test accuracy: 9742/10000 (97.42%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 98.1
# Three      - 98.0
# Four       - 97.4
# Five       - 98.9
# Six        - 97.7
# Seven      - 94.6
# Eight      - 96.2
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 87/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.268455
#
# Average test loss: 0.0859, Test accuracy: 9748/10000 (97.48%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.8
# Two        - 97.4
# Three      - 97.9
# Four       - 98.5
# Five       - 98.6
# Six        - 96.6
# Seven      - 94.3
# Eight      - 96.7
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 88/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.250069
#
# Average test loss: 0.0860, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 98.0
# Three      - 97.9
# Four       - 98.6
# Five       - 98.8
# Six        - 97.7
# Seven      - 96.1
# Eight      - 95.7
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 89/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.263277
#
# Average test loss: 0.0736, Test accuracy: 9777/10000 (97.77%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.5
# Two        - 97.1
# Three      - 98.3
# Four       - 98.9
# Five       - 99.1
# Six        - 97.8
# Seven      - 95.5
# Eight      - 95.2
# Nine       - 97.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 90/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.261085
#
# Average test loss: 0.0746, Test accuracy: 9758/10000 (97.58%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 97.6
# Three      - 97.6
# Four       - 98.3
# Five       - 98.1
# Six        - 98.4
# Seven      - 95.8
# Eight      - 97.0
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 91/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 0.231995
#
# Average test loss: 0.0761, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.1
# Two        - 98.3
# Three      - 98.0
# Four       - 98.2
# Five       - 99.3
# Six        - 97.7
# Seven      - 96.7
# Eight      - 95.9
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 92/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.266977
#
# Average test loss: 0.0801, Test accuracy: 9736/10000 (97.36%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.0
# Three      - 98.3
# Four       - 97.6
# Five       - 98.9
# Six        - 97.9
# Seven      - 95.2
# Eight      - 95.8
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 93/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.267032
#
# Average test loss: 0.0784, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 97.1
# Three      - 97.6
# Four       - 98.6
# Five       - 98.4
# Six        - 97.5
# Seven      - 95.9
# Eight      - 97.0
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 94/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.266232
#
# Average test loss: 0.0693, Test accuracy: 9785/10000 (97.85%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.7
# Two        - 98.2
# Three      - 97.3
# Four       - 97.8
# Five       - 99.0
# Six        - 97.1
# Seven      - 93.2
# Eight      - 96.4
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.269610
#
# Average test loss: 0.0777, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 99.1
# Three      - 98.6
# Four       - 98.3
# Five       - 98.8
# Six        - 98.0
# Seven      - 93.4
# Eight      - 96.1
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.248444
#
# Average test loss: 0.0786, Test accuracy: 9779/10000 (97.79%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.1
# Two        - 97.9
# Three      - 99.0
# Four       - 98.3
# Five       - 98.9
# Six        - 98.7
# Seven      - 96.0
# Eight      - 97.4
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.260354
#
# Average test loss: 0.0759, Test accuracy: 9762/10000 (97.62%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.5
# Two        - 98.3
# Three      - 97.9
# Four       - 98.4
# Five       - 98.9
# Six        - 97.8
# Seven      - 96.1
# Eight      - 96.9
# Nine       - 94.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.244941
#
# Average test loss: 0.0765, Test accuracy: 9773/10000 (97.73%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.2
# Three      - 97.8
# Four       - 97.4
# Five       - 98.7
# Six        - 97.0
# Seven      - 94.7
# Eight      - 96.3
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.253557
#
# Average test loss: 0.0775, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.9
# Two        - 98.4
# Three      - 97.8
# Four       - 98.2
# Five       - 99.1
# Six        - 98.6
# Seven      - 95.4
# Eight      - 97.2
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.236919
#
# Average test loss: 0.0824, Test accuracy: 9762/10000 (97.62%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.7
# Two        - 98.2
# Three      - 97.4
# Four       - 97.9
# Five       - 98.9
# Six        - 97.6
# Seven      - 95.8
# Eight      - 95.5
# Nine       - 96.0
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0738, Test accuracy: 9800/10000 (98.00%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.2
# Two        - 98.0
# Three      - 98.2
# Four       - 99.2
# Five       - 98.8
# Six        - 96.9
# Seven      - 96.2
# Eight      - 96.8
# Nine       - 96.7
# Global accuracies:  [30.47, 59.03, 67.31, 75.32, 82.92, 86.38, 87.65, 89.31, 89.93, 90.6, 91.77, 92.34, 91.78, 92.82, 92.85, 93.63, 93.56, 93.89, 94.01, 94.11, 94.87, 94.28, 94.38, 94.97, 94.95, 95.36, 95.5, 95.1, 95.43, 95.47, 95.59, 95.64, 96.0, 96.39, 96.11, 95.91, 95.92, 96.13, 96.53, 96.56, 96.59, 96.39, 96.46, 96.25, 96.36, 96.83, 96.61, 96.75, 96.84, 96.65, 97.13, 96.78, 96.84, 96.83, 96.98, 96.89, 96.7, 96.94, 97.01, 97.01, 97.17, 97.1, 97.14, 97.01, 96.85, 97.18, 97.31, 97.11, 97.26, 97.65, 97.38, 97.34, 97.57, 97.14, 97.58, 97.3, 97.49, 97.54, 97.67, 97.56, 97.08, 97.51, 97.38, 97.41, 97.67, 97.42, 97.48, 97.44, 97.77, 97.58, 97.78, 97.36, 97.76, 97.85, 97.7, 97.79, 97.62, 97.73, 97.53, 97.62, 98.0]
# Class 7 accuracies:  [24.36, 77.91, 82.6, 82.79, 85.34, 87.16, 88.83, 86.63, 84.4, 86.07, 89.85, 89.17, 89.28, 87.68, 90.11, 88.69, 90.18, 90.82, 89.6, 93.45, 91.23, 91.27, 92.23, 94.77, 92.84, 91.3, 90.75, 92.81, 89.6, 91.39, 90.12, 91.43, 93.53, 92.76, 91.89, 92.53, 93.94, 93.38, 93.49, 95.76, 92.15, 94.35, 91.61, 93.71, 94.68, 93.65, 94.69, 95.4, 95.45, 94.82, 95.05, 94.92, 93.63, 94.69, 94.15, 93.33, 95.88, 96.11, 93.79, 96.76, 95.53, 94.98, 95.14, 94.42, 94.05, 92.65, 94.96, 94.9, 94.0, 96.17, 93.67, 95.89, 94.44, 93.16, 96.91, 95.18, 94.94, 95.15, 94.31, 95.75, 93.87, 95.16, 94.17, 95.34, 94.78, 94.64, 94.34, 96.07, 95.51, 95.81, 96.67, 95.23, 95.86, 93.23, 93.43, 96.01, 96.14, 94.71, 95.38, 95.8, 96.24]
# Test loss: [2.2557, 2.1513, 1.7952, 1.1901, 0.785, 0.591, 0.4935, 0.4237, 0.397, 0.3474, 0.3025, 0.284, 0.2809, 0.253, 0.2472, 0.2269, 0.2231, 0.2101, 0.2068, 0.1945, 0.179, 0.1867, 0.1825, 0.1671, 0.1694, 0.1555, 0.1514, 0.1582, 0.1487, 0.1485, 0.1474, 0.1387, 0.1336, 0.1302, 0.1296, 0.1359, 0.1289, 0.125, 0.1209, 0.1203, 0.1156, 0.1156, 0.1152, 0.1217, 0.1153, 0.1066, 0.1143, 0.1091, 0.1081, 0.1062, 0.0957, 0.1029, 0.101, 0.1065, 0.1006, 0.1033, 0.1091, 0.1072, 0.0938, 0.0995, 0.0932, 0.0972, 0.0962, 0.1007, 0.1021, 0.0996, 0.0939, 0.0954, 0.0929, 0.087, 0.09, 0.0876, 0.0859, 0.0967, 0.088, 0.0909, 0.0857, 0.0802, 0.0838, 0.0837, 0.0986, 0.0841, 0.082, 0.0854, 0.0839, 0.0856, 0.0859, 0.086, 0.0736, 0.0746, 0.0761, 0.0801, 0.0784, 0.0693, 0.0777, 0.0786, 0.0759, 0.0765, 0.0775, 0.0824, 0.0738]
# Label-flipping attack succes rate: 0.56
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.006
# --> End of Experiment.

# %%
RULE = 'tmean'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: tmean
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.281664
#
# Average test loss: 2.2575, Test accuracy: 2628/10000 (26.28%)
#
# Class      - Accuracy
# Zero       - 3.9
# One        - 98.1
# Two        - 51.7
# Three      - 28.7
# Four       - 1.1
# Five       - 0.3
# Six        - 0.0
# Seven      - 5.1
# Eight      - 25.3
# Nine       - 44.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.229461
#
# Average test loss: 2.1563, Test accuracy: 5583/10000 (55.83%)
#
# Class      - Accuracy
# Zero       - 87.2
# One        - 99.6
# Two        - 45.5
# Three      - 69.4
# Four       - 36.4
# Five       - 2.3
# Six        - 46.6
# Seven      - 51.3
# Eight      - 58.0
# Nine       - 70.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 2.086770
#
# Average test loss: 1.8060, Test accuracy: 6724/10000 (67.24%)
#
# Class      - Accuracy
# Zero       - 93.0
# One        - 98.2
# Two        - 48.4
# Three      - 80.5
# Four       - 62.7
# Five       - 10.8
# Six        - 74.4
# Seven      - 79.8
# Eight      - 58.8
# Nine       - 62.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 1.740192
#
# Average test loss: 1.2064, Test accuracy: 7483/10000 (74.83%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 98.0
# Two        - 68.8
# Three      - 81.3
# Four       - 82.5
# Five       - 41.8
# Six        - 79.4
# Seven      - 81.8
# Eight      - 62.0
# Nine       - 55.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 1.366348
#
# Average test loss: 0.7949, Test accuracy: 8293/10000 (82.93%)
#
# Class      - Accuracy
# Zero       - 96.3
# One        - 93.9
# Two        - 83.5
# Three      - 85.7
# Four       - 83.8
# Five       - 73.6
# Six        - 87.7
# Seven      - 85.3
# Eight      - 70.1
# Nine       - 71.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 1.129147
#
# Average test loss: 0.5973, Test accuracy: 8614/10000 (86.14%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 95.9
# Two        - 84.9
# Three      - 88.8
# Four       - 85.9
# Five       - 78.5
# Six        - 90.9
# Seven      - 86.1
# Eight      - 75.6
# Nine       - 80.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.971783
#
# Average test loss: 0.4955, Test accuracy: 8749/10000 (87.49%)
#
# Class      - Accuracy
# Zero       - 97.5
# One        - 96.8
# Two        - 88.5
# Three      - 90.4
# Four       - 91.8
# Five       - 80.0
# Six        - 90.8
# Seven      - 88.6
# Eight      - 80.3
# Nine       - 79.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.872134
#
# Average test loss: 0.4233, Test accuracy: 8927/10000 (89.27%)
#
# Class      - Accuracy
# Zero       - 97.0
# One        - 96.6
# Two        - 90.8
# Three      - 89.7
# Four       - 92.4
# Five       - 82.8
# Six        - 94.6
# Seven      - 86.5
# Eight      - 80.8
# Nine       - 78.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.841250
#
# Average test loss: 0.4259, Test accuracy: 8834/10000 (88.34%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 97.9
# Two        - 91.5
# Three      - 90.2
# Four       - 93.6
# Five       - 88.0
# Six        - 94.9
# Seven      - 72.0
# Eight      - 79.5
# Nine       - 80.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.754850
#
# Average test loss: 0.3478, Test accuracy: 9076/10000 (90.76%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 97.8
# Two        - 90.6
# Three      - 90.2
# Four       - 91.9
# Five       - 88.6
# Six        - 95.9
# Seven      - 85.5
# Eight      - 83.2
# Nine       - 88.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.713967
#
# Average test loss: 0.3034, Test accuracy: 9190/10000 (91.90%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.3
# Two        - 90.5
# Three      - 92.3
# Four       - 94.6
# Five       - 86.6
# Six        - 93.3
# Seven      - 90.0
# Eight      - 85.2
# Nine       - 86.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.689869
#
# Average test loss: 0.2921, Test accuracy: 9196/10000 (91.96%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.5
# Two        - 91.1
# Three      - 93.0
# Four       - 94.8
# Five       - 88.2
# Six        - 94.8
# Seven      - 85.2
# Eight      - 83.4
# Nine       - 88.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.652028
#
# Average test loss: 0.2895, Test accuracy: 9145/10000 (91.45%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 97.6
# Two        - 92.4
# Three      - 93.1
# Four       - 94.8
# Five       - 89.2
# Six        - 95.1
# Seven      - 85.4
# Eight      - 88.9
# Nine       - 90.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.609548
#
# Average test loss: 0.2529, Test accuracy: 9282/10000 (92.82%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 97.9
# Two        - 90.6
# Three      - 93.6
# Four       - 94.9
# Five       - 90.8
# Six        - 95.7
# Seven      - 87.6
# Eight      - 87.7
# Nine       - 87.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.596557
#
# Average test loss: 0.2476, Test accuracy: 9266/10000 (92.66%)
#
# Class      - Accuracy
# Zero       - 97.5
# One        - 98.2
# Two        - 90.8
# Three      - 94.3
# Four       - 93.8
# Five       - 91.3
# Six        - 96.0
# Seven      - 89.7
# Eight      - 86.5
# Nine       - 89.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.566356
#
# Average test loss: 0.2273, Test accuracy: 9368/10000 (93.68%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.2
# Two        - 92.0
# Three      - 94.4
# Four       - 96.1
# Five       - 92.3
# Six        - 96.4
# Seven      - 88.7
# Eight      - 90.0
# Nine       - 91.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.546127
#
# Average test loss: 0.2227, Test accuracy: 9360/10000 (93.60%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 91.3
# Three      - 94.8
# Four       - 95.5
# Five       - 91.4
# Six        - 95.8
# Seven      - 90.2
# Eight      - 90.0
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.524265
#
# Average test loss: 0.2097, Test accuracy: 9387/10000 (93.87%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 97.7
# Two        - 92.9
# Three      - 93.9
# Four       - 95.3
# Five       - 92.4
# Six        - 96.1
# Seven      - 90.8
# Eight      - 87.5
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.523789
#
# Average test loss: 0.2071, Test accuracy: 9392/10000 (93.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.2
# Two        - 94.6
# Three      - 95.6
# Four       - 95.0
# Five       - 92.0
# Six        - 96.6
# Seven      - 89.3
# Eight      - 91.4
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.497177
#
# Average test loss: 0.1941, Test accuracy: 9410/10000 (94.10%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.7
# Two        - 92.7
# Three      - 94.2
# Four       - 96.5
# Five       - 92.0
# Six        - 97.0
# Seven      - 93.6
# Eight      - 90.4
# Nine       - 91.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.495663
#
# Average test loss: 0.1779, Test accuracy: 9483/10000 (94.83%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.3
# Two        - 93.1
# Three      - 93.9
# Four       - 94.1
# Five       - 93.8
# Six        - 96.2
# Seven      - 91.0
# Eight      - 91.0
# Nine       - 92.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.477747
#
# Average test loss: 0.1868, Test accuracy: 9428/10000 (94.28%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.5
# Two        - 95.9
# Three      - 94.7
# Four       - 95.3
# Five       - 94.3
# Six        - 95.7
# Seven      - 90.8
# Eight      - 88.8
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.474024
#
# Average test loss: 0.1822, Test accuracy: 9447/10000 (94.47%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.6
# Two        - 91.9
# Three      - 93.8
# Four       - 94.7
# Five       - 95.6
# Six        - 96.3
# Seven      - 92.2
# Eight      - 92.2
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.437297
#
# Average test loss: 0.1672, Test accuracy: 9512/10000 (95.12%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 92.9
# Three      - 94.1
# Four       - 95.4
# Five       - 94.8
# Six        - 96.3
# Seven      - 94.5
# Eight      - 91.7
# Nine       - 93.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.453267
#
# Average test loss: 0.1696, Test accuracy: 9489/10000 (94.89%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.9
# Two        - 96.3
# Three      - 95.9
# Four       - 95.1
# Five       - 94.4
# Six        - 96.3
# Seven      - 92.4
# Eight      - 92.0
# Nine       - 92.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.449338
#
# Average test loss: 0.1621, Test accuracy: 9518/10000 (95.18%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 97.9
# Two        - 95.0
# Three      - 96.4
# Four       - 96.1
# Five       - 95.5
# Six        - 95.7
# Seven      - 89.7
# Eight      - 93.5
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.420780
#
# Average test loss: 0.1507, Test accuracy: 9561/10000 (95.61%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 94.9
# Three      - 95.5
# Four       - 97.0
# Five       - 96.1
# Six        - 96.1
# Seven      - 91.1
# Eight      - 91.4
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.431309
#
# Average test loss: 0.1582, Test accuracy: 9518/10000 (95.18%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.7
# Two        - 95.3
# Three      - 95.3
# Four       - 95.2
# Five       - 97.3
# Six        - 97.1
# Seven      - 92.9
# Eight      - 92.4
# Nine       - 92.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.431765
#
# Average test loss: 0.1550, Test accuracy: 9534/10000 (95.34%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.7
# Two        - 96.3
# Three      - 95.6
# Four       - 96.5
# Five       - 96.8
# Six        - 97.3
# Seven      - 87.8
# Eight      - 91.0
# Nine       - 93.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.422677
#
# Average test loss: 0.1559, Test accuracy: 9539/10000 (95.39%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.3
# Two        - 97.5
# Three      - 96.4
# Four       - 96.3
# Five       - 96.3
# Six        - 97.6
# Seven      - 89.0
# Eight      - 92.5
# Nine       - 92.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.413305
#
# Average test loss: 0.1541, Test accuracy: 9541/10000 (95.41%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.1
# Three      - 96.5
# Four       - 96.8
# Five       - 96.3
# Six        - 96.9
# Seven      - 88.2
# Eight      - 92.0
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.391592
#
# Average test loss: 0.1385, Test accuracy: 9572/10000 (95.72%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.7
# Two        - 96.9
# Three      - 96.1
# Four       - 95.8
# Five       - 97.5
# Six        - 96.8
# Seven      - 91.2
# Eight      - 93.4
# Nine       - 93.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.389784
#
# Average test loss: 0.1333, Test accuracy: 9605/10000 (96.05%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.5
# Two        - 96.4
# Three      - 96.7
# Four       - 95.8
# Five       - 96.2
# Six        - 97.1
# Seven      - 93.2
# Eight      - 94.0
# Nine       - 93.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.388412
#
# Average test loss: 0.1302, Test accuracy: 9639/10000 (96.39%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 96.1
# Three      - 96.1
# Four       - 96.6
# Five       - 98.1
# Six        - 96.9
# Seven      - 92.9
# Eight      - 93.7
# Nine       - 92.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.389537
#
# Average test loss: 0.1347, Test accuracy: 9593/10000 (95.93%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.4
# Two        - 96.1
# Three      - 97.4
# Four       - 95.8
# Five       - 97.0
# Six        - 97.0
# Seven      - 90.1
# Eight      - 93.8
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.383707
#
# Average test loss: 0.1425, Test accuracy: 9558/10000 (95.58%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.8
# Two        - 96.0
# Three      - 96.0
# Four       - 96.3
# Five       - 96.7
# Six        - 97.6
# Seven      - 90.7
# Eight      - 95.0
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.368178
#
# Average test loss: 0.1282, Test accuracy: 9602/10000 (96.02%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.7
# Two        - 96.5
# Three      - 96.9
# Four       - 95.9
# Five       - 97.8
# Six        - 97.2
# Seven      - 94.3
# Eight      - 93.2
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.381321
#
# Average test loss: 0.1311, Test accuracy: 9601/10000 (96.01%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.2
# Two        - 97.5
# Three      - 96.8
# Four       - 96.7
# Five       - 97.7
# Six        - 97.3
# Seven      - 92.3
# Eight      - 94.4
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.361209
#
# Average test loss: 0.1204, Test accuracy: 9661/10000 (96.61%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.1
# Two        - 96.7
# Three      - 97.1
# Four       - 96.7
# Five       - 98.1
# Six        - 96.6
# Seven      - 93.8
# Eight      - 91.8
# Nine       - 94.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.349120
#
# Average test loss: 0.1204, Test accuracy: 9665/10000 (96.65%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.9
# Two        - 97.1
# Three      - 97.1
# Four       - 96.8
# Five       - 97.4
# Six        - 97.7
# Seven      - 95.9
# Eight      - 92.4
# Nine       - 93.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.368040
#
# Average test loss: 0.1206, Test accuracy: 9650/10000 (96.50%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 96.4
# Three      - 97.5
# Four       - 96.8
# Five       - 98.1
# Six        - 97.7
# Seven      - 90.9
# Eight      - 94.0
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.358217
#
# Average test loss: 0.1153, Test accuracy: 9649/10000 (96.49%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.5
# Three      - 96.3
# Four       - 96.5
# Five       - 98.7
# Six        - 96.6
# Seven      - 95.4
# Eight      - 92.5
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.362640
#
# Average test loss: 0.1204, Test accuracy: 9637/10000 (96.37%)
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.1
# Two        - 95.5
# Three      - 96.5
# Four       - 96.3
# Five       - 98.1
# Six        - 97.9
# Seven      - 90.5
# Eight      - 93.4
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.343994
#
# Average test loss: 0.1284, Test accuracy: 9611/10000 (96.11%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.4
# Two        - 97.1
# Three      - 96.3
# Four       - 96.4
# Five       - 97.5
# Six        - 97.4
# Seven      - 91.8
# Eight      - 93.2
# Nine       - 94.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.329992
#
# Average test loss: 0.1151, Test accuracy: 9636/10000 (96.36%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 96.9
# Three      - 96.9
# Four       - 97.7
# Five       - 97.6
# Six        - 97.2
# Seven      - 94.5
# Eight      - 94.9
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.331536
#
# Average test loss: 0.1070, Test accuracy: 9694/10000 (96.94%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.3
# Two        - 97.3
# Three      - 96.9
# Four       - 97.2
# Five       - 96.3
# Six        - 97.7
# Seven      - 94.5
# Eight      - 94.6
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.339182
#
# Average test loss: 0.1136, Test accuracy: 9672/10000 (96.72%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.8
# Two        - 96.1
# Three      - 96.2
# Four       - 97.3
# Five       - 98.4
# Six        - 97.4
# Seven      - 94.8
# Eight      - 94.6
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 48/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.338746
#
# Average test loss: 0.1088, Test accuracy: 9677/10000 (96.77%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.1
# Two        - 95.7
# Three      - 96.6
# Four       - 97.6
# Five       - 97.9
# Six        - 98.5
# Seven      - 95.5
# Eight      - 93.9
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 49/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.323612
#
# Average test loss: 0.1079, Test accuracy: 9687/10000 (96.87%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 96.4
# Three      - 97.9
# Four       - 97.3
# Five       - 98.4
# Six        - 97.5
# Seven      - 95.4
# Eight      - 94.1
# Nine       - 94.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 50/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.326613
#
# Average test loss: 0.1066, Test accuracy: 9666/10000 (96.66%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.6
# Two        - 96.8
# Three      - 96.7
# Four       - 97.6
# Five       - 98.1
# Six        - 97.3
# Seven      - 94.9
# Eight      - 93.0
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 51/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.315512
#
# Average test loss: 0.0955, Test accuracy: 9710/10000 (97.10%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 96.4
# Three      - 96.0
# Four       - 97.4
# Five       - 98.8
# Six        - 97.9
# Seven      - 95.2
# Eight      - 95.1
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 52/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.312757
#
# Average test loss: 0.1027, Test accuracy: 9679/10000 (96.79%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.0
# Two        - 96.0
# Three      - 97.3
# Four       - 96.9
# Five       - 97.8
# Six        - 97.1
# Seven      - 95.2
# Eight      - 93.4
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 53/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.334913
#
# Average test loss: 0.1053, Test accuracy: 9675/10000 (96.75%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.0
# Three      - 97.0
# Four       - 96.8
# Five       - 97.9
# Six        - 97.3
# Seven      - 91.6
# Eight      - 96.1
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 54/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.313621
#
# Average test loss: 0.1063, Test accuracy: 9681/10000 (96.81%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 96.4
# Three      - 97.1
# Four       - 97.1
# Five       - 97.7
# Six        - 98.0
# Seven      - 95.3
# Eight      - 93.2
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 55/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.312367
#
# Average test loss: 0.1001, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 96.9
# Three      - 97.9
# Four       - 98.5
# Five       - 98.5
# Six        - 97.1
# Seven      - 94.6
# Eight      - 93.9
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 56/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.309259
#
# Average test loss: 0.1028, Test accuracy: 9693/10000 (96.93%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 97.2
# Three      - 97.4
# Four       - 98.2
# Five       - 97.4
# Six        - 97.0
# Seven      - 93.8
# Eight      - 95.5
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 57/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.306046
#
# Average test loss: 0.1091, Test accuracy: 9661/10000 (96.61%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.8
# Three      - 96.7
# Four       - 97.5
# Five       - 97.9
# Six        - 98.1
# Seven      - 96.5
# Eight      - 94.2
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 58/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.291461
#
# Average test loss: 0.1075, Test accuracy: 9691/10000 (96.91%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 97.7
# Three      - 96.4
# Four       - 96.9
# Five       - 97.9
# Six        - 97.3
# Seven      - 96.2
# Eight      - 95.2
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 59/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.313211
#
# Average test loss: 0.0989, Test accuracy: 9698/10000 (96.98%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.2
# Two        - 97.4
# Three      - 98.2
# Four       - 98.3
# Five       - 97.8
# Six        - 98.0
# Seven      - 93.6
# Eight      - 95.0
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 60/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.311410
#
# Average test loss: 0.1003, Test accuracy: 9701/10000 (97.01%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.5
# Two        - 97.3
# Three      - 96.8
# Four       - 97.8
# Five       - 98.5
# Six        - 97.2
# Seven      - 96.8
# Eight      - 95.8
# Nine       - 94.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 61/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# ...
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.268464
#
# Average test loss: 0.0906, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.1
# Two        - 98.2
# Three      - 98.0
# Four       - 97.7
# Five       - 98.5
# Six        - 97.7
# Seven      - 94.1
# Eight      - 97.5
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 85/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.257263
#
# Average test loss: 0.0904, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.8
# Two        - 98.3
# Three      - 97.9
# Four       - 98.0
# Five       - 98.9
# Six        - 96.8
# Seven      - 93.7
# Eight      - 95.2
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 86/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.253482
#
# Average test loss: 0.0855, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 98.1
# Three      - 97.6
# Four       - 97.3
# Five       - 99.0
# Six        - 97.8
# Seven      - 95.0
# Eight      - 96.1
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 87/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.258648
#
# Average test loss: 0.0917, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.1
# Two        - 97.6
# Three      - 98.0
# Four       - 98.2
# Five       - 98.6
# Six        - 96.9
# Seven      - 93.6
# Eight      - 95.8
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 88/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.247193
#
# Average test loss: 0.0849, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 97.9
# Three      - 97.4
# Four       - 98.6
# Five       - 98.8
# Six        - 97.7
# Seven      - 96.4
# Eight      - 96.2
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 89/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.255549
#
# Average test loss: 0.0741, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.6
# Two        - 97.2
# Three      - 98.3
# Four       - 98.5
# Five       - 99.1
# Six        - 97.8
# Seven      - 95.7
# Eight      - 96.0
# Nine       - 97.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 90/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.253892
#
# Average test loss: 0.0749, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 97.6
# Three      - 97.8
# Four       - 98.3
# Five       - 98.0
# Six        - 98.4
# Seven      - 96.0
# Eight      - 97.1
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 91/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 0.232877
#
# Average test loss: 0.0758, Test accuracy: 9783/10000 (97.83%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 98.3
# Three      - 98.0
# Four       - 98.0
# Five       - 99.3
# Six        - 97.8
# Seven      - 96.9
# Eight      - 95.9
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 92/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.260234
#
# Average test loss: 0.0798, Test accuracy: 9749/10000 (97.49%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 98.9
# Two        - 97.9
# Three      - 98.0
# Four       - 97.7
# Five       - 99.0
# Six        - 98.3
# Seven      - 95.5
# Eight      - 95.7
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 93/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.256211
#
# Average test loss: 0.0823, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.3
# Two        - 97.6
# Three      - 97.6
# Four       - 98.4
# Five       - 98.4
# Six        - 97.9
# Seven      - 94.6
# Eight      - 96.9
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 94/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.251643
#
# Average test loss: 0.0756, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 98.2
# Three      - 97.4
# Four       - 98.1
# Five       - 99.0
# Six        - 97.2
# Seven      - 92.4
# Eight      - 96.1
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.250380
#
# Average test loss: 0.1037, Test accuracy: 9711/10000 (97.11%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 99.0
# Three      - 98.5
# Four       - 98.1
# Five       - 99.0
# Six        - 97.7
# Seven      - 89.4
# Eight      - 95.8
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.241170
#
# Average test loss: 0.0789, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.1
# Two        - 97.9
# Three      - 98.9
# Four       - 98.3
# Five       - 98.9
# Six        - 98.7
# Seven      - 95.8
# Eight      - 97.0
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.248230
#
# Average test loss: 0.0809, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 98.2
# Three      - 98.1
# Four       - 98.4
# Five       - 98.9
# Six        - 97.8
# Seven      - 95.5
# Eight      - 96.4
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.236341
#
# Average test loss: 0.0766, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 98.2
# Three      - 98.0
# Four       - 97.0
# Five       - 98.8
# Six        - 97.0
# Seven      - 95.0
# Eight      - 95.8
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.244991
#
# Average test loss: 0.0781, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 98.9
# Two        - 98.8
# Three      - 97.8
# Four       - 97.9
# Five       - 99.1
# Six        - 98.7
# Seven      - 96.0
# Eight      - 96.7
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.233100
#
# Average test loss: 0.0815, Test accuracy: 9772/10000 (97.72%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.7
# Two        - 98.4
# Three      - 97.4
# Four       - 97.9
# Five       - 99.0
# Six        - 97.9
# Seven      - 95.9
# Eight      - 95.9
# Nine       - 96.1
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0750, Test accuracy: 9796/10000 (97.96%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.2
# Two        - 98.0
# Three      - 98.1
# Four       - 99.0
# Five       - 98.8
# Six        - 97.1
# Seven      - 96.0
# Eight      - 96.6
# Nine       - 96.7
# Global accuracies:  [26.28, 55.83, 67.24, 74.83, 82.93, 86.14, 87.49, 89.27, 88.34, 90.76, 91.9, 91.96, 91.45, 92.82, 92.66, 93.68, 93.6, 93.87, 93.92, 94.1, 94.83, 94.28, 94.47, 95.12, 94.89, 95.18, 95.61, 95.18, 95.34, 95.39, 95.41, 95.72, 96.05, 96.39, 95.93, 95.58, 96.02, 96.01, 96.61, 96.65, 96.5, 96.49, 96.37, 96.11, 96.36, 96.94, 96.72, 96.77, 96.87, 96.66, 97.1, 96.79, 96.75, 96.81, 97.09, 96.93, 96.61, 96.91, 96.98, 97.01, 97.15, 97.17, 97.13, 96.92, 96.85, 97.01, 97.28, 97.21, 97.06, 97.6, 97.18, 97.4, 97.57, 96.98, 97.56, 97.36, 97.5, 97.58, 97.5, 97.51, 96.95, 97.56, 97.32, 97.19, 97.54, 97.43, 97.41, 97.44, 97.82, 97.74, 97.83, 97.49, 97.76, 97.78, 97.11, 97.7, 97.65, 97.65, 97.65, 97.72, 97.96]
# Class 7 accuracies:  [5.15, 51.32, 79.78, 81.76, 85.34, 86.14, 88.63, 86.54, 72.03, 85.47, 89.95, 85.23, 85.36, 87.58, 89.74, 88.69, 90.18, 90.82, 89.29, 93.55, 91.03, 90.84, 92.23, 94.47, 92.37, 89.75, 91.14, 92.91, 87.76, 89.02, 88.21, 91.23, 93.22, 92.86, 90.06, 90.67, 94.33, 92.28, 93.78, 95.86, 90.85, 95.36, 90.48, 91.85, 94.48, 94.53, 94.79, 95.5, 95.36, 94.92, 95.25, 95.23, 91.58, 95.29, 94.57, 93.82, 96.45, 96.21, 93.6, 96.76, 95.64, 95.09, 95.24, 92.76, 94.54, 91.51, 94.96, 95.2, 92.9, 96.07, 92.44, 95.99, 94.74, 91.57, 97.12, 95.81, 95.04, 95.26, 93.15, 95.86, 92.41, 95.36, 93.96, 94.09, 93.65, 95.03, 93.64, 96.36, 95.7, 96.01, 96.95, 95.54, 94.62, 92.38, 89.43, 95.82, 95.55, 95.02, 95.96, 95.9, 95.96]
# Test loss: [2.2575, 2.1563, 1.806, 1.2064, 0.7949, 0.5973, 0.4955, 0.4233, 0.4259, 0.3478, 0.3034, 0.2921, 0.2895, 0.2529, 0.2476, 0.2273, 0.2227, 0.2097, 0.2071, 0.1941, 0.1779, 0.1868, 0.1822, 0.1672, 0.1696, 0.1621, 0.1507, 0.1582, 0.155, 0.1559, 0.1541, 0.1385, 0.1333, 0.1302, 0.1347, 0.1425, 0.1282, 0.1311, 0.1204, 0.1204, 0.1206, 0.1153, 0.1204, 0.1284, 0.1151, 0.107, 0.1136, 0.1088, 0.1079, 0.1066, 0.0955, 0.1027, 0.1053, 0.1063, 0.1001, 0.1028, 0.1091, 0.1075, 0.0989, 0.1003, 0.0933, 0.097, 0.0956, 0.1051, 0.1023, 0.1029, 0.0937, 0.0949, 0.0972, 0.0863, 0.0943, 0.0875, 0.0853, 0.1007, 0.0875, 0.091, 0.0853, 0.0803, 0.0876, 0.0839, 0.1031, 0.0834, 0.0853, 0.0906, 0.0904, 0.0855, 0.0917, 0.0849, 0.0741, 0.0749, 0.0758, 0.0798, 0.0823, 0.0756, 0.1037, 0.0789, 0.0809, 0.0766, 0.0781, 0.0815, 0.075]
# Label-flipping attack succes rate: 0.56
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.006
# --> End of Experiment.

# %%
RULE = 'mkrum'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: mkrum
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.281666
#
# Average test loss: 2.2530, Test accuracy: 3297/10000 (32.97%)
#
# Class      - Accuracy
# Zero       - 3.0
# One        - 67.7
# Two        - 60.4
# Three      - 36.1
# Four       - 1.0
# Five       - 0.4
# Six        - 0.0
# Seven      - 59.0
# Eight      - 43.3
# Nine       - 60.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.229447
#
# Average test loss: 2.1451, Test accuracy: 5734/10000 (57.34%)
#
# Class      - Accuracy
# Zero       - 81.7
# One        - 91.6
# Two        - 57.1
# Three      - 61.3
# Four       - 43.1
# Five       - 2.0
# Six        - 46.6
# Seven      - 92.4
# Eight      - 66.1
# Nine       - 38.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 2.073528
#
# Average test loss: 1.7678, Test accuracy: 6750/10000 (67.50%)
#
# Class      - Accuracy
# Zero       - 93.3
# One        - 97.3
# Two        - 47.3
# Three      - 79.5
# Four       - 67.2
# Five       - 15.7
# Six        - 78.5
# Seven      - 87.5
# Eight      - 57.7
# Nine       - 55.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 1.707526
#
# Average test loss: 1.1315, Test accuracy: 7704/10000 (77.04%)
#
# Class      - Accuracy
# Zero       - 94.5
# One        - 97.0
# Two        - 73.1
# Three      - 79.4
# Four       - 83.3
# Five       - 49.3
# Six        - 81.2
# Seven      - 86.8
# Eight      - 61.8
# Nine       - 64.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 1.329930
#
# Average test loss: 0.7537, Test accuracy: 8360/10000 (83.60%)
#
# Class      - Accuracy
# Zero       - 96.4
# One        - 94.5
# Two        - 84.8
# Three      - 85.9
# Four       - 84.2
# Five       - 71.8
# Six        - 88.4
# Seven      - 87.8
# Eight      - 71.4
# Nine       - 73.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 1.106374
#
# Average test loss: 0.5606, Test accuracy: 8703/10000 (87.03%)
#
# Class      - Accuracy
# Zero       - 97.2
# One        - 96.0
# Two        - 85.5
# Three      - 89.3
# Four       - 86.0
# Five       - 74.8
# Six        - 91.0
# Seven      - 89.2
# Eight      - 78.1
# Nine       - 83.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.951896
#
# Average test loss: 0.4747, Test accuracy: 8819/10000 (88.19%)
#
# Class      - Accuracy
# Zero       - 96.8
# One        - 97.1
# Two        - 88.6
# Three      - 89.9
# Four       - 92.0
# Five       - 80.9
# Six        - 92.6
# Seven      - 89.2
# Eight      - 82.5
# Nine       - 79.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.856809
#
# Average test loss: 0.4135, Test accuracy: 8925/10000 (89.25%)
#
# Class      - Accuracy
# Zero       - 96.8
# One        - 95.8
# Two        - 89.7
# Three      - 89.9
# Four       - 92.8
# Five       - 85.4
# Six        - 94.8
# Seven      - 88.8
# Eight      - 77.4
# Nine       - 80.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.842833
#
# Average test loss: 0.3688, Test accuracy: 9041/10000 (90.41%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 97.6
# Two        - 90.9
# Three      - 89.1
# Four       - 91.4
# Five       - 88.4
# Six        - 94.7
# Seven      - 91.2
# Eight      - 77.5
# Nine       - 84.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.757191
#
# Average test loss: 0.3396, Test accuracy: 9093/10000 (90.93%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 98.1
# Two        - 89.3
# Three      - 90.2
# Four       - 92.5
# Five       - 88.0
# Six        - 96.4
# Seven      - 89.6
# Eight      - 83.1
# Nine       - 87.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.717353
#
# Average test loss: 0.2951, Test accuracy: 9204/10000 (92.04%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.6
# Two        - 90.3
# Three      - 91.2
# Four       - 92.8
# Five       - 86.4
# Six        - 94.2
# Seven      - 92.4
# Eight      - 85.5
# Nine       - 86.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.701902
#
# Average test loss: 0.2820, Test accuracy: 9257/10000 (92.57%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.2
# Two        - 90.5
# Three      - 92.1
# Four       - 95.3
# Five       - 89.9
# Six        - 95.0
# Seven      - 93.3
# Eight      - 83.0
# Nine       - 88.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.673372
#
# Average test loss: 0.2725, Test accuracy: 9193/10000 (91.93%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.4
# Two        - 92.1
# Three      - 92.3
# Four       - 95.1
# Five       - 91.0
# Six        - 95.5
# Seven      - 92.3
# Eight      - 88.1
# Nine       - 88.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.620785
#
# Average test loss: 0.2518, Test accuracy: 9311/10000 (93.11%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.2
# Two        - 90.8
# Three      - 93.0
# Four       - 96.0
# Five       - 91.6
# Six        - 95.6
# Seven      - 91.7
# Eight      - 87.9
# Nine       - 86.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.610945
#
# Average test loss: 0.2480, Test accuracy: 9278/10000 (92.78%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.2
# Two        - 89.9
# Three      - 94.0
# Four       - 93.9
# Five       - 90.6
# Six        - 96.4
# Seven      - 91.7
# Eight      - 86.6
# Nine       - 88.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.579083
#
# Average test loss: 0.2248, Test accuracy: 9347/10000 (93.47%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.5
# Two        - 91.6
# Three      - 92.9
# Four       - 96.2
# Five       - 91.1
# Six        - 96.9
# Seven      - 90.6
# Eight      - 89.8
# Nine       - 89.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.560102
#
# Average test loss: 0.2207, Test accuracy: 9348/10000 (93.48%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 91.4
# Three      - 94.6
# Four       - 95.2
# Five       - 90.3
# Six        - 95.9
# Seven      - 93.3
# Eight      - 89.6
# Nine       - 91.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.526990
#
# Average test loss: 0.2083, Test accuracy: 9374/10000 (93.74%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 97.6
# Two        - 92.3
# Three      - 93.6
# Four       - 94.5
# Five       - 93.5
# Six        - 96.1
# Seven      - 92.5
# Eight      - 87.2
# Nine       - 92.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.539580
#
# Average test loss: 0.2034, Test accuracy: 9395/10000 (93.95%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.1
# Two        - 94.4
# Three      - 95.1
# Four       - 94.4
# Five       - 93.8
# Six        - 96.8
# Seven      - 92.2
# Eight      - 89.8
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.500956
#
# Average test loss: 0.1942, Test accuracy: 9404/10000 (94.04%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.6
# Two        - 92.6
# Three      - 94.1
# Four       - 96.7
# Five       - 92.4
# Six        - 96.7
# Seven      - 94.7
# Eight      - 89.4
# Nine       - 91.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.511479
#
# Average test loss: 0.1752, Test accuracy: 9491/10000 (94.91%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 98.2
# Two        - 92.7
# Three      - 92.7
# Four       - 94.1
# Five       - 93.8
# Six        - 96.3
# Seven      - 93.2
# Eight      - 91.7
# Nine       - 92.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.490926
#
# Average test loss: 0.1862, Test accuracy: 9444/10000 (94.44%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.6
# Two        - 95.8
# Three      - 94.4
# Four       - 96.1
# Five       - 95.0
# Six        - 95.8
# Seven      - 93.1
# Eight      - 87.9
# Nine       - 92.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.491614
#
# Average test loss: 0.1800, Test accuracy: 9443/10000 (94.43%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.7
# Two        - 91.8
# Three      - 93.5
# Four       - 94.5
# Five       - 93.7
# Six        - 96.6
# Seven      - 94.4
# Eight      - 92.9
# Nine       - 91.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.434742
#
# Average test loss: 0.1680, Test accuracy: 9514/10000 (95.14%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 93.3
# Three      - 93.3
# Four       - 94.4
# Five       - 95.6
# Six        - 96.5
# Seven      - 95.2
# Eight      - 92.9
# Nine       - 91.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.469665
#
# Average test loss: 0.1670, Test accuracy: 9521/10000 (95.21%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 96.4
# Three      - 95.8
# Four       - 95.4
# Five       - 94.6
# Six        - 96.7
# Seven      - 93.6
# Eight      - 92.5
# Nine       - 91.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.471629
#
# Average test loss: 0.1498, Test accuracy: 9569/10000 (95.69%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.3
# Two        - 94.8
# Three      - 96.1
# Four       - 95.5
# Five       - 95.4
# Six        - 96.2
# Seven      - 94.4
# Eight      - 94.2
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.430333
#
# Average test loss: 0.1510, Test accuracy: 9556/10000 (95.56%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.9
# Two        - 95.2
# Three      - 95.7
# Four       - 96.7
# Five       - 95.9
# Six        - 97.2
# Seven      - 91.3
# Eight      - 90.9
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.448600
#
# Average test loss: 0.1588, Test accuracy: 9521/10000 (95.21%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.7
# Two        - 95.8
# Three      - 94.9
# Four       - 94.8
# Five       - 97.1
# Six        - 97.5
# Seven      - 94.1
# Eight      - 91.6
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.461077
#
# Average test loss: 0.1446, Test accuracy: 9583/10000 (95.83%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.8
# Two        - 95.1
# Three      - 94.9
# Four       - 96.7
# Five       - 97.2
# Six        - 97.1
# Seven      - 93.0
# Eight      - 91.2
# Nine       - 93.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.459301
#
# Average test loss: 0.1443, Test accuracy: 9560/10000 (95.60%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.7
# Two        - 95.8
# Three      - 96.1
# Four       - 96.7
# Five       - 96.5
# Six        - 97.4
# Seven      - 94.4
# Eight      - 93.3
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.455577
#
# Average test loss: 0.1450, Test accuracy: 9562/10000 (95.62%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 95.4
# Three      - 96.0
# Four       - 96.3
# Five       - 95.7
# Six        - 96.6
# Seven      - 94.8
# Eight      - 92.5
# Nine       - 94.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.413766
#
# Average test loss: 0.1351, Test accuracy: 9593/10000 (95.93%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.8
# Two        - 95.7
# Three      - 95.4
# Four       - 95.7
# Five       - 97.4
# Six        - 96.6
# Seven      - 93.8
# Eight      - 93.6
# Nine       - 93.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.407582
#
# Average test loss: 0.1320, Test accuracy: 9610/10000 (96.10%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.6
# Two        - 95.7
# Three      - 96.4
# Four       - 95.6
# Five       - 96.5
# Six        - 96.5
# Seven      - 94.9
# Eight      - 93.4
# Nine       - 93.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.411434
#
# Average test loss: 0.1270, Test accuracy: 9638/10000 (96.38%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.1
# Two        - 95.4
# Three      - 96.0
# Four       - 96.4
# Five       - 97.8
# Six        - 96.8
# Seven      - 93.1
# Eight      - 94.1
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.421543
#
# Average test loss: 0.1256, Test accuracy: 9642/10000 (96.42%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.2
# Two        - 95.1
# Three      - 97.2
# Four       - 96.7
# Five       - 96.5
# Six        - 96.6
# Seven      - 95.3
# Eight      - 94.4
# Nine       - 93.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.420903
#
# Average test loss: 0.1288, Test accuracy: 9602/10000 (96.02%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.7
# Two        - 95.6
# Three      - 95.9
# Four       - 96.6
# Five       - 96.1
# Six        - 97.2
# Seven      - 94.1
# Eight      - 94.0
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.378007
#
# Average test loss: 0.1266, Test accuracy: 9609/10000 (96.09%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.4
# Two        - 96.6
# Three      - 96.5
# Four       - 96.9
# Five       - 97.6
# Six        - 97.2
# Seven      - 95.1
# Eight      - 93.7
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.416394
#
# Average test loss: 0.1239, Test accuracy: 9619/10000 (96.19%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 98.8
# Two        - 97.1
# Three      - 96.3
# Four       - 96.7
# Five       - 97.9
# Six        - 97.1
# Seven      - 95.7
# Eight      - 94.1
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.371655
#
# Average test loss: 0.1192, Test accuracy: 9664/10000 (96.64%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.2
# Two        - 96.6
# Three      - 96.3
# Four       - 96.9
# Five       - 98.1
# Six        - 96.6
# Seven      - 94.8
# Eight      - 92.0
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.358634
#
# Average test loss: 0.1199, Test accuracy: 9659/10000 (96.59%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 96.9
# Three      - 96.8
# Four       - 96.4
# Five       - 97.1
# Six        - 97.5
# Seven      - 96.2
# Eight      - 93.5
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.401336
#
# Average test loss: 0.1137, Test accuracy: 9657/10000 (96.57%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.5
# Two        - 94.6
# Three      - 96.7
# Four       - 96.9
# Five       - 97.7
# Six        - 97.3
# Seven      - 94.8
# Eight      - 94.5
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.386314
#
# Average test loss: 0.1160, Test accuracy: 9650/10000 (96.50%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.0
# Three      - 96.2
# Four       - 96.5
# Five       - 99.1
# Six        - 96.1
# Seven      - 95.5
# Eight      - 91.9
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.397027
#
# Average test loss: 0.1126, Test accuracy: 9676/10000 (96.76%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.4
# Two        - 95.4
# Three      - 96.3
# Four       - 96.7
# Five       - 97.3
# Six        - 97.8
# Seven      - 94.6
# Eight      - 94.7
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.383809
#
# Average test loss: 0.1168, Test accuracy: 9660/10000 (96.60%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 96.6
# Three      - 96.1
# Four       - 96.9
# Five       - 98.1
# Six        - 97.2
# Seven      - 95.9
# Eight      - 93.5
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.355505
#
# Average test loss: 0.1136, Test accuracy: 9665/10000 (96.65%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 96.1
# Three      - 96.9
# Four       - 98.0
# Five       - 97.0
# Six        - 97.2
# Seven      - 96.2
# Eight      - 95.2
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.339780
#
# Average test loss: 0.1048, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.8
# Two        - 97.2
# Three      - 96.7
# Four       - 96.9
# Five       - 96.9
# Six        - 97.6
# Seven      - 94.7
# Eight      - 94.5
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.361013
#
# Average test loss: 0.1116, Test accuracy: 9682/10000 (96.82%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.5
# Two        - 96.1
# Three      - 96.0
# Four       - 97.9
# Five       - 98.3
# Six        - 97.6
# Seven      - 95.9
# Eight      - 94.5
# Nine       - 92.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 48/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.362630
#
# Average test loss: 0.1060, Test accuracy: 9686/10000 (96.86%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.8
# Two        - 95.5
# Three      - 95.5
# Four       - 97.7
# Five       - 98.7
# Six        - 98.6
# Seven      - 95.9
# Eight      - 94.9
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 49/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.335492
#
# Average test loss: 0.1051, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.4
# Two        - 96.2
# Three      - 97.9
# Four       - 97.7
# Five       - 98.6
# Six        - 97.1
# Seven      - 96.6
# Eight      - 94.4
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 50/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.349002
#
# Average test loss: 0.1040, Test accuracy: 9686/10000 (96.86%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.5
# Two        - 97.4
# Three      - 96.4
# Four       - 97.7
# Five       - 98.3
# Six        - 97.5
# Seven      - 95.2
# Eight      - 94.1
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 51/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.326708
#
# Average test loss: 0.0935, Test accuracy: 9735/10000 (97.35%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.7
# Two        - 97.1
# Three      - 95.9
# Four       - 97.4
# Five       - 99.0
# Six        - 97.9
# Seven      - 95.8
# Eight      - 96.2
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 52/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.322835
#
# Average test loss: 0.1024, Test accuracy: 9688/10000 (96.88%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.8
# Three      - 96.9
# Four       - 97.0
# Five       - 97.9
# Six        - 97.3
# Seven      - 95.6
# Eight      - 94.6
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 53/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.365578
#
# Average test loss: 0.0987, Test accuracy: 9683/10000 (96.83%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.9
# Three      - 96.8
# Four       - 97.2
# Five       - 97.9
# Six        - 97.5
# Seven      - 95.4
# Eight      - 96.2
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 54/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.339613
#
# Average test loss: 0.1026, Test accuracy: 9704/10000 (97.04%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.3
# Two        - 96.2
# Three      - 97.0
# Four       - 97.9
# Five       - 97.7
# Six        - 98.0
# Seven      - 96.0
# Eight      - 93.5
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 55/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.336080
#
# Average test loss: 0.0965, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.8
# Two        - 96.2
# Three      - 97.7
# Four       - 98.1
# Five       - 98.0
# Six        - 97.5
# Seven      - 95.4
# Eight      - 95.6
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 56/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.332859
#
# Average test loss: 0.0991, Test accuracy: 9716/10000 (97.16%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.8
# Two        - 96.2
# Three      - 97.6
# Four       - 98.2
# Five       - 98.2
# Six        - 97.0
# Seven      - 95.0
# Eight      - 96.0
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 57/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.328623
#
# Average test loss: 0.1077, Test accuracy: 9681/10000 (96.81%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.7
# Three      - 96.7
# Four       - 97.3
# Five       - 97.7
# Six        - 98.4
# Seven      - 96.5
# Eight      - 94.5
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 58/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.298356
#
# Average test loss: 0.1060, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.3
# Two        - 97.3
# Three      - 96.6
# Four       - 96.5
# Five       - 97.1
# Six        - 97.1
# Seven      - 96.3
# Eight      - 96.1
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 59/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.346766
#
# Average test loss: 0.0878, Test accuracy: 9740/10000 (97.40%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.6
# Two        - 95.6
# Three      - 97.8
# Four       - 98.5
# Five       - 98.2
# Six        - 98.0
# Seven      - 95.9
# Eight      - 95.5
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 60/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.335576
#
# Average test loss: 0.0987, Test accuracy: 9708/10000 (97.08%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.7
# Two        - 97.5
# Three      - 96.6
# Four       - 97.8
# Five       - 97.9
# Six        - 97.5
# Seven      - 96.8
# Eight      - 95.8
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 61/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# ...
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.311134
#
# Average test loss: 0.0801, Test accuracy: 9747/10000 (97.47%)
#
# Class      - Accuracy
# Zero       - 99.7
# One        - 98.9
# Two        - 97.7
# Three      - 97.6
# Four       - 98.0
# Five       - 98.4
# Six        - 97.9
# Seven      - 96.2
# Eight      - 97.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 85/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.295014
#
# Average test loss: 0.0797, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.0
# Two        - 97.8
# Three      - 97.9
# Four       - 98.2
# Five       - 98.6
# Six        - 97.3
# Seven      - 95.5
# Eight      - 95.7
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 86/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.279937
#
# Average test loss: 0.0816, Test accuracy: 9752/10000 (97.52%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 97.8
# Three      - 97.7
# Four       - 97.7
# Five       - 98.8
# Six        - 97.7
# Seven      - 96.2
# Eight      - 96.5
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 87/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.299807
#
# Average test loss: 0.0808, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.8
# Two        - 97.2
# Three      - 98.2
# Four       - 98.8
# Five       - 98.7
# Six        - 97.2
# Seven      - 96.2
# Eight      - 96.3
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 88/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.254538
#
# Average test loss: 0.0826, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 97.4
# Three      - 97.3
# Four       - 97.6
# Five       - 98.8
# Six        - 98.0
# Seven      - 96.3
# Eight      - 96.6
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 89/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.283633
#
# Average test loss: 0.0706, Test accuracy: 9793/10000 (97.93%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.5
# Two        - 97.0
# Three      - 98.0
# Four       - 98.5
# Five       - 98.9
# Six        - 98.1
# Seven      - 96.1
# Eight      - 96.5
# Nine       - 97.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 90/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.277294
#
# Average test loss: 0.0718, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.7
# Two        - 97.3
# Three      - 97.1
# Four       - 98.3
# Five       - 97.8
# Six        - 98.4
# Seven      - 96.5
# Eight      - 97.4
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 91/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 0.228870
#
# Average test loss: 0.0738, Test accuracy: 9790/10000 (97.90%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.8
# Two        - 98.3
# Three      - 97.6
# Four       - 98.3
# Five       - 99.3
# Six        - 97.9
# Seven      - 96.7
# Eight      - 96.3
# Nine       - 97.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 92/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.278948
#
# Average test loss: 0.0763, Test accuracy: 9757/10000 (97.57%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.0
# Two        - 97.5
# Three      - 97.7
# Four       - 97.6
# Five       - 99.0
# Six        - 98.2
# Seven      - 95.4
# Eight      - 96.5
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 93/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.294761
#
# Average test loss: 0.0761, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.8
# Two        - 97.0
# Three      - 97.7
# Four       - 98.8
# Five       - 97.7
# Six        - 98.1
# Seven      - 97.3
# Eight      - 96.7
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 94/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.299892
#
# Average test loss: 0.0679, Test accuracy: 9797/10000 (97.97%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.7
# Two        - 97.9
# Three      - 97.0
# Four       - 98.5
# Five       - 98.8
# Six        - 97.7
# Seven      - 95.0
# Eight      - 96.7
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.314548
#
# Average test loss: 0.0710, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 98.6
# Three      - 98.4
# Four       - 98.4
# Five       - 99.0
# Six        - 98.2
# Seven      - 95.2
# Eight      - 96.6
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.270819
#
# Average test loss: 0.0772, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.0
# Two        - 97.8
# Three      - 98.6
# Four       - 98.7
# Five       - 98.1
# Six        - 98.3
# Seven      - 96.3
# Eight      - 97.8
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.292407
#
# Average test loss: 0.0733, Test accuracy: 9779/10000 (97.79%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 98.1
# Three      - 97.9
# Four       - 98.7
# Five       - 98.9
# Six        - 97.9
# Seven      - 96.8
# Eight      - 96.0
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.262825
#
# Average test loss: 0.0748, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.0
# Two        - 98.0
# Three      - 97.8
# Four       - 97.4
# Five       - 98.5
# Six        - 97.0
# Seven      - 94.9
# Eight      - 95.9
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.271922
#
# Average test loss: 0.0731, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 98.8
# Two        - 98.0
# Three      - 97.8
# Four       - 98.2
# Five       - 98.9
# Six        - 98.8
# Seven      - 96.5
# Eight      - 97.1
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.244816
#
# Average test loss: 0.0796, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.5
# Three      - 97.0
# Four       - 98.0
# Five       - 98.4
# Six        - 98.2
# Seven      - 95.9
# Eight      - 96.4
# Nine       - 96.6
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0698, Test accuracy: 9815/10000 (98.15%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.9
# Three      - 98.1
# Four       - 99.0
# Five       - 98.7
# Six        - 97.6
# Seven      - 96.7
# Eight      - 96.6
# Nine       - 96.7
# Global accuracies:  [32.97, 57.34, 67.5, 77.04, 83.6, 87.03, 88.19, 89.25, 90.41, 90.93, 92.04, 92.57, 91.93, 93.11, 92.78, 93.47, 93.48, 93.74, 93.95, 94.04, 94.91, 94.44, 94.43, 95.14, 95.21, 95.69, 95.56, 95.21, 95.83, 95.6, 95.62, 95.93, 96.1, 96.38, 96.42, 96.02, 96.09, 96.19, 96.64, 96.59, 96.57, 96.5, 96.76, 96.6, 96.65, 97.0, 96.82, 96.86, 97.09, 96.86, 97.35, 96.88, 96.83, 97.04, 97.27, 97.16, 96.81, 97.0, 97.4, 97.08, 97.14, 97.19, 97.19, 97.31, 97.11, 97.24, 97.33, 97.42, 97.42, 97.66, 97.5, 97.49, 97.72, 97.26, 97.57, 97.44, 97.53, 97.77, 97.68, 97.65, 97.33, 97.64, 97.53, 97.47, 97.76, 97.52, 97.74, 97.53, 97.93, 97.74, 97.9, 97.57, 97.8, 97.97, 97.78, 97.78, 97.79, 97.76, 97.82, 97.76, 98.15]
# Class 7 accuracies:  [59.01, 92.38, 87.53, 86.78, 87.85, 89.19, 89.23, 88.78, 91.15, 89.62, 92.44, 93.29, 92.27, 91.68, 91.71, 90.65, 93.28, 92.48, 92.22, 94.66, 93.17, 93.08, 94.41, 95.18, 93.59, 94.39, 91.34, 94.09, 93.01, 94.36, 94.82, 93.83, 94.86, 93.06, 95.33, 94.11, 95.1, 95.69, 94.85, 96.15, 94.83, 95.46, 94.62, 95.87, 96.19, 94.73, 95.87, 95.9, 96.64, 95.23, 95.75, 95.64, 95.4, 95.99, 95.41, 95.02, 96.55, 96.31, 95.86, 96.76, 95.64, 96.05, 96.04, 96.28, 95.93, 94.2, 95.27, 96.3, 95.5, 96.56, 95.71, 96.69, 95.81, 94.85, 96.6, 95.7, 96.01, 95.88, 95.75, 96.17, 95.42, 96.35, 96.25, 96.17, 95.5, 96.2, 96.16, 96.26, 96.09, 96.51, 96.67, 95.44, 97.31, 95.03, 95.17, 96.29, 96.83, 94.91, 96.54, 95.9, 96.71]
# Test loss: [2.253, 2.1451, 1.7678, 1.1315, 0.7537, 0.5606, 0.4747, 0.4135, 0.3688, 0.3396, 0.2951, 0.282, 0.2725, 0.2518, 0.248, 0.2248, 0.2207, 0.2083, 0.2034, 0.1942, 0.1752, 0.1862, 0.18, 0.168, 0.167, 0.1498, 0.151, 0.1588, 0.1446, 0.1443, 0.145, 0.1351, 0.132, 0.127, 0.1256, 0.1288, 0.1266, 0.1239, 0.1192, 0.1199, 0.1137, 0.116, 0.1126, 0.1168, 0.1136, 0.1048, 0.1116, 0.106, 0.1051, 0.104, 0.0935, 0.1024, 0.0987, 0.1026, 0.0965, 0.0991, 0.1077, 0.106, 0.0878, 0.0987, 0.0939, 0.0949, 0.095, 0.0951, 0.0984, 0.0957, 0.091, 0.0904, 0.0886, 0.0842, 0.0867, 0.0835, 0.081, 0.0907, 0.089, 0.089, 0.0816, 0.0778, 0.0804, 0.0816, 0.0939, 0.0818, 0.0783, 0.0801, 0.0797, 0.0816, 0.0808, 0.0826, 0.0706, 0.0718, 0.0738, 0.0763, 0.0761, 0.0679, 0.071, 0.0772, 0.0733, 0.0748, 0.0731, 0.0796, 0.0698]
# Label-flipping attack succes rate: 0.19
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.008
# --> End of Experiment.

# %%
RULE = 'foolsgold'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: foolsgold
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.281665
# Aggregation took 0.0154
#
# Average test loss: 2.2591, Test accuracy: 2118/10000 (21.18%)
#
# Class      - Accuracy
# Zero       - 1.6
# One        - 99.2
# Two        - 32.3
# Three      - 22.4
# Four       - 1.0
# Five       - 0.3
# Six        - 0.0
# Seven      - 0.9
# Eight      - 17.9
# Nine       - 34.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.228989
# Aggregation took 0.0135
#
# Average test loss: 2.1604, Test accuracy: 4969/10000 (49.69%)
#
# Class      - Accuracy
# Zero       - 85.6
# One        - 100.0
# Two        - 35.3
# Three      - 67.7
# Four       - 33.3
# Five       - 1.1
# Six        - 45.9
# Seven      - 20.8
# Eight      - 46.6
# Nine       - 65.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 2.089981
# Aggregation took 0.0148
#
# Average test loss: 1.8158, Test accuracy: 6673/10000 (66.73%)
#
# Class      - Accuracy
# Zero       - 92.4
# One        - 98.6
# Two        - 47.3
# Three      - 81.7
# Four       - 60.4
# Five       - 11.3
# Six        - 74.6
# Seven      - 72.2
# Eight      - 56.8
# Nine       - 69.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 1.745305
# Aggregation took 0.0121
#
# Average test loss: 1.2342, Test accuracy: 7423/10000 (74.23%)
#
# Class      - Accuracy
# Zero       - 95.0
# One        - 98.7
# Two        - 65.8
# Three      - 81.4
# Four       - 82.6
# Five       - 42.3
# Six        - 81.7
# Seven      - 73.3
# Eight      - 60.6
# Nine       - 56.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 1.374121
# Aggregation took 0.0123
#
# Average test loss: 0.8084, Test accuracy: 8289/10000 (82.89%)
#
# Class      - Accuracy
# Zero       - 96.3
# One        - 94.4
# Two        - 82.6
# Three      - 85.6
# Four       - 83.8
# Five       - 73.7
# Six        - 87.7
# Seven      - 82.1
# Eight      - 70.4
# Nine       - 72.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 1.130457
# Aggregation took 0.0111
#
# Average test loss: 0.5907, Test accuracy: 8598/10000 (85.98%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 93.6
# Two        - 85.2
# Three      - 86.8
# Four       - 83.8
# Five       - 73.3
# Six        - 88.5
# Seven      - 88.7
# Eight      - 80.4
# Nine       - 80.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.977970
# Aggregation took 0.0131
#
# Average test loss: 0.5043, Test accuracy: 8704/10000 (87.04%)
#
# Class      - Accuracy
# Zero       - 96.1
# One        - 97.5
# Two        - 87.9
# Three      - 85.9
# Four       - 91.5
# Five       - 83.1
# Six        - 91.9
# Seven      - 88.8
# Eight      - 79.4
# Nine       - 73.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.880378
# Aggregation took 0.0136
#
# Average test loss: 0.4205, Test accuracy: 8910/10000 (89.10%)
#
# Class      - Accuracy
# Zero       - 97.0
# One        - 97.1
# Two        - 89.8
# Three      - 89.9
# Four       - 91.9
# Five       - 84.0
# Six        - 93.9
# Seven      - 87.7
# Eight      - 79.7
# Nine       - 75.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.850896
# Aggregation took 0.012
#
# Average test loss: 0.4000, Test accuracy: 8892/10000 (88.92%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.2
# Two        - 90.5
# Three      - 88.3
# Four       - 95.3
# Five       - 88.4
# Six        - 93.8
# Seven      - 89.1
# Eight      - 76.8
# Nine       - 73.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.772627
# Aggregation took 0.0129
#
# Average test loss: 0.3498, Test accuracy: 9089/10000 (90.89%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 97.6
# Two        - 90.1
# Three      - 89.5
# Four       - 91.6
# Five       - 90.2
# Six        - 95.3
# Seven      - 87.7
# Eight      - 84.1
# Nine       - 86.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.726962
# Aggregation took 0.012
#
# Average test loss: 0.3064, Test accuracy: 9173/10000 (91.73%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.5
# Two        - 89.3
# Three      - 91.3
# Four       - 94.4
# Five       - 86.0
# Six        - 94.6
# Seven      - 91.1
# Eight      - 86.5
# Nine       - 82.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.707340
# Aggregation took 0.0127
#
# Average test loss: 0.2934, Test accuracy: 9217/10000 (92.17%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.4
# Two        - 90.9
# Three      - 92.4
# Four       - 95.1
# Five       - 87.1
# Six        - 94.1
# Seven      - 93.0
# Eight      - 82.3
# Nine       - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.677512
# Aggregation took 0.0119
#
# Average test loss: 0.2816, Test accuracy: 9183/10000 (91.83%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.3
# Two        - 91.8
# Three      - 93.2
# Four       - 94.5
# Five       - 90.2
# Six        - 95.3
# Seven      - 92.4
# Eight      - 86.1
# Nine       - 90.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.626904
# Aggregation took 0.0128
#
# Average test loss: 0.2549, Test accuracy: 9292/10000 (92.92%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.2
# Two        - 90.4
# Three      - 92.3
# Four       - 95.9
# Five       - 91.2
# Six        - 95.0
# Seven      - 89.8
# Eight      - 88.2
# Nine       - 86.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.612066
# Aggregation took 0.012
#
# Average test loss: 0.2487, Test accuracy: 9280/10000 (92.80%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.3
# Two        - 89.3
# Three      - 92.9
# Four       - 93.6
# Five       - 91.8
# Six        - 95.8
# Seven      - 92.2
# Eight      - 86.4
# Nine       - 87.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.582668
# Aggregation took 0.0115
#
# Average test loss: 0.2263, Test accuracy: 9358/10000 (93.58%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.8
# Two        - 91.8
# Three      - 93.8
# Four       - 96.1
# Five       - 91.8
# Six        - 96.7
# Seven      - 91.2
# Eight      - 88.5
# Nine       - 90.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.563126
# Aggregation took 0.0109
#
# Average test loss: 0.2228, Test accuracy: 9366/10000 (93.66%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.9
# Two        - 91.2
# Three      - 94.9
# Four       - 95.5
# Five       - 91.3
# Six        - 96.0
# Seven      - 91.7
# Eight      - 90.1
# Nine       - 90.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.532744
# Aggregation took 0.0116
#
# Average test loss: 0.2093, Test accuracy: 9361/10000 (93.61%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 97.6
# Two        - 92.7
# Three      - 93.5
# Four       - 94.8
# Five       - 93.1
# Six        - 96.1
# Seven      - 90.8
# Eight      - 86.5
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.540557
# Aggregation took 0.0141
#
# Average test loss: 0.2079, Test accuracy: 9411/10000 (94.11%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.3
# Two        - 94.4
# Three      - 95.0
# Four       - 94.6
# Five       - 92.9
# Six        - 96.4
# Seven      - 92.1
# Eight      - 90.8
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.503961
# Aggregation took 0.014
#
# Average test loss: 0.1954, Test accuracy: 9396/10000 (93.96%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.7
# Two        - 92.9
# Three      - 94.5
# Four       - 95.8
# Five       - 92.3
# Six        - 96.8
# Seven      - 94.2
# Eight      - 90.3
# Nine       - 90.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.510254
# Aggregation took 0.0111
#
# Average test loss: 0.1770, Test accuracy: 9492/10000 (94.92%)
# Class      - Accuracy
# Zero       - 97.6
# One        - 98.6
# Two        - 92.5
# Three      - 92.8
# Four       - 94.3
# Five       - 93.8
# Six        - 96.3
# Seven      - 92.9
# Eight      - 91.0
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.495172
# Aggregation took 0.0114
#
# Average test loss: 0.1863, Test accuracy: 9431/10000 (94.31%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.6
# Two        - 96.2
# Three      - 94.1
# Four       - 95.8
# Five       - 93.7
# Six        - 96.0
# Seven      - 92.8
# Eight      - 88.5
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.492206
# Aggregation took 0.0119
#
# Average test loss: 0.1836, Test accuracy: 9454/10000 (94.54%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 92.0
# Three      - 93.4
# Four       - 95.3
# Five       - 94.4
# Six        - 96.7
# Seven      - 94.5
# Eight      - 91.7
# Nine       - 91.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 0.439317
# Aggregation took 0.0121
#
# Average test loss: 0.1703, Test accuracy: 9508/10000 (95.08%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 93.5
# Three      - 93.3
# Four       - 94.8
# Five       - 94.8
# Six        - 96.5
# Seven      - 94.8
# Eight      - 91.0
# Nine       - 94.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.471820
# Aggregation took 0.0115
#
# Average test loss: 0.1692, Test accuracy: 9511/10000 (95.11%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 98.9
# Two        - 96.4
# Three      - 95.8
# Four       - 96.5
# Five       - 93.7
# Six        - 96.7
# Seven      - 94.0
# Eight      - 92.2
# Nine       - 90.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.475589
# Aggregation took 0.0115
#
# Average test loss: 0.1540, Test accuracy: 9546/10000 (95.46%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.5
# Two        - 95.1
# Three      - 96.0
# Four       - 95.8
# Five       - 94.5
# Six        - 96.2
# Seven      - 94.7
# Eight      - 92.8
# Nine       - 93.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.432749
# Aggregation took 0.0122
#
# Average test loss: 0.1514, Test accuracy: 9554/10000 (95.54%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.0
# Two        - 95.1
# Three      - 94.5
# Four       - 96.8
# Five       - 96.2
# Six        - 97.1
# Seven      - 93.1
# Eight      - 91.3
# Nine       - 94.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.450782
# Aggregation took 0.0124
#
# Average test loss: 0.1597, Test accuracy: 9524/10000 (95.24%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.5
# Two        - 96.1
# Three      - 95.3
# Four       - 93.8
# Five       - 97.2
# Six        - 97.5
# Seven      - 92.6
# Eight      - 92.0
# Nine       - 91.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.460793
# Aggregation took 0.0121
#
# Average test loss: 0.1480, Test accuracy: 9567/10000 (95.67%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 95.7
# Three      - 95.4
# Four       - 96.5
# Five       - 96.5
# Six        - 97.1
# Seven      - 92.6
# Eight      - 90.8
# Nine       - 93.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.460376
# Aggregation took 0.0126
#
# Average test loss: 0.1501, Test accuracy: 9551/10000 (95.51%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.4
# Two        - 96.6
# Three      - 95.1
# Four       - 96.5
# Five       - 95.9
# Six        - 97.8
# Seven      - 93.4
# Eight      - 91.8
# Nine       - 91.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.454434
# Aggregation took 0.0115
#
# Average test loss: 0.1442, Test accuracy: 9561/10000 (95.61%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 95.9
# Three      - 95.7
# Four       - 96.4
# Five       - 95.7
# Six        - 97.0
# Seven      - 93.6
# Eight      - 92.6
# Nine       - 94.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.418356
# Aggregation took 0.0127
#
# Average test loss: 0.1393, Test accuracy: 9578/10000 (95.78%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.0
# Two        - 96.8
# Three      - 95.8
# Four       - 95.6
# Five       - 95.8
# Six        - 97.1
# Seven      - 93.9
# Eight      - 93.2
# Nine       - 93.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.409924
# Aggregation took 0.0101
#
# Average test loss: 0.1316, Test accuracy: 9603/10000 (96.03%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.5
# Two        - 95.5
# Three      - 96.1
# Four       - 95.8
# Five       - 96.6
# Six        - 96.9
# Seven      - 95.4
# Eight      - 93.5
# Nine       - 93.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.410960
# Aggregation took 0.0124
#
# Average test loss: 0.1281, Test accuracy: 9633/10000 (96.33%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.0
# Two        - 96.5
# Three      - 95.5
# Four       - 96.6
# Five       - 97.3
# Six        - 96.8
# Seven      - 93.6
# Eight      - 93.8
# Nine       - 93.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.423053
# Aggregation took 0.012
#
# Average test loss: 0.1259, Test accuracy: 9627/10000 (96.27%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.5
# Two        - 96.6
# Three      - 96.4
# Four       - 95.7
# Five       - 96.4
# Six        - 97.0
# Seven      - 95.0
# Eight      - 93.9
# Nine       - 93.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.421055
# Aggregation took 0.0115
#
# Average test loss: 0.1276, Test accuracy: 9599/10000 (95.99%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.6
# Two        - 96.1
# Three      - 95.8
# Four       - 96.4
# Five       - 95.8
# Six        - 97.2
# Seven      - 94.0
# Eight      - 94.7
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.379660
# Aggregation took 0.0115
#
# Average test loss: 0.1261, Test accuracy: 9608/10000 (96.08%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.4
# Two        - 96.7
# Three      - 96.4
# Four       - 95.9
# Five       - 97.3
# Six        - 97.3
# Seven      - 94.1
# Eight      - 93.9
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.415887
# Aggregation took 0.0115
#
# Average test loss: 0.1215, Test accuracy: 9623/10000 (96.23%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.2
# Two        - 97.5
# Three      - 96.2
# Four       - 96.8
# Five       - 98.2
# Six        - 97.1
# Seven      - 95.6
# Eight      - 94.1
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.370306
# Aggregation took 0.0122
#
# Average test loss: 0.1197, Test accuracy: 9658/10000 (96.58%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.2
# Two        - 97.1
# Three      - 96.6
# Four       - 96.6
# Five       - 97.5
# Six        - 96.6
# Seven      - 94.5
# Eight      - 91.4
# Nine       - 94.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.358462
# Aggregation took 0.0125
#
# Average test loss: 0.1196, Test accuracy: 9655/10000 (96.55%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.0
# Two        - 96.8
# Three      - 96.9
# Four       - 96.4
# Five       - 97.3
# Six        - 97.6
# Seven      - 95.8
# Eight      - 92.8
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.398850
# Aggregation took 0.0115
#
# Average test loss: 0.1134, Test accuracy: 9666/10000 (96.66%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.9
# Two        - 95.9
# Three      - 97.0
# Four       - 96.8
# Five       - 97.2
# Six        - 97.5
# Seven      - 94.5
# Eight      - 93.5
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.386014
# Aggregation took 0.0117
# Average test loss: 0.1135, Test accuracy: 9652/10000 (96.52%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.2
# Two        - 96.3
# Three      - 96.2
# Four       - 96.4
# Five       - 98.9
# Six        - 96.6
# Seven      - 95.6
# Eight      - 91.8
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.395060
# Aggregation took 0.0131
#
# Average test loss: 0.1113, Test accuracy: 9666/10000 (96.66%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.1
# Two        - 95.1
# Three      - 96.6
# Four       - 96.3
# Five       - 98.3
# Six        - 97.8
# Seven      - 94.9
# Eight      - 94.3
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.383774
# Aggregation took 0.013
#
# Average test loss: 0.1189, Test accuracy: 9654/10000 (96.54%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.0
# Three      - 96.2
# Four       - 96.5
# Five       - 97.3
# Six        - 97.4
# Seven      - 95.8
# Eight      - 93.0
# Nine       - 93.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.354145
# Aggregation took 0.0101
#
# Average test loss: 0.1132, Test accuracy: 9667/10000 (96.67%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.2
# Two        - 96.9
# Three      - 96.8
# Four       - 98.2
# Five       - 97.3
# Six        - 97.1
# Seven      - 96.5
# Eight      - 95.8
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.338823
# Aggregation took 0.0124
#
# Average test loss: 0.1057, Test accuracy: 9680/10000 (96.80%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 96.7
# Three      - 96.9
# Four       - 97.3
# Five       - 97.3
# Six        - 97.5
# Seven      - 94.9
# Eight      - 94.1
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.358901
# Aggregation took 0.0125
#
# Average test loss: 0.1120, Test accuracy: 9684/10000 (96.84%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.4
# Two        - 96.1
# Three      - 96.0
# Four       - 98.3
# Five       - 98.3
# Six        - 97.4
# Seven      - 95.6
# Eight      - 94.7
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 48/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.362183
# Aggregation took 0.0115
#
# Average test loss: 0.1045, Test accuracy: 9685/10000 (96.85%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 95.7
# Three      - 96.3
# Four       - 97.5
# Five       - 98.5
# Six        - 98.4
# Seven      - 96.2
# Eight      - 94.7
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 49/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.331520
# Aggregation took 0.013
#
# Average test loss: 0.1051, Test accuracy: 9699/10000 (96.99%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.4
# Two        - 96.5
# Three      - 97.9
# Four       - 97.5
# Five       - 98.5
# Six        - 97.3
# Seven      - 96.0
# Eight      - 94.5
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 50/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.347920
# Aggregation took 0.012
#
# Average test loss: 0.1060, Test accuracy: 9679/10000 (96.79%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.5
# Two        - 97.3
# Three      - 96.8
# Four       - 97.2
# Five       - 98.1
# Six        - 97.6
# Seven      - 95.6
# Eight      - 93.7
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 51/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.324804
# Aggregation took 0.0153
#
# Average test loss: 0.0941, Test accuracy: 9731/10000 (97.31%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.7
# Two        - 96.6
# Three      - 95.6
# Four       - 97.4
# Five       - 99.0
# Six        - 97.8
# Seven      - 96.5
# Eight      - 95.6
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 52/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.321396
# Aggregation took 0.0111
#
# Average test loss: 0.1019, Test accuracy: 9688/10000 (96.88%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.2
# Three      - 97.3
# Four       - 96.5
# Five       - 98.1
# Six        - 96.9
# Seven      - 95.4
# Eight      - 93.9
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 53/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.363763
# Aggregation took 0.0115
#
# Average test loss: 0.0974, Test accuracy: 9697/10000 (96.97%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.8
# Three      - 96.9
# Four       - 96.6
# Five       - 97.9
# Six        - 97.3
# Seven      - 95.9
# Eight      - 95.7
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 54/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.336195
# Aggregation took 0.0116
#
# Average test loss: 0.1027, Test accuracy: 9713/10000 (97.13%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.3
# Two        - 96.4
# Three      - 97.1
# Four       - 97.4
# Five       - 98.3
# Six        - 97.9
# Seven      - 97.1
# Eight      - 93.6
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 55/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.334838
# Aggregation took 0.0129
#
# Average test loss: 0.0966, Test accuracy: 9724/10000 (97.24%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.8
# Three      - 97.7
# Four       - 98.2
# Five       - 98.2
# Six        - 97.8
# Seven      - 95.2
# Eight      - 94.2
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 56/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.330165
# Aggregation took 0.012
#
# Average test loss: 0.0987, Test accuracy: 9718/10000 (97.18%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 96.8
# Three      - 97.5
# Four       - 98.2
# Five       - 98.0
# Six        - 97.4
# Seven      - 95.0
# Eight      - 95.3
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 57/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.328259
# Aggregation took 0.0171
#
# Average test loss: 0.1056, Test accuracy: 9677/10000 (96.77%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 97.7
# Three      - 96.9
# Four       - 97.4
# Five       - 98.3
# Six        - 98.1
# Seven      - 97.2
# Eight      - 94.3
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 58/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.301031
# Aggregation took 0.0125
#
# Average test loss: 0.1047, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.6
# Two        - 97.7
# Three      - 96.3
# Four       - 97.0
# Five       - 97.8
# Six        - 97.7
# Seven      - 96.6
# Eight      - 94.8
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 59/100 |
#
#
# Selected Peers:
# Peer 19  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# ...
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 98.9
# Two        - 98.3
# Three      - 97.7
# Four       - 97.9
# Five       - 98.2
# Six        - 97.7
# Seven      - 96.0
# Eight      - 97.4
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 85/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.294158
# Aggregation took 0.0115
#
# Average test loss: 0.0781, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 98.3
# Three      - 97.6
# Four       - 98.3
# Five       - 98.5
# Six        - 97.1
# Seven      - 95.9
# Eight      - 95.1
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 86/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.278900
# Aggregation took 0.012
#
# Average test loss: 0.0804, Test accuracy: 9742/10000 (97.42%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.5
# Two        - 97.4
# Three      - 97.7
# Four       - 97.4
# Five       - 99.0
# Six        - 98.2
# Seven      - 96.2
# Eight      - 96.1
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 87/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.295462
# Aggregation took 0.0108
#
# Average test loss: 0.0798, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.8
# Two        - 97.6
# Three      - 98.1
# Four       - 98.9
# Five       - 98.5
# Six        - 97.1
# Seven      - 96.4
# Eight      - 96.1
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 88/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.251738
# Aggregation took 0.0117
#
# Average test loss: 0.0796, Test accuracy: 9747/10000 (97.47%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 97.6
# Three      - 97.1
# Four       - 98.2
# Five       - 98.8
# Six        - 98.1
# Seven      - 96.9
# Eight      - 95.7
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 89/100 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.279444
# Aggregation took 0.0114
#
# Average test loss: 0.0697, Test accuracy: 9769/10000 (97.69%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.5
# Two        - 96.9
# Three      - 98.1
# Four       - 98.4
# Five       - 98.8
# Six        - 97.7
# Seven      - 95.9
# Eight      - 95.1
# Nine       - 97.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 90/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.273812
# Aggregation took 0.011
#
# Average test loss: 0.0720, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.8
# Two        - 97.4
# Three      - 97.2
# Four       - 98.4
# Five       - 98.2
# Six        - 98.7
# Seven      - 96.4
# Eight      - 97.2
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 91/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 0.226585
# Aggregation took 0.0118
#
# Average test loss: 0.0715, Test accuracy: 9790/10000 (97.90%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 99.0
# Two        - 98.7
# Three      - 97.6
# Four       - 98.4
# Five       - 99.3
# Six        - 97.9
# Seven      - 96.8
# Eight      - 95.8
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 92/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.273389
# Aggregation took 0.0114
#
# Average test loss: 0.0752, Test accuracy: 9751/10000 (97.51%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.0
# Two        - 97.7
# Three      - 97.6
# Four       - 97.4
# Five       - 99.0
# Six        - 98.1
# Seven      - 96.3
# Eight      - 96.3
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 93/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.290766
# Aggregation took 0.0115
#
# Average test loss: 0.0742, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 97.6
# Three      - 97.6
# Four       - 98.7
# Five       - 97.8
# Six        - 97.9
# Seven      - 96.6
# Eight      - 96.6
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 94/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.294868
# Aggregation took 0.011
# Average test loss: 0.0667, Test accuracy: 9789/10000 (97.89%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.7
# Two        - 97.3
# Three      - 97.1
# Four       - 98.1
# Five       - 98.5
# Six        - 97.7
# Seven      - 94.9
# Eight      - 96.2
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.309905
# Aggregation took 0.0127
#
# Average test loss: 0.0706, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.3
# Two        - 98.5
# Three      - 97.9
# Four       - 98.4
# Five       - 98.7
# Six        - 98.2
# Seven      - 95.7
# Eight      - 96.1
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.265159
# Aggregation took 0.0109
#
# Average test loss: 0.0744, Test accuracy: 9773/10000 (97.73%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.2
# Two        - 98.1
# Three      - 98.6
# Four       - 98.2
# Five       - 99.0
# Six        - 98.4
# Seven      - 96.7
# Eight      - 97.0
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 11  is  attacker reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.288004
# Aggregation took 0.013
#
# Average test loss: 0.0709, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.6
# Two        - 98.1
# Three      - 97.8
# Four       - 99.0
# Five       - 98.7
# Six        - 97.7
# Seven      - 97.4
# Eight      - 96.2
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.258865
# Aggregation took 0.0119
#
# Average test loss: 0.0732, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 98.2
# Three      - 97.8
# Four       - 97.3
# Five       - 98.4
# Six        - 97.4
# Seven      - 95.3
# Eight      - 95.8
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.267985
# Aggregation took 0.011
#
# Average test loss: 0.0725, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 98.8
# Two        - 98.8
# Three      - 97.8
# Four       - 98.2
# Five       - 98.5
# Six        - 99.1
# Seven      - 96.7
# Eight      - 96.7
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.242657
# Aggregation took 0.0117
#
# Average test loss: 0.0776, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.5
# Two        - 98.4
# Three      - 97.2
# Four       - 98.1
# Five       - 98.5
# Six        - 98.1
# Seven      - 96.0
# Eight      - 96.0
# Nine       - 96.7
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0689, Test accuracy: 9803/10000 (98.03%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.2
# Two        - 98.0
# Three      - 97.9
# Four       - 98.9
# Five       - 98.9
# Six        - 97.5
# Seven      - 96.9
# Eight      - 96.6
# Nine       - 96.7
# Global accuracies:  [21.18, 49.69, 66.73, 74.23, 82.89, 85.98, 87.04, 89.1, 88.92, 90.89, 91.73, 92.17, 91.83, 92.92, 92.8, 93.58, 93.66, 93.61, 94.11, 93.96, 94.92, 94.31, 94.54, 95.08, 95.11, 95.46, 95.54, 95.24, 95.67, 95.51, 95.61, 95.78, 96.03, 96.33, 96.27, 95.99, 96.08, 96.23, 96.58, 96.55, 96.66, 96.52, 96.66, 96.54, 96.67, 96.8, 96.84, 96.85, 96.99, 96.79, 97.31, 96.88, 96.97, 97.13, 97.24, 97.18, 96.77, 97.0, 97.39, 97.12, 97.14, 97.2, 97.27, 97.21, 96.9, 97.19, 97.39, 97.29, 97.3, 97.6, 97.45, 97.38, 97.67, 97.18, 97.56, 97.5, 97.5, 97.67, 97.69, 97.69, 97.36, 97.63, 97.52, 97.5, 97.8, 97.42, 97.68, 97.47, 97.69, 97.82, 97.9, 97.51, 97.8, 97.89, 97.68, 97.73, 97.78, 97.7, 97.8, 97.67, 98.03]
# Class 7 accuracies:  [0.89, 20.82, 72.23, 73.26, 82.06, 88.69, 88.83, 87.71, 89.06, 87.75, 91.14, 93.0, 92.37, 89.78, 92.18, 91.16, 91.68, 90.82, 92.12, 94.16, 92.86, 92.76, 94.51, 94.77, 93.97, 94.68, 93.11, 92.62, 92.64, 93.37, 93.58, 93.93, 95.38, 93.57, 95.03, 94.01, 94.13, 95.59, 94.46, 95.76, 94.53, 95.56, 94.93, 95.78, 96.49, 94.92, 95.58, 96.2, 96.05, 95.65, 96.46, 95.44, 95.89, 97.09, 95.2, 95.02, 97.22, 96.61, 95.86, 97.33, 95.95, 96.05, 95.64, 96.59, 95.63, 94.51, 95.48, 95.6, 95.2, 96.66, 95.81, 96.39, 95.71, 95.31, 96.5, 95.7, 95.43, 95.77, 96.33, 96.6, 96.01, 96.54, 96.57, 95.96, 95.91, 96.2, 96.36, 96.85, 95.9, 96.41, 96.76, 96.35, 96.59, 94.92, 95.69, 96.67, 97.43, 95.32, 96.73, 96.0, 96.9]
# Test loss: [2.2591, 2.1604, 1.8158, 1.2342, 0.8084, 0.5907, 0.5043, 0.4205, 0.4, 0.3498, 0.3064, 0.2934, 0.2816, 0.2549, 0.2487, 0.2263, 0.2228, 0.2093, 0.2079, 0.1954, 0.177, 0.1863, 0.1836, 0.1703, 0.1692, 0.154, 0.1514, 0.1597, 0.148, 0.1501, 0.1442, 0.1393, 0.1316, 0.1281, 0.1259, 0.1276, 0.1261, 0.1215, 0.1197, 0.1196, 0.1134, 0.1135, 0.1113, 0.1189, 0.1132, 0.1057, 0.112, 0.1045, 0.1051, 0.106, 0.0941, 0.1019, 0.0974, 0.1027, 0.0966, 0.0987, 0.1056, 0.1047, 0.0874, 0.0961, 0.0917, 0.0937, 0.0937, 0.0948, 0.0979, 0.0942, 0.0904, 0.0908, 0.0878, 0.0831, 0.0857, 0.0848, 0.0809, 0.0891, 0.0852, 0.0893, 0.0821, 0.0769, 0.0789, 0.0805, 0.0923, 0.0798, 0.0774, 0.0806, 0.0781, 0.0804, 0.0798, 0.0796, 0.0697, 0.072, 0.0715, 0.0752, 0.0742, 0.0667, 0.0706, 0.0744, 0.0709, 0.0732, 0.0725, 0.0776, 0.0689]
# Label-flipping attack succes rate: 0.09
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.012
# --> End of Experiment.

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# E:\anaconda\envs\fragments\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: ffl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s2
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 2.281667
# Mixing took 0.032
# -> Update reputation
# Aggregation took 0.0395
# E:\文件\论文\论文源码\via - 副本\aggregation.py:68: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:1050.)
#   var_tensor.add_(1 / s, all_grads[t])
# Average test loss: 2.2587, Test accuracy: 1835/10000 (18.35%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 99.7
# Two        - 17.6
# Three      - 23.2
# Four       - 0.0
# Five       - 0.0
# Six        - 0.1
# Seven      - 3.3
# Eight      - 14.4
# Nine       - 26.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: 0.29105979204177856
# Peer 18  is  honest reputation: 0.11689746379852295
# Peer 7  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: -0.035569071769714355
# Peer 3  is  honest reputation: -0.035569071769714355
# Peer 16  is  honest reputation: 0.29105979204177856
# Peer 1  is  attacker reputation: 0.20508748292922974
# Peer 15  is  honest reputation: 0.0
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 2.228401
# Mixing took 0.0265
# -> Update reputation
# Aggregation took 0.019
#
# Average test loss: 2.1459, Test accuracy: 6052/10000 (60.52%)
#
# Class      - Accuracy
# Zero       - 87.5
# One        - 98.6
# Two        - 46.2
# Three      - 69.2
# Four       - 24.1
# Five       - 0.4
# Six        - 53.6
# Seven      - 76.5
# Eight      - 68.6
# Nine       - 69.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: -0.018974721431732178
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.20508748292922974
# Peer 1  is  attacker reputation: -0.18575447797775269
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.016220688819885254
# Peer 2  is  attacker reputation: 0.11689746379852295
# Peer 11  is  attacker reputation: 0.0
# 1  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 2.075421
# Mixing took 0.026
# -> Update reputation
# Aggregation took 0.0227
#
# Average test loss: 1.8145, Test accuracy: 6339/10000 (63.39%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 99.2
# Two        - 44.7
# Three      - 79.2
# Four       - 63.2
# Five       - 11.2
# Six        - 72.8
# Seven      - 55.2
# Eight      - 61.1
# Nine       - 54.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: -0.0014969706535339355
# Peer 6  is  honest reputation: 0.024288654327392578
# Peer 8  is  honest reputation: -0.03632110357284546
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: -0.09978216886520386
# Peer 1  is  attacker reputation: -0.22207558155059814
# Peer 16  is  honest reputation: 0.325131893157959
# Peer 17  is  honest reputation: 0.0
# Peer 11  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.043263375759124756
# 19  attack  7  to  1 !
# 1  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 1.752370
# Mixing took 0.0256
# -> Update reputation
# Aggregation took 0.0182
#
# Average test loss: 1.2717, Test accuracy: 7355/10000 (73.55%)
#
# Class      - Accuracy
# Zero       - 94.7
# One        - 98.2
# Two        - 73.3
# Three      - 85.6
# Four       - 80.9
# Five       - 48.5
# Six        - 81.5
# Seven      - 69.4
# Eight      - 62.6
# Nine       - 57.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.016220688819885254
# Peer 13  is  honest reputation: 0.2989844083786011
# Peer 4  is  honest reputation: 0.11011761426925659
# Peer 2  is  attacker reputation: 0.2741885781288147
# Peer 3  is  honest reputation: 0.09294426441192627
# Peer 12  is  honest reputation: 0.0
# Peer 14  is  honest reputation: 0.15729111433029175
# Peer 18  is  honest reputation: 0.11689746379852295
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: -0.22207558155059814
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 1.391094
# Mixing took 0.0223
# -> Update reputation
# Aggregation took 0.0157
#
# Average test loss: 0.8372, Test accuracy: 8215/10000 (82.15%)
#
# Class      - Accuracy
# Zero       - 95.8
# One        - 96.1
# Two        - 83.5
# Three      - 86.3
# Four       - 82.9
# Five       - 67.6
# Six        - 87.9
# Seven      - 79.8
# Eight      - 69.7
# Nine       - 73.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.016220688819885254
# Peer 14  is  honest reputation: 0.31304460763931274
# Peer 7  is  honest reputation: 0.016594350337982178
# Peer 18  is  honest reputation: 0.24499505758285522
# Peer 8  is  honest reputation: -0.09803307056427002
# Peer 6  is  honest reputation: 0.11872988939285278
# Peer 5  is  honest reputation: 0.043263375759124756
# Peer 11  is  attacker reputation: 0.11797720193862915
# Peer 2  is  attacker reputation: 0.2741885781288147
# Peer 3  is  honest reputation: 0.05216497182846069
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 1.140907
# Mixing took 0.0255
# -> Update reputation
# Aggregation took 0.018
#
# Average test loss: 0.6115, Test accuracy: 8595/10000 (85.95%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 95.1
# Two        - 85.8
# Three      - 88.6
# Four       - 86.0
# Five       - 78.5
# Six        - 87.6
# Seven      - 80.6
# Eight      - 74.2
# Nine       - 79.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.23821520805358887
# Peer 2  is  attacker reputation: 0.2741885781288147
# Peer 7  is  honest reputation: 0.2622029781341553
# Peer 5  is  honest reputation: 0.3010033965110779
# Peer 19  is  attacker reputation: 0.056545376777648926
# Peer 11  is  attacker reputation: 0.08402895927429199
# Peer 16  is  honest reputation: 0.48145943880081177
# Peer 6  is  honest reputation: 0.11872988939285278
# Peer 8  is  honest reputation: -0.13198131322860718
# Peer 13  is  honest reputation: 0.30411428213119507
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 1.002870
# Mixing took 0.026
# -> Update reputation
# Aggregation took 0.019
#
# Average test loss: 0.5168, Test accuracy: 8705/10000 (87.05%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 95.9
# Two        - 86.8
# Three      - 90.3
# Four       - 88.2
# Five       - 85.7
# Six        - 91.3
# Seven      - 84.3
# Eight      - 75.8
# Nine       - 76.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.15645939111709595
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.13160920143127441
# Peer 11  is  attacker reputation: -0.03370022773742676
# Peer 0  is  honest reputation: -0.040779292583465576
# Peer 10  is  honest reputation: -0.06171196699142456
# Peer 4  is  honest reputation: 0.5018057227134705
# Peer 12  is  honest reputation: 0.155753493309021
# Peer 18  is  honest reputation: 0.48581117391586304
# Peer 5  is  honest reputation: 0.5871980786323547
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.891222
# Mixing took 0.0245
# -> Update reputation
# Aggregation took 0.0165
#
# Average test loss: 0.4278, Test accuracy: 8935/10000 (89.35%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 97.5
# Two        - 90.9
# Three      - 90.3
# Four       - 91.6
# Five       - 83.1
# Six        - 91.2
# Seven      - 86.0
# Eight      - 83.3
# Nine       - 79.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.11872988939285278
# Peer 11  is  attacker reputation: -0.03370022773742676
# Peer 3  is  honest reputation: 0.2977735996246338
# Peer 14  is  honest reputation: 0.5707846283912659
# Peer 7  is  honest reputation: 0.5593928694725037
# Peer 1  is  attacker reputation: -0.21694570779800415
# Peer 8  is  honest reputation: 0.10294950008392334
# Peer 9  is  honest reputation: 0.3312743902206421
# Peer 10  is  honest reputation: 0.26956242322921753
# Peer 16  is  honest reputation: 0.7676541209220886
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.826793
# Mixing took 0.0225
# -> Update reputation
# Aggregation took 0.0167
#
# Average test loss: 0.3992, Test accuracy: 8995/10000 (89.95%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 96.8
# Two        - 89.6
# Three      - 90.0
# Four       - 92.3
# Five       - 85.9
# Six        - 94.0
# Seven      - 86.5
# Eight      - 84.3
# Nine       - 83.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.11797720193862915
# Peer 15  is  honest reputation: 0.25703680515289307
# Peer 12  is  honest reputation: 0.48839271068573
# Peer 1  is  attacker reputation: -0.21694570779800415
# Peer 4  is  honest reputation: 0.8344449400901794
# Peer 14  is  honest reputation: 0.5707846283912659
# Peer 19  is  attacker reputation: 0.056545376777648926
# Peer 9  is  honest reputation: 0.723796010017395
# Peer 3  is  honest reputation: 0.6965938806533813
# Peer 7  is  honest reputation: 0.9582131505012512
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.777913
# Mixing took 0.0255
# -> Update reputation
# Aggregation took 0.02
#
# Average test loss: 0.3506, Test accuracy: 9096/10000 (90.96%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 98.0
# Two        - 92.3
# Three      - 89.9
# Four       - 92.3
# Five       - 87.1
# Six        - 94.2
# Seven      - 87.3
# Eight      - 82.5
# Nine       - 87.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 1.233510673046112
# Peer 17  is  honest reputation: 0.09316909313201904
# Peer 8  is  honest reputation: 0.47801637649536133
# Peer 2  is  attacker reputation: 0.12779968976974487
# Peer 5  is  honest reputation: 0.8931265473365784
# Peer 13  is  honest reputation: 0.6013041734695435
# Peer 6  is  honest reputation: 0.09096461534500122
# Peer 18  is  honest reputation: 0.7917396426200867
# Peer 16  is  honest reputation: 1.1427209973335266
# Peer 1  is  attacker reputation: -0.21694570779800415
# 2  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.729357
# Mixing took 0.0235
# -> Update reputation
# Aggregation took 0.0155
#
# Average test loss: 0.3225, Test accuracy: 9109/10000 (91.09%)
#
# Class      - Accuracy
# Zero       - 96.9
# One        - 98.0
# Two        - 90.8
# Three      - 91.2
# Four       - 92.6
# Five       - 89.9
# Six        - 94.5
# Seven      - 87.4
# Eight      - 83.0
# Nine       - 87.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: 0.12779968976974487
# Peer 10  is  honest reputation: 0.6620840430259705
# Peer 4  is  honest reputation: 1.1097424626350403
# Peer 6  is  honest reputation: 0.09096461534500122
# Peer 12  is  honest reputation: 0.7471656203269958
# Peer 14  is  honest reputation: 0.8295575380325317
# Peer 9  is  honest reputation: 1.007511019706726
# Peer 18  is  honest reputation: 1.1180012822151184
# Peer 13  is  honest reputation: 0.9407021403312683
# Peer 17  is  honest reputation: 0.06921887397766113
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.680311
# Mixing took 0.0255
# -> Update reputation
# Aggregation took 0.019
#
# Average test loss: 0.2938, Test accuracy: 9175/10000 (91.75%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 97.9
# Two        - 91.7
# Three      - 91.7
# Four       - 93.7
# Five       - 89.6
# Six        - 93.7
# Seven      - 90.0
# Eight      - 86.2
# Nine       - 87.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 1.5597723126411438
# Peer 11  is  attacker reputation: -0.06146550178527832
# Peer 9  is  honest reputation: 1.0318055152893066
# Peer 8  is  honest reputation: 0.823056697845459
# Peer 18  is  honest reputation: 1.1180012822151184
# Peer 5  is  honest reputation: 1.2325245141983032
# Peer 4  is  honest reputation: 1.1424511075019836
# Peer 12  is  honest reputation: 0.7471656203269958
# Peer 10  is  honest reputation: 0.686378538608551
# Peer 19  is  attacker reputation: 0.03173726797103882
# 11  attack  7  to  1 !
# 19  attack  7  to  1 !
# Average of peers' local losses: 0.655538
# Mixing took 0.027
# -> Update reputation
# Aggregation took 0.018
#
# Average test loss: 0.2742, Test accuracy: 9223/10000 (92.23%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.6
# Two        - 92.3
# Three      - 92.7
# Four       - 93.6
# Five       - 89.7
# Six        - 94.9
# Seven      - 88.6
# Eight      - 87.9
# Nine       - 89.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.44673722982406616
# Peer 10  is  honest reputation: 0.6514822840690613
# Peer 2  is  attacker reputation: -0.3661652207374573
# Peer 18  is  honest reputation: 1.1180012822151184
# Peer 15  is  honest reputation: 0.25703680515289307
# Peer 12  is  honest reputation: 1.0441337823867798
# Peer 19  is  attacker reputation: -0.0031589865684509277
# Peer 11  is  attacker reputation: -0.06146550178527832
# Peer 9  is  honest reputation: 1.3085631132125854
# Peer 4  is  honest reputation: 1.4255004525184631
# 2  attack  7  to  1 !
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.627014
# Mixing took 0.025
# -> Update reputation
# Aggregation took 0.019
#
# Average test loss: 0.2595, Test accuracy: 9278/10000 (92.78%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 96.5
# Two        - 91.7
# Three      - 92.6
# Four       - 92.9
# Five       - 89.6
# Six        - 94.1
# Seven      - 86.9
# Eight      - 87.6
# Nine       - 90.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.5603154897689819
# Peer 6  is  honest reputation: 0.11643612384796143
# Peer 3  is  honest reputation: 0.9803088903427124
# Peer 18  is  honest reputation: 1.4299671053886414
# Peer 10  is  honest reputation: 0.9547609686851501
# Peer 7  is  honest reputation: 1.8365299105644226
# Peer 19  is  attacker reputation: -0.10852593183517456
# Peer 0  is  honest reputation: -0.040779292583465576
# Peer 11  is  attacker reputation: -0.06146550178527832
# Peer 13  is  honest reputation: 0.7406697273254395
# 19  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.604427
# Mixing took 0.0255
# -> Update reputation
# Aggregation took 0.0191
#
# Average test loss: 0.2532, Test accuracy: 9238/10000 (92.38%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 92.3
# Three      - 93.3
# Four       - 94.1
# Five       - 88.6
# Six        - 94.6
# Seven      - 88.0
# Eight      - 88.1
# Nine       - 90.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: -0.24089592695236206
# Peer 9  is  honest reputation: 1.6024956107139587
# Peer 3  is  honest reputation: 1.350258708000183
# Peer 14  is  honest reputation: 0.8550290465354919
# Peer 17  is  honest reputation: 0.10192751884460449
# Peer 8  is  honest reputation: 1.1061060428619385
# Peer 6  is  honest reputation: 0.4847508668899536
# Peer 7  is  honest reputation: 2.2064797282218933
# Peer 19  is  attacker reputation: -0.15888270735740662
# Peer 2  is  attacker reputation: -0.4715321660041809
# 1  attack  7  to  1 !
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.590860
# Mixing took 0.0305
# -> Update reputation
# Aggregation took 0.018
#
# Average test loss: 0.2337, Test accuracy: 9358/10000 (93.58%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.2
# Two        - 92.9
# Three      - 93.2
# Four       - 96.8
# Five       - 91.7
# Six        - 95.3
# Seven      - 90.1
# Eight      - 87.8
# Nine       - 90.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.39741700887680054
# Peer 12  is  honest reputation: 1.0441337823867798
# Peer 13  is  honest reputation: 1.0971500277519226
# Peer 16  is  honest reputation: 1.4877613186836243
# Peer 15  is  honest reputation: 0.5603154897689819
# Peer 18  is  honest reputation: 1.7982818484306335
# Peer 4  is  honest reputation: 1.737466275691986
# Peer 11  is  attacker reputation: -0.06146550178527832
# Peer 5  is  honest reputation: 1.5294926762580872
# Peer 1  is  attacker reputation: -0.33572691679000854
# 11  attack  7  to  1 !
# 1  attack  7  to  1 !
# Average of peers' local losses: 0.553245
# Mixing took 0.024
# -> Update reputation
# Aggregation took 0.016
#
# Average test loss: 0.2243, Test accuracy: 9359/10000 (93.59%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.2
# Two        - 91.9
# Three      - 94.3
# Four       - 95.0
# Five       - 90.7
# Six        - 96.0
# Seven      - 88.7
# Eight      - 89.1
# Nine       - 91.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.5658382773399353
# Peer 5  is  honest reputation: 1.5524425506591797
# Peer 11  is  attacker reputation: -0.625312328338623
# Peer 3  is  honest reputation: 1.6635796427726746
# Peer 13  is  honest reputation: 1.0971500277519226
# Peer 7  is  honest reputation: 2.5019692182540894
# Peer 2  is  attacker reputation: -0.5663631558418274
# Peer 17  is  honest reputation: 0.42036688327789307
# Peer 0  is  honest reputation: -0.09113606810569763
# Peer 12  is  honest reputation: 1.0441337823867798
# 11  attack  7  to  1 !
# 2  attack  7  to  1 !
# Average of peers' local losses: 0.539051
# Mixing took 0.0268
# -> Update reputation
# Aggregation took 0.0165
#
# Average test loss: 0.2078, Test accuracy: 9412/10000 (94.12%)
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.4
# Two        - 91.9
# Three      - 93.7
# Four       - 95.5
# Five       - 92.1
# Six        - 95.8
# Seven      - 90.4
# Eight      - 89.4
# Nine       - 90.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 1.8118303418159485
# Peer 6  is  honest reputation: 0.781972348690033
# Peer 7  is  honest reputation: 2.8604912161827087
# Peer 19  is  attacker reputation: -0.15888270735740662
# Peer 13  is  honest reputation: 1.455672025680542
# Peer 16  is  honest reputation: 1.4932841062545776
# Peer 2  is  attacker reputation: -0.5663631558418274
# Peer 11  is  attacker reputation: -0.6505318880081177
# Peer 0  is  honest reputation: 0.2179953157901764
# Peer 3  is  honest reputation: 1.6635796427726746
# 19  attack  7  to  1 !
# 2  attack  7  to  1 !
# 11  attack  7  to  1 !
# Average of peers' local losses: 0.545932
# Mixing took 0.026
# -> Update reputation
# Aggregation took 0.018
#
# Average test loss: 0.2416, Test accuracy: 9295/10000 (92.95%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.6
# Two        - 93.6
# Three      - 94.1
# Four       - 95.4
# Five       - 92.0
# Six        - 96.4
# Seven      - 78.4
# Eight      - 90.3
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 2.8604912161827087
# Peer 18  is  honest reputation: 2.3485377430915833
# Peer 5  is  honest reputation: 1.8471405506134033
# Peer 6  is  honest reputation: 0.7506648600101471
# Peer 12  is  honest reputation: 1.3532651662826538
# Peer 0  is  honest reputation: 0.7499580681324005
# Peer 9  is  honest reputation: 1.899717092514038
# Peer 3  is  honest reputation: 2.1715232729911804
# Peer 4  is  honest reputation: 1.751014769077301
# Peer 16  is  honest reputation: 1.4932841062545776
# Average of peers' local losses: 0.503834
# Mixing took 0.0267
# -> Update reputation
# Aggregation took 0.018
#
# Average test loss: 0.2005, Test accuracy: 9426/10000 (94.26%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.7
# Two        - 92.8
# Three      - 93.8
# Four       - 96.5
# Five       - 93.2
# Six        - 95.7
# Seven      - 92.4
# Eight      - 89.7
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 2.046444833278656
# Peer 8  is  honest reputation: 1.1061060428619385
# Peer 10  is  honest reputation: 1.3112412691116333
# Peer 13  is  honest reputation: 1.4243645370006561
# Peer 3  is  honest reputation: 2.1279035806655884
# Peer 16  is  honest reputation: 1.4496644139289856
# Peer 7  is  honest reputation: 3.009084403514862
# Peer 5  is  honest reputation: 1.8471405506134033
# Peer 18  is  honest reputation: 2.4971309304237366
# Peer 12  is  honest reputation: 1.4999929070472717
# Average of peers' local losses: 0.478023
# Mixing took 0.025
# -> Update reputation
# [0.91930634 0.96061057 0.5713035  0.64259357 0.82593055 0.87971361
#  0.77331207 0.98757812 0.5268313  0.73027077]
# Aggregation took 0.0252
#
# Average test loss: 0.1932, Test accuracy: 9438/10000 (94.38%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.7
# Two        - 92.4
# Three      - 94.0
# Four       - 94.6
# Five       - 94.1
# Six        - 96.2
# Seven      - 92.2
# Eight      - 87.6
# Nine       - 91.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 2.036285102367401
# Peer 5  is  honest reputation: 1.8369808197021484
# Peer 18  is  honest reputation: 2.6155423521995544
# Peer 8  is  honest reputation: 1.2475343942642212
# Peer 13  is  honest reputation: 1.4243645370006561
# Peer 4  is  honest reputation: 1.8867058753967285
# Peer 3  is  honest reputation: 2.2463150024414062
# Peer 16  is  honest reputation: 1.5910927653312683
# Peer 15  is  honest reputation: 0.8605362772941589
# Peer 7  is  honest reputation: 3.1993919610977173
# Average of peers' local losses: 0.463271
# Mixing took 0.0232
# -> Update reputation
# [0.46969907 0.59573805 0.86469386 0.89789226 0.96061057 0.73027077
#  0.83163499 0.21362865 0.93960376 0.99078513]
# Aggregation took 0.0192
#
# Average test loss: 0.1794, Test accuracy: 9472/10000 (94.72%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.5
# Two        - 94.2
# Three      - 95.6
# Four       - 94.6
# Five       - 94.6
# Six        - 96.8
# Seven      - 91.9
# Eight      - 88.6
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 1.1683499813079834
# Peer 6  is  honest reputation: 0.7506648600101471
# Peer 9  is  honest reputation: 2.123020827770233
# Peer 16  is  honest reputation: 1.5910927653312683
# Peer 18  is  honest reputation: 2.6155423521995544
# Peer 3  is  honest reputation: 2.3964415192604065
# Peer 4  is  honest reputation: 1.9734416007995605
# Peer 10  is  honest reputation: 1.3112412691116333
# Peer 15  is  honest reputation: 0.8787559270858765
# Peer 5  is  honest reputation: 1.855200469493866
# Average of peers' local losses: 0.450531
# Mixing took 0.0226
# -> Update reputation
# [0.88156307 0.90532517 0.25286184 0.96369075 0.72751434 0.08280847
#  0.58868891 0.9425987  0.48094049 0.90125754]
# Aggregation took 0.015
#
# Average test loss: 0.1761, Test accuracy: 9470/10000 (94.70%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.2
# Two        - 95.2
# Three      - 95.6
# Four       - 95.5
# Five       - 92.2
# Six        - 96.9
# Seven      - 91.4
# Eight      - 91.0
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 1.567569375038147
# Peer 6  is  honest reputation: 0.7271414697170258
# Peer 8  is  honest reputation: 1.1714696288108826
# Peer 13  is  honest reputation: 1.3482997715473175
# Peer 3  is  honest reputation: 2.4050004482269287
# Peer 14  is  honest reputation: 1.1683499813079834
# Peer 7  is  honest reputation: 3.3495184779167175
# Peer 5  is  honest reputation: 2.026881694793701
# Peer 12  is  honest reputation: 1.690300464630127
# Peer 9  is  honest reputation: 2.123020827770233
# Average of peers' local losses: 0.448791
# Mixing took 0.026
# -> Update reputation
# [0.73373191 0.78547051 0.98780694 0.35303919 0.90979746 0.94766159
#  0.61010069 0.88265581 0.48094049 0.08280847]
# Aggregation took 0.015
#
# Average test loss: 0.1723, Test accuracy: 9493/10000 (94.93%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.3
# Two        - 93.7
# Three      - 94.5
# Four       - 95.2
# Five       - 95.4
# Six        - 97.1
# Seven      - 94.1
# Eight      - 90.9
# Nine       - 92.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 3.191103219985962
# Peer 3  is  honest reputation: 2.4524700045585632
# Peer 5  is  honest reputation: 2.0318065881729126
# Peer 9  is  honest reputation: 2.1704903841018677
# Peer 16  is  honest reputation: 1.580906867980957
# Peer 6  is  honest reputation: 0.7271414697170258
# Peer 12  is  honest reputation: 1.703637957572937
# Peer 15  is  honest reputation: 0.902610719203949
# Peer 10  is  honest reputation: 1.3198001980781555
# Peer 14  is  honest reputation: 1.1683499813079834
# Average of peers' local losses: 0.426508
# Mixing took 0.0215
# -> Update reputation
# [0.3343017  0.90087788 0.46970951 0.92780279 0.92002367 0.80837737
#  0.52232152 0.98907705]
# Aggregation took 0.014
#
# Average test loss: 0.1627, Test accuracy: 9509/10000 (95.09%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 93.5
# Three      - 94.5
# Four       - 94.6
# Five       - 94.9
# Six        - 96.6
# Seven      - 93.9
# Eight      - 92.4
# Nine       - 93.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 3.246423125267029
# Peer 6  is  honest reputation: 0.7271414697170258
# Peer 13  is  honest reputation: 1.353224664926529
# Peer 14  is  honest reputation: 1.2236698865890503
# Peer 9  is  honest reputation: 2.2333239912986755
# Peer 4  is  honest reputation: 2.1451228260993958
# Peer 10  is  honest reputation: 1.1538404822349548
# Peer 8  is  honest reputation: 1.013054370880127
# Peer 3  is  honest reputation: 2.2865102887153625
# Peer 5  is  honest reputation: 2.121002197265625
# Average of peers' local losses: 0.425449
# Mixing took 0.02
# -> Update reputation
# [0.98863603 0.06301306 0.58218944 0.9197222  0.94935283 0.73754997
#  0.93302969 0.51781485]
# Aggregation took 0.0125
# Average test loss: 0.1566, Test accuracy: 9521/10000 (95.21%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.8
# Three      - 95.5
# Four       - 95.8
# Five       - 95.0
# Six        - 96.2
# Seven      - 93.7
# Eight      - 92.9
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 2.4096219539642334
# Peer 7  is  honest reputation: 3.1668156385421753
# Peer 18  is  honest reputation: 2.639397144317627
# Peer 5  is  honest reputation: 2.265734553337097
# Peer 13  is  honest reputation: 1.5295226275920868
# Peer 15  is  honest reputation: 0.9918063282966614
# Peer 10  is  honest reputation: 1.1538404822349548
# Peer 4  is  honest reputation: 2.1716586351394653
# Peer 3  is  honest reputation: 2.2865102887153625
# Peer 14  is  honest reputation: 1.2502056956291199
# Average of peers' local losses: 0.411346
# Mixing took 0.0229
# -> Update reputation
# [0.51492082 0.73754997 0.56862695 0.94731188 0.9447732  0.53767111
#  0.93584915 0.96909432 0.9913168  0.95053294]
# Aggregation took 0.0159
#
# Average test loss: 0.1597, Test accuracy: 9531/10000 (95.31%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 95.9
# Three      - 95.7
# Four       - 96.4
# Five       - 95.9
# Six        - 96.6
# Seven      - 93.9
# Eight      - 91.4
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.885649174451828
# Peer 9  is  honest reputation: 2.3893449306488037
# Peer 12  is  honest reputation: 1.7664715647697449
# Peer 4  is  honest reputation: 2.365163505077362
# Peer 7  is  honest reputation: 3.302018165588379
# Peer 14  is  honest reputation: 1.2299286723136902
# Peer 15  is  honest reputation: 1.185311198234558
# Peer 8  is  honest reputation: 1.1577867269515991
# Peer 13  is  honest reputation: 1.5295226275920868
# Peer 3  is  honest reputation: 2.421712815761566
# Average of peers' local losses: 0.405867
# Mixing took 0.0215
# -> Update reputation
# [0.78935245 0.95869569 0.95881058 0.95399192 0.54070408 0.29632683
#  0.82401741 0.55988313]
# Aggregation took 0.013
#
# Average test loss: 0.1507, Test accuracy: 9571/10000 (95.71%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.4
# Two        - 95.0
# Three      - 95.1
# Four       - 96.4
# Five       - 97.1
# Six        - 96.5
# Seven      - 93.3
# Eight      - 92.3
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 1.1895873546600342
# Peer 18  is  honest reputation: 2.6616318821907043
# Peer 6  is  honest reputation: 0.6475339829921722
# Peer 3  is  honest reputation: 2.5153929591178894
# Peer 16  is  honest reputation: 1.580906867980957
# Peer 14  is  honest reputation: 1.2171002626419067
# Peer 12  is  honest reputation: 1.7536431550979614
# Peer 9  is  honest reputation: 2.513970971107483
# Peer 5  is  honest reputation: 2.2879692912101746
# Peer 8  is  honest reputation: 1.1577867269515991
# Average of peers' local losses: 0.395307
# Mixing took 0.0263
# -> Update reputation
# [0.61361981 0.57528942 0.970086   0.82126425 0.06301306 0.96909432
#  0.51209113 0.95549214 0.86868207 0.9528642 ]
# Aggregation took 0.0153
#
# Average test loss: 0.1434, Test accuracy: 9558/10000 (95.58%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 94.4
# Three      - 95.1
# Four       - 96.5
# Five       - 96.6
# Six        - 97.8
# Seven      - 93.4
# Eight      - 91.0
# Nine       - 93.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 0  is  honest reputation: 0.8899253308773041
# Peer 10  is  honest reputation: 1.1538404822349548
# Peer 15  is  honest reputation: 1.1499974131584167
# Peer 5  is  honest reputation: 2.4464471340179443
# Peer 14  is  honest reputation: 1.2991440296173096
# Peer 16  is  honest reputation: 1.745126187801361
# Peer 6  is  honest reputation: 0.6475339829921722
# Peer 8  is  honest reputation: 1.239830493927002
# Peer 18  is  honest reputation: 2.6616318821907043
# Peer 3  is  honest reputation: 2.475803017616272
# Average of peers' local losses: 0.393726
# Mixing took 0.0261
# -> Update reputation
# [0.55703681 0.03621422 0.70193525 0.96725127 0.96471188 0.86388431
#  0.97363484 0.36798267 0.59336583 0.59087017]
# Aggregation took 0.0149
#
# Average test loss: 0.1462, Test accuracy: 9593/10000 (95.93%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.5
# Two        - 96.2
# Three      - 96.1
# Four       - 96.0
# Five       - 97.1
# Six        - 96.3
# Seven      - 93.8
# Eight      - 92.9
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 1.1828394532203674
# Peer 5  is  honest reputation: 2.51361483335495
# Peer 14  is  honest reputation: 1.3749427795410156
# Peer 13  is  honest reputation: 1.654148668050766
# Peer 16  is  honest reputation: 1.8122938871383667
# Peer 8  is  honest reputation: 1.1323640942573547
# Peer 18  is  honest reputation: 2.6616318821907043
# Peer 7  is  honest reputation: 3.302018165588379
# Peer 6  is  honest reputation: 0.540067583322525
# Peer 3  is  honest reputation: 2.551601767539978
# Average of peers' local losses: 0.389627
# Mixing took 0.0195
# -> Update reputation
# [0.89843336 0.9740254  0.99442257 0.67534841 0.98013111 0.97530074
#  0.0035739  0.68498674]
# Aggregation took 0.0142
#
# Average test loss: 0.1395, Test accuracy: 9611/10000 (96.11%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 96.4
# Three      - 96.0
# Four       - 96.2
# Five       - 96.2
# Six        - 97.6
# Seven      - 94.2
# Eight      - 90.5
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.4094429910182953
# Peer 14  is  honest reputation: 1.2443181872367859
# Peer 9  is  honest reputation: 2.678190290927887
# Peer 0  is  honest reputation: 0.8899253308773041
# Peer 8  is  honest reputation: 1.1323640942573547
# Peer 18  is  honest reputation: 2.7067505717277527
# Peer 5  is  honest reputation: 2.571224570274353
# Peer 12  is  honest reputation: 1.9121209979057312
# Peer 4  is  honest reputation: 2.4588436484336853
# Peer 3  is  honest reputation: 2.5967204570770264
# Average of peers' local losses: 0.374538
# Mixing took 0.019
# -> Update reputation
# [0.9770223  0.98044339 0.97588968 0.98156125 0.92385819 0.6831454
#  0.9597944  0.35781343]
# Aggregation took 0.0118
#
# Average test loss: 0.1539, Test accuracy: 9545/10000 (95.45%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.4
# Two        - 96.4
# Three      - 96.8
# Four       - 95.9
# Five       - 97.2
# Six        - 96.8
# Seven      - 93.7
# Eight      - 91.8
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 1.654148668050766
# Peer 15  is  honest reputation: 1.226381003856659
# Peer 18  is  honest reputation: 2.7444621324539185
# Peer 5  is  honest reputation: 2.608936131000519
# Peer 12  is  honest reputation: 2.020614266395569
# Peer 14  is  honest reputation: 1.2443181872367859
# Peer 9  is  honest reputation: 2.714750349521637
# Peer 6  is  honest reputation: 0.4094429910182953
# Peer 0  is  honest reputation: 0.7802450954914093
# Peer 3  is  honest reputation: 2.6332805156707764
# Average of peers' local losses: 0.369500
# Mixing took 0.0355
# -> Update reputation
# [0.76203688 0.89142508 0.00245582 0.98040004 0.75182531 0.98253972
#  0.92434802 0.36073474 0.98750431 0.98364567]
# Aggregation took 0.0191
#
# Average test loss: 0.1374, Test accuracy: 9591/10000 (95.91%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 96.0
# Three      - 95.6
# Four       - 96.0
# Five       - 95.7
# Six        - 97.1
# Seven      - 93.8
# Eight      - 92.1
# Nine       - 93.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 1.2408573627471924
# Peer 16  is  honest reputation: 1.8699036240577698
# Peer 4  is  honest reputation: 2.3491634130477905
# Peer 5  is  honest reputation: 2.8016143441200256
# Peer 0  is  honest reputation: 0.7802450954914093
# Peer 3  is  honest reputation: 2.7686174511909485
# Peer 14  is  honest reputation: 1.379655122756958
# Peer 15  is  honest reputation: 1.4035698175430298
# Peer 18  is  honest reputation: 2.9371403455734253
# Peer 9  is  honest reputation: 2.7102779746055603
# Average of peers' local losses: 0.367903
# Mixing took 0.0262
# -> Update reputation
# [0.9632951  0.76995873 0.98527588 0.72790322 0.26101322 0.9844368
#  0.98364567 0.89907817 0.77318884 0.98142644]
# Aggregation took 0.0157
# Average test loss: 0.1288, Test accuracy: 9658/10000 (96.58%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.2
# Two        - 95.1
# Three      - 96.2
# Four       - 96.3
# Five       - 97.6
# Six        - 97.4
# Seven      - 93.8
# Eight      - 94.3
# Nine       - 93.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 2.8545279502868652
# Peer 0  is  honest reputation: 0.6697101891040802
# Peer 9  is  honest reputation: 2.7374314665794373
# Peer 18  is  honest reputation: 2.826605439186096
# Peer 12  is  honest reputation: 2.020614266395569
# Peer 13  is  honest reputation: 1.8313374817371368
# Peer 6  is  honest reputation: 0.40497061610221863
# Peer 16  is  honest reputation: 1.8699036240577698
# Peer 10  is  honest reputation: 1.1866825222969055
# Peer 5  is  honest reputation: 2.8016143441200256
# Average of peers' local losses: 0.358694
# Mixing took 0.0271
# -> Update reputation
# [0.98162322 0.26601511 0.00245582 0.65509237 0.92913552 0.8981858
#  0.98160781 0.88165849 0.98832562 0.98703086]
# Aggregation took 0.0158
#
# Average test loss: 0.1343, Test accuracy: 9603/10000 (96.03%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 98.9
# Two        - 94.1
# Three      - 96.4
# Four       - 96.7
# Five       - 97.3
# Six        - 96.5
# Seven      - 93.8
# Eight      - 93.0
# Nine       - 93.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 2.0545437335968018
# Peer 3  is  honest reputation: 2.9713404774665833
# Peer 4  is  honest reputation: 2.3922494649887085
# Peer 7  is  honest reputation: 3.3455597162246704
# Peer 16  is  honest reputation: 1.7856819033622742
# Peer 18  is  honest reputation: 2.7423837184906006
# Peer 9  is  honest reputation: 2.742806613445282
# Peer 14  is  honest reputation: 1.422741174697876
# Peer 10  is  honest reputation: 1.1866825222969055
# Peer 15  is  honest reputation: 1.4307233095169067
# Average of peers' local losses: 0.354942
# Mixing took 0.0237
# -> Update reputation
# [0.96574946 0.88926376 0.98384726 0.69066581 0.7233045  0.9773279
#  0.99518192 0.93810844]
# Aggregation took 0.013
#
# Average test loss: 0.1244, Test accuracy: 9622/10000 (96.22%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.5
# Two        - 96.3
# Three      - 96.7
# Four       - 96.0
# Five       - 97.6
# Six        - 96.9
# Seven      - 94.1
# Eight      - 94.7
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 1.8209104537963867
# Peer 0  is  honest reputation: 0.6750853359699249
# Peer 12  is  honest reputation: 2.1245567202568054
# Peer 15  is  honest reputation: 1.4307233095169067
# Peer 4  is  honest reputation: 2.427478015422821
# Peer 6  is  honest reputation: 0.40497061610221863
# Peer 3  is  honest reputation: 2.9713404774665833
# Peer 7  is  honest reputation: 3.415572702884674
# Peer 9  is  honest reputation: 2.807866632938385
# Peer 8  is  honest reputation: 1.3267678618431091
# Average of peers' local losses: 0.351968
# Mixing took 0.0269
# -> Update reputation
# [0.95254371 0.84883571 0.93305238 0.98249396 0.03713871 0.29795195
#  0.77358745 0.72836923 0.98564287 0.99407004]
# Aggregation took 0.0158
#
# Average test loss: 0.1280, Test accuracy: 9596/10000 (95.96%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.3
# Two        - 95.7
# Three      - 95.3
# Four       - 97.1
# Five       - 97.2
# Six        - 96.9
# Seven      - 94.3
# Eight      - 93.7
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.5437705218791962
# Peer 9  is  honest reputation: 2.8713971972465515
# Peer 0  is  honest reputation: 0.8138852417469025
# Peer 4  is  honest reputation: 2.3651543259620667
# Peer 3  is  honest reputation: 2.9713404774665833
# Peer 13  is  honest reputation: 1.8652669489383698
# Peer 14  is  honest reputation: 1.3170554637908936
# Peer 8  is  honest reputation: 1.4318596720695496
# Peer 18  is  honest reputation: 2.636698007583618
# Peer 10  is  honest reputation: 1.2517425417900085
# Average of peers' local losses: 0.349759
# Mixing took 0.0222
# -> Update reputation
# [0.74039317 0.96398855 0.01478126 0.27743133 0.97805413 0.90132061
#  0.98815851 0.98555734]
# Aggregation took 0.0137
#
# Average test loss: 0.1261, Test accuracy: 9624/10000 (96.24%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.2
# Two        - 97.2
# Three      - 94.5
# Four       - 96.3
# Five       - 98.6
# Six        - 98.3
# Seven      - 93.8
# Eight      - 95.0
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 2.4389421939849854
# Peer 13  is  honest reputation: 1.9187082350254059
# Peer 15  is  honest reputation: 1.5358151197433472
# Peer 0  is  honest reputation: 0.724391371011734
# Peer 14  is  honest reputation: 1.3908433318138123
# Peer 9  is  honest reputation: 2.9012284874916077
# Peer 5  is  honest reputation: 2.9184268712997437
# Peer 18  is  honest reputation: 2.6901392936706543
# Peer 3  is  honest reputation: 3.0011717677116394
# Peer 8  is  honest reputation: 1.4318596720695496
# Average of peers' local losses: 0.347300
# Mixing took 0.0254
# -> Update reputation
# [0.98415224 0.71009524 0.98226921 0.83487763 0.7800195  0.96755516
#  0.98986001 0.98763027 0.27743133 0.90132061]
# Aggregation took 0.0146
#
# Average test loss: 0.1216, Test accuracy: 9632/10000 (96.32%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.8
# Two        - 97.5
# Three      - 96.0
# Four       - 96.5
# Five       - 98.4
# Six        - 97.6
# Seven      - 95.0
# Eight      - 93.0
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 1.9187082350254059
# Peer 9  is  honest reputation: 2.979217290878296
# Peer 4  is  honest reputation: 2.491997182369232
# Peer 3  is  honest reputation: 3.0791605710983276
# Peer 6  is  honest reputation: 0.4542766511440277
# Peer 0  is  honest reputation: 0.724391371011734
# Peer 15  is  honest reputation: 1.6435174345970154
# Peer 7  is  honest reputation: 3.415572702884674
# Peer 10  is  honest reputation: 1.2517425417900085
# Peer 18  is  honest reputation: 2.7978416085243225
# Average of peers' local losses: 0.340248
# Mixing took 0.0244
# -> Update reputation
# [0.99648885 0.99161696 0.75256444 0.92828018 0.99048045 0.98335022
#  0.98053243 0.49569281 0.00420713 0.83164515]
# Aggregation took 0.022
#
# Average test loss: 0.1209, Test accuracy: 9645/10000 (96.45%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.9
# Three      - 95.4
# Four       - 97.2
# Five       - 98.4
# Six        - 97.5
# Seven      - 94.5
# Eight      - 93.6
# Nine       - 94.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.3866114020347595
# Peer 16  is  honest reputation: 1.7585867643356323
# Peer 9  is  honest reputation: 3.1430145502090454
# Peer 4  is  honest reputation: 2.7189542055130005
# Peer 15  is  honest reputation: 1.601216733455658
# Peer 13  is  honest reputation: 2.053577095270157
# Peer 8  is  honest reputation: 1.4849146604537964
# Peer 7  is  honest reputation: 3.5793699622154236
# Peer 6  is  honest reputation: 0.4119759500026703
# Peer 3  is  honest reputation: 3.0791605710983276
# Average of peers' local losses: 0.339281
# Mixing took 0.0234
# -> Update reputation
# [0.92842986 0.99050096 0.76746951 0.81117099 0.9938915  0.81363062
#  0.02520331 0.98132571 0.8512134  0.99579553]
# Aggregation took 0.0161
#
# Average test loss: 0.1184, Test accuracy: 9656/10000 (96.56%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.5
# Two        - 96.9
# Three      - 96.5
# Four       - 97.5
# Five       - 96.5
# Six        - 98.5
# Seven      - 95.8
# Eight      - 93.0
# Nine       - 93.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 2.7978416085243225
# Peer 6  is  honest reputation: 0.495981901884079
# Peer 16  is  honest reputation: 1.731315016746521
# Peer 3  is  honest reputation: 3.143248498439789
# Peer 15  is  honest reputation: 1.601216733455658
# Peer 12  is  honest reputation: 2.188087284564972
# Peer 0  is  honest reputation: 0.9513483941555023
# Peer 13  is  honest reputation: 2.117665022611618
# Peer 5  is  honest reputation: 2.8544538021087646
# Peer 7  is  honest reputation: 3.5520982146263123
# Average of peers' local losses: 0.335029
# Mixing took 0.022
# -> Update reputation
# [0.98331735 0.03059711 0.94777272 0.99650164 0.91637457 0.97785587
#  0.84668231 0.5330875 ]
# Aggregation took 0.0125
#
# Average test loss: 0.1147, Test accuracy: 9661/10000 (96.61%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.7
# Two        - 95.5
# Three      - 95.8
# Four       - 97.3
# Five       - 98.1
# Six        - 96.9
# Seven      - 94.6
# Eight      - 92.7
# Nine       - 93.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.6084509491920471
# Peer 7  is  honest reputation: 3.660396695137024
# Peer 14  is  honest reputation: 1.3268702626228333
# Peer 9  is  honest reputation: 3.364854097366333
# Peer 4  is  honest reputation: 2.802960157394409
# Peer 16  is  honest reputation: 1.731315016746521
# Peer 6  is  honest reputation: 0.5175739824771881
# Peer 5  is  honest reputation: 2.876045882701874
# Peer 13  is  honest reputation: 2.052888721227646
# Peer 12  is  honest reputation: 2.2963857650756836
# Average of peers' local losses: 0.329495
# Mixing took 0.0267
# -> Update reputation
# [0.03059711 0.98331735 0.93048828 0.83893847 0.94652524 0.99353672
#  0.98647395 0.99755192 0.87036009 0.73064892]
# Aggregation took 0.0157
#
# Average test loss: 0.1088, Test accuracy: 9662/10000 (96.62%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 99.2
# Two        - 96.7
# Three      - 96.4
# Four       - 97.1
# Five       - 98.0
# Six        - 97.2
# Seven      - 95.1
# Eight      - 91.2
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 3.143248498439789
# Peer 0  is  honest reputation: 1.0814158618450165
# Peer 8  is  honest reputation: 1.4849146604537964
# Peer 18  is  honest reputation: 2.7330653071403503
# Peer 4  is  honest reputation: 2.9817169904708862
# Peer 15  is  honest reputation: 1.7312842011451721
# Peer 5  is  honest reputation: 2.876045882701874
# Peer 13  is  honest reputation: 2.148983746767044
# Peer 10  is  honest reputation: 1.7045459747314453
# Peer 9  is  honest reputation: 3.3527313470840454
# Average of peers' local losses: 0.324131
# Mixing took 0.0267
# -> Update reputation
# [0.94725323 0.99513387 0.98880331 0.9934233  0.83893847 0.84668231
#  0.53683747 0.76293513 0.97730644 0.98613686]
# Aggregation took 0.0154
#
# Average test loss: 0.1131, Test accuracy: 9662/10000 (96.62%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.9
# Two        - 97.4
# Three      - 95.8
# Four       - 96.9
# Five       - 97.3
# Six        - 97.8
# Seven      - 96.0
# Eight      - 94.7
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 3.344004809856415
# Peer 18  is  honest reputation: 2.7206721901893616
# Peer 4  is  honest reputation: 2.9693238735198975
# Peer 6  is  honest reputation: 0.5175739824771881
# Peer 8  is  honest reputation: 1.4901680946350098
# Peer 0  is  honest reputation: 1.0866692960262299
# Peer 10  is  honest reputation: 1.7045459747314453
# Peer 7  is  honest reputation: 3.839153528213501
# Peer 15  is  honest reputation: 1.7312842011451721
# Peer 9  is  honest reputation: 3.495051145553589
# Average of peers' local losses: 0.324798
# Mixing took 0.0195
# -> Update reputation
# [0.98127681 0.99458165 0.89351099 0.99670116 0.53796222 0.83940626
#  0.98600561 0.99752861]
# Aggregation took 0.0125
#
# Average test loss: 0.1135, Test accuracy: 9663/10000 (96.63%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 99.3
# Two        - 97.4
# Three      - 97.1
# Four       - 96.4
# Five       - 97.5
# Six        - 97.7
# Seven      - 94.0
# Eight      - 94.4
# Nine       - 94.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.2913035452365875
# Peer 7  is  honest reputation: 3.8344091176986694
# Peer 3  is  honest reputation: 3.4411668181419373
# Peer 18  is  honest reputation: 2.817834198474884
# Peer 16  is  honest reputation: 1.8215301036834717
# Peer 6  is  honest reputation: 0.5175739824771881
# Peer 8  is  honest reputation: 1.4901680946350098
# Peer 4  is  honest reputation: 2.964579463005066
# Peer 5  is  honest reputation: 3.0768021941184998
# Peer 14  is  honest reputation: 1.417085349559784
# Average of peers' local losses: 0.319598
# Mixing took 0.0496
# -> Update reputation
# [0.89184934 0.80033028 0.76491616 0.95468528 0.03059711 0.98127681
#  0.99686314 0.98226494 0.9888764  0.99461713]
# Aggregation took 0.0183
#
# Average test loss: 0.1015, Test accuracy: 9699/10000 (96.99%)
#
# Class      - Accuracy
# Zero       - 98.5
# ...
# Peer 18  is  honest reputation: 3.9230786561965942
# Peer 14  is  honest reputation: 2.5455410480499268
# Peer 9  is  honest reputation: 4.327883690595627
# Average of peers' local losses: 0.233861
# Mixing took 0.026
# -> Update reputation
# [0.90560849 0.93166103 0.9852691  0.99481719 0.95022759 0.99420245
#  0.70524225 0.99344535 0.99707645 0.94345701]
# Aggregation took 0.0156
#
# Average test loss: 0.0776, Test accuracy: 9764/10000 (97.64%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 98.4
# Three      - 97.4
# Four       - 97.6
# Five       - 99.2
# Six        - 98.6
# Seven      - 96.9
# Eight      - 96.2
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 89/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 4.041043698787689
# Peer 12  is  honest reputation: 3.516344726085663
# Peer 13  is  honest reputation: 3.923286348581314
# Peer 4  is  honest reputation: 2.833174705505371
# Peer 5  is  honest reputation: 3.803916096687317
# Peer 8  is  honest reputation: 2.7353911995887756
# Peer 18  is  honest reputation: 3.9848458766937256
# Peer 6  is  honest reputation: 1.2877022325992584
# Peer 14  is  honest reputation: 2.5671162605285645
# Peer 16  is  honest reputation: 1.9422178268432617
# Average of peers' local losses: 0.230471
# Mixing took 0.0266
# -> Update reputation
# [0.9060446  0.99172539 0.99428306 0.22617933 0.98183217 0.99360079
#  0.69449822 0.92882558 0.94482961 0.99360846]
# Aggregation took 0.0156
#
# Average test loss: 0.0758, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.5
# Two        - 98.3
# Three      - 97.3
# Four       - 97.7
# Five       - 98.6
# Six        - 97.9
# Seven      - 96.9
# Eight      - 95.2
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 90/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 1.9422178268432617
# Peer 7  is  honest reputation: 3.956385910511017
# Peer 14  is  honest reputation: 2.5906072854995728
# Peer 3  is  honest reputation: 5.107183337211609
# Peer 5  is  honest reputation: 3.827407121658325
# Peer 0  is  honest reputation: 2.5640370547771454
# Peer 8  is  honest reputation: 2.7353911995887756
# Peer 4  is  honest reputation: 2.866876244544983
# Peer 12  is  honest reputation: 3.4316869378089905
# Peer 9  is  honest reputation: 4.327883690595627
# Average of peers' local losses: 0.234343
# Mixing took 0.026
# -> Update reputation
# [0.99172539 0.99935759 0.97968336 0.92065836 0.95957209 0.93078224
#  0.99467942 0.99746554 0.90988488 0.7187411 ]
# Aggregation took 0.016
#
# Average test loss: 0.0754, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.6
# Three      - 97.6
# Four       - 98.2
# Five       - 98.2
# Six        - 96.9
# Seven      - 96.5
# Eight      - 95.6
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 91/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 2.678954780101776
# Peer 7  is  honest reputation: 4.048952877521515
# Peer 10  is  honest reputation: 2.898683726787567
# Peer 6  is  honest reputation: 1.3157837688922882
# Peer 5  is  honest reputation: 3.827407121658325
# Peer 15  is  honest reputation: 3.2513939440250397
# Peer 13  is  honest reputation: 3.956987887620926
# Peer 3  is  honest reputation: 5.107183337211609
# Peer 16  is  honest reputation: 1.990660548210144
# Peer 12  is  honest reputation: 3.375250518321991
# Average of peers' local losses: 0.229976
# Mixing took 0.0267
# -> Update reputation
# [0.95683314 0.9955888  0.19626398 0.99119293 0.99947184 0.98326724
#  0.97909299 0.99486113 0.79809598 0.94487125]
# Aggregation took 0.016
#
# Average test loss: 0.0762, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.7
# Three      - 97.8
# Four       - 98.5
# Five       - 98.0
# Six        - 97.6
# Seven      - 96.3
# Eight      - 95.8
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 92/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 3.972427576780319
# Peer 14  is  honest reputation: 2.7498361468315125
# Peer 5  is  honest reputation: 3.7021461725234985
# Peer 4  is  honest reputation: 3.0261051058769226
# Peer 0  is  honest reputation: 2.6124797761440277
# Peer 9  is  honest reputation: 4.420450657606125
# Peer 8  is  honest reputation: 2.7733187675476074
# Peer 15  is  honest reputation: 3.266833633184433
# Peer 3  is  honest reputation: 5.111178040504456
# Peer 12  is  honest reputation: 3.3792452216148376
# Average of peers' local losses: 0.229003
# Mixing took 0.0255
# -> Update reputation
# [0.94030814 0.98185259 0.92625795 0.9670731  0.99486113 0.99789922
#  0.99311    0.98362223 0.99963384 0.95964119]
# Aggregation took 0.0161
#
# Average test loss: 0.0748, Test accuracy: 9757/10000 (97.57%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 98.2
# Three      - 97.2
# Four       - 98.4
# Five       - 99.4
# Six        - 98.6
# Seven      - 96.7
# Eight      - 96.2
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 93/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 3.390056401491165
# Peer 5  is  honest reputation: 3.8253689408302307
# Peer 9  is  honest reputation: 4.420450657606125
# Peer 7  is  honest reputation: 4.048952877521515
# Peer 6  is  honest reputation: 1.1905228197574615
# Peer 3  is  honest reputation: 5.294374346733093
# Peer 8  is  honest reputation: 2.7323821783065796
# Peer 4  is  honest reputation: 3.0366849303245544
# Peer 0  is  honest reputation: 2.6230596005916595
# Peer 13  is  honest reputation: 3.972427576780319
# Average of peers' local losses: 0.227164
# Mixing took 0.0236
# -> Update reputation
# [0.9689316  0.99350375 0.93981532 0.99829709 0.95419582 0.99972101
#  0.99473622 0.98047942]
# Aggregation took 0.0127
#
# Average test loss: 0.0699, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 98.5
# Three      - 97.8
# Four       - 99.0
# Five       - 98.6
# Six        - 97.4
# Seven      - 96.6
# Eight      - 97.0
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 94/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 4.525535076856613
# Peer 16  is  honest reputation: 2.0850245356559753
# Peer 15  is  honest reputation: 3.3014913499355316
# Peer 3  is  honest reputation: 5.430350422859192
# Peer 7  is  honest reputation: 3.9603878259658813
# Peer 18  is  honest reputation: 4.012927412986755
# Peer 4  is  honest reputation: 3.0662065744400024
# Peer 6  is  honest reputation: 1.1905228197574615
# Peer 0  is  honest reputation: 2.728144019842148
# Peer 13  is  honest reputation: 3.972427576780319
# Average of peers' local losses: 0.230003
# Mixing took 0.0271
# -> Update reputation
# [0.98069107 0.99831572 0.99556996 0.22862083 0.99499467 0.99973474
#  0.9123223  0.71536344 0.96205895 0.99370603]
# Aggregation took 0.0155
#
# Average test loss: 0.0705, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 97.7
# Three      - 97.8
# Four       - 98.6
# Five       - 98.8
# Six        - 97.6
# Seven      - 97.7
# Eight      - 95.2
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 5.5572574734687805
# Peer 8  is  honest reputation: 2.8683582544326782
# Peer 13  is  honest reputation: 3.972427576780319
# Peer 18  is  honest reputation: 4.148486912250519
# Peer 15  is  honest reputation: 3.4086653888225555
# Peer 0  is  honest reputation: 2.634551614522934
# Peer 16  is  honest reputation: 1.9914321303367615
# Peer 5  is  honest reputation: 3.8548905849456787
# Peer 4  is  honest reputation: 3.0662065744400024
# Peer 7  is  honest reputation: 4.08729487657547
# Average of peers' local losses: 0.230834
# Mixing took 0.0265
# -> Update reputation
# [0.99248458 0.97697305 0.75788986 0.92667968 0.99556996 0.96205895
#  0.9534685  0.99339848 0.99601207 0.99978876]
# Aggregation took 0.016
#
# Average test loss: 0.0714, Test accuracy: 9791/10000 (97.91%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.0
# Two        - 98.2
# Three      - 97.6
# Four       - 97.7
# Five       - 97.8
# Six        - 98.2
# Seven      - 97.7
# Eight      - 96.3
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 2.961964726448059
# Peer 5  is  honest reputation: 3.9484970569610596
# Peer 15  is  honest reputation: 3.319677025079727
# Peer 12  is  honest reputation: 3.33830863237381
# Peer 14  is  honest reputation: 2.93303245306015
# Peer 16  is  honest reputation: 2.0845869183540344
# Peer 4  is  honest reputation: 3.0662065744400024
# Peer 9  is  honest reputation: 4.632709115743637
# Peer 3  is  honest reputation: 5.67112797498703
# Peer 10  is  honest reputation: 2.898683726787567
# Average of peers' local losses: 0.219023
# Mixing took 0.0219
# -> Update reputation
# [0.98326941 0.97237635 0.761493   0.99350967 0.99822745 0.99977768
#  0.98147285 0.95880634]
# Aggregation took 0.012
#
# Average test loss: 0.0759, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 97.8
# Three      - 97.3
# Four       - 98.3
# Five       - 98.0
# Six        - 97.8
# Seven      - 97.0
# Eight      - 95.8
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 1.326082319021225
# Peer 3  is  honest reputation: 5.645565390586853
# Peer 10  is  honest reputation: 2.898683726787567
# Peer 12  is  honest reputation: 3.4295278191566467
# Peer 4  is  honest reputation: 3.227509617805481
# Peer 14  is  honest reputation: 3.024251639842987
# Peer 9  is  honest reputation: 4.60714653134346
# Peer 7  is  honest reputation: 4.2011653780937195
# Peer 5  is  honest reputation: 3.9570178985595703
# Peer 16  is  honest reputation: 2.093107759952545
# Average of peers' local losses: 0.222244
# Mixing took 0.0221
# -> Update reputation
# [0.99833475 0.97402823 0.93766311 0.995256   0.99979021 0.98250764
#  0.99504057 0.96839306]
# Aggregation took 0.0131
#
# Average test loss: 0.0763, Test accuracy: 9758/10000 (97.58%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 99.1
# Three      - 96.7
# Four       - 98.4
# Five       - 98.6
# Six        - 98.7
# Seven      - 96.2
# Eight      - 96.7
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 1.326082319021225
# Peer 14  is  honest reputation: 3.1591466665267944
# Peer 13  is  honest reputation: 3.883439213037491
# Peer 8  is  honest reputation: 2.961964726448059
# Peer 9  is  honest reputation: 4.638396114110947
# Peer 15  is  honest reputation: 3.4809800684452057
# Peer 18  is  honest reputation: 4.148486912250519
# Peer 3  is  honest reputation: 5.674562990665436
# Peer 7  is  honest reputation: 4.114172518253326
# Peer 4  is  honest reputation: 3.2587592005729675
# Average of peers' local losses: 0.224239
# Mixing took 0.0255
# -> Update reputation
# [0.99865084 0.99615535 0.98836879 0.99478262 0.99538276 0.20887314
#  0.99986185 0.96911407 0.97703238 0.97203981]
# Aggregation took 0.0155
#
# Average test loss: 0.0764, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.4
# Three      - 97.9
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 96.4
# Eight      - 95.4
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 2.093107759952545
# Peer 3  is  honest reputation: 5.821243166923523
# Peer 15  is  honest reputation: 3.601814478635788
# Peer 12  is  honest reputation: 3.4585254192352295
# Peer 0  is  honest reputation: 2.727706402540207
# Peer 8  is  honest reputation: 3.1086449027061462
# Peer 7  is  honest reputation: 4.157273948192596
# Peer 10  is  honest reputation: 2.811690866947174
# Peer 6  is  honest reputation: 1.2431184947490692
# Peer 9  is  honest reputation: 4.681497544050217
# Average of peers' local losses: 0.221542
# Mixing took 0.0271
# -> Update reputation
# [0.99663158 0.99987899 0.99869493 0.22471661 0.95214376 0.97593986
#  0.94537113 0.78860812 0.92840407 0.98715655]
# Aggregation took 0.016
#
# Average test loss: 0.0705, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 98.1
# Three      - 97.3
# Four       - 98.6
# Five       - 98.6
# Six        - 98.8
# Seven      - 96.5
# Eight      - 96.2
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 4.747998625040054
# Peer 7  is  honest reputation: 4.273387789726257
# Peer 10  is  honest reputation: 2.8673242926597595
# Peer 3  is  honest reputation: 5.937357008457184
# Peer 15  is  honest reputation: 3.601814478635788
# Peer 0  is  honest reputation: 2.727706402540207
# Peer 14  is  honest reputation: 3.1591466665267944
# Peer 18  is  honest reputation: 4.065523087978363
# Peer 4  is  honest reputation: 3.2587592005729675
# Peer 5  is  honest reputation: 4.091912925243378
# Average of peers' local losses: 0.224876
# Mixing took 0.0256
# -> Update reputation
# [0.98769378 0.99536443 0.95457731 0.94038194 0.97741286 0.99883854
#  0.99986233 0.99616867]
# Aggregation took 0.0125
#
# Average test loss: 0.0758, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.9
# Three      - 97.3
# Four       - 98.4
# Five       - 98.4
# Six        - 98.3
# Seven      - 97.6
# Eight      - 95.3
# Nine       - 95.7
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0647, Test accuracy: 9784/10000 (97.84%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.2
# Three      - 97.4
# Four       - 97.9
# Five       - 98.6
# Six        - 98.7
# Seven      - 97.1
# Eight      - 96.3
# Nine       - 95.0
# Global accuracies:  [18.35, 60.52, 63.39, 73.55, 82.15, 85.95, 87.05, 89.35, 89.95, 90.96, 91.09, 91.75, 92.23, 92.78, 92.38, 93.58, 93.59, 94.12, 92.95, 94.26, 94.38, 94.72, 94.7, 94.93, 95.09, 95.21, 95.31, 95.71, 95.58, 95.93, 96.11, 95.45, 95.91, 96.58, 96.03, 96.22, 95.96, 96.24, 96.32, 96.45, 96.56, 96.61, 96.62, 96.62, 96.63, 96.99, 96.69, 96.88, 96.27, 96.56, 96.81, 96.81, 96.96, 97.15, 97.01, 97.2, 97.18, 97.34, 97.21, 97.01, 97.28, 97.08, 97.15, 97.03, 97.4, 97.2, 97.31, 97.4, 97.35, 97.36, 97.42, 97.46, 97.42, 97.25, 97.09, 97.51, 97.2, 97.34, 97.33, 97.71, 97.67, 97.46, 97.59, 97.48, 97.48, 97.42, 97.77, 97.64, 97.65, 97.75, 97.7, 97.57, 97.75, 97.74, 97.91, 97.74, 97.58, 97.67, 97.56, 97.6, 97.84]
# Class 7 accuracies:  [3.35, 76.53, 55.21, 69.41, 79.78, 80.6, 84.32, 85.97, 86.5, 87.28, 87.38, 89.97, 88.57, 86.92, 87.97, 90.09, 88.73, 90.37, 78.43, 92.41, 92.22, 91.95, 91.38, 94.05, 93.92, 93.67, 93.93, 93.34, 93.43, 93.84, 94.19, 93.69, 93.83, 93.82, 93.83, 94.09, 94.33, 93.75, 94.98, 94.54, 95.8, 94.61, 95.13, 96.01, 94.0, 95.62, 95.33, 94.05, 94.28, 96.39, 95.75, 95.63, 96.05, 96.02, 94.28, 96.54, 97.0, 95.7, 95.1, 95.77, 94.51, 96.74, 95.08, 95.8, 96.3, 95.67, 96.12, 95.94, 95.89, 96.25, 95.18, 95.67, 96.69, 96.22, 95.31, 95.44, 96.18, 96.38, 96.71, 95.19, 95.99, 95.6, 96.58, 96.53, 95.99, 97.19, 95.95, 96.95, 96.92, 96.5, 96.33, 96.7, 96.58, 97.66, 97.67, 97.02, 96.21, 96.37, 96.55, 97.64, 97.08]
# Test loss: [2.2587, 2.1459, 1.8145, 1.2717, 0.8372, 0.6115, 0.5168, 0.4278, 0.3992, 0.3506, 0.3225, 0.2938, 0.2742, 0.2595, 0.2532, 0.2337, 0.2243, 0.2078, 0.2416, 0.2005, 0.1932, 0.1794, 0.1761, 0.1723, 0.1627, 0.1566, 0.1597, 0.1507, 0.1434, 0.1462, 0.1395, 0.1539, 0.1374, 0.1288, 0.1343, 0.1244, 0.128, 0.1261, 0.1216, 0.1209, 0.1184, 0.1147, 0.1088, 0.1131, 0.1135, 0.1015, 0.1108, 0.1069, 0.1166, 0.1086, 0.1039, 0.0974, 0.1005, 0.0976, 0.0966, 0.0982, 0.0904, 0.0916, 0.0943, 0.1062, 0.0858, 0.0973, 0.094, 0.0977, 0.0912, 0.0919, 0.0858, 0.0833, 0.0859, 0.0875, 0.09, 0.0871, 0.0837, 0.0888, 0.0926, 0.0808, 0.0863, 0.0884, 0.0822, 0.0763, 0.0756, 0.0799, 0.0768, 0.0792, 0.0792, 0.0803, 0.0681, 0.0776, 0.0758, 0.0754, 0.0762, 0.0748, 0.0699, 0.0705, 0.0714, 0.0759, 0.0763, 0.0764, 0.0705, 0.0758, 0.0647]
# Label-flipping attack succes rate: 0.3
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.016
# --> End of Experiment.
